# %%
import os

os.environ['CUDA_VISIBLE_DEVICES'] = '1'

# %%
import sys

SOURCE_DIR = os.path.dirname(os.path.dirname(os.path.abspath(__name__)))
sys.path.insert(0, SOURCE_DIR)

# %%
import malaya_speech
import numpy as np

# %%
y, sr = malaya_speech.load('../speech/7021-79759-0004.flac')
y = y[:sr * 10]
len(y), len(y) / sr
# Out:
# (160000, 10.0)

# %%
import IPython.display as ipd

ipd.Audio(y, rate = sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(malaya_speech.augmentation.waveform.lowpass_filter(y), rate = sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(malaya_speech.augmentation.waveform.highpass_filter(y, cutoff = 2000), rate = sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(malaya_speech.augmentation.waveform.bandpass_filter(y, cutoff_low = 200, cutoff_high = 400), rate = sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
