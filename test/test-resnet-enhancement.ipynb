# %%
import os

os.environ['CUDA_VISIBLE_DEVICES'] = '1'

# %%
import sys

SOURCE_DIR = os.path.dirname(os.path.dirname(os.path.abspath(__name__)))
sys.path.insert(0, SOURCE_DIR)

# %%
import malaya_speech
import malaya_speech.config
import malaya_speech.train.model.resnet_unet_enhancement as unet
from malaya_speech.train.model import enhancement
import tensorflow as tf
# Out:
# WARNING:tensorflow:From /Users/huseinzolkepli/Documents/malaya-speech/malaya_speech/train/optimizer/__init__.py:38: The name tf.train.AdagradOptimizer is deprecated. Please use tf.compat.v1.train.AdagradOptimizer instead.
#
# WARNING:tensorflow:From /Users/huseinzolkepli/Documents/malaya-speech/malaya_speech/train/optimizer/__init__.py:39: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /Users/huseinzolkepli/Documents/malaya-speech/malaya_speech/train/optimizer/__init__.py:40: The name tf.train.FtrlOptimizer is deprecated. Please use tf.compat.v1.train.FtrlOptimizer instead.
#
# WARNING:tensorflow:From /Users/huseinzolkepli/Documents/malaya-speech/malaya_speech/train/optimizer/__init__.py:42: The name tf.train.RMSPropOptimizer is deprecated. Please use tf.compat.v1.train.RMSPropOptimizer instead.
#
# WARNING:tensorflow:From /Users/huseinzolkepli/Documents/malaya-speech/malaya_speech/train/optimizer/__init__.py:43: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
tf.reset_default_graph()
x = tf.placeholder(tf.float32, (None, 1))
partitioned_x = malaya_speech.tf_featurization.pad_and_partition(x, 4096)
model = unet.Model(partitioned_x, channels_interval = 24)
# Out:
# WARNING:tensorflow:From /Users/huseinzolkepli/Documents/tf-1.15/env/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Tensor("strided_slice_3:0", shape=(?, 2048, 24), dtype=float32)
# Tensor("strided_slice_4:0", shape=(?, 1024, 48), dtype=float32)
# Tensor("strided_slice_5:0", shape=(?, 512, 72), dtype=float32)
# Tensor("strided_slice_6:0", shape=(?, 256, 96), dtype=float32)
# Tensor("strided_slice_7:0", shape=(?, 128, 120), dtype=float32)
# Tensor("strided_slice_8:0", shape=(?, 64, 144), dtype=float32)
# Tensor("strided_slice_9:0", shape=(?, 32, 168), dtype=float32)
# Tensor("strided_slice_10:0", shape=(?, 16, 192), dtype=float32)
# Tensor("strided_slice_11:0", shape=(?, 8, 216), dtype=float32)
# Tensor("strided_slice_12:0", shape=(?, 4, 240), dtype=float32)
# Tensor("strided_slice_13:0", shape=(?, 2, 264), dtype=float32)
# Tensor("strided_slice_14:0", shape=(?, 1, 288), dtype=float32)
# Tensor("sequential/leaky_re_lu_1/LeakyRelu:0", shape=(?, 1, 288), dtype=float32)
# Tensor("sequential_1/leaky_re_lu_2/LeakyRelu:0", shape=(?, 2, 288), dtype=float32)
# Tensor("sequential_2/leaky_re_lu_3/LeakyRelu:0", shape=(?, 4, 264), dtype=float32)
# Tensor("sequential_3/leaky_re_lu_4/LeakyRelu:0", shape=(?, 8, 240), dtype=float32)
# Tensor("sequential_4/leaky_re_lu_5/LeakyRelu:0", shape=(?, 16, 216), dtype=float32)
# Tensor("sequential_5/leaky_re_lu_6/LeakyRelu:0", shape=(?, 32, 192), dtype=float32)
# Tensor("sequential_6/leaky_re_lu_7/LeakyRelu:0", shape=(?, 64, 168), dtype=float32)
# Tensor("sequential_7/leaky_re_lu_8/LeakyRelu:0", shape=(?, 128, 144), dtype=float32)
# Tensor("sequential_8/leaky_re_lu_9/LeakyRelu:0", shape=(?, 256, 120), dtype=float32)
# Tensor("sequential_9/leaky_re_lu_10/LeakyRelu:0", shape=(?, 512, 96), dtype=float32)
# Tensor("sequential_10/leaky_re_lu_11/LeakyRelu:0", shape=(?, 1024, 72), dtype=float32)
# Tensor("sequential_11/leaky_re_lu_12/LeakyRelu:0", shape=(?, 2048, 48), dtype=float32)
# Tensor("sequential_12/leaky_re_lu_13/LeakyRelu:0", shape=(?, 4096, 24), dtype=float32)
# Tensor("sequential_12/leaky_re_lu_13/LeakyRelu:0", shape=(?, 4096, 24), dtype=float32) Tensor("Reshape:0", shape=(?, 4096, 1), dtype=float32)

# %%
model.logits
# Out:
# <tf.Tensor 'sequential_13/activation/Tanh:0' shape=(?, 4096, 1) dtype=float32>

# %%
logits = tf.reshape(model.logits, (-1, 1))
logits = logits[:tf.shape(x)[0]]
logits
# Out:
# <tf.Tensor 'strided_slice_40:0' shape=(?, 1) dtype=float32>

# %%
snr = enhancement.loss.snr(model.logits, partitioned_x)
sdr = enhancement.loss.sdr(model.logits, partitioned_x)
# Out:
# WARNING:tensorflow:From /Users/huseinzolkepli/Documents/malaya-speech/malaya_speech/train/model/enhancement/loss.py:7: The name tf.log is deprecated. Please use tf.math.log instead.

# %%
sess = tf.InteractiveSession()
sess.run(tf.global_variables_initializer())

# %%
import numpy as np

# %%
y, sr = malaya_speech.load('../speech/record/savewav_2020-09-06_21-48-43_174842.wav', sr = 22050)

# %%
y_, snr_, sdr_ = sess.run([logits, snr, sdr], feed_dict = {x: np.expand_dims(y, -1)})
y_.shape
# Out:
# (258867, 1)

# %%
import IPython.display as ipd

ipd.Audio(y_.reshape((-1)), rate = 22050)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
snr_, sdr_
# Out:
# ((0.42554104, -16.994202), -2.4315636e-07)

# %%
y
# Out:
# array([-0.00570545, -0.01051882, -0.01370371, ...,  0.0140948 ,
#         0.01236383,  0.01233889])

# %%
y_[:,0]
# Out:
# array([0.13602391, 0.07940106, 0.0288547 , ..., 0.07307905, 0.29358134,
#        0.05365924], dtype=float32)

# %%
saver = tf.train.Saver()
saver.save(sess, 'test/model.ckpt')
# Out:
# 'test/model.ckpt'

# %%
# !ls -lh test
# Out:
# total 72320
# -rw-r--r--  1 huseinzolkepli  staff    77B Feb 25 16:45 checkpoint
# -rw-r--r--  1 huseinzolkepli  staff    35M Feb 25 16:45 model.ckpt.data-00000-of-00001
# -rw-r--r--  1 huseinzolkepli  staff   8.5K Feb 25 16:45 model.ckpt.index
# -rw-r--r--  1 huseinzolkepli  staff   763K Feb 25 16:45 model.ckpt.meta

# %%
# !rm -rf test
