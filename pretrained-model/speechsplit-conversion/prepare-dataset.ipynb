# %%
import os

os.environ['CUDA_VISIBLE_DEVICES'] = ''

# %%
import numpy as np
import random
import tensorflow as tf
from math import ceil
from glob import glob
from pysptk import sptk
from collections import defaultdict
from scipy.signal import get_window
from scipy import signal
import pandas as pd
import malaya_speech
import pyworld as pw

# %%
vctk = glob('vtck/**/*.flac', recursive = True)

vctk_speakers = defaultdict(list)
for f in vctk:
    s = f.split('/')[-1].split('_')[0]
    vctk_speakers[s].append(f)

files = glob('/home/husein/speech-bahasa/ST-CMDS-20170001_1-OS/*.wav')
speakers_mandarin = defaultdict(list)
for f in files:
    speakers_mandarin[f[:-9]].append(f)

df_nepali = pd.read_csv(
    '/home/husein/speech-bahasa/nepali_0/asr_nepali/utt_spk_text.tsv',
    sep = '\t',
    header = None,
)
asr_nepali = glob('/home/husein/speech-bahasa/*/asr_nepali/data/*/*.flac')
asr_nepali_replaced = {
    f.split('/')[-1].replace('.flac', ''): f for f in asr_nepali
}
df_nepali = df_nepali[df_nepali[0].isin(asr_nepali_replaced.keys())]

speakers_nepali = defaultdict(list)
for i in range(len(df_nepali)):
    speakers_nepali[df_nepali.iloc[i, 1]].append(
        asr_nepali_replaced[df_nepali.iloc[i, 0]]
    )

speakers = []
for s in vctk_speakers.keys():
    speakers.extend(
        random.sample(vctk_speakers[s], min(500, len(vctk_speakers[s])))
    )

for s in speakers_mandarin.keys():
    speakers.extend(
        random.sample(speakers_mandarin[s], min(300, len(speakers_mandarin[s])))
    )

for s in speakers_nepali.keys():
    speakers.extend(
        random.sample(speakers_nepali[s], min(300, len(speakers_nepali[s])))
    )

salina = glob('/home/husein/speech-bahasa/salina/output-wav-salina/*.wav')
salina = random.sample(salina, 5000)
male = glob('/home/husein/speech-bahasa/turki/output-wav-turki/*.wav')
male.extend(
    glob(
        '/home/husein/speech-bahasa/dari-pasentran-ke-istana/output-wav-dari-pasentran-ke-istana/*.wav'
    )
)
male = random.sample(male, 5000)
haqkiem = glob('/home/husein/speech-bahasa/haqkiem/*.wav')
khalil = glob('/home/husein/speech-bahasa/tolong-sebut/*.wav')
mas = glob('/home/husein/speech-bahasa/sebut-perkataan-woman/*.wav')
husein = glob('/home/husein/speech-bahasa/audio-wattpad/*.wav')
husein.extend(glob('/home/husein/speech-bahasa/audio-iium/*.wav'))
husein.extend(glob('/home/husein/speech-bahasa/audio/*.wav'))
husein.extend(glob('/home/husein/speech-bahasa/sebut-perkataan-man/*.wav'))

files = salina + male + haqkiem + khalil + mas + husein + speakers

# %%
def butter_highpass(cutoff, fs, order=5):
    nyq = 0.5 * fs
    normal_cutoff = cutoff / nyq
    b, a = signal.butter(order, normal_cutoff, btype='high', analog=False)
    return b, a

sr = 22050
freqs = {'female': [100, 600], 'male': [50, 250]}
b, a = butter_highpass(30, sr, order = 5)

# %%
from math import ceil

def is_outlier(x, p25, p75):
    """Check if value is an outlier."""
    lower = p25 - 1.5 * (p75 - p25)
    upper = p75 + 1.5 * (p75 - p25)
    return x <= lower or x >= upper


def remove_outlier(x, p_bottom: int = 25, p_top: int = 75):
    """Remove outlier from x."""
    p_bottom = np.percentile(x, p_bottom)
    p_top = np.percentile(x, p_top)

    indices_of_outliers = []
    for ind, value in enumerate(x):
        if is_outlier(value, p_bottom, p_top):
            indices_of_outliers.append(ind)

    x[indices_of_outliers] = 0.0
    x[indices_of_outliers] = np.max(x)
    return x

def speaker_normalization(f0, index_nonzero, mean_f0, std_f0):
    f0 = f0.astype(float).copy()
    f0[index_nonzero] = (f0[index_nonzero] - mean_f0) / std_f0 / 4.0
    f0[index_nonzero] = np.clip(f0[index_nonzero], -1, 1)
    f0[index_nonzero] = (f0[index_nonzero] + 1) / 2.0
    return f0

def preprocess_wav(x):
    if x.shape[0] % 256 == 0:
        x = np.concatenate((x, np.array([1e-06])), axis=0)
    y = signal.filtfilt(b, a, x)
    wav = y * 0.96 + (np.random.uniform(size = y.shape[0]) - 0.5)*1e-06
    return wav

def get_f0_sptk(wav, lo, hi):
    f0_rapt = sptk.rapt(wav.astype(np.float32)*32768, sr, 256, min=lo, max=hi, otype=2)
    index_nonzero = (f0_rapt != -1e10)
    mean_f0, std_f0 = np.mean(f0_rapt[index_nonzero]), np.std(f0_rapt[index_nonzero])
    return speaker_normalization(f0_rapt, index_nonzero, mean_f0, std_f0)

def get_f0_pyworld(wav):
    x = wav
    _f0, t = pw.dio(wav, sr,
                    f0_ceil=7600,
                   frame_period=1000 * 256 / sr,
                   )
    f0_rapt = pw.stonemask(x.astype(np.double), _f0, t, sr)
    index_nonzero = (f0_rapt != 0.0)
    mean_f0, std_f0 = np.mean(f0_rapt[index_nonzero]), np.std(f0_rapt[index_nonzero])
    return speaker_normalization(f0_rapt, index_nonzero, mean_f0, std_f0)

# %%
len(files)
# Out:
# 194817

# %%
# !rm -rf speechsplit-dataset
# !mkdir speechsplit-dataset

# %%
from tqdm import tqdm
import pickle

def loop(files):
    files, index = files
    vggvox_v2 = malaya_speech.gender.deep_model(model = 'vggvox-v2')
    for i in tqdm(range(len(files))):
        f = files[i]
        try:
            x, fs = malaya_speech.load(f, sr = sr)
            wav = preprocess_wav(x)
            x_16k = malaya_speech.resample(x, sr, 16000)
            lo, hi = freqs.get(vggvox_v2(x_16k), [50, 250])
            f0 = np.expand_dims(get_f0_sptk(wav, lo, hi), -1)
            f0_pyworld = np.expand_dims(get_f0_pyworld(wav), -1)
            mel = malaya_speech.featurization.universal_mel(wav)
            with open(f'speechsplit-dataset/{index}-{i}.pkl', 'wb') as fopen:
                pickle.dump([wav, f0, f0_pyworld, mel], fopen)
        except Exception as e:
            print(e)
            pass

# %%
import mp

mp.multiprocessing(files, loop, cores = 12, returned = False)
# Out:
#   0%|          | 1/16234 [00:01<8:43:26,  1.93s/it]/home/husein/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
# /home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:217: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:186: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
#   0%|          | 31/16234 [00:14<1:59:30,  2.26it/s]/home/husein/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
# /home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:217: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:186: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
#   0%|          | 22/16234 [00:14<2:36:58,  1.72it/s]/home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
#   1%|          | 199/16234 [01:54<2:22:51,  1.87it/s]/home/husein/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
#   1%|▏         | 237/16234 [01:54<1:52:36,  2.37it/s]/home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
# /home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:217: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
#   1%|          | 190/16234 [01:54<2:28:32,  1.80it/s]/home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:186: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
#   1%|▏         | 243/16234 [02:02<2:16:39,  1.95it/s]/home/husein/.local/lib/python3.6/site-packages/ipykernel_launcher.py:26: RuntimeWarning: invalid value encountered in true_divide
#   2%|▏         | 330/16234 [03:10<2:20:05,  1.89it/s]/home/husein/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
# /home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:217: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:186: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
#   2%|▏         | 333/16234 [03:10<2:35:12,  1.71it/s]/home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
#   4%|▍         | 614/16234 [05:09<2:57:14,  1.47it/s]/home/husein/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
#   3%|▎         | 513/16234 [05:08<2:17:45,  1.90it/s]/home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
#   3%|▎         | 555/16234 [05:09<1:56:39,  2.24it/s]/home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:217: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
#   2%|▏         | 309/16234 [05:09<3:32:17,  1.25it/s]/home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:186: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
# /home/husein/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
#   3%|▎         | 525/16234 [05:09<2:37:29,  1.66it/s]/home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
# /home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:217: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
#   3%|▎         | 518/16234 [05:09<2:43:27,  1.60it/s]/home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:186: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
#   4%|▍         | 627/16234 [05:18<1:32:35,  2.81it/s]/home/husein/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
# /home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:217: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:186: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
#   8%|▊         | 1366/16234 [10:25<1:27:48,  2.82it/s]/home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#   7%|▋         | 1184/16234 [11:44<2:26:26,  1.71it/s]/home/husein/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
#   7%|▋         | 1212/16234 [11:44<2:31:05,  1.66it/s]/home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
# /home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:217: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:186: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
#   9%|▉         | 1527/16234 [13:59<2:09:16,  1.90it/s]/home/husein/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
# /home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:217: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:186: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
#  20%|█▉        | 3242/16234 [29:19<2:01:16,  1.79it/s]/home/husein/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
#  19%|█▉        | 3149/16234 [29:19<2:03:49,  1.76it/s]/home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
# /home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:217: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:186: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
#  23%|██▎       | 3744/16234 [29:19<1:34:48,  2.20it/s]/home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
#  22%|██▏       | 3610/16234 [33:47<1:49:54,  1.91it/s]/home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  45%|████▍     | 7261/16234 [1:04:02<1:17:02,  1.94it/s]/home/husein/.local/lib/python3.6/site-packages/ipykernel_launcher.py:26: RuntimeWarning: invalid value encountered in true_divide
#  58%|█████▊    | 9442/16234 [1:28:27<1:01:50,  1.83it/s] /home/husein/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
# /home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:217: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:186: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
#  65%|██████▌   | 10570/16234 [1:32:19<59:11,  1.59it/s]  /home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  64%|██████▍   | 10364/16234 [1:37:50<1:04:44,  1.51it/s]/home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  69%|██████▉   | 11187/16234 [1:45:12<46:24,  1.81it/s]] /home/husein/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
#  70%|███████   | 11417/16234 [1:45:12<46:04,  1.74it/s]/home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:217: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:186: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /home/husein/.local/lib/python3.6/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
# 100%|██████████| 16234/16234 [2:14:48<00:00,  2.01it/s]]
# 100%|██████████| 9/9 [00:05<00:00,  1.78it/s] 1.71it/s]]
# 100%|██████████| 16234/16234 [2:18:58<00:00,  1.95it/s]]
# 100%|██████████| 16234/16234 [2:20:54<00:00,  1.92it/s]]
# 100%|██████████| 16234/16234 [2:21:32<00:00,  1.91it/s]]
# 100%|██████████| 16234/16234 [2:23:49<00:00,  1.88it/s]]
# 100%|██████████| 16234/16234 [2:27:24<00:00,  1.84it/s]]
# 100%|██████████| 16234/16234 [2:27:31<00:00,  1.83it/s]]
# 100%|██████████| 16234/16234 [2:27:38<00:00,  1.83it/s]]
# 100%|██████████| 16234/16234 [2:28:47<00:00,  1.82it/s]]
# 100%|██████████| 16234/16234 [2:29:03<00:00,  1.82it/s]]
# 100%|██████████| 16234/16234 [2:29:35<00:00,  1.81it/s]]
# 100%|██████████| 16234/16234 [3:24:49<00:00,  1.32it/s]

# %%
# !du -hs speechsplit-dataset
# Out:
# 169G	speechsplit-dataset
