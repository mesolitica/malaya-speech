# %%
import os

os.environ['CUDA_VISIBLE_DEVICES'] = ''

# %%
import malaya_speech.train.model.quartznet as quartznet
import malaya_speech
import tensorflow as tf
import numpy as np
import json
# Out:
# WARNING:tensorflow:From /home/husein/malaya-speech/malaya_speech/train/optimizer.py:34: The name tf.train.AdagradOptimizer is deprecated. Please use tf.compat.v1.train.AdagradOptimizer instead.
#
# WARNING:tensorflow:From /home/husein/malaya-speech/malaya_speech/train/optimizer.py:35: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /home/husein/malaya-speech/malaya_speech/train/optimizer.py:36: The name tf.train.FtrlOptimizer is deprecated. Please use tf.compat.v1.train.FtrlOptimizer instead.
#
# WARNING:tensorflow:From /home/husein/malaya-speech/malaya_speech/train/optimizer.py:38: The name tf.train.RMSPropOptimizer is deprecated. Please use tf.compat.v1.train.RMSPropOptimizer instead.
#
# WARNING:tensorflow:From /home/husein/malaya-speech/malaya_speech/train/optimizer.py:39: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /home/husein/malaya-speech/malaya_speech/train/model/quartznet/layer.py:6: The name tf.layers.Conv1D is deprecated. Please use tf.compat.v1.layers.Conv1D instead.

# %%
with open('malaya-speech-sst-vocab.json') as fopen:
    unique_vocab = json.load(fopen)

# %%
featurizer = malaya_speech.tf_featurization.STTFeaturizer(
    normalize_per_feature = True
)

# %%
X = tf.placeholder(tf.float32, [None, None])
X_len = tf.placeholder(tf.int32, [None])

# %%
batch_size = tf.shape(X)[0]
features = tf.TensorArray(dtype = tf.float32, size = batch_size, dynamic_size = True, infer_shape = False)
features_len = tf.TensorArray(dtype = tf.int32, size = batch_size)

init_state = (0, features, features_len)

def condition(i, features, features_len):
    return i < batch_size

def body(i, features, features_len):
    f = featurizer(X[i, :X_len[i]])
    f_len = tf.shape(f)[0]
    return i + 1, features.write(i, f), features_len.write(i, f_len)

_, features, features_len = tf.while_loop(condition, body, init_state)
features_len = features_len.stack()
padded_features = tf.TensorArray(dtype = tf.float32, size = batch_size)
maxlen = tf.reduce_max(features_len)

init_state = (0, padded_features)

def condition(i, padded_features):
    return i < batch_size

def body(i, padded_features):
    f = features.read(i)
    f = tf.pad(f, [[0, maxlen - tf.shape(f)[0]], [0,0]])
    return i + 1, padded_features.write(i, f)

_, padded_features = tf.while_loop(condition, body, init_state)
padded_features = padded_features.stack()
padded_features.set_shape((None, None, 80))

# %%
model = quartznet.Model(padded_features, features_len, mode = 'eval')
logits = tf.layers.dense(model.logits['outputs'], len(unique_vocab) + 1)
seq_lens = model.logits['src_length']
logits = tf.transpose(logits, [1, 0, 2])
logits = tf.identity(logits, name = 'logits')
seq_lens = tf.identity(seq_lens, name = 'seq_lens')
# Out:
# WARNING:tensorflow:From /home/husein/malaya-speech/malaya_speech/train/model/quartznet/abstract.py:141: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /home/husein/malaya-speech/malaya_speech/train/model/quartznet/layer.py:327: separable_conv1d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.SeparableConv1D` instead.
# WARNING:tensorflow:From /home/husein/.local/lib/python3.6/site-packages/tensorflow_core/python/layers/convolutional.py:971: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /home/husein/malaya-speech/malaya_speech/train/model/quartznet/layer.py:358: batch_normalization (from tensorflow.python.layers.normalization) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.BatchNormalization instead.  In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.batch_normalization` documentation).
# WARNING:tensorflow:From /home/husein/malaya-speech/malaya_speech/train/model/quartznet/abstract.py:369: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /home/husein/malaya-speech/malaya_speech/train/model/quartznet/layer.py:340: conv1d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv1D` instead.
# WARNING:tensorflow:From <ipython-input-7-494cacee5bc9>:2: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.

# %%
# decoded = tf.nn.ctc_beam_search_decoder(logits, seq_lens, beam_width=100, top_paths=1, merge_repeated=True)
# preds = tf.sparse.to_dense(tf.to_int32(decoded[0][0]))
# preds = tf.identity(preds, 'logits')

# %%
sess = tf.InteractiveSession()
sess.run(tf.global_variables_initializer())

# %%
var_lists = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES)
saver = tf.train.Saver(var_list = var_lists)
saver.restore(sess, 'asr-quartznet-ctc-adam-part2/model.ckpt-270000')
# Out:
# INFO:tensorflow:Restoring parameters from asr-quartznet-ctc-adam-part2/model.ckpt-270000

# %%
y, _ = malaya_speech.load('husein-zolkepli.wav')
y1, _ = malaya_speech.load('khalil-nooh.wav')

# %%
padded, lens = malaya_speech.padding.sequence_1d([y, y1], return_len = True)

# %%
decoded = sess.run(logits, feed_dict = {X: padded, X_len: lens})

# %%
# results = []
# for i in range(len(decoded)):
#     results.append(malaya_speech.char.decode(decoded[i], lookup = unique_vocab).replace('<PAD>', ''))
# results

# %%
saver = tf.train.Saver()
saver.save(sess, 'asr-quartznet-ctc-output/model.ckpt')
# Out:
# 'asr-quartznet-ctc-output/model.ckpt'

# %%
strings = ','.join(
    [
        n.name
        for n in tf.get_default_graph().as_graph_def().node
        if ('Variable' in n.op
        or 'Placeholder' in n.name
        or 'logits' in n.name
        or 't_logits' in n.name
        or 'seq_lens' in n.name
        or 'alphas' in n.name
        or 'self/Softmax' in n.name)
        and 'adam' not in n.name
        and 'beta' not in n.name
        and 'global_step' not in n.name
        and 'Assign' not in n.name
    ]
)
strings.split(',')
# Out:
# ['Placeholder',
#  'Placeholder_1',
#  'w2l_encoder/conv11/depthwise_kernel',
#  'w2l_encoder/conv11/pointwise_kernel',
#  'w2l_encoder/conv11/bn/gamma',
#  'w2l_encoder/conv11/bn/moving_mean',
#  'w2l_encoder/conv11/bn/moving_variance',
#  'w2l_encoder/conv21/depthwise_kernel',
#  'w2l_encoder/conv21/pointwise_kernel',
#  'w2l_encoder/conv21/bn/gamma',
#  'w2l_encoder/conv21/bn/moving_mean',
#  'w2l_encoder/conv21/bn/moving_variance',
#  'w2l_encoder/conv22/depthwise_kernel',
#  'w2l_encoder/conv22/pointwise_kernel',
#  'w2l_encoder/conv22/bn/gamma',
#  'w2l_encoder/conv22/bn/moving_mean',
#  'w2l_encoder/conv22/bn/moving_variance',
#  'w2l_encoder/conv23/depthwise_kernel',
#  'w2l_encoder/conv23/pointwise_kernel',
#  'w2l_encoder/conv23/bn/gamma',
#  'w2l_encoder/conv23/bn/moving_mean',
#  'w2l_encoder/conv23/bn/moving_variance',
#  'w2l_encoder/conv24/depthwise_kernel',
#  'w2l_encoder/conv24/pointwise_kernel',
#  'w2l_encoder/conv24/bn/gamma',
#  'w2l_encoder/conv24/bn/moving_mean',
#  'w2l_encoder/conv24/bn/moving_variance',
#  'w2l_encoder/conv25/res/depthwise_kernel',
#  'w2l_encoder/conv25/res/pointwise_kernel',
#  'w2l_encoder/conv25/res_bn/gamma',
#  'w2l_encoder/conv25/res_bn/moving_mean',
#  'w2l_encoder/conv25/res_bn/moving_variance',
#  'w2l_encoder/conv25/depthwise_kernel',
#  'w2l_encoder/conv25/pointwise_kernel',
#  'w2l_encoder/conv25/bn/gamma',
#  'w2l_encoder/conv25/bn/moving_mean',
#  'w2l_encoder/conv25/bn/moving_variance',
#  'w2l_encoder/conv31/depthwise_kernel',
#  'w2l_encoder/conv31/pointwise_kernel',
#  'w2l_encoder/conv31/bn/gamma',
#  'w2l_encoder/conv31/bn/moving_mean',
#  'w2l_encoder/conv31/bn/moving_variance',
#  'w2l_encoder/conv32/depthwise_kernel',
#  'w2l_encoder/conv32/pointwise_kernel',
#  'w2l_encoder/conv32/bn/gamma',
#  'w2l_encoder/conv32/bn/moving_mean',
#  'w2l_encoder/conv32/bn/moving_variance',
#  'w2l_encoder/conv33/depthwise_kernel',
#  'w2l_encoder/conv33/pointwise_kernel',
#  'w2l_encoder/conv33/bn/gamma',
#  'w2l_encoder/conv33/bn/moving_mean',
#  'w2l_encoder/conv33/bn/moving_variance',
#  'w2l_encoder/conv34/depthwise_kernel',
#  'w2l_encoder/conv34/pointwise_kernel',
#  'w2l_encoder/conv34/bn/gamma',
#  'w2l_encoder/conv34/bn/moving_mean',
#  'w2l_encoder/conv34/bn/moving_variance',
#  'w2l_encoder/conv35/res/depthwise_kernel',
#  'w2l_encoder/conv35/res/pointwise_kernel',
#  'w2l_encoder/conv35/res_bn/gamma',
#  'w2l_encoder/conv35/res_bn/moving_mean',
#  'w2l_encoder/conv35/res_bn/moving_variance',
#  'w2l_encoder/conv35/depthwise_kernel',
#  'w2l_encoder/conv35/pointwise_kernel',
#  'w2l_encoder/conv35/bn/gamma',
#  'w2l_encoder/conv35/bn/moving_mean',
#  'w2l_encoder/conv35/bn/moving_variance',
#  'w2l_encoder/conv41/depthwise_kernel',
#  'w2l_encoder/conv41/pointwise_kernel',
#  'w2l_encoder/conv41/bn/gamma',
#  'w2l_encoder/conv41/bn/moving_mean',
#  'w2l_encoder/conv41/bn/moving_variance',
#  'w2l_encoder/conv42/depthwise_kernel',
#  'w2l_encoder/conv42/pointwise_kernel',
#  'w2l_encoder/conv42/bn/gamma',
#  'w2l_encoder/conv42/bn/moving_mean',
#  'w2l_encoder/conv42/bn/moving_variance',
#  'w2l_encoder/conv43/depthwise_kernel',
#  'w2l_encoder/conv43/pointwise_kernel',
#  'w2l_encoder/conv43/bn/gamma',
#  'w2l_encoder/conv43/bn/moving_mean',
#  'w2l_encoder/conv43/bn/moving_variance',
#  'w2l_encoder/conv44/depthwise_kernel',
#  'w2l_encoder/conv44/pointwise_kernel',
#  'w2l_encoder/conv44/bn/gamma',
#  'w2l_encoder/conv44/bn/moving_mean',
#  'w2l_encoder/conv44/bn/moving_variance',
#  'w2l_encoder/conv45/res/depthwise_kernel',
#  'w2l_encoder/conv45/res/pointwise_kernel',
#  'w2l_encoder/conv45/res_bn/gamma',
#  'w2l_encoder/conv45/res_bn/moving_mean',
#  'w2l_encoder/conv45/res_bn/moving_variance',
#  'w2l_encoder/conv45/depthwise_kernel',
#  'w2l_encoder/conv45/pointwise_kernel',
#  'w2l_encoder/conv45/bn/gamma',
#  'w2l_encoder/conv45/bn/moving_mean',
#  'w2l_encoder/conv45/bn/moving_variance',
#  'w2l_encoder/conv51/depthwise_kernel',
#  'w2l_encoder/conv51/pointwise_kernel',
#  'w2l_encoder/conv51/bn/gamma',
#  'w2l_encoder/conv51/bn/moving_mean',
#  'w2l_encoder/conv51/bn/moving_variance',
#  'w2l_encoder/conv52/depthwise_kernel',
#  'w2l_encoder/conv52/pointwise_kernel',
#  'w2l_encoder/conv52/bn/gamma',
#  'w2l_encoder/conv52/bn/moving_mean',
#  'w2l_encoder/conv52/bn/moving_variance',
#  'w2l_encoder/conv53/depthwise_kernel',
#  'w2l_encoder/conv53/pointwise_kernel',
#  'w2l_encoder/conv53/bn/gamma',
#  'w2l_encoder/conv53/bn/moving_mean',
#  'w2l_encoder/conv53/bn/moving_variance',
#  'w2l_encoder/conv54/depthwise_kernel',
#  'w2l_encoder/conv54/pointwise_kernel',
#  'w2l_encoder/conv54/bn/gamma',
#  'w2l_encoder/conv54/bn/moving_mean',
#  'w2l_encoder/conv54/bn/moving_variance',
#  'w2l_encoder/conv55/res/depthwise_kernel',
#  'w2l_encoder/conv55/res/pointwise_kernel',
#  'w2l_encoder/conv55/res_bn/gamma',
#  'w2l_encoder/conv55/res_bn/moving_mean',
#  'w2l_encoder/conv55/res_bn/moving_variance',
#  'w2l_encoder/conv55/depthwise_kernel',
#  'w2l_encoder/conv55/pointwise_kernel',
#  'w2l_encoder/conv55/bn/gamma',
#  'w2l_encoder/conv55/bn/moving_mean',
#  'w2l_encoder/conv55/bn/moving_variance',
#  'w2l_encoder/conv61/depthwise_kernel',
#  'w2l_encoder/conv61/pointwise_kernel',
#  'w2l_encoder/conv61/bn/gamma',
#  'w2l_encoder/conv61/bn/moving_mean',
#  'w2l_encoder/conv61/bn/moving_variance',
#  'w2l_encoder/conv62/depthwise_kernel',
#  'w2l_encoder/conv62/pointwise_kernel',
#  'w2l_encoder/conv62/bn/gamma',
#  'w2l_encoder/conv62/bn/moving_mean',
#  'w2l_encoder/conv62/bn/moving_variance',
#  'w2l_encoder/conv63/depthwise_kernel',
#  'w2l_encoder/conv63/pointwise_kernel',
#  'w2l_encoder/conv63/bn/gamma',
#  'w2l_encoder/conv63/bn/moving_mean',
#  'w2l_encoder/conv63/bn/moving_variance',
#  'w2l_encoder/conv64/depthwise_kernel',
#  'w2l_encoder/conv64/pointwise_kernel',
#  'w2l_encoder/conv64/bn/gamma',
#  'w2l_encoder/conv64/bn/moving_mean',
#  'w2l_encoder/conv64/bn/moving_variance',
#  'w2l_encoder/conv65/res/depthwise_kernel',
#  'w2l_encoder/conv65/res/pointwise_kernel',
#  'w2l_encoder/conv65/res_bn/gamma',
#  'w2l_encoder/conv65/res_bn/moving_mean',
#  'w2l_encoder/conv65/res_bn/moving_variance',
#  'w2l_encoder/conv65/depthwise_kernel',
#  'w2l_encoder/conv65/pointwise_kernel',
#  'w2l_encoder/conv65/bn/gamma',
#  'w2l_encoder/conv65/bn/moving_mean',
#  'w2l_encoder/conv65/bn/moving_variance',
#  'w2l_encoder/conv71/depthwise_kernel',
#  'w2l_encoder/conv71/pointwise_kernel',
#  'w2l_encoder/conv71/bn/gamma',
#  'w2l_encoder/conv71/bn/moving_mean',
#  'w2l_encoder/conv71/bn/moving_variance',
#  'w2l_encoder/conv72/depthwise_kernel',
#  'w2l_encoder/conv72/pointwise_kernel',
#  'w2l_encoder/conv72/bn/gamma',
#  'w2l_encoder/conv72/bn/moving_mean',
#  'w2l_encoder/conv72/bn/moving_variance',
#  'w2l_encoder/conv73/depthwise_kernel',
#  'w2l_encoder/conv73/pointwise_kernel',
#  'w2l_encoder/conv73/bn/gamma',
#  'w2l_encoder/conv73/bn/moving_mean',
#  'w2l_encoder/conv73/bn/moving_variance',
#  'w2l_encoder/conv74/depthwise_kernel',
#  'w2l_encoder/conv74/pointwise_kernel',
#  'w2l_encoder/conv74/bn/gamma',
#  'w2l_encoder/conv74/bn/moving_mean',
#  'w2l_encoder/conv74/bn/moving_variance',
#  'w2l_encoder/conv75/res/depthwise_kernel',
#  'w2l_encoder/conv75/res/pointwise_kernel',
#  'w2l_encoder/conv75/res_bn/gamma',
#  'w2l_encoder/conv75/res_bn/moving_mean',
#  'w2l_encoder/conv75/res_bn/moving_variance',
#  'w2l_encoder/conv75/depthwise_kernel',
#  'w2l_encoder/conv75/pointwise_kernel',
#  'w2l_encoder/conv75/bn/gamma',
#  'w2l_encoder/conv75/bn/moving_mean',
#  'w2l_encoder/conv75/bn/moving_variance',
#  'w2l_encoder/conv81/depthwise_kernel',
#  'w2l_encoder/conv81/pointwise_kernel',
#  'w2l_encoder/conv81/bn/gamma',
#  'w2l_encoder/conv81/bn/moving_mean',
#  'w2l_encoder/conv81/bn/moving_variance',
#  'w2l_encoder/conv82/depthwise_kernel',
#  'w2l_encoder/conv82/pointwise_kernel',
#  'w2l_encoder/conv82/bn/gamma',
#  'w2l_encoder/conv82/bn/moving_mean',
#  'w2l_encoder/conv82/bn/moving_variance',
#  'w2l_encoder/conv83/depthwise_kernel',
#  'w2l_encoder/conv83/pointwise_kernel',
#  'w2l_encoder/conv83/bn/gamma',
#  'w2l_encoder/conv83/bn/moving_mean',
#  'w2l_encoder/conv83/bn/moving_variance',
#  'w2l_encoder/conv84/depthwise_kernel',
#  'w2l_encoder/conv84/pointwise_kernel',
#  'w2l_encoder/conv84/bn/gamma',
#  'w2l_encoder/conv84/bn/moving_mean',
#  'w2l_encoder/conv84/bn/moving_variance',
#  'w2l_encoder/conv85/res/depthwise_kernel',
#  'w2l_encoder/conv85/res/pointwise_kernel',
#  'w2l_encoder/conv85/res_bn/gamma',
#  'w2l_encoder/conv85/res_bn/moving_mean',
#  'w2l_encoder/conv85/res_bn/moving_variance',
#  'w2l_encoder/conv85/depthwise_kernel',
#  'w2l_encoder/conv85/pointwise_kernel',
#  'w2l_encoder/conv85/bn/gamma',
#  'w2l_encoder/conv85/bn/moving_mean',
#  'w2l_encoder/conv85/bn/moving_variance',
#  'w2l_encoder/conv91/depthwise_kernel',
#  'w2l_encoder/conv91/pointwise_kernel',
#  'w2l_encoder/conv91/bn/gamma',
#  'w2l_encoder/conv91/bn/moving_mean',
#  'w2l_encoder/conv91/bn/moving_variance',
#  'w2l_encoder/conv92/depthwise_kernel',
#  'w2l_encoder/conv92/pointwise_kernel',
#  'w2l_encoder/conv92/bn/gamma',
#  'w2l_encoder/conv92/bn/moving_mean',
#  'w2l_encoder/conv92/bn/moving_variance',
#  'w2l_encoder/conv93/depthwise_kernel',
#  'w2l_encoder/conv93/pointwise_kernel',
#  'w2l_encoder/conv93/bn/gamma',
#  'w2l_encoder/conv93/bn/moving_mean',
#  'w2l_encoder/conv93/bn/moving_variance',
#  'w2l_encoder/conv94/depthwise_kernel',
#  'w2l_encoder/conv94/pointwise_kernel',
#  'w2l_encoder/conv94/bn/gamma',
#  'w2l_encoder/conv94/bn/moving_mean',
#  'w2l_encoder/conv94/bn/moving_variance',
#  'w2l_encoder/conv95/res/depthwise_kernel',
#  'w2l_encoder/conv95/res/pointwise_kernel',
#  'w2l_encoder/conv95/res_bn/gamma',
#  'w2l_encoder/conv95/res_bn/moving_mean',
#  'w2l_encoder/conv95/res_bn/moving_variance',
#  'w2l_encoder/conv95/depthwise_kernel',
#  'w2l_encoder/conv95/pointwise_kernel',
#  'w2l_encoder/conv95/bn/gamma',
#  'w2l_encoder/conv95/bn/moving_mean',
#  'w2l_encoder/conv95/bn/moving_variance',
#  'w2l_encoder/conv101/depthwise_kernel',
#  'w2l_encoder/conv101/pointwise_kernel',
#  'w2l_encoder/conv101/bn/gamma',
#  'w2l_encoder/conv101/bn/moving_mean',
#  'w2l_encoder/conv101/bn/moving_variance',
#  'w2l_encoder/conv102/depthwise_kernel',
#  'w2l_encoder/conv102/pointwise_kernel',
#  'w2l_encoder/conv102/bn/gamma',
#  'w2l_encoder/conv102/bn/moving_mean',
#  'w2l_encoder/conv102/bn/moving_variance',
#  'w2l_encoder/conv103/depthwise_kernel',
#  'w2l_encoder/conv103/pointwise_kernel',
#  'w2l_encoder/conv103/bn/gamma',
#  'w2l_encoder/conv103/bn/moving_mean',
#  'w2l_encoder/conv103/bn/moving_variance',
#  'w2l_encoder/conv104/depthwise_kernel',
#  'w2l_encoder/conv104/pointwise_kernel',
#  'w2l_encoder/conv104/bn/gamma',
#  'w2l_encoder/conv104/bn/moving_mean',
#  'w2l_encoder/conv104/bn/moving_variance',
#  'w2l_encoder/conv105/res/depthwise_kernel',
#  'w2l_encoder/conv105/res/pointwise_kernel',
#  'w2l_encoder/conv105/res_bn/gamma',
#  'w2l_encoder/conv105/res_bn/moving_mean',
#  'w2l_encoder/conv105/res_bn/moving_variance',
#  'w2l_encoder/conv105/depthwise_kernel',
#  'w2l_encoder/conv105/pointwise_kernel',
#  'w2l_encoder/conv105/bn/gamma',
#  'w2l_encoder/conv105/bn/moving_mean',
#  'w2l_encoder/conv105/bn/moving_variance',
#  'w2l_encoder/conv111/depthwise_kernel',
#  'w2l_encoder/conv111/pointwise_kernel',
#  'w2l_encoder/conv111/bn/gamma',
#  'w2l_encoder/conv111/bn/moving_mean',
#  'w2l_encoder/conv111/bn/moving_variance',
#  'w2l_encoder/conv112/depthwise_kernel',
#  'w2l_encoder/conv112/pointwise_kernel',
#  'w2l_encoder/conv112/bn/gamma',
#  'w2l_encoder/conv112/bn/moving_mean',
#  'w2l_encoder/conv112/bn/moving_variance',
#  'w2l_encoder/conv113/depthwise_kernel',
#  'w2l_encoder/conv113/pointwise_kernel',
#  'w2l_encoder/conv113/bn/gamma',
#  'w2l_encoder/conv113/bn/moving_mean',
#  'w2l_encoder/conv113/bn/moving_variance',
#  'w2l_encoder/conv114/depthwise_kernel',
#  'w2l_encoder/conv114/pointwise_kernel',
#  'w2l_encoder/conv114/bn/gamma',
#  'w2l_encoder/conv114/bn/moving_mean',
#  'w2l_encoder/conv114/bn/moving_variance',
#  'w2l_encoder/conv115/res/depthwise_kernel',
#  'w2l_encoder/conv115/res/pointwise_kernel',
#  'w2l_encoder/conv115/res_bn/gamma',
#  'w2l_encoder/conv115/res_bn/moving_mean',
#  'w2l_encoder/conv115/res_bn/moving_variance',
#  'w2l_encoder/conv115/depthwise_kernel',
#  'w2l_encoder/conv115/pointwise_kernel',
#  'w2l_encoder/conv115/bn/gamma',
#  'w2l_encoder/conv115/bn/moving_mean',
#  'w2l_encoder/conv115/bn/moving_variance',
#  'w2l_encoder/conv121/depthwise_kernel',
#  'w2l_encoder/conv121/pointwise_kernel',
#  'w2l_encoder/conv121/bn/gamma',
#  'w2l_encoder/conv121/bn/moving_mean',
#  'w2l_encoder/conv121/bn/moving_variance',
#  'w2l_encoder/conv122/depthwise_kernel',
#  'w2l_encoder/conv122/pointwise_kernel',
#  'w2l_encoder/conv122/bn/gamma',
#  'w2l_encoder/conv122/bn/moving_mean',
#  'w2l_encoder/conv122/bn/moving_variance',
#  'w2l_encoder/conv123/depthwise_kernel',
#  'w2l_encoder/conv123/pointwise_kernel',
#  'w2l_encoder/conv123/bn/gamma',
#  'w2l_encoder/conv123/bn/moving_mean',
#  'w2l_encoder/conv123/bn/moving_variance',
#  'w2l_encoder/conv124/depthwise_kernel',
#  'w2l_encoder/conv124/pointwise_kernel',
#  'w2l_encoder/conv124/bn/gamma',
#  'w2l_encoder/conv124/bn/moving_mean',
#  'w2l_encoder/conv124/bn/moving_variance',
#  'w2l_encoder/conv125/res/depthwise_kernel',
#  'w2l_encoder/conv125/res/pointwise_kernel',
#  'w2l_encoder/conv125/res_bn/gamma',
#  'w2l_encoder/conv125/res_bn/moving_mean',
#  'w2l_encoder/conv125/res_bn/moving_variance',
#  'w2l_encoder/conv125/depthwise_kernel',
#  'w2l_encoder/conv125/pointwise_kernel',
#  'w2l_encoder/conv125/bn/gamma',
#  'w2l_encoder/conv125/bn/moving_mean',
#  'w2l_encoder/conv125/bn/moving_variance',
#  'w2l_encoder/conv131/depthwise_kernel',
#  'w2l_encoder/conv131/pointwise_kernel',
#  'w2l_encoder/conv131/bn/gamma',
#  'w2l_encoder/conv131/bn/moving_mean',
#  'w2l_encoder/conv131/bn/moving_variance',
#  'w2l_encoder/conv132/depthwise_kernel',
#  'w2l_encoder/conv132/pointwise_kernel',
#  'w2l_encoder/conv132/bn/gamma',
#  'w2l_encoder/conv132/bn/moving_mean',
#  'w2l_encoder/conv132/bn/moving_variance',
#  'w2l_encoder/conv133/depthwise_kernel',
#  'w2l_encoder/conv133/pointwise_kernel',
#  'w2l_encoder/conv133/bn/gamma',
#  'w2l_encoder/conv133/bn/moving_mean',
#  'w2l_encoder/conv133/bn/moving_variance',
#  'w2l_encoder/conv134/depthwise_kernel',
#  'w2l_encoder/conv134/pointwise_kernel',
#  'w2l_encoder/conv134/bn/gamma',
#  'w2l_encoder/conv134/bn/moving_mean',
#  'w2l_encoder/conv134/bn/moving_variance',
#  'w2l_encoder/conv135/res/depthwise_kernel',
#  'w2l_encoder/conv135/res/pointwise_kernel',
#  'w2l_encoder/conv135/res_bn/gamma',
#  'w2l_encoder/conv135/res_bn/moving_mean',
#  'w2l_encoder/conv135/res_bn/moving_variance',
#  'w2l_encoder/conv135/depthwise_kernel',
#  'w2l_encoder/conv135/pointwise_kernel',
#  'w2l_encoder/conv135/bn/gamma',
#  'w2l_encoder/conv135/bn/moving_mean',
#  'w2l_encoder/conv135/bn/moving_variance',
#  'w2l_encoder/conv141/depthwise_kernel',
#  'w2l_encoder/conv141/pointwise_kernel',
#  'w2l_encoder/conv141/bn/gamma',
#  'w2l_encoder/conv141/bn/moving_mean',
#  'w2l_encoder/conv141/bn/moving_variance',
#  'w2l_encoder/conv142/depthwise_kernel',
#  'w2l_encoder/conv142/pointwise_kernel',
#  'w2l_encoder/conv142/bn/gamma',
#  'w2l_encoder/conv142/bn/moving_mean',
#  'w2l_encoder/conv142/bn/moving_variance',
#  'w2l_encoder/conv143/depthwise_kernel',
#  'w2l_encoder/conv143/pointwise_kernel',
#  'w2l_encoder/conv143/bn/gamma',
#  'w2l_encoder/conv143/bn/moving_mean',
#  'w2l_encoder/conv143/bn/moving_variance',
#  'w2l_encoder/conv144/depthwise_kernel',
#  'w2l_encoder/conv144/pointwise_kernel',
#  'w2l_encoder/conv144/bn/gamma',
#  'w2l_encoder/conv144/bn/moving_mean',
#  'w2l_encoder/conv144/bn/moving_variance',
#  'w2l_encoder/conv145/res/depthwise_kernel',
#  'w2l_encoder/conv145/res/pointwise_kernel',
#  'w2l_encoder/conv145/res_bn/gamma',
#  'w2l_encoder/conv145/res_bn/moving_mean',
#  'w2l_encoder/conv145/res_bn/moving_variance',
#  'w2l_encoder/conv145/depthwise_kernel',
#  'w2l_encoder/conv145/pointwise_kernel',
#  'w2l_encoder/conv145/bn/gamma',
#  'w2l_encoder/conv145/bn/moving_mean',
#  'w2l_encoder/conv145/bn/moving_variance',
#  'w2l_encoder/conv151/depthwise_kernel',
#  'w2l_encoder/conv151/pointwise_kernel',
#  'w2l_encoder/conv151/bn/gamma',
#  'w2l_encoder/conv151/bn/moving_mean',
#  'w2l_encoder/conv151/bn/moving_variance',
#  'w2l_encoder/conv152/depthwise_kernel',
#  'w2l_encoder/conv152/pointwise_kernel',
#  'w2l_encoder/conv152/bn/gamma',
#  'w2l_encoder/conv152/bn/moving_mean',
#  'w2l_encoder/conv152/bn/moving_variance',
#  'w2l_encoder/conv153/depthwise_kernel',
#  'w2l_encoder/conv153/pointwise_kernel',
#  'w2l_encoder/conv153/bn/gamma',
#  'w2l_encoder/conv153/bn/moving_mean',
#  'w2l_encoder/conv153/bn/moving_variance',
#  'w2l_encoder/conv154/depthwise_kernel',
#  'w2l_encoder/conv154/pointwise_kernel',
#  'w2l_encoder/conv154/bn/gamma',
#  'w2l_encoder/conv154/bn/moving_mean',
#  'w2l_encoder/conv154/bn/moving_variance',
#  'w2l_encoder/conv155/res/depthwise_kernel',
#  'w2l_encoder/conv155/res/pointwise_kernel',
#  'w2l_encoder/conv155/res_bn/gamma',
#  'w2l_encoder/conv155/res_bn/moving_mean',
#  'w2l_encoder/conv155/res_bn/moving_variance',
#  'w2l_encoder/conv155/depthwise_kernel',
#  'w2l_encoder/conv155/pointwise_kernel',
#  'w2l_encoder/conv155/bn/gamma',
#  'w2l_encoder/conv155/bn/moving_mean',
#  'w2l_encoder/conv155/bn/moving_variance',
#  'w2l_encoder/conv161/depthwise_kernel',
#  'w2l_encoder/conv161/pointwise_kernel',
#  'w2l_encoder/conv161/bn/gamma',
#  'w2l_encoder/conv161/bn/moving_mean',
#  'w2l_encoder/conv161/bn/moving_variance',
#  'w2l_encoder/conv162/depthwise_kernel',
#  'w2l_encoder/conv162/pointwise_kernel',
#  'w2l_encoder/conv162/bn/gamma',
#  'w2l_encoder/conv162/bn/moving_mean',
#  'w2l_encoder/conv162/bn/moving_variance',
#  'w2l_encoder/conv163/depthwise_kernel',
#  'w2l_encoder/conv163/pointwise_kernel',
#  'w2l_encoder/conv163/bn/gamma',
#  'w2l_encoder/conv163/bn/moving_mean',
#  'w2l_encoder/conv163/bn/moving_variance',
#  'w2l_encoder/conv164/depthwise_kernel',
#  'w2l_encoder/conv164/pointwise_kernel',
#  'w2l_encoder/conv164/bn/gamma',
#  'w2l_encoder/conv164/bn/moving_mean',
#  'w2l_encoder/conv164/bn/moving_variance',
#  'w2l_encoder/conv165/res/depthwise_kernel',
#  'w2l_encoder/conv165/res/pointwise_kernel',
#  'w2l_encoder/conv165/res_bn/gamma',
#  'w2l_encoder/conv165/res_bn/moving_mean',
#  'w2l_encoder/conv165/res_bn/moving_variance',
#  'w2l_encoder/conv165/depthwise_kernel',
#  'w2l_encoder/conv165/pointwise_kernel',
#  'w2l_encoder/conv165/bn/gamma',
#  'w2l_encoder/conv165/bn/moving_mean',
#  'w2l_encoder/conv165/bn/moving_variance',
#  'w2l_encoder/conv171/res/depthwise_kernel',
#  'w2l_encoder/conv171/res/pointwise_kernel',
#  'w2l_encoder/conv171/res_bn/gamma',
#  'w2l_encoder/conv171/res_bn/moving_mean',
#  'w2l_encoder/conv171/res_bn/moving_variance',
#  'w2l_encoder/conv171/depthwise_kernel',
#  'w2l_encoder/conv171/pointwise_kernel',
#  'w2l_encoder/conv171/bn/gamma',
#  'w2l_encoder/conv171/bn/moving_mean',
#  'w2l_encoder/conv171/bn/moving_variance',
#  'w2l_encoder/conv181/kernel',
#  'w2l_encoder/conv181/bn/gamma',
#  'w2l_encoder/conv181/bn/moving_mean',
#  'w2l_encoder/conv181/bn/moving_variance',
#  'dense/kernel',
#  'dense/bias',
#  'logits',
#  'seq_lens']

# %%
def freeze_graph(model_dir, output_node_names):

    if not tf.gfile.Exists(model_dir):
        raise AssertionError(
            "Export directory doesn't exists. Please specify an export "
            'directory: %s' % model_dir
        )

    checkpoint = tf.train.get_checkpoint_state(model_dir)
    input_checkpoint = checkpoint.model_checkpoint_path

    absolute_model_dir = '/'.join(input_checkpoint.split('/')[:-1])
    output_graph = absolute_model_dir + '/frozen_model.pb'
    clear_devices = True
    with tf.Session(graph = tf.Graph()) as sess:
        saver = tf.train.import_meta_graph(
            input_checkpoint + '.meta', clear_devices = clear_devices
        )
        saver.restore(sess, input_checkpoint)
        output_graph_def = tf.graph_util.convert_variables_to_constants(
            sess,
            tf.get_default_graph().as_graph_def(),
            output_node_names.split(','),
        )
        with tf.gfile.GFile(output_graph, 'wb') as f:
            f.write(output_graph_def.SerializeToString())
        print('%d ops in the final graph.' % len(output_graph_def.node))

# %%
freeze_graph('asr-quartznet-ctc-output', strings)
# Out:
# INFO:tensorflow:Restoring parameters from asr-quartznet-ctc-output/model.ckpt
# WARNING:tensorflow:From <ipython-input-17-9a7215a4e58a>:23: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# WARNING:tensorflow:From /home/husein/.local/lib/python3.6/site-packages/tensorflow_core/python/framework/graph_util_impl.py:277: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# INFO:tensorflow:Froze 565 variables.
# INFO:tensorflow:Converted 565 variables to const ops.
# 3549 ops in the final graph.

# %%
def load_graph(frozen_graph_filename):
    with tf.gfile.GFile(frozen_graph_filename, 'rb') as f:
        graph_def = tf.GraphDef()
        graph_def.ParseFromString(f.read())
    with tf.Graph().as_default() as graph:
        tf.import_graph_def(graph_def)
    return graph

# %%
g = load_graph('asr-quartznet-ctc-output/frozen_model.pb')
x = g.get_tensor_by_name('import/Placeholder:0')
x_lens = g.get_tensor_by_name('import/Placeholder_1:0')
logits = g.get_tensor_by_name('import/logits:0')
seq_lens = g.get_tensor_by_name('import/seq_lens:0')
test_sess = tf.InteractiveSession(graph = g)
result = test_sess.run([logits, seq_lens], feed_dict = {x: padded, x_lens: lens})
result
# Out:
# [array([[[ -84.5379   ,  -82.79561  ,  -10.087287 , ...,  -51.145416 ,
#           -149.3778   ,   16.79637  ],
#          [ -65.14783  ,  -63.808704 ,  -10.393862 , ...,  -40.582966 ,
#           -120.965164 ,   13.112476 ]],
#
#         [[ -94.58125  ,  -94.09883  ,  -11.996426 , ...,  -62.57859  ,
#           -150.48581  ,   16.297886 ],
#          [ -77.958244 ,  -78.656425 ,   -9.595647 , ...,  -48.550175 ,
#           -125.34512  ,   13.658209 ]],
#
#         [[-126.261986 , -122.39516  ,  -10.872917 , ...,  -89.26167  ,
#           -240.20914  ,   20.670303 ],
#          [-103.20415  , -100.64028  ,   -8.713641 , ...,  -66.272194 ,
#           -205.90721  ,   17.901423 ]],
#
#         ...,
#
#         [[-149.80501  , -145.71222  ,  -37.61645  , ...,  -94.94084  ,
#           -271.87778  ,   24.769342 ],
#          [ -16.619572 ,  -16.38736  ,   -1.8026912, ...,   -9.357312 ,
#            -20.182959 ,    2.7737248]],
#
#         [[-144.4081   , -141.93152  ,  -23.449245 , ..., -103.52729  ,
#           -266.91586  ,   25.8719   ],
#          [ -16.619572 ,  -16.38736  ,   -1.8026912, ...,   -9.357312 ,
#            -20.182959 ,    2.7737248]],
#
#         [[-140.87817  , -137.76004  ,  -22.476875 , ...,  -82.09739  ,
#           -254.17915  ,   22.934645 ],
#          [ -16.619572 ,  -16.38736  ,   -1.8026912, ...,   -9.357312 ,
#            -20.182959 ,    2.7737248]]], dtype=float32),
#  array([281, 196], dtype=int32)]

# %%
from tensorflow.tools.graph_transforms import TransformGraph

# %%
transforms = ['add_default_attributes',
             'remove_nodes(op=Identity, op=CheckNumerics, op=Dropout)',
             'fold_constants(ignore_errors=true)',
             'fold_batch_norms',
             'fold_old_batch_norms',
             'quantize_weights',
             'strip_unused_nodes',
             'sort_by_execution_order']

pb = 'asr-quartznet-ctc-output/frozen_model.pb'

input_graph_def = tf.GraphDef()
with tf.gfile.FastGFile(pb, 'rb') as f:
    input_graph_def.ParseFromString(f.read())

transformed_graph_def = TransformGraph(input_graph_def, 
                                           ['Placeholder', 'Placeholder_1'],
                                           ['logits', 'seq_lens'], transforms)
    
with tf.gfile.GFile(f'{pb}.quantized', 'wb') as f:
    f.write(transformed_graph_def.SerializeToString())
