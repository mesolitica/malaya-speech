# %%
from glob import glob
from sklearn.model_selection import train_test_split
import json

# %%
mels = glob('../speech-bahasa/output-osman/mels/*.npy')
mels.extend(glob('../speech-bahasa/output-osman-parliament/mels/*.npy'))

len(mels)
# Out:
# 109570

# %%
import numpy as np

mel_stat = np.load('../speech-bahasa/osman-stats/stats.npy')
mel = np.load(mels[0])

# %%
# %%time

def norm_mean_std(x, mean, std):
    zero_idxs = np.where(x == 0.0)[0]
    x = (x - mean) / std
    x[zero_idxs] = 0.0
    return x

norm_mean_std(mel, mel_stat[0], mel_stat[1])
# Out:
# CPU times: user 609 µs, sys: 523 µs, total: 1.13 ms
# Wall time: 648 µs
# array([[-2.943194 , -3.0162587, -3.1752992, ..., -2.232502 , -1.9050784,
#         -2.0515218],
#        [-3.1594667, -3.2598207, -3.1248288, ..., -2.2309084, -1.9878994,
#         -1.9751582],
#        [-2.563818 , -3.0313869, -3.061151 , ..., -2.2125485, -2.0057526,
#         -1.947648 ],
#        ...,
#        [-3.199402 , -3.5751731, -3.353618 , ..., -2.37052  , -2.1585937,
#         -1.9663814],
#        [-3.663712 , -4.1883006, -3.920242 , ..., -2.402786 , -2.1763134,
#         -2.2347116],
#        [-3.961376 , -4.2629504, -4.3360066, ..., -2.2738907, -2.119386 ,
#         -2.0032194]], dtype=float32)

# %%
text_ids = np.load(mels[1].replace('mels', 'text_ids'), allow_pickle=True)[0]
text_ids
# Out:
# 'foto : Instagram garis miring @ alexmorgan tiga belas Loading . . . Nama Alex Morgan menjadi buah bibir di Piala Dunia Wanita dua ribu sembilan belas .'

# %%
import IPython.display as ipd
ipd.Audio(np.load(mels[1].replace('mels', 'audios')), rate = 22500)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
train, test = train_test_split(mels, test_size = 3000)
with open('mels-osman.json', 'w') as fopen:
    json.dump({'train': train, 'test': test}, fopen)
