# %%
import os

os.environ['CUDA_VISIBLE_DEVICES'] = ''

# %%
import sys

SOURCE_DIR = os.path.dirname(os.path.dirname(os.path.abspath(__name__)))
sys.path.insert(0, SOURCE_DIR)

# %%
import malaya_speech
import malaya_speech.config
from malaya_speech.train.model import srgan
from malaya_speech.train.model import enhancement
import tensorflow as tf
import numpy as np
# Out:
# WARNING:tensorflow:From /home/husein/malaya-speech/malaya_speech/train/optimizer/__init__.py:38: The name tf.train.AdagradOptimizer is deprecated. Please use tf.compat.v1.train.AdagradOptimizer instead.
#
# WARNING:tensorflow:From /home/husein/malaya-speech/malaya_speech/train/optimizer/__init__.py:39: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /home/husein/malaya-speech/malaya_speech/train/optimizer/__init__.py:40: The name tf.train.FtrlOptimizer is deprecated. Please use tf.compat.v1.train.FtrlOptimizer instead.
#
# WARNING:tensorflow:From /home/husein/malaya-speech/malaya_speech/train/optimizer/__init__.py:42: The name tf.train.RMSPropOptimizer is deprecated. Please use tf.compat.v1.train.RMSPropOptimizer instead.
#
# WARNING:tensorflow:From /home/husein/malaya-speech/malaya_speech/train/optimizer/__init__.py:43: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /home/husein/malaya-speech/malaya_speech/train/model/openseq2seq/layer.py:6: The name tf.layers.Conv1D is deprecated. Please use tf.compat.v1.layers.Conv1D instead.
#
# WARNING:tensorflow:From /home/husein/malaya-speech/malaya_speech/train/model/openseq2seq/attention.py:4: The name tf.layers.Layer is deprecated. Please use tf.compat.v1.layers.Layer instead.

# %%
sr = 44100
partition_size = 2048
reduction_factor = 4

# %%
tf.reset_default_graph()

x = tf.placeholder(tf.float32, (None,))
x_ = tf.expand_dims(x, 1)
partitioned_x = malaya_speech.tf_featurization.pad_and_partition(x_, partition_size // reduction_factor)

with tf.variable_scope('generator') as gen:
    model = srgan.Model(partitioned_x, training = True, num_filters = 128)
    
model.logits.set_shape((None, partition_size, 1))
logits = tf.reshape(model.logits, (-1, 1))
logits = logits[:tf.shape(x)[0] * reduction_factor, 0]

logits = tf.identity(logits, name = 'logits')

# %%
sess = tf.InteractiveSession()
sess.run(tf.global_variables_initializer())
# Out:
# /home/husein/.local/lib/python3.6/site-packages/tensorflow_core/python/client/session.py:1750: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '

# %%
path = 'srgan-mae-128'
ckpt_path = tf.train.latest_checkpoint(path)
ckpt_path
# Out:
# 'srgan-mae-128/model.ckpt-565000'

# %%
var_list = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES)
saver = tf.train.Saver(var_list = var_list)
saver.restore(sess, ckpt_path)
# Out:
# INFO:tensorflow:Restoring parameters from srgan-mae-128/model.ckpt-565000

# %%
import IPython.display as ipd
import museval
import matplotlib.pyplot as plt
from glob import glob

# %%
def get_pair(f):
    return f.split('/')[-1].split('-')[0]


def read_wav(f):
    return malaya_speech.load(f, sr = sr)

# %%
Y = glob('testset-super-resolution/*-y.wav')
len(Y)
# Out:
# 100

# %%
from tqdm import tqdm
from glob import glob

sdrs, isrs, sars = [], [], []

for y in tqdm(Y):
    y_ = f'testset-super-resolution/{get_pair(y)}-y_.wav'
    y, _ = read_wav(y)
    y_, _ = read_wav(y_)
    y__ = sess.run(logits, feed_dict = {x: y_})
    sdr, isr, _, sar = museval.evaluate(np.expand_dims(y__, 0), 
                                    np.expand_dims(y, 0))
    sdrs.append(np.nanmean(sdr))
    isrs.append(np.nanmean(isr))
    sars.append(np.nanmean(sar))
# Out:
# 100%|██████████| 100/100 [01:52<00:00,  1.13s/it]

# %%
np.mean(sdrs), np.mean(isrs), np.mean(sars)
# Out:
# (17.033455599949807, 22.330261386547964, 17.45437281657514)

# %%
l, sr_ = malaya_speech.load('89.wav', sr = sr // reduction_factor)
len(l) / sr_, sr_
# Out:
# (4.106031746031746, 11025)

# %%
ipd.Audio(l, rate = sr_)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
y_ = sess.run(logits, feed_dict = {x: l})

# %%
ipd.Audio(y_, rate = sr_ * reduction_factor)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
resampled = malaya_speech.resample(l, sr // reduction_factor, sr)
ipd.Audio(resampled, rate = sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
saver = tf.train.Saver()
saver.save(sess, 'srgan-128-output/model.ckpt')
# Out:
# 'srgan-128-output/model.ckpt'

# %%
strings = ','.join(
    [
        n.name
        for n in tf.get_default_graph().as_graph_def().node
        if ('Variable' in n.op
        or 'Placeholder' in n.name
        or 'logits' in n.name)
        and 'adam' not in n.name
        and 'beta' not in n.name
        and 'global_step' not in n.name
        and 'Assign' not in n.name
    ]
)
strings.split(',')
# Out:
# ['Placeholder',
#  'generator/conv1d/kernel/Read/ReadVariableOp',
#  'generator/conv1d/bias/Read/ReadVariableOp',
#  'generator/conv1d/conv1d/ExpandDims_1/ReadVariableOp',
#  'generator/conv1d/BiasAdd/ReadVariableOp',
#  'generator/p_re_lu/alpha/Read/ReadVariableOp',
#  'generator/p_re_lu/ReadVariableOp',
#  'generator/conv1d_1/kernel/Read/ReadVariableOp',
#  'generator/conv1d_1/bias/Read/ReadVariableOp',
#  'generator/conv1d_1/conv1d/ExpandDims_1/ReadVariableOp',
#  'generator/conv1d_1/BiasAdd/ReadVariableOp',
#  'generator/batch_normalization/gamma/Read/ReadVariableOp',
#  'generator/batch_normalization/moving_mean/Read/ReadVariableOp',
#  'generator/batch_normalization/moving_variance/Read/ReadVariableOp',
#  'generator/batch_normalization/batchnorm/mul/ReadVariableOp',
#  'generator/batch_normalization/batchnorm/ReadVariableOp',
#  'generator/p_re_lu_1/alpha/Read/ReadVariableOp',
#  'generator/p_re_lu_1/ReadVariableOp',
#  'generator/conv1d_2/kernel/Read/ReadVariableOp',
#  'generator/conv1d_2/bias/Read/ReadVariableOp',
#  'generator/conv1d_2/conv1d/ExpandDims_1/ReadVariableOp',
#  'generator/conv1d_2/BiasAdd/ReadVariableOp',
#  'generator/batch_normalization_1/gamma/Read/ReadVariableOp',
#  'generator/batch_normalization_1/moving_mean/Read/ReadVariableOp',
#  'generator/batch_normalization_1/moving_variance/Read/ReadVariableOp',
#  'generator/batch_normalization_1/batchnorm/mul/ReadVariableOp',
#  'generator/batch_normalization_1/batchnorm/ReadVariableOp',
#  'generator/conv1d_3/kernel/Read/ReadVariableOp',
#  'generator/conv1d_3/bias/Read/ReadVariableOp',
#  'generator/conv1d_3/conv1d/ExpandDims_1/ReadVariableOp',
#  'generator/conv1d_3/BiasAdd/ReadVariableOp',
#  'generator/batch_normalization_2/gamma/Read/ReadVariableOp',
#  'generator/batch_normalization_2/moving_mean/Read/ReadVariableOp',
#  'generator/batch_normalization_2/moving_variance/Read/ReadVariableOp',
#  'generator/batch_normalization_2/batchnorm/mul/ReadVariableOp',
#  'generator/batch_normalization_2/batchnorm/ReadVariableOp',
#  'generator/p_re_lu_2/alpha/Read/ReadVariableOp',
#  'generator/p_re_lu_2/ReadVariableOp',
#  'generator/conv1d_4/kernel/Read/ReadVariableOp',
#  'generator/conv1d_4/bias/Read/ReadVariableOp',
#  'generator/conv1d_4/conv1d/ExpandDims_1/ReadVariableOp',
#  'generator/conv1d_4/BiasAdd/ReadVariableOp',
#  'generator/batch_normalization_3/gamma/Read/ReadVariableOp',
#  'generator/batch_normalization_3/moving_mean/Read/ReadVariableOp',
#  'generator/batch_normalization_3/moving_variance/Read/ReadVariableOp',
#  'generator/batch_normalization_3/batchnorm/mul/ReadVariableOp',
#  'generator/batch_normalization_3/batchnorm/ReadVariableOp',
#  'generator/conv1d_5/kernel/Read/ReadVariableOp',
#  'generator/conv1d_5/bias/Read/ReadVariableOp',
#  'generator/conv1d_5/conv1d/ExpandDims_1/ReadVariableOp',
#  'generator/conv1d_5/BiasAdd/ReadVariableOp',
#  'generator/batch_normalization_4/gamma/Read/ReadVariableOp',
#  'generator/batch_normalization_4/moving_mean/Read/ReadVariableOp',
#  'generator/batch_normalization_4/moving_variance/Read/ReadVariableOp',
#  'generator/batch_normalization_4/batchnorm/mul/ReadVariableOp',
#  'generator/batch_normalization_4/batchnorm/ReadVariableOp',
#  'generator/p_re_lu_3/alpha/Read/ReadVariableOp',
#  'generator/p_re_lu_3/ReadVariableOp',
#  'generator/conv1d_6/kernel/Read/ReadVariableOp',
#  'generator/conv1d_6/bias/Read/ReadVariableOp',
#  'generator/conv1d_6/conv1d/ExpandDims_1/ReadVariableOp',
#  'generator/conv1d_6/BiasAdd/ReadVariableOp',
#  'generator/batch_normalization_5/gamma/Read/ReadVariableOp',
#  'generator/batch_normalization_5/moving_mean/Read/ReadVariableOp',
#  'generator/batch_normalization_5/moving_variance/Read/ReadVariableOp',
#  'generator/batch_normalization_5/batchnorm/mul/ReadVariableOp',
#  'generator/batch_normalization_5/batchnorm/ReadVariableOp',
#  'generator/conv1d_7/kernel/Read/ReadVariableOp',
#  'generator/conv1d_7/bias/Read/ReadVariableOp',
#  'generator/conv1d_7/conv1d/ExpandDims_1/ReadVariableOp',
#  'generator/conv1d_7/BiasAdd/ReadVariableOp',
#  'generator/batch_normalization_6/gamma/Read/ReadVariableOp',
#  'generator/batch_normalization_6/moving_mean/Read/ReadVariableOp',
#  'generator/batch_normalization_6/moving_variance/Read/ReadVariableOp',
#  'generator/batch_normalization_6/batchnorm/mul/ReadVariableOp',
#  'generator/batch_normalization_6/batchnorm/ReadVariableOp',
#  'generator/p_re_lu_4/alpha/Read/ReadVariableOp',
#  'generator/p_re_lu_4/ReadVariableOp',
#  'generator/conv1d_8/kernel/Read/ReadVariableOp',
#  'generator/conv1d_8/bias/Read/ReadVariableOp',
#  'generator/conv1d_8/conv1d/ExpandDims_1/ReadVariableOp',
#  'generator/conv1d_8/BiasAdd/ReadVariableOp',
#  'generator/batch_normalization_7/gamma/Read/ReadVariableOp',
#  'generator/batch_normalization_7/moving_mean/Read/ReadVariableOp',
#  'generator/batch_normalization_7/moving_variance/Read/ReadVariableOp',
#  'generator/batch_normalization_7/batchnorm/mul/ReadVariableOp',
#  'generator/batch_normalization_7/batchnorm/ReadVariableOp',
#  'generator/conv1d_9/kernel/Read/ReadVariableOp',
#  'generator/conv1d_9/bias/Read/ReadVariableOp',
#  'generator/conv1d_9/conv1d/ExpandDims_1/ReadVariableOp',
#  'generator/conv1d_9/BiasAdd/ReadVariableOp',
#  'generator/batch_normalization_8/gamma/Read/ReadVariableOp',
#  'generator/batch_normalization_8/moving_mean/Read/ReadVariableOp',
#  'generator/batch_normalization_8/moving_variance/Read/ReadVariableOp',
#  'generator/batch_normalization_8/batchnorm/mul/ReadVariableOp',
#  'generator/batch_normalization_8/batchnorm/ReadVariableOp',
#  'generator/p_re_lu_5/alpha/Read/ReadVariableOp',
#  'generator/p_re_lu_5/ReadVariableOp',
#  'generator/conv1d_10/kernel/Read/ReadVariableOp',
#  'generator/conv1d_10/bias/Read/ReadVariableOp',
#  'generator/conv1d_10/conv1d/ExpandDims_1/ReadVariableOp',
#  'generator/conv1d_10/BiasAdd/ReadVariableOp',
#  'generator/batch_normalization_9/gamma/Read/ReadVariableOp',
#  'generator/batch_normalization_9/moving_mean/Read/ReadVariableOp',
#  'generator/batch_normalization_9/moving_variance/Read/ReadVariableOp',
#  'generator/batch_normalization_9/batchnorm/mul/ReadVariableOp',
#  'generator/batch_normalization_9/batchnorm/ReadVariableOp',
#  'generator/conv1d_11/kernel/Read/ReadVariableOp',
#  'generator/conv1d_11/bias/Read/ReadVariableOp',
#  'generator/conv1d_11/conv1d/ExpandDims_1/ReadVariableOp',
#  'generator/conv1d_11/BiasAdd/ReadVariableOp',
#  'generator/batch_normalization_10/gamma/Read/ReadVariableOp',
#  'generator/batch_normalization_10/moving_mean/Read/ReadVariableOp',
#  'generator/batch_normalization_10/moving_variance/Read/ReadVariableOp',
#  'generator/batch_normalization_10/batchnorm/mul/ReadVariableOp',
#  'generator/batch_normalization_10/batchnorm/ReadVariableOp',
#  'generator/p_re_lu_6/alpha/Read/ReadVariableOp',
#  'generator/p_re_lu_6/ReadVariableOp',
#  'generator/conv1d_12/kernel/Read/ReadVariableOp',
#  'generator/conv1d_12/bias/Read/ReadVariableOp',
#  'generator/conv1d_12/conv1d/ExpandDims_1/ReadVariableOp',
#  'generator/conv1d_12/BiasAdd/ReadVariableOp',
#  'generator/batch_normalization_11/gamma/Read/ReadVariableOp',
#  'generator/batch_normalization_11/moving_mean/Read/ReadVariableOp',
#  'generator/batch_normalization_11/moving_variance/Read/ReadVariableOp',
#  'generator/batch_normalization_11/batchnorm/mul/ReadVariableOp',
#  'generator/batch_normalization_11/batchnorm/ReadVariableOp',
#  'generator/conv1d_13/kernel/Read/ReadVariableOp',
#  'generator/conv1d_13/bias/Read/ReadVariableOp',
#  'generator/conv1d_13/conv1d/ExpandDims_1/ReadVariableOp',
#  'generator/conv1d_13/BiasAdd/ReadVariableOp',
#  'generator/batch_normalization_12/gamma/Read/ReadVariableOp',
#  'generator/batch_normalization_12/moving_mean/Read/ReadVariableOp',
#  'generator/batch_normalization_12/moving_variance/Read/ReadVariableOp',
#  'generator/batch_normalization_12/batchnorm/mul/ReadVariableOp',
#  'generator/batch_normalization_12/batchnorm/ReadVariableOp',
#  'generator/p_re_lu_7/alpha/Read/ReadVariableOp',
#  'generator/p_re_lu_7/ReadVariableOp',
#  'generator/conv1d_14/kernel/Read/ReadVariableOp',
#  'generator/conv1d_14/bias/Read/ReadVariableOp',
#  'generator/conv1d_14/conv1d/ExpandDims_1/ReadVariableOp',
#  'generator/conv1d_14/BiasAdd/ReadVariableOp',
#  'generator/batch_normalization_13/gamma/Read/ReadVariableOp',
#  'generator/batch_normalization_13/moving_mean/Read/ReadVariableOp',
#  'generator/batch_normalization_13/moving_variance/Read/ReadVariableOp',
#  'generator/batch_normalization_13/batchnorm/mul/ReadVariableOp',
#  'generator/batch_normalization_13/batchnorm/ReadVariableOp',
#  'generator/conv1d_15/kernel/Read/ReadVariableOp',
#  'generator/conv1d_15/bias/Read/ReadVariableOp',
#  'generator/conv1d_15/conv1d/ExpandDims_1/ReadVariableOp',
#  'generator/conv1d_15/BiasAdd/ReadVariableOp',
#  'generator/batch_normalization_14/gamma/Read/ReadVariableOp',
#  'generator/batch_normalization_14/moving_mean/Read/ReadVariableOp',
#  'generator/batch_normalization_14/moving_variance/Read/ReadVariableOp',
#  'generator/batch_normalization_14/batchnorm/mul/ReadVariableOp',
#  'generator/batch_normalization_14/batchnorm/ReadVariableOp',
#  'generator/p_re_lu_8/alpha/Read/ReadVariableOp',
#  'generator/p_re_lu_8/ReadVariableOp',
#  'generator/conv1d_16/kernel/Read/ReadVariableOp',
#  'generator/conv1d_16/bias/Read/ReadVariableOp',
#  'generator/conv1d_16/conv1d/ExpandDims_1/ReadVariableOp',
#  'generator/conv1d_16/BiasAdd/ReadVariableOp',
#  'generator/batch_normalization_15/gamma/Read/ReadVariableOp',
#  'generator/batch_normalization_15/moving_mean/Read/ReadVariableOp',
#  'generator/batch_normalization_15/moving_variance/Read/ReadVariableOp',
#  'generator/batch_normalization_15/batchnorm/mul/ReadVariableOp',
#  'generator/batch_normalization_15/batchnorm/ReadVariableOp',
#  'generator/conv1d_17/kernel/Read/ReadVariableOp',
#  'generator/conv1d_17/bias/Read/ReadVariableOp',
#  'generator/conv1d_17/conv1d/ExpandDims_1/ReadVariableOp',
#  'generator/conv1d_17/BiasAdd/ReadVariableOp',
#  'generator/batch_normalization_16/gamma/Read/ReadVariableOp',
#  'generator/batch_normalization_16/moving_mean/Read/ReadVariableOp',
#  'generator/batch_normalization_16/moving_variance/Read/ReadVariableOp',
#  'generator/batch_normalization_16/batchnorm/mul/ReadVariableOp',
#  'generator/batch_normalization_16/batchnorm/ReadVariableOp',
#  'generator/p_re_lu_9/alpha/Read/ReadVariableOp',
#  'generator/p_re_lu_9/ReadVariableOp',
#  'generator/conv1d_18/kernel/Read/ReadVariableOp',
#  'generator/conv1d_18/bias/Read/ReadVariableOp',
#  'generator/conv1d_18/conv1d/ExpandDims_1/ReadVariableOp',
#  'generator/conv1d_18/BiasAdd/ReadVariableOp',
#  'generator/batch_normalization_17/gamma/Read/ReadVariableOp',
#  'generator/batch_normalization_17/moving_mean/Read/ReadVariableOp',
#  'generator/batch_normalization_17/moving_variance/Read/ReadVariableOp',
#  'generator/batch_normalization_17/batchnorm/mul/ReadVariableOp',
#  'generator/batch_normalization_17/batchnorm/ReadVariableOp',
#  'generator/conv1d_19/kernel/Read/ReadVariableOp',
#  'generator/conv1d_19/bias/Read/ReadVariableOp',
#  'generator/conv1d_19/conv1d/ExpandDims_1/ReadVariableOp',
#  'generator/conv1d_19/BiasAdd/ReadVariableOp',
#  'generator/batch_normalization_18/gamma/Read/ReadVariableOp',
#  'generator/batch_normalization_18/moving_mean/Read/ReadVariableOp',
#  'generator/batch_normalization_18/moving_variance/Read/ReadVariableOp',
#  'generator/batch_normalization_18/batchnorm/mul/ReadVariableOp',
#  'generator/batch_normalization_18/batchnorm/ReadVariableOp',
#  'generator/p_re_lu_10/alpha/Read/ReadVariableOp',
#  'generator/p_re_lu_10/ReadVariableOp',
#  'generator/conv1d_20/kernel/Read/ReadVariableOp',
#  'generator/conv1d_20/bias/Read/ReadVariableOp',
#  'generator/conv1d_20/conv1d/ExpandDims_1/ReadVariableOp',
#  'generator/conv1d_20/BiasAdd/ReadVariableOp',
#  'generator/batch_normalization_19/gamma/Read/ReadVariableOp',
#  'generator/batch_normalization_19/moving_mean/Read/ReadVariableOp',
#  'generator/batch_normalization_19/moving_variance/Read/ReadVariableOp',
#  'generator/batch_normalization_19/batchnorm/mul/ReadVariableOp',
#  'generator/batch_normalization_19/batchnorm/ReadVariableOp',
#  'generator/conv1d_21/kernel/Read/ReadVariableOp',
#  'generator/conv1d_21/bias/Read/ReadVariableOp',
#  'generator/conv1d_21/conv1d/ExpandDims_1/ReadVariableOp',
#  'generator/conv1d_21/BiasAdd/ReadVariableOp',
#  'generator/batch_normalization_20/gamma/Read/ReadVariableOp',
#  'generator/batch_normalization_20/moving_mean/Read/ReadVariableOp',
#  'generator/batch_normalization_20/moving_variance/Read/ReadVariableOp',
#  'generator/batch_normalization_20/batchnorm/mul/ReadVariableOp',
#  'generator/batch_normalization_20/batchnorm/ReadVariableOp',
#  'generator/p_re_lu_11/alpha/Read/ReadVariableOp',
#  'generator/p_re_lu_11/ReadVariableOp',
#  'generator/conv1d_22/kernel/Read/ReadVariableOp',
#  'generator/conv1d_22/bias/Read/ReadVariableOp',
#  'generator/conv1d_22/conv1d/ExpandDims_1/ReadVariableOp',
#  'generator/conv1d_22/BiasAdd/ReadVariableOp',
#  'generator/batch_normalization_21/gamma/Read/ReadVariableOp',
#  'generator/batch_normalization_21/moving_mean/Read/ReadVariableOp',
#  'generator/batch_normalization_21/moving_variance/Read/ReadVariableOp',
#  'generator/batch_normalization_21/batchnorm/mul/ReadVariableOp',
#  'generator/batch_normalization_21/batchnorm/ReadVariableOp',
#  'generator/conv1d_23/kernel/Read/ReadVariableOp',
#  'generator/conv1d_23/bias/Read/ReadVariableOp',
#  'generator/conv1d_23/conv1d/ExpandDims_1/ReadVariableOp',
#  'generator/conv1d_23/BiasAdd/ReadVariableOp',
#  'generator/batch_normalization_22/gamma/Read/ReadVariableOp',
#  'generator/batch_normalization_22/moving_mean/Read/ReadVariableOp',
#  'generator/batch_normalization_22/moving_variance/Read/ReadVariableOp',
#  'generator/batch_normalization_22/batchnorm/mul/ReadVariableOp',
#  'generator/batch_normalization_22/batchnorm/ReadVariableOp',
#  'generator/p_re_lu_12/alpha/Read/ReadVariableOp',
#  'generator/p_re_lu_12/ReadVariableOp',
#  'generator/conv1d_24/kernel/Read/ReadVariableOp',
#  'generator/conv1d_24/bias/Read/ReadVariableOp',
#  'generator/conv1d_24/conv1d/ExpandDims_1/ReadVariableOp',
#  'generator/conv1d_24/BiasAdd/ReadVariableOp',
#  'generator/batch_normalization_23/gamma/Read/ReadVariableOp',
#  'generator/batch_normalization_23/moving_mean/Read/ReadVariableOp',
#  'generator/batch_normalization_23/moving_variance/Read/ReadVariableOp',
#  'generator/batch_normalization_23/batchnorm/mul/ReadVariableOp',
#  'generator/batch_normalization_23/batchnorm/ReadVariableOp',
#  'generator/conv1d_25/kernel/Read/ReadVariableOp',
#  'generator/conv1d_25/bias/Read/ReadVariableOp',
#  'generator/conv1d_25/conv1d/ExpandDims_1/ReadVariableOp',
#  'generator/conv1d_25/BiasAdd/ReadVariableOp',
#  'generator/batch_normalization_24/gamma/Read/ReadVariableOp',
#  'generator/batch_normalization_24/moving_mean/Read/ReadVariableOp',
#  'generator/batch_normalization_24/moving_variance/Read/ReadVariableOp',
#  'generator/batch_normalization_24/batchnorm/mul/ReadVariableOp',
#  'generator/batch_normalization_24/batchnorm/ReadVariableOp',
#  'generator/p_re_lu_13/alpha/Read/ReadVariableOp',
#  'generator/p_re_lu_13/ReadVariableOp',
#  'generator/conv1d_26/kernel/Read/ReadVariableOp',
#  'generator/conv1d_26/bias/Read/ReadVariableOp',
#  'generator/conv1d_26/conv1d/ExpandDims_1/ReadVariableOp',
#  'generator/conv1d_26/BiasAdd/ReadVariableOp',
#  'generator/batch_normalization_25/gamma/Read/ReadVariableOp',
#  'generator/batch_normalization_25/moving_mean/Read/ReadVariableOp',
#  'generator/batch_normalization_25/moving_variance/Read/ReadVariableOp',
#  'generator/batch_normalization_25/batchnorm/mul/ReadVariableOp',
#  'generator/batch_normalization_25/batchnorm/ReadVariableOp',
#  'generator/conv1d_27/kernel/Read/ReadVariableOp',
#  'generator/conv1d_27/bias/Read/ReadVariableOp',
#  'generator/conv1d_27/conv1d/ExpandDims_1/ReadVariableOp',
#  'generator/conv1d_27/BiasAdd/ReadVariableOp',
#  'generator/batch_normalization_26/gamma/Read/ReadVariableOp',
#  'generator/batch_normalization_26/moving_mean/Read/ReadVariableOp',
#  'generator/batch_normalization_26/moving_variance/Read/ReadVariableOp',
#  'generator/batch_normalization_26/batchnorm/mul/ReadVariableOp',
#  'generator/batch_normalization_26/batchnorm/ReadVariableOp',
#  'generator/p_re_lu_14/alpha/Read/ReadVariableOp',
#  'generator/p_re_lu_14/ReadVariableOp',
#  'generator/conv1d_28/kernel/Read/ReadVariableOp',
#  'generator/conv1d_28/bias/Read/ReadVariableOp',
#  'generator/conv1d_28/conv1d/ExpandDims_1/ReadVariableOp',
#  'generator/conv1d_28/BiasAdd/ReadVariableOp',
#  'generator/batch_normalization_27/gamma/Read/ReadVariableOp',
#  'generator/batch_normalization_27/moving_mean/Read/ReadVariableOp',
#  'generator/batch_normalization_27/moving_variance/Read/ReadVariableOp',
#  'generator/batch_normalization_27/batchnorm/mul/ReadVariableOp',
#  'generator/batch_normalization_27/batchnorm/ReadVariableOp',
#  'generator/conv1d_29/kernel/Read/ReadVariableOp',
#  'generator/conv1d_29/bias/Read/ReadVariableOp',
#  'generator/conv1d_29/conv1d/ExpandDims_1/ReadVariableOp',
#  'generator/conv1d_29/BiasAdd/ReadVariableOp',
#  'generator/batch_normalization_28/gamma/Read/ReadVariableOp',
#  'generator/batch_normalization_28/moving_mean/Read/ReadVariableOp',
#  'generator/batch_normalization_28/moving_variance/Read/ReadVariableOp',
#  'generator/batch_normalization_28/batchnorm/mul/ReadVariableOp',
#  'generator/batch_normalization_28/batchnorm/ReadVariableOp',
#  'generator/p_re_lu_15/alpha/Read/ReadVariableOp',
#  'generator/p_re_lu_15/ReadVariableOp',
#  'generator/conv1d_30/kernel/Read/ReadVariableOp',
#  'generator/conv1d_30/bias/Read/ReadVariableOp',
#  'generator/conv1d_30/conv1d/ExpandDims_1/ReadVariableOp',
#  'generator/conv1d_30/BiasAdd/ReadVariableOp',
#  'generator/batch_normalization_29/gamma/Read/ReadVariableOp',
#  'generator/batch_normalization_29/moving_mean/Read/ReadVariableOp',
#  'generator/batch_normalization_29/moving_variance/Read/ReadVariableOp',
#  'generator/batch_normalization_29/batchnorm/mul/ReadVariableOp',
#  'generator/batch_normalization_29/batchnorm/ReadVariableOp',
#  'generator/conv1d_31/kernel/Read/ReadVariableOp',
#  'generator/conv1d_31/bias/Read/ReadVariableOp',
#  'generator/conv1d_31/conv1d/ExpandDims_1/ReadVariableOp',
#  'generator/conv1d_31/BiasAdd/ReadVariableOp',
#  'generator/batch_normalization_30/gamma/Read/ReadVariableOp',
#  'generator/batch_normalization_30/moving_mean/Read/ReadVariableOp',
#  'generator/batch_normalization_30/moving_variance/Read/ReadVariableOp',
#  'generator/batch_normalization_30/batchnorm/mul/ReadVariableOp',
#  'generator/batch_normalization_30/batchnorm/ReadVariableOp',
#  'generator/p_re_lu_16/alpha/Read/ReadVariableOp',
#  'generator/p_re_lu_16/ReadVariableOp',
#  'generator/conv1d_32/kernel/Read/ReadVariableOp',
#  'generator/conv1d_32/bias/Read/ReadVariableOp',
#  'generator/conv1d_32/conv1d/ExpandDims_1/ReadVariableOp',
#  'generator/conv1d_32/BiasAdd/ReadVariableOp',
#  'generator/batch_normalization_31/gamma/Read/ReadVariableOp',
#  'generator/batch_normalization_31/moving_mean/Read/ReadVariableOp',
#  'generator/batch_normalization_31/moving_variance/Read/ReadVariableOp',
#  'generator/batch_normalization_31/batchnorm/mul/ReadVariableOp',
#  'generator/batch_normalization_31/batchnorm/ReadVariableOp',
#  'generator/conv1d_33/kernel/Read/ReadVariableOp',
#  'generator/conv1d_33/bias/Read/ReadVariableOp',
#  'generator/conv1d_33/conv1d/ExpandDims_1/ReadVariableOp',
#  'generator/conv1d_33/BiasAdd/ReadVariableOp',
#  'generator/batch_normalization_32/gamma/Read/ReadVariableOp',
#  'generator/batch_normalization_32/moving_mean/Read/ReadVariableOp',
#  'generator/batch_normalization_32/moving_variance/Read/ReadVariableOp',
#  'generator/batch_normalization_32/batchnorm/mul/ReadVariableOp',
#  'generator/batch_normalization_32/batchnorm/ReadVariableOp',
#  'generator/conv1d_34/kernel/Read/ReadVariableOp',
#  'generator/conv1d_34/bias/Read/ReadVariableOp',
#  'generator/conv1d_34/conv1d/ExpandDims_1/ReadVariableOp',
#  'generator/conv1d_34/BiasAdd/ReadVariableOp',
#  'generator/p_re_lu_17/alpha/Read/ReadVariableOp',
#  'generator/p_re_lu_17/ReadVariableOp',
#  'generator/conv1d_35/kernel/Read/ReadVariableOp',
#  'generator/conv1d_35/bias/Read/ReadVariableOp',
#  'generator/conv1d_35/conv1d/ExpandDims_1/ReadVariableOp',
#  'generator/conv1d_35/BiasAdd/ReadVariableOp',
#  'generator/p_re_lu_18/alpha/Read/ReadVariableOp',
#  'generator/p_re_lu_18/ReadVariableOp',
#  'generator/conv1d_36/kernel/Read/ReadVariableOp',
#  'generator/conv1d_36/bias/Read/ReadVariableOp',
#  'generator/conv1d_36/conv1d/ExpandDims_1/ReadVariableOp',
#  'generator/conv1d_36/BiasAdd/ReadVariableOp',
#  'logits']

# %%
def freeze_graph(model_dir, output_node_names):

    if not tf.gfile.Exists(model_dir):
        raise AssertionError(
            "Export directory doesn't exists. Please specify an export "
            'directory: %s' % model_dir
        )

    checkpoint = tf.train.get_checkpoint_state(model_dir)
    input_checkpoint = checkpoint.model_checkpoint_path

    absolute_model_dir = '/'.join(input_checkpoint.split('/')[:-1])
    output_graph = absolute_model_dir + '/frozen_model.pb'
    clear_devices = True
    with tf.Session(graph = tf.Graph()) as sess:
        saver = tf.train.import_meta_graph(
            input_checkpoint + '.meta', clear_devices = clear_devices
        )
        saver.restore(sess, input_checkpoint)
        output_graph_def = tf.graph_util.convert_variables_to_constants(
            sess,
            tf.get_default_graph().as_graph_def(),
            output_node_names.split(','),
        )
        with tf.gfile.GFile(output_graph, 'wb') as f:
            f.write(output_graph_def.SerializeToString())
        print('%d ops in the final graph.' % len(output_graph_def.node))

# %%
freeze_graph('srgan-128-output', strings)
# Out:
# INFO:tensorflow:Restoring parameters from srgan-128-output/model.ckpt
# WARNING:tensorflow:From <ipython-input-25-9a7215a4e58a>:23: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# WARNING:tensorflow:From /home/husein/.local/lib/python3.6/site-packages/tensorflow_core/python/framework/graph_util_impl.py:277: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# INFO:tensorflow:Froze 225 variables.
# INFO:tensorflow:Converted 225 variables to const ops.
# 1568 ops in the final graph.

# %%
def load_graph(frozen_graph_filename, **kwargs):
    with tf.gfile.GFile(frozen_graph_filename, 'rb') as f:
        graph_def = tf.GraphDef()
        graph_def.ParseFromString(f.read())

    # https://github.com/onnx/tensorflow-onnx/issues/77#issuecomment-445066091
    # to fix import T5
    for node in graph_def.node:
        if node.op == 'RefSwitch':
            node.op = 'Switch'
            for index in xrange(len(node.input)):
                if 'moving_' in node.input[index]:
                    node.input[index] = node.input[index] + '/read'
        elif node.op == 'AssignSub':
            node.op = 'Sub'
            if 'use_locking' in node.attr:
                del node.attr['use_locking']
        elif node.op == 'AssignAdd':
            node.op = 'Add'
            if 'use_locking' in node.attr:
                del node.attr['use_locking']
        elif node.op == 'Assign':
            node.op = 'Identity'
            if 'use_locking' in node.attr:
                del node.attr['use_locking']
            if 'validate_shape' in node.attr:
                del node.attr['validate_shape']
            if len(node.input) == 2:
                node.input[0] = node.input[1]
                del node.input[1]

    with tf.Graph().as_default() as graph:
        tf.import_graph_def(graph_def)
    return graph

# %%
g = load_graph('srgan-128-output/frozen_model.pb')
x = g.get_tensor_by_name('import/Placeholder:0')
logits = g.get_tensor_by_name('import/logits:0')

# %%
test_sess = tf.InteractiveSession(graph = g)

# %%
y_ = test_sess.run(logits, feed_dict = {x: l})

# %%
ipd.Audio(y_, rate = sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from tensorflow.tools.graph_transforms import TransformGraph

pb = 'srgan-128-output/frozen_model.pb'

transforms = ['add_default_attributes',
             'remove_nodes(op=Identity, op=CheckNumerics)',
             'fold_batch_norms',
             'fold_old_batch_norms',
             'quantize_weights(fallback_min=-1024, fallback_max=1024)',
             'strip_unused_nodes',
             'sort_by_execution_order']

input_graph_def = tf.GraphDef()
with tf.gfile.FastGFile(pb, 'rb') as f:
    input_graph_def.ParseFromString(f.read())

transformed_graph_def = TransformGraph(input_graph_def, 
                                           ['Placeholder'],
                                           ['logits'], transforms)
    
with tf.gfile.GFile(f'{pb}.quantized', 'wb') as f:
    f.write(transformed_graph_def.SerializeToString())
# Out:
# WARNING:tensorflow:From <ipython-input-32-acdb9aca8764>:14: FastGFile.__init__ (from tensorflow.python.platform.gfile) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.gfile.GFile.

# %%
g = load_graph('srgan-128-output/frozen_model.pb.quantized')
x = g.get_tensor_by_name('import/Placeholder:0')
logits = g.get_tensor_by_name('import/logits:0')
test_sess = tf.InteractiveSession(graph = g)

# %%
y_ = test_sess.run(logits, feed_dict = {x: l})
ipd.Audio(y_, rate = sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
