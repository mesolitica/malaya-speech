# %%
import os
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '/home/ubuntu/mesolitica-tpu.json'

# %%
import tensorflow as tf
from malaya_speech.utils import subword

subwords = subword.load('transducer-singlish.subword')
# Out:
# /home/ubuntu/.local/lib/python3.7/site-packages/malaya_boilerplate/frozen_graph.py:25: UserWarning: Cannot import beam_search_ops from Tensorflow Addons, `deep_model` for stemmer will not available to use, make sure Tensorflow Addons version >= 0.12.0
#   'Cannot import beam_search_ops from Tensorflow Addons, `deep_model` for stemmer will not available to use, make sure Tensorflow Addons version >= 0.12.0'

# %%
import string

char_vocabs = [''] + list(string.ascii_lowercase + string.digits) + [' ']

# %%
files = tf.compat.v1.gfile.Glob('gs://mesolitica-tpu-general/imda/*/*.tfrecord')

# %%
sr = 16000
maxlen = 18
maxlen_subwords = 100
minlen_text = 1
global_count = 0

# %%
from google.cloud import storage
import numpy as np
import six

def to_example(dictionary):
    """Helper: build tf.Example from (string -> int/float/str list) dictionary."""
    features = {}
    for (k, v) in six.iteritems(dictionary):
        if not v:
            raise ValueError('Empty generated field: %s' % str((k, v)))
        # Subtly in PY2 vs PY3, map is not scriptable in py3. As a result,
        # map objects will fail with TypeError, unless converted to a list.
        if six.PY3 and isinstance(v, map):
            v = list(v)
        if isinstance(v[0], six.integer_types) or np.issubdtype(
            type(v[0]), np.integer
        ):
            features[k] = tf.train.Feature(
                int64_list=tf.train.Int64List(value=v)
            )
        elif isinstance(v[0], float):
            features[k] = tf.train.Feature(
                float_list=tf.train.FloatList(value=v)
            )
        elif isinstance(v[0], six.string_types):
            if not six.PY2:  # Convert in python 3.
                v = [bytes(x, 'utf-8') for x in v]
            features[k] = tf.train.Feature(
                bytes_list=tf.train.BytesList(value=v)
            )
        elif isinstance(v[0], bytes):
            features[k] = tf.train.Feature(
                bytes_list=tf.train.BytesList(value=v)
            )
        else:
            raise ValueError(
                'Value for %s is not a recognized type; v: %s type: %s'
                % (k, str(v[0]), str(type(v[0])))
            )
    return tf.train.Example(features=tf.train.Features(feature=features))

# %%
def parse(serialized_example):

    data_fields = {
        'waveforms': tf.compat.v1.VarLenFeature(tf.float32),
        'targets': tf.compat.v1.VarLenFeature(tf.int64),
        'targets_length': tf.compat.v1.VarLenFeature(tf.int64),
    }
    features = tf.compat.v1.parse_single_example(
        serialized_example, features=data_fields
    )
    for k in features.keys():
        features[k] = features[k].values
    return features

# %%
from tqdm import tqdm

def parse(serialized_example):

    data_fields = {
        'waveforms': tf.compat.v1.VarLenFeature(tf.float32),
        'targets': tf.compat.v1.VarLenFeature(tf.int64),
        'targets_length': tf.compat.v1.VarLenFeature(tf.int64),
    }
    features = tf.compat.v1.parse_single_example(
        serialized_example, features=data_fields
    )
    for k in features.keys():
        features[k] = features[k].values
    return features

def loop(files):
    client = storage.Client()
    bucket = client.bucket('mesolitica-tpu-general')
    files, index = files
    output_file = f'{index}-{global_count}.tfrecord'
    writer = tf.io.TFRecordWriter(output_file)
    
    d = tf.data.TFRecordDataset(files)
    d = d.map(parse, num_parallel_calls=20)
    d = d.filter(
        lambda x: tf.less(tf.shape(x['waveforms'])[0] / sr, maxlen)
    )
    d = d.filter(
        lambda x: tf.less(tf.shape(x['targets'])[0], maxlen_subwords)
    )
    d = d.as_numpy_iterator()
    for r in tqdm(d):
        t = subword.decode(subwords, r['targets'])
        new_t = [char_vocabs.index(c) for c in t]
        example = to_example({'waveforms': r['waveforms'].tolist(), 
                              'targets': new_t, 
                              'targets_length': [len(new_t)],
                             'lang': [1]})
        writer.write(example.SerializeToString())
    
    writer.close()
    blob = bucket.blob(f'singlish/{output_file}')
    blob.upload_from_filename(output_file)
    os.system(f'rm {output_file}')

# %%
import mp

# %%
batch_size = 8
for i in range(0, len(files), batch_size):
    batch = files[i: i + batch_size]
    mp.multiprocessing(batch, loop, cores = len(batch), returned = False)
    global_count += 1
# Out:
# 2466it [01:43, 19.29it/s]
# 4166it [02:27, 28.17it/s]
# 4166it [02:28, 27.96it/s]
# 4166it [02:31, 27.44it/s]
# 4166it [02:36, 26.58it/s]
# 4166it [02:39, 26.14it/s]
# 4166it [02:43, 25.44it/s]
# 4141it [02:48, 24.53it/s]
# 3553it [02:07, 36.83it/s]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 4166it [02:26, 28.37it/s]
# 4166it [02:27, 28.23it/s]
# 4166it [02:30, 27.59it/s]
# 4166it [02:34, 26.95it/s]
# 4166it [02:34, 26.94it/s]
# 4166it [02:35, 26.76it/s]
# 4166it [02:36, 26.63it/s]
# 4166it [02:41, 25.72it/s]
# 985it [00:36, 26.71it/s]]
# 4166it [02:21, 29.53it/s]
# 4166it [02:23, 29.04it/s]
# 4166it [02:25, 28.63it/s]
# 4166it [02:29, 27.79it/s]
# 4166it [02:31, 27.51it/s]
# 4166it [02:34, 26.92it/s]
# 4164it [02:37, 26.44it/s]
# 3950it [02:27, 34.55it/s]
# 4166it [02:31, 27.57it/s]
# 3949it [02:31, 45.88it/s]
# 4166it [02:32, 27.28it/s]
# 4166it [02:32, 27.23it/s]
# 4166it [02:37, 26.49it/s]
# 4166it [02:39, 26.06it/s]
# 4166it [02:41, 25.78it/s]
# 4166it [02:24, 28.76it/s]
# 4166it [02:25, 28.56it/s]
# 4166it [02:26, 28.52it/s]
# 4166it [02:30, 27.60it/s]
# 4164it [02:33, 27.06it/s]
# 4166it [02:36, 26.63it/s]
# 4166it [02:39, 26.17it/s]
# 4166it [02:40, 25.92it/s]
# 985it [00:39, 24.78it/s]]
# 2195it [01:21, 41.37it/s]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 4it [00:01,  2.13it/s]/s]
# 4it [00:02,  1.89it/s]
# 4it [00:02,  1.83it/s]
# 4it [00:02,  1.80it/s]
#
# 4it [00:02,  1.72it/s]
#
# 4it [00:02,  1.74it/s]
# 4it [00:02,  1.82it/s]
# 4it [00:02,  1.81it/s]
# 4it [00:02,  1.82it/s]
# 4it [00:02,  1.80it/s]
# 4it [00:02,  1.79it/s]
# 4it [00:02,  1.74it/s]
# 4it [00:02,  1.73it/s]
# 4it [00:03,  1.30it/s]
# 4it [00:02,  1.86it/s]
# 4it [00:02,  1.81it/s]
# 4it [00:02,  1.83it/s]
#
# 4it [00:02,  1.79it/s]
# 4it [00:02,  1.75it/s]
# 4it [00:02,  1.74it/s]
# 4it [00:02,  1.73it/s]
# 4it [00:02,  1.78it/s]
# 2638it [01:21, 68.11it/s]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 2423it [01:34,  2.57it/s]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 2290it [01:13, 59.00it/s]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 3071it [01:29, 29.35it/s]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 4166it [02:01, 34.38it/s]
# 4166it [02:07, 32.71it/s]
# 4166it [02:07, 32.56it/s]
# 4166it [02:12, 31.47it/s]
# 4166it [02:14, 30.89it/s]
# 4166it [02:15, 30.81it/s]
# 4166it [02:15, 30.80it/s]
# 4163it [02:15, 30.76it/s]
# 110it [00:04, 23.28it/s]
# 2882it [01:23, 57.08it/s]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 3277it [01:45, 35.22it/s]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 2854it [01:27, 10.12it/s]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 4166it [02:12, 31.54it/s]
# 4166it [02:13, 31.26it/s]
# 4165it [02:13, 31.21it/s]
# 3682it [01:50, 43.27it/s]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 1309it [00:38, 17.29it/s]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 4166it [01:52, 37.14it/s]
# 4166it [01:58, 35.01it/s]
# 4166it [01:59, 34.95it/s]
# 4166it [02:02, 34.06it/s]
# 4166it [02:05, 33.25it/s]
# 4166it [02:05, 33.21it/s]
# 4166it [02:06, 32.94it/s]
# 1319it [00:40, 65.68it/s]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 4166it [01:57, 35.41it/s]
# 4166it [02:03, 33.61it/s]
# 4166it [02:06, 32.90it/s]
# 4166it [02:07, 32.57it/s]
# 4166it [02:09, 32.15it/s]
# 4165it [02:11, 31.74it/s]
# 4165it [02:11, 31.72it/s]
# 4166it [02:12, 31.51it/s]
# 414it [00:17, 37.90it/s]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 4166it [02:05, 33.24it/s]
# 4166it [02:07, 32.58it/s]
# 4166it [02:10, 32.04it/s]
# 4166it [02:10, 31.94it/s]
# 4166it [02:11, 31.76it/s]
# 4166it [02:12, 31.55it/s]
# 4166it [02:15, 30.80it/s]
# 4166it [02:17, 30.34it/s]
# 4166it [02:06, 33.04it/s]
# 4166it [02:06, 32.89it/s]
# 4166it [02:08, 32.41it/s]
# 3810it [02:09, 29.37it/s]
# 4166it [02:13, 31.15it/s]
# 4166it [02:15, 30.79it/s]
# 4166it [02:15, 30.64it/s]
# 4165it [02:17, 30.24it/s]
# 110it [00:04, 23.17it/s]
# 4166it [01:56, 35.88it/s]
# 4166it [01:56, 35.73it/s]
# 4165it [01:57, 35.45it/s]
# 4166it [01:59, 34.88it/s]
# 4165it [02:03, 33.70it/s]
# 4164it [02:04, 33.37it/s]
# 4166it [02:08, 32.35it/s]
# 4165it [02:06, 32.92it/s]
# 4160it [02:08, 47.56it/s]
# 4166it [02:08, 32.34it/s]
# 4166it [02:08, 32.31it/s]
# 4166it [02:10, 31.82it/s]
# 4166it [02:14, 31.01it/s]
# 4166it [02:14, 30.92it/s]
# 4166it [02:18, 30.10it/s]
# 4166it [01:59, 34.94it/s]
# 4166it [02:01, 34.17it/s]
# 4166it [02:07, 32.69it/s]
# 4165it [02:07, 32.60it/s]
# 4166it [02:09, 32.29it/s]
# 4165it [02:09, 32.07it/s]
# 4166it [02:13, 31.17it/s]
# 4163it [02:18, 29.99it/s]
# 1903it [01:11, 55.24it/s]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 4166it [02:04, 33.49it/s]
# 4166it [02:08, 32.48it/s]
# 3949it [02:12, 56.33it/s]
# 4166it [02:12, 31.38it/s]
# 4166it [02:13, 31.28it/s]
# 4166it [02:14, 30.97it/s]
# 4166it [02:14, 30.88it/s]
# 4166it [02:18, 30.01it/s]
# 110it [00:04, 25.22it/s]
# 1279it [00:41, 58.30it/s]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 3972it [01:55, 17.58it/s]
# 3912it [01:57, 45.97it/s]
# 4166it [01:59, 34.75it/s]
# 4166it [02:00, 34.65it/s]
# 4164it [02:02, 33.88it/s]
# 4165it [02:03, 33.82it/s]
# 4166it [02:09, 32.22it/s]
# 4it [00:02,  1.82it/s]
# 4it [00:02,  1.80it/s]
# 4it [00:02,  1.78it/s]
# 3310it [01:27, 60.85it/s] IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 4165it [01:01, 68.17it/s]
# 3547it [01:08, 60.56it/s]]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 4164it [01:08, 60.44it/s]]
# 4164it [01:11, 58.09it/s]
# 4162it [01:13, 56.75it/s]
# 4165it [01:13, 56.56it/s]
# 4164it [01:14, 56.01it/s]
# 4162it [01:15, 54.78it/s]
# 4162it [01:17, 53.68it/s]
# 4163it [01:18, 53.00it/s]
# 585it [00:16, 62.58it/s] IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 4164it [01:07, 61.35it/s]
# 4165it [01:10, 59.45it/s]
# 4165it [01:10, 59.20it/s]]
# 4164it [01:10, 59.15it/s]]
# 4165it [01:12, 57.54it/s]
# 4166it [01:14, 56.05it/s]
# 4164it [01:14, 55.81it/s]
# 4163it [01:17, 53.65it/s]
# 2133it [00:39, 86.78it/s] IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 4165it [01:13, 56.89it/s]]
# 4165it [01:14, 55.74it/s]
# 4164it [01:15, 55.15it/s]
# 4164it [01:16, 54.47it/s]
# 4164it [01:16, 54.46it/s]
# 4164it [01:16, 54.28it/s]
# 4165it [01:16, 54.21it/s]
# 4165it [01:18, 53.19it/s]
# 4164it [01:07, 61.87it/s]]
# 4162it [01:10, 58.71it/s]
# 4163it [01:11, 58.39it/s]
# 4164it [01:12, 57.51it/s] IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 2769it [00:55, 50.05it/s]
# 4165it [01:14, 56.23it/s]
# 4165it [01:14, 56.04it/s]
# 4163it [01:14, 55.85it/s]
# 4163it [01:14, 55.57it/s]
# 4164it [01:16, 54.74it/s]
# 4165it [01:16, 54.68it/s]
# 4163it [01:16, 54.54it/s]
# 4it [00:02,  1.91it/s]
# 4163it [01:06, 62.39it/s]
# 4164it [01:07, 61.80it/s]
# 4165it [01:07, 61.43it/s]
# 4163it [01:08, 60.97it/s]
# 4024it [01:08, 25.10it/s]
# 4164it [01:08, 60.73it/s]
# 4163it [01:09, 59.96it/s]
# 4it [00:02,  1.88it/s]
#
# 4it [00:02,  1.87it/s]
# 1it [00:02,  2.12s/it]
# 4it [00:02,  1.86it/s]
# 4it [00:02,  1.84it/s]
# 4it [00:02,  1.80it/s]
# 4it [00:02,  1.80it/s]
# 3it [00:02,  1.41it/s]
# 4it [00:02,  1.87it/s]
# 4it [00:02,  1.86it/s]
# 4it [00:02,  1.85it/s]
#
# 4it [00:02,  1.81it/s]
# 4it [00:02,  1.84it/s]
# 4it [00:02,  1.79it/s]
# 4it [00:02,  1.89it/s]
# 1it [00:02,  2.13s/it]
# 4it [00:02,  1.87it/s]
# 4it [00:02,  1.86it/s]
# 4it [00:02,  1.84it/s]
# 4it [00:02,  1.84it/s]
# 4it [00:02,  1.81it/s]
# 4it [00:03,  1.24it/s]
# 4it [00:02,  1.90it/s]
# 4it [00:02,  1.87it/s]
# 4it [00:02,  1.81it/s]
# 739it [00:18, 75.38it/s]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 4067it [01:35, 42.48it/s]
# 4074it [01:35, 42.47it/s]
# 4074it [01:37, 41.70it/s]
# 4062it [01:38, 41.19it/s]]
# 4062it [01:40, 40.51it/s]
# 4046it [01:42, 39.60it/s]]
# 4039it [01:44, 38.49it/s]
# 2114it [00:58, 52.93it/s] IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 4065it [01:38, 41.42it/s]
# 4080it [01:40, 40.76it/s]]
# 4069it [01:40, 40.39it/s]
# 3699it [01:42, 39.89it/s]
# 4067it [01:43, 39.15it/s]
# 4073it [01:45, 38.43it/s]
# 4067it [01:48, 37.63it/s]
# 2155it [00:59, 36.19it/s]
# 3037it [01:19, 59.43it/s] IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 4052it [01:26, 46.79it/s]
# 3798it [01:26, 81.25it/s]
# 4064it [01:28, 46.04it/s]
# 4060it [01:30, 44.93it/s]]
# 4053it [01:30, 44.82it/s]
# 4050it [01:31, 44.05it/s]
# 364it [00:10, 33.31it/s]
# 2831it [01:09, 90.81it/s] IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 3284it [01:19, 60.49it/s] IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 2899it [01:16, 82.42it/s]]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 297it [00:17, 17.31it/s]
# 2344it [01:38, 50.82it/s]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# loop((files[:1], 0))

# %%
# client = storage.Client()
# bucket = client.bucket('mesolitica-tpu-general')

# %%
# output_file = '0-0.tfrecord'
# blob = bucket.blob(f'singlish/{output_file}')
# blob.upload_from_filename(output_file)
# os.system(f'rm {output_file}')
