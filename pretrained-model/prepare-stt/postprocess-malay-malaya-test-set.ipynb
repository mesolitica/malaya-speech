# %%
# !wget https://f000.backblazeb2.com/file/malaya-speech-model/asr-dataset/malay-test.tar.gz
# !wget https://f000.backblazeb2.com/file/malaya-speech-model/asr-dataset/malay-test.json

# %%
# !tar -vzxf malay-test.tar.gz

# %%
import json

with open('malay-test.json') as fopen:
    data = json.load(fopen)

# %%
import malaya
from malaya.text.normalization import cardinal

tokenizer = malaya.tokenizer.Tokenizer(hypen = False, parliament = False, time = False, time_pukul = False,
                                      temperature = False, distance = False, volume = False, duration = False,
                                      weight = False, date = False, money = False)

# %%
def tokenize_and_replace(t):
    tokenized = tokenizer.tokenize(t)
    for i in range(len(tokenized)):
        c = cardinal(tokenized[i])
        if c != tokenized[i]:
            tokenized[i] = c
    return ' '.join(tokenized)

tokenize_and_replace('pada 15 ogos 1940 pihak berikat menyerang perancis selatan serangan ini dipanggil operation dragoon')
# Out:
# 'pada lima belas ogos seribu sembilan ratus empat puluh pihak berikat menyerang perancis selatan serangan ini dipanggil operation dragoon'

# %%
from tqdm import tqdm
import re

new_data = []
for d in tqdm(data):
    processed = tokenize_and_replace(d)
        
    new_data.append({
        'original': d,
        'cleaned': processed,
        'accept': len(processed) and not len(re.findall(r'\d+', processed)),
    })
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 765/765 [00:00<00:00, 47310.46it/s]

# %%
new_data
# Out:
# [{'original': 'tangan aku disentuh lembut',
#   'cleaned': 'tangan aku disentuh lembut',
#   'accept': True},
#  {'original': 'kenapa tidak kita mengusir obummer',
#   'cleaned': 'kenapa tidak kita mengusir obummer',
#   'accept': True},
#  {'original': 'sama kalau kekasih kau ikut jantan lain kan saving duit hantaran 20k kau tu',
#   'cleaned': 'sama kalau kekasih kau ikut jantan lain kan saving duit hantaran 20k kau tu',
#   'accept': False},
#  {'original': 'laki laki bernama andra itu segera mengalihkan pandangannya ke libra kemudian',
#   'cleaned': 'laki laki bernama andra itu segera mengalihkan pandangannya ke libra kemudian',
#   'accept': True},
#  {'original': 'kenapa saya berurusan dengan atheis internet biasanya meninggalkan keputusan yang tidak baik',
#   'cleaned': 'kenapa saya berurusan dengan atheis internet biasanya meninggalkan keputusan yang tidak baik',
#   'accept': True},
#  {'original': 'dan perlukan duit untuk operation dalam kadar segera',
#   'cleaned': 'dan perlukan duit untuk operation dalam kadar segera',
#   'accept': True},
#  {'original': 'tokong adalah bukti bahawa umno tidak ada belas kasihan',
#   'cleaned': 'tokong adalah bukti bahawa umno tidak ada belas kasihan',
#   'accept': True},
#  {'original': 'ditengah tengah nikmatnya aku menyantap makanan bangdik tiba tiba si chef',
#   'cleaned': 'ditengah tengah nikmatnya aku menyantap makanan bangdik tiba tiba si chef',
#   'accept': True},
#  {'original': 'kenapa lelaki lebih bijak daripada gadis dalam setiap aspek',
#   'cleaned': 'kenapa lelaki lebih bijak daripada gadis dalam setiap aspek',
#   'accept': True},
#  {'original': 'waktu siang buka siaran yang anak kau suka',
#   'cleaned': 'waktu siang buka siaran yang anak kau suka',
#   'accept': True},
#  {'original': 'kenapa doktor ezor alaris dapat membunuh seseorang dan berjalan kaki',
#   'cleaned': 'kenapa doktor ezor alaris dapat membunuh seseorang dan berjalan kaki',
#   'accept': True},
#  {'original': 'gue eh sorry maksudnya aku boleh ketawa gak',
#   'cleaned': 'gue eh sorry maksudnya aku boleh ketawa gak',
#   'accept': True},
#  {'original': 'sekiranya saya memanggil polis pada anak gay saya',
#   'cleaned': 'sekiranya saya memanggil polis pada anak gay saya',
#   'accept': True},
#  {'original': 'boleh diubah dengan menambah',
#   'cleaned': 'boleh diubah dengan menambah',
#   'accept': True},
#  {'original': 'menunggu peserta negara lain yang belum tiba serta proses',
#   'cleaned': 'menunggu peserta negara lain yang belum tiba serta proses',
#   'accept': True},
#  {'original': 'sebut perkataan acuan',
#   'cleaned': 'sebut perkataan acuan',
#   'accept': True},
#  {'original': 'adakah untuk menyedut rokok untuk bertaubat walaupun ateis anda',
#   'cleaned': 'adakah untuk menyedut rokok untuk bertaubat walaupun ateis anda',
#   'accept': True},
#  {'original': 'c tudung rambut sama seperti di sektor swasta',
#   'cleaned': 'c tudung rambut sama seperti di sektor swasta',
#   'accept': True},
#  {'original': 'sebelum ini menteri hal ehwal ekonomi datuk seri mohamed azmin ali',
#   'cleaned': 'sebelum ini menteri hal ehwal ekonomi datuk seri mohamed azmin ali',
#   'accept': True},
#  {'original': 'bagaimana orang yahudi cuba mengiklankan akal komuniti mereka',
#   'cleaned': 'bagaimana orang yahudi cuba mengiklankan akal komuniti mereka',
#   'accept': True},
#  {'original': 'akan demokrat membuat kita menjadi rejim komunis',
#   'cleaned': 'akan demokrat membuat kita menjadi rejim komunis',
#   'accept': True},
#  {'original': 'kenapa bengalis begitu bijak daripada kumpulan lain',
#   'cleaned': 'kenapa bengalis begitu bijak daripada kumpulan lain',
#   'accept': True},
#  {'original': 'kenapa tidak akan membatalkan rekodnya terutamanya pulangan cukai',
#   'cleaned': 'kenapa tidak akan membatalkan rekodnya terutamanya pulangan cukai',
#   'accept': True},
#  {'original': 'kenapa orang di utah kasar dan sombong dan mementingkan diri sendiri',
#   'cleaned': 'kenapa orang di utah kasar dan sombong dan mementingkan diri sendiri',
#   'accept': True},
#  {'original': 'kategori negara eropah kategori',
#   'cleaned': 'kategori negara eropah kategori',
#   'accept': True},
#  {'original': 'tolong sebut dermaga',
#   'cleaned': 'tolong sebut dermaga',
#   'accept': True},
#  {'original': 'serta menafikan menjadikannya sebagai asas bagi filem terbitan mereka',
#   'cleaned': 'serta menafikan menjadikannya sebagai asas bagi filem terbitan mereka',
#   'accept': True},
#  {'original': 'kota kinabalu naib presiden warisan junz wong berkata tidak',
#   'cleaned': 'kota kinabalu naib presiden warisan junz wong berkata tidak',
#   'accept': True},
#  {'original': 'mengapa orang amerika afrika sama ada mangsa atau penjenayah',
#   'cleaned': 'mengapa orang amerika afrika sama ada mangsa atau penjenayah',
#   'accept': True},
#  {'original': 'katanya kementeriannya juga sudah melakukan siasatan berhubung perkara',
#   'cleaned': 'katanya kementeriannya juga sudah melakukan siasatan berhubung perkara',
#   'accept': True},
#  {'original': 'ayah saya cikgu sekolah menengah',
#   'cleaned': 'ayah saya cikgu sekolah menengah',
#   'accept': True},
#  {'original': 'dia menundukkan kepala mencari dibawah meja yasmin melihat sebuah gantungan',
#   'cleaned': 'dia menundukkan kepala mencari dibawah meja yasmin melihat sebuah gantungan',
#   'accept': True},
#  {'original': 'aku call tanya ustaz ustaz tanya sampai part ayat mana anak menangis kuat',
#   'cleaned': 'aku call tanya ustaz ustaz tanya sampai part ayat mana anak menangis kuat',
#   'accept': True},
#  {'original': 'dan kajian mendalam oleh pasukan teknikal akan berterusan',
#   'cleaned': 'dan kajian mendalam oleh pasukan teknikal akan berterusan',
#   'accept': True},
#  {'original': 'yasmin sampai dikelas lalu membuka pintu dengan kencang segera dia berlari',
#   'cleaned': 'yasmin sampai dikelas lalu membuka pintu dengan kencang segera dia berlari',
#   'accept': True},
#  {'original': 'dan mesti naik atas',
#   'cleaned': 'dan mesti naik atas',
#   'accept': True},
#  {'original': 'prada juga bekerja sama dengan the humane society',
#   'cleaned': 'prada juga bekerja sama dengan the humane society',
#   'accept': True},
#  {'original': 'yang jernih serta tenang',
#   'cleaned': 'yang jernih serta tenang',
#   'accept': True},
#  {'original': 'dalam kenyataan yang dikeluarkan pejabat menteri pelancongan seni dan budaya hari',
#   'cleaned': 'dalam kenyataan yang dikeluarkan pejabat menteri pelancongan seni dan budaya hari',
#   'accept': True},
#  {'original': 'yas tunggu libra berteriak sekencang mungkin tapi yasmin tak mendengar',
#   'cleaned': 'yas tunggu libra berteriak sekencang mungkin tapi yasmin tak mendengar',
#   'accept': True},
#  {'original': 'adakah orang bertemu sehingga kehilangan keperawanan mereka di sini',
#   'cleaned': 'adakah orang bertemu sehingga kehilangan keperawanan mereka di sini',
#   'accept': True},
#  {'original': 'sudah setengah habis dimakan olehku membuat bangdik menggelengkan kepala',
#   'cleaned': 'sudah setengah habis dimakan olehku membuat bangdik menggelengkan kepala',
#   'accept': True},
#  {'original': 'melihat gambar keseluruhannya adakah orang kulit hitam yang paling tidak terkawal',
#   'cleaned': 'melihat gambar keseluruhannya adakah orang kulit hitam yang paling tidak terkawal',
#   'accept': True},
#  {'original': 'membuat rambutnya kadang terlihat berwarna kemerahan',
#   'cleaned': 'membuat rambutnya kadang terlihat berwarna kemerahan',
#   'accept': True},
#  {'original': 'sebut perkataan aktinoterapi',
#   'cleaned': 'sebut perkataan aktinoterapi',
#   'accept': True},
#  {'original': 'peletakan jawatan presiden abdelaziz bouteflika',
#   'cleaned': 'peletakan jawatan presiden abdelaziz bouteflika',
#   'accept': True},
#  {'original': 'bagaimana saya boleh merayu dengan ibu balu saya',
#   'cleaned': 'bagaimana saya boleh merayu dengan ibu balu saya',
#   'accept': True},
#  {'original': 'mengikuti 2 jam pelajaran bersama pak dadi rasanya libra ingin cepat cepat',
#   'cleaned': 'mengikuti dua jam pelajaran bersama pak dadi rasanya libra ingin cepat cepat',
#   'accept': True},
#  {'original': 'adakah orang kulit putih mempunyai rasa identiti dan budaya yang paling rendah',
#   'cleaned': 'adakah orang kulit putih mempunyai rasa identiti dan budaya yang paling rendah',
#   'accept': True},
#  {'original': 'kenapa lgbt orang peduli tentang label begitu banyak',
#   'cleaned': 'kenapa lgbt orang peduli tentang label begitu banyak',
#   'accept': True},
#  {'original': 'keadaan kini terkawal dan semua pihak berkuasa berkaitan telah dimaklumkan',
#   'cleaned': 'keadaan kini terkawal dan semua pihak berkuasa berkaitan telah dimaklumkan',
#   'accept': True},
#  {'original': 'yasmin terdiam melihat sekeliling sambil mengingat ingat kembali kapan',
#   'cleaned': 'yasmin terdiam melihat sekeliling sambil mengingat ingat kembali kapan',
#   'accept': True},
#  {'original': 'manakala china terdapat radio',
#   'cleaned': 'manakala china terdapat radio',
#   'accept': True},
#  {'original': 'bayangkan sudah lah ibu tunggal anak2 lelaki pulak makin bermasalah ketika itu',
#   'cleaned': 'bayangkan sudah lah ibu tunggal anak2 lelaki pulak makin bermasalah ketika itu',
#   'accept': False},
#  {'original': 'sayangnya rasulullah pada kita',
#   'cleaned': 'sayangnya rasulullah pada kita',
#   'accept': True},
#  {'original': 'libra dan gisel yang baru datang dengan nafas ngos ngosan menatap',
#   'cleaned': 'libra dan gisel yang baru datang dengan nafas ngos ngosan menatap',
#   'accept': True},
#  {'original': 'hari jumaat lepas kerja siap siap untuk nak naik bas ke shah alam',
#   'cleaned': 'hari jumaat lepas kerja siap siap untuk nak naik bas ke shah alam',
#   'accept': True},
#  {'original': 'rafflesia merupakan genus sejenis',
#   'cleaned': 'rafflesia merupakan genus sejenis',
#   'accept': True},
#  {'original': 'adakah orang orang kulit putih di amerika menganggap mereka istimewa',
#   'cleaned': 'adakah orang orang kulit putih di amerika menganggap mereka istimewa',
#   'accept': True},
#  {'original': 'apa yang aku kurang dan kawan aku lebih',
#   'cleaned': 'apa yang aku kurang dan kawan aku lebih',
#   'accept': True},
#  {'original': 'kegirangan seraya mengayun ayunkan kunci motornya',
#   'cleaned': 'kegirangan seraya mengayun ayunkan kunci motornya',
#   'accept': True},
#  {'original': 'pelajaran fisika dan daffa sudah mewajari hal ini libra sudah mulai resah',
#   'cleaned': 'pelajaran fisika dan daffa sudah mewajari hal ini libra sudah mulai resah',
#   'accept': True},
#  {'original': 'adalah cina indonesian atau slogan',
#   'cleaned': 'adalah cina indonesian atau slogan',
#   'accept': True},
#  {'original': 'baru baru ini kesatuan perkhidmatan perguruan kebangsaan semenanjung malaysia nutp',
#   'cleaned': 'baru baru ini kesatuan perkhidmatan perguruan kebangsaan semenanjung malaysia nutp',
#   'accept': True},
#  {'original': 'mengapa bahasa sepanyol masih tidak baik di bahasa inggeris',
#   'cleaned': 'mengapa bahasa sepanyol masih tidak baik di bahasa inggeris',
#   'accept': True},
#  {'original': 'bagaimana anda bengkok dan mengisap asshole anda sendiri',
#   'cleaned': 'bagaimana anda bengkok dan mengisap asshole anda sendiri',
#   'accept': True},
#  {'original': 'assalamualaikum sapa pernah kena tindih',
#   'cleaned': 'assalamualaikum sapa pernah kena tindih',
#   'accept': True},
#  {'original': 'tolong sebut pengertian',
#   'cleaned': 'tolong sebut pengertian',
#   'accept': True},
#  {'original': 'ujarnya dengan nafas yang masih ngos ngosan',
#   'cleaned': 'ujarnya dengan nafas yang masih ngos ngosan',
#   'accept': True},
#  {'original': 'malangnya adrian mendakwa pihak pengurusan tempat itu tidak bersetuju dan berikan',
#   'cleaned': 'malangnya adrian mendakwa pihak pengurusan tempat itu tidak bersetuju dan berikan',
#   'accept': True},
#  {'original': 'libra s pov', 'cleaned': 'libra s pov', 'accept': True},
#  {'original': 'kenapa gadis gadis putih membenci lelaki india',
#   'cleaned': 'kenapa gadis gadis putih membenci lelaki india',
#   'accept': True},
#  {'original': 'bagaimana perogol di india adalah muslim',
#   'cleaned': 'bagaimana perogol di india adalah muslim',
#   'accept': True},
#  {'original': 'dan memasukkan ke dalam tempatnya lalu segera mengemasi barangnya kedalam tas',
#   'cleaned': 'dan memasukkan ke dalam tempatnya lalu segera mengemasi barangnya kedalam tas',
#   'accept': True},
#  {'original': 'terus membenarkan kemasukan perkataan',
#   'cleaned': 'terus membenarkan kemasukan perkataan',
#   'accept': True},
#  {'original': 'ya kamu juga harusnya ngaca dong kamu udah makan berapa kali makanya abang',
#   'cleaned': 'ya kamu juga harusnya ngaca dong kamu udah makan berapa kali makanya abang',
#   'accept': True},
#  {'original': 'paham dah', 'cleaned': 'paham dah', 'accept': True},
#  {'original': 'tolong sebut kemaluan',
#   'cleaned': 'tolong sebut kemaluan',
#   'accept': True},
#  {'original': 'mempunyai tuhan meletakkan jeweh sebagai penguasa dunia moden',
#   'cleaned': 'mempunyai tuhan meletakkan jeweh sebagai penguasa dunia moden',
#   'accept': True},
#  {'original': 'kembali andraku yang dulu',
#   'cleaned': 'kembali andraku yang dulu',
#   'accept': True},
#  {'original': 'mengapa manaphy pergi ke restoran di pokemon',
#   'cleaned': 'mengapa manaphy pergi ke restoran di pokemon',
#   'accept': True},
#  {'original': 'dan dokumen perjalanan bangladesh',
#   'cleaned': 'dan dokumen perjalanan bangladesh',
#   'accept': True},
#  {'original': 'adakah ia baik untuk seorang wanita berumur 12 tahun',
#   'cleaned': 'adakah ia baik untuk seorang wanita berumur dua belas tahun',
#   'accept': True},
#  {'original': 'adakah anda menggunakan sos pasta untuk cabai anda',
#   'cleaned': 'adakah anda menggunakan sos pasta untuk cabai anda',
#   'accept': True},
#  {'original': 'dakwah jugak tu tanpa kita sedar',
#   'cleaned': 'dakwah jugak tu tanpa kita sedar',
#   'accept': True},
#  {'original': 'perut karet gumamnya',
#   'cleaned': 'perut karet gumamnya',
#   'accept': True},
#  {'original': 'lipat yas cepet banget parah gisel duduk di sebuah kursi sambil mengatur',
#   'cleaned': 'lipat yas cepet banget parah gisel duduk di sebuah kursi sambil mengatur',
#   'accept': True},
#  {'original': 'kenapa ada orang yang bertanya soalan mengenai orang bodoh seperti itu',
#   'cleaned': 'kenapa ada orang yang bertanya soalan mengenai orang bodoh seperti itu',
#   'accept': True},
#  {'original': 'bank yang terletak negara',
#   'cleaned': 'bank yang terletak negara',
#   'accept': True},
#  {'original': 'kuno asia tenggara masih',
#   'cleaned': 'kuno asia tenggara masih',
#   'accept': True},
#  {'original': 'adakah serbaneka orang yang paling indah di dunia',
#   'cleaned': 'adakah serbaneka orang yang paling indah di dunia',
#   'accept': True},
#  {'original': 'antara foto aditya pradana putra',
#   'cleaned': 'antara foto aditya pradana putra',
#   'accept': True},
#  {'original': 'oleh huruf iaitu dan',
#   'cleaned': 'oleh huruf iaitu dan',
#   'accept': True},
#  {'original': 'malah malaysia juga terlibat',
#   'cleaned': 'malah malaysia juga terlibat',
#   'accept': True},
#  {'original': 'ah itu mah kamunya aja yang emang rakus',
#   'cleaned': 'ah itu mah kamunya aja yang emang rakus',
#   'accept': True},
#  {'original': 'the fight', 'cleaned': 'the fight', 'accept': True},
#  {'original': 'senjata jerman buat seketika',
#   'cleaned': 'senjata jerman buat seketika',
#   'accept': True},
#  {'original': 'bumi bulan selari gerhana',
#   'cleaned': 'bumi bulan selari gerhana',
#   'accept': True},
#  {'original': 'tolong sebut pseudoelectoral',
#   'cleaned': 'tolong sebut pseudoelectoral',
#   'accept': True},
#  {'original': 'kenapa indian utara mahu india yang tidak bercakap dan hindu',
#   'cleaned': 'kenapa indian utara mahu india yang tidak bercakap dan hindu',
#   'accept': True},
#  {'original': 'dirinya terakhir menyimpan kunci motornya oh iya aku lupa iya bener di',
#   'cleaned': 'dirinya terakhir menyimpan kunci motornya oh iya aku lupa iya bener di',
#   'accept': True},
#  {'original': 'kenapa jews dan israelis mengejek iranian bukan agama lebih',
#   'cleaned': 'kenapa jews dan israelis mengejek iranian bukan agama lebih',
#   'accept': True},
#  {'original': 'memindahkan tasnya ke dadanya lalu membukanya yasmin panik segera',
#   'cleaned': 'memindahkan tasnya ke dadanya lalu membukanya yasmin panik segera',
#   'accept': True},
#  {'original': 'aku libra terdiam menatap andra',
#   'cleaned': 'aku libra terdiam menatap andra',
#   'accept': True},
#  {'original': 'ketika dia panik dia akan menangis selama kurang lebih 15 menit menurut',
#   'cleaned': 'ketika dia panik dia akan menangis selama kurang lebih lima belas menit menurut',
#   'accept': True},
#  {'original': 'apa apa sekatan namun',
#   'cleaned': 'apa apa sekatan namun',
#   'accept': True},
#  {'original': 'mengapa nabi mohammad menggunakan rogol sebagai senjata untuk menyebarkan islam',
#   'cleaned': 'mengapa nabi mohammad menggunakan rogol sebagai senjata untuk menyebarkan islam',
#   'accept': True},
#  {'original': 'hospital tanah merah',
#   'cleaned': 'hospital tanah merah',
#   'accept': True},
#  {'original': 'sebut perkataan abstrak',
#   'cleaned': 'sebut perkataan abstrak',
#   'accept': True},
#  {'original': 'sistem suria terikat pasang',
#   'cleaned': 'sistem suria terikat pasang',
#   'accept': True},
#  {'original': 'sekeliling trx seperti pasar baharu untuk peniaga dan pembinaan jalan',
#   'cleaned': 'sekeliling trx seperti pasar baharu untuk peniaga dan pembinaan jalan',
#   'accept': True},
#  {'original': 'kenapa media tidak memanggil donald trump kerana sakit mental',
#   'cleaned': 'kenapa media tidak memanggil donald trump kerana sakit mental',
#   'accept': True},
#  {'original': 'dimanakah saya boleh bertemu wanita muda seksi yang mati',
#   'cleaned': 'dimanakah saya boleh bertemu wanita muda seksi yang mati',
#   'accept': True},
#  {'original': 'aku rasa maksud dia bukan solat',
#   'cleaned': 'aku rasa maksud dia bukan solat',
#   'accept': True},
#  {'original': 'sebut perkataan ahadiat',
#   'cleaned': 'sebut perkataan ahadiat',
#   'accept': True},
#  {'original': 'ppfftt kamu sehat kan',
#   'cleaned': 'ppfftt kamu sehat kan',
#   'accept': True},
#  {'original': 'tumbuh tumbuhan lain rafflesia',
#   'cleaned': 'tumbuh tumbuhan lain rafflesia',
#   'accept': True},
#  {'original': 'adakah benar turunan menikmati kualiti hidup yang lebih tinggi berbanding dengan orang eropah',
#   'cleaned': 'adakah benar turunan menikmati kualiti hidup yang lebih tinggi berbanding dengan orang eropah',
#   'accept': True},
#  {'original': 'kemudian pergi klinik lain pula sebab kami pindah ke tempat lain',
#   'cleaned': 'kemudian pergi klinik lain pula sebab kami pindah ke tempat lain',
#   'accept': True},
#  {'original': 'sebut perkataan ampe',
#   'cleaned': 'sebut perkataan ampe',
#   'accept': True},
#  {'original': 'kenapa aku perlu diam',
#   'cleaned': 'kenapa aku perlu diam',
#   'accept': True},
#  {'original': 'dalam gelak kecil itu sesuatu yang harus penulis',
#   'cleaned': 'dalam gelak kecil itu sesuatu yang harus penulis',
#   'accept': True},
#  {'original': 'sementara abad menyaksikan para',
#   'cleaned': 'sementara abad menyaksikan para',
#   'accept': True},
#  {'original': 'mengeluarkan hp nya muka abang terlihat berseri seri',
#   'cleaned': 'mengeluarkan hp nya muka abang terlihat berseri seri',
#   'accept': True},
#  {'original': 'melaka pada zaman itu',
#   'cleaned': 'melaka pada zaman itu',
#   'accept': True},
#  {'original': 'berapa ramai evolusionis yang diperlukan untuk mengubah dunia cahaya',
#   'cleaned': 'berapa ramai evolusionis yang diperlukan untuk mengubah dunia cahaya',
#   'accept': True},
#  {'original': 'iyaa siap bos sahut libra seraya menyimpan kelima jari kanannya disamping',
#   'cleaned': 'iyaa siap bos sahut libra seraya menyimpan kelima jari kanannya disamping',
#   'accept': True},
#  {'original': 'itu andra batin libra',
#   'cleaned': 'itu andra batin libra',
#   'accept': True},
#  {'original': 'ok tu lupakan', 'cleaned': 'ok tu lupakan', 'accept': True},
#  {'original': 'tidak bumi algeria yang',
#   'cleaned': 'tidak bumi algeria yang',
#   'accept': True},
#  {'original': 'kenapa foto nirbhaya masih belum diturunkan',
#   'cleaned': 'kenapa foto nirbhaya masih belum diturunkan',
#   'accept': True},
#  {'original': 'kenapa pembenci muslihat membuat kebohongan tanpa satu bukti',
#   'cleaned': 'kenapa pembenci muslihat membuat kebohongan tanpa satu bukti',
#   'accept': True},
#  {'original': 'sebut perkataan almukhalis',
#   'cleaned': 'sebut perkataan almukhalis',
#   'accept': True},
#  {'original': 'adakah stephen menjajakan manusia sebenar atau robot yang mewakili tangki pemikir',
#   'cleaned': 'adakah stephen menjajakan manusia sebenar atau robot yang mewakili tangki pemikir',
#   'accept': True},
#  {'original': 'bisnes berjalan macan biasa',
#   'cleaned': 'bisnes berjalan macan biasa',
#   'accept': True},
#  {'original': 'bagaimanapun istilah melayu adalah',
#   'cleaned': 'bagaimanapun istilah melayu adalah',
#   'accept': True},
#  {'original': 'adakah anda liberal bodoh benar benar percaya',
#   'cleaned': 'adakah anda liberal bodoh benar benar percaya',
#   'accept': True},
#  {'original': 'bagaimana wanita lebih hipokrit daripada lelaki dalam situasi pertuturan',
#   'cleaned': 'bagaimana wanita lebih hipokrit daripada lelaki dalam situasi pertuturan',
#   'accept': True},
#  {'original': 'dunia haiwan liar alat',
#   'cleaned': 'dunia haiwan liar alat',
#   'accept': True},
#  {'original': 'libra terus memperhatikan laki laki itu tak lama kemudian laki laki itu',
#   'cleaned': 'libra terus memperhatikan laki laki itu tak lama kemudian laki laki itu',
#   'accept': True},
#  {'original': 'mengapa anda melihat beberapa orang hitam yang janggal sosial',
#   'cleaned': 'mengapa anda melihat beberapa orang hitam yang janggal sosial',
#   'accept': True},
#  {'original': 'bolehkah anda menghuraikan fantasi seks anda dengan ibu anda',
#   'cleaned': 'bolehkah anda menghuraikan fantasi seks anda dengan ibu anda',
#   'accept': True},
#  {'original': 'selain bekas menteri besar kedah itu yang turut menyampaikan',
#   'cleaned': 'selain bekas menteri besar kedah itu yang turut menyampaikan',
#   'accept': True},
#  {'original': 'apakah jalan kerjaya untuk diktator jahat di sub saharan africa',
#   'cleaned': 'apakah jalan kerjaya untuk diktator jahat di sub saharan africa',
#   'accept': True},
#  {'original': 'tolong sebut pengenalan semula',
#   'cleaned': 'tolong sebut pengenalan semula',
#   'accept': True},
#  {'original': 'sejarah kehidupan bumi baru',
#   'cleaned': 'sejarah kehidupan bumi baru',
#   'accept': True},
#  {'original': 'kenapa ada daya tarik dengan nasi jerman di sini',
#   'cleaned': 'kenapa ada daya tarik dengan nasi jerman di sini',
#   'accept': True},
#  {'original': 'adakah anda percaya bahawa donald trump adalah kedatangan kedua jesus christ',
#   'cleaned': 'adakah anda percaya bahawa donald trump adalah kedatangan kedua jesus christ',
#   'accept': True},
#  {'original': 'sebagai wakil ketua dpr ri',
#   'cleaned': 'sebagai wakil ketua dpr ri',
#   'accept': True},
#  {'original': 'sampingan faktor kemegahan juga',
#   'cleaned': 'sampingan faktor kemegahan juga',
#   'accept': True},
#  {'original': 'saudara lebih pintar daripada saudara perempuan',
#   'cleaned': 'saudara lebih pintar daripada saudara perempuan',
#   'accept': True},
#  {'original': 'jangan terlalu enak jadi aku nambah terus',
#   'cleaned': 'jangan terlalu enak jadi aku nambah terus',
#   'accept': True},
#  {'original': 'akak memang malu sangat nak mintak',
#   'cleaned': 'akak memang malu sangat nak mintak',
#   'accept': True},
#  {'original': 'dipercayai untuk menentukan usia',
#   'cleaned': 'dipercayai untuk menentukan usia',
#   'accept': True},
#  {'original': 'selepas lebih kurang tiga',
#   'cleaned': 'selepas lebih kurang tiga',
#   'accept': True},
#  {'original': 'mengapa wanita afrika kolar putih sukar bekerja dengan tidak bersifat perkauman atau stereotaip',
#   'cleaned': 'mengapa wanita afrika kolar putih sukar bekerja dengan tidak bersifat perkauman atau stereotaip',
#   'accept': True},
#  {'original': 'dika keluar lagi dari kamar dika tanpa berkomentar apapun libra hanya',
#   'cleaned': 'dika keluar lagi dari kamar dika tanpa berkomentar apapun libra hanya',
#   'accept': True},
#  {'original': 'kenapa india selatan perlu membayar dan mensubsidi kemalasan india utara',
#   'cleaned': 'kenapa india selatan perlu membayar dan mensubsidi kemalasan india utara',
#   'accept': True},
#  {'original': 'kenapa gadis gadis singapura jadi orang kulit putih',
#   'cleaned': 'kenapa gadis gadis singapura jadi orang kulit putih',
#   'accept': True},
#  {'original': 'bagaimana saya menggalakkan isteri saya melakukan lebih banyak kerja rumah',
#   'cleaned': 'bagaimana saya menggalakkan isteri saya melakukan lebih banyak kerja rumah',
#   'accept': True},
#  {'original': 'hidupnya bebas tanpa tanggungjawab bak pelajar universiti yg tgh cuti sem',
#   'cleaned': 'hidupnya bebas tanpa tanggungjawab bak pelajar universiti yg tgh cuti sem',
#   'accept': True},
#  {'original': 'apabila anda mengatakan pembohongan ianya cukup untuk mengepit',
#   'cleaned': 'apabila anda mengatakan pembohongan ianya cukup untuk mengepit',
#   'accept': True},
#  {'original': 'bandung 2017',
#   'cleaned': 'bandung dua ribu tujuh belas',
#   'accept': True},
#  {'original': 'sebagaimana haiwan mamalia yang',
#   'cleaned': 'sebagaimana haiwan mamalia yang',
#   'accept': True},
#  {'original': 'tempat duduk di barisan ujung paling depan meskipun resikonya akan selalu',
#   'cleaned': 'tempat duduk di barisan ujung paling depan meskipun resikonya akan selalu',
#   'accept': True},
#  {'original': 'selepas program itu dihebahkan waktu siarannya oleh pengacaranya',
#   'cleaned': 'selepas program itu dihebahkan waktu siarannya oleh pengacaranya',
#   'accept': True},
#  {'original': 'tolong sebut vindresser',
#   'cleaned': 'tolong sebut vindresser',
#   'accept': True},
#  {'original': 'kenapa anda memutuskan untuk berkahwin dengan anak saudara anda',
#   'cleaned': 'kenapa anda memutuskan untuk berkahwin dengan anak saudara anda',
#   'accept': True},
#  {'original': 'sebut perkataan pengedar',
#   'cleaned': 'sebut perkataan pengedar',
#   'accept': True},
#  {'original': 'sorang ini lah yang menjadi kaki dan tangan kepada ibu',
#   'cleaned': 'sorang ini lah yang menjadi kaki dan tangan kepada ibu',
#   'accept': True},
#  {'original': 'adakah anda mudah merompak sebuah bank di india dan kemudian lari ke luar negara',
#   'cleaned': 'adakah anda mudah merompak sebuah bank di india dan kemudian lari ke luar negara',
#   'accept': True},
#  {'original': 'yang berkongsi video nyanyian mereka sebagai tanda menyukai lagu',
#   'cleaned': 'yang berkongsi video nyanyian mereka sebagai tanda menyukai lagu',
#   'accept': True},
#  {'original': 'tidak dinafikan impak lagu isabella sangat besar dalam kerjaya saya',
#   'cleaned': 'tidak dinafikan impak lagu isabella sangat besar dalam kerjaya saya',
#   'accept': True},
#  {'original': 'tas lalu berlari sekencang mungkin menuju kelas libra dan gisel mengikuti',
#   'cleaned': 'tas lalu berlari sekencang mungkin menuju kelas libra dan gisel mengikuti',
#   'accept': True},
#  {'original': 'dia tetap berlari',
#   'cleaned': 'dia tetap berlari',
#   'accept': True},
#  {'original': 'tolong sebut secara fizikal',
#   'cleaned': 'tolong sebut secara fizikal',
#   'accept': True},
#  {'original': 'hentaman komet ketiadaan udara',
#   'cleaned': 'hentaman komet ketiadaan udara',
#   'accept': True},
#  {'original': 'kenapa pokoknya begitu jelek dan gemuk',
#   'cleaned': 'kenapa pokoknya begitu jelek dan gemuk',
#   'accept': True},
#  {'original': 'adakah roy adams pernah menyentuh anda dengan tidak sesuai',
#   'cleaned': 'adakah roy adams pernah menyentuh anda dengan tidak sesuai',
#   'accept': True},
#  {'original': 'setiap tahun populasi penyu',
#   'cleaned': 'setiap tahun populasi penyu',
#   'accept': True},
#  {'original': 'untuk beredar frasa bahasa',
#   'cleaned': 'untuk beredar frasa bahasa',
#   'accept': True},
#  {'original': 'kenapa kebanyakan polis dan bekas polis',
#   'cleaned': 'kenapa kebanyakan polis dan bekas polis',
#   'accept': True},
#  {'original': 'kejadian ini bukanlah kejadian yang aneh',
#   'cleaned': 'kejadian ini bukanlah kejadian yang aneh',
#   'accept': True},
#  {'original': 'penasaran mereka pun menghampiri kerumunan itu',
#   'cleaned': 'penasaran mereka pun menghampiri kerumunan itu',
#   'accept': True},
#  {'original': 'daripada bulan akan tetapi',
#   'cleaned': 'daripada bulan akan tetapi',
#   'accept': True},
#  {'original': 'patutkah izzul ditendang di pantat telanjangnya',
#   'cleaned': 'patutkah izzul ditendang di pantat telanjangnya',
#   'accept': True},
#  {'original': 'mengapa rohingya muslim tidak berpendidikan',
#   'cleaned': 'mengapa rohingya muslim tidak berpendidikan',
#   'accept': True},
#  {'original': 'mengapa liberal membenci negara negara putih yang tinggal putih',
#   'cleaned': 'mengapa liberal membenci negara negara putih yang tinggal putih',
#   'accept': True},
#  {'original': 'kata yang dipinjam daripada',
#   'cleaned': 'kata yang dipinjam daripada',
#   'accept': True},
#  {'original': 'sosial dan ekonomi cerita',
#   'cleaned': 'sosial dan ekonomi cerita',
#   'accept': True},
#  {'original': 'kenapa melakukan pelanggaran seksual chelsea clinton',
#   'cleaned': 'kenapa melakukan pelanggaran seksual chelsea clinton',
#   'accept': True},
#  {'original': 'tolong sebut rumah ikan',
#   'cleaned': 'tolong sebut rumah ikan',
#   'accept': True},
#  {'original': 'sebut perkataan tidak dapat diskriminasi',
#   'cleaned': 'sebut perkataan tidak dapat diskriminasi',
#   'accept': True},
#  {'original': 'kenapa orang british begitu terobsesi dengan senjata amerika',
#   'cleaned': 'kenapa orang british begitu terobsesi dengan senjata amerika',
#   'accept': True},
#  {'original': 'kenapa tidak orang putih kembali ke eropah dan bukannya memberitahu orang lain ke mana',
#   'cleaned': 'kenapa tidak orang putih kembali ke eropah dan bukannya memberitahu orang lain ke mana',
#   'accept': True},
#  {'original': 'masakan abangku sayang ini ini cuma tumis tahu yang makanan rumah doang udah',
#   'cleaned': 'masakan abangku sayang ini ini cuma tumis tahu yang makanan rumah doang udah',
#   'accept': True},
#  {'original': 'menurut beberapa teori penutur',
#   'cleaned': 'menurut beberapa teori penutur',
#   'accept': True},
#  {'original': 'ibu perak satu percubaan',
#   'cleaned': 'ibu perak satu percubaan',
#   'accept': True},
#  {'original': 'tahulah kita sama keluarga kita tapi orang dari keluarga lain',
#   'cleaned': 'tahulah kita sama keluarga kita tapi orang dari keluarga lain',
#   'accept': True},
#  {'original': 'kenapa schlong saya begitu besar',
#   'cleaned': 'kenapa schlong saya begitu besar',
#   'accept': True},
#  {'original': 'tangis membuat libra dan gisel semakin panik ya yasmin memang agak cengeng',
#   'cleaned': 'tangis membuat libra dan gisel semakin panik ya yasmin memang agak cengeng',
#   'accept': True},
#  {'original': 'karena tau laki laki itu adalah kakak kelas',
#   'cleaned': 'karena tau laki laki itu adalah kakak kelas',
#   'accept': True},
#  {'original': 'seperti sekarang libra sedang duduk di tempat gisel karena sekarang',
#   'cleaned': 'seperti sekarang libra sedang duduk di tempat gisel karena sekarang',
#   'accept': True},
#  {'original': 'tidak pernah menjanjikan pembersihan etnik',
#   'cleaned': 'tidak pernah menjanjikan pembersihan etnik',
#   'accept': True},
#  {'original': 'bagaimana membiarkan pendatang tanpa izin ke dalam menyelesaikan sesuatu',
#   'cleaned': 'bagaimana membiarkan pendatang tanpa izin ke dalam menyelesaikan sesuatu',
#   'accept': True},
#  {'original': 'assalamualaikum reader semua',
#   'cleaned': 'assalamualaikum reader semua',
#   'accept': True},
#  {'original': 'adakah ia buruk bahawa iq saya ialah 249',
#   'cleaned': 'adakah ia buruk bahawa iq saya ialah dua ratus empat puluh sembilan',
#   'accept': True},
#  {'original': 'sakit li', 'cleaned': 'sakit li', 'accept': True},
#  {'original': 'aku cakap kawan facebook kirim salam',
#   'cleaned': 'aku cakap kawan facebook kirim salam',
#   'accept': True},
#  {'original': 'di kawasan perbatasan sehingga roda perekonomian di kawasan tersebut bisa',
#   'cleaned': 'di kawasan perbatasan sehingga roda perekonomian di kawasan tersebut bisa',
#   'accept': True},
#  {'original': 'keluar dari ruangan maut itu sesekali libra melepas kacamatanya dan',
#   'cleaned': 'keluar dari ruangan maut itu sesekali libra melepas kacamatanya dan',
#   'accept': True},
#  {'original': 'kenapa quora menyokong islamis dan pengguna pengganas',
#   'cleaned': 'kenapa quora menyokong islamis dan pengguna pengganas',
#   'accept': True},
#  {'original': 'mengapa orang asing begitu rasis mereka selalu mendarat di usa',
#   'cleaned': 'mengapa orang asing begitu rasis mereka selalu mendarat di usa',
#   'accept': True},
#  {'original': 'eh ke tempat biasa dulu kan gisel mengingatkan',
#   'cleaned': 'eh ke tempat biasa dulu kan gisel mengingatkan',
#   'accept': True},
#  {'original': 'sebut perkataan adang',
#   'cleaned': 'sebut perkataan adang',
#   'accept': True},
#  {'original': 'seorang kawan dan penasihat',
#   'cleaned': 'seorang kawan dan penasihat',
#   'accept': True},
#  {'original': 'kali ini aku nak cuba kerja lain pula',
#   'cleaned': 'kali ini aku nak cuba kerja lain pula',
#   'accept': True},
#  {'original': 'mengapa pelancong australia di bali tidak bersikap diri',
#   'cleaned': 'mengapa pelancong australia di bali tidak bersikap diri',
#   'accept': True},
#  {'original': 'adakah kebanyakan orang yang tidak mempunyai kehidupan yang menggunakan quora',
#   'cleaned': 'adakah kebanyakan orang yang tidak mempunyai kehidupan yang menggunakan quora',
#   'accept': True},
#  {'original': 'itu tetapi mengatasi amerika',
#   'cleaned': 'itu tetapi mengatasi amerika',
#   'accept': True},
#  {'original': 'pasti si abang lagi chat sama kak dea gumamku dalam hati',
#   'cleaned': 'pasti si abang lagi chat sama kak dea gumamku dalam hati',
#   'accept': True},
#  {'original': 'mengapa merogol seorang gadis seperti jenayah khas',
#   'cleaned': 'mengapa merogol seorang gadis seperti jenayah khas',
#   'accept': True},
#  {'original': 'tolong sebut tidak memalukan',
#   'cleaned': 'tolong sebut tidak memalukan',
#   'accept': True},
#  {'original': 'kawan macam nilah yang akan jadi musuh di akhirat nanti',
#   'cleaned': 'kawan macam nilah yang akan jadi musuh di akhirat nanti',
#   'accept': True},
#  {'original': 'beliau berkata sukar menguasai kitab arab merentas pelbagai',
#   'cleaned': 'beliau berkata sukar menguasai kitab arab merentas pelbagai',
#   'accept': True},
#  {'original': 'seperti alga hijau tidak',
#   'cleaned': 'seperti alga hijau tidak',
#   'accept': True},
#  {'original': 'sebut perkataan aduan',
#   'cleaned': 'sebut perkataan aduan',
#   'accept': True},
#  {'original': 'tolong sebut berfaedah',
#   'cleaned': 'tolong sebut berfaedah',
#   'accept': True},
#  {'original': 'kenapa saya dibenarkan menjadi gemuk',
#   'cleaned': 'kenapa saya dibenarkan menjadi gemuk',
#   'accept': True},
#  {'original': 'mungkin akta anti pencatutan perlu dipinda sekiranya ia sukar untuk dikuatkuasakan',
#   'cleaned': 'mungkin akta anti pencatutan perlu dipinda sekiranya ia sukar untuk dikuatkuasakan',
#   'accept': True},
#  {'original': 'sebut perkataan amangkurat',
#   'cleaned': 'sebut perkataan amangkurat',
#   'accept': True},
#  {'original': 'sebut perkataan mengaku',
#   'cleaned': 'sebut perkataan mengaku',
#   'accept': True},
#  {'original': 'kawasan pentadbiran dengan daripadanya',
#   'cleaned': 'kawasan pentadbiran dengan daripadanya',
#   'accept': True},
#  {'original': 'shht ah bang malu aku',
#   'cleaned': 'shht ah bang malu aku',
#   'accept': True},
#  {'original': 'ahli geologi sedar akan',
#   'cleaned': 'ahli geologi sedar akan',
#   'accept': True},
#  {'original': 'belajar bersyukur',
#   'cleaned': 'belajar bersyukur',
#   'accept': True},
#  {'original': 'nipis dasar laut iaitu',
#   'cleaned': 'nipis dasar laut iaitu',
#   'accept': True},
#  {'original': 'sebut perkataan altar',
#   'cleaned': 'sebut perkataan altar',
#   'accept': True},
#  {'original': 'anda berencana pindah ke suatu kota',
#   'cleaned': 'anda berencana pindah ke suatu kota',
#   'accept': True},
#  {'original': 'penting fardhu tu',
#   'cleaned': 'penting fardhu tu',
#   'accept': True},
#  {'original': 'saintis perancis mencapai kejayaan',
#   'cleaned': 'saintis perancis mencapai kejayaan',
#   'accept': True},
#  {'original': 'mengapa ramai orang rusia mengatakan bahawa ukrainian adalah nazis',
#   'cleaned': 'mengapa ramai orang rusia mengatakan bahawa ukrainian adalah nazis',
#   'accept': True},
#  {'original': 'parti buruhnya penggal kedua',
#   'cleaned': 'parti buruhnya penggal kedua',
#   'accept': True},
#  {'original': 'lain dengan bahasa malaysia',
#   'cleaned': 'lain dengan bahasa malaysia',
#   'accept': True},
#  {'original': 'menteri kewangan lim guan eng hari ini mengumumkan harga runcit',
#   'cleaned': 'menteri kewangan lim guan eng hari ini mengumumkan harga runcit',
#   'accept': True},
#  {'original': 'mangsa pedofilia abang kandung aku sendiri',
#   'cleaned': 'mangsa pedofilia abang kandung aku sendiri',
#   'accept': True},
#  {'original': 'ipa 3 arahnya tepat mengenai punggung salah satu siswi dikelas tersebut',
#   'cleaned': 'ipa tiga arahnya tepat mengenai punggung salah satu siswi dikelas tersebut',
#   'accept': True},
#  {'original': 'agar bisa segera keluar dari ruangan maut pak dadi mulai keluar kelas',
#   'cleaned': 'agar bisa segera keluar dari ruangan maut pak dadi mulai keluar kelas',
#   'accept': True},
#  {'original': 'separuh daripada buta europe sebelum gelas',
#   'cleaned': 'separuh daripada buta europe sebelum gelas',
#   'accept': True},
#  {'original': 'isu lgbt persetubuhan haram dan anak luar nikah sepatutnya',
#   'cleaned': 'isu lgbt persetubuhan haram dan anak luar nikah sepatutnya',
#   'accept': True},
#  {'original': 'adakah anda tahu jesus membenci agama',
#   'cleaned': 'adakah anda tahu jesus membenci agama',
#   'accept': True},
#  {'original': 'nya tanpa daffa karena daffa punya geng nya sendiri dengan anak laki laki',
#   'cleaned': 'nya tanpa daffa karena daffa punya geng nya sendiri dengan anak laki laki',
#   'accept': True},
#  {'original': 'justifikasi bagi menggelar diri',
#   'cleaned': 'justifikasi bagi menggelar diri',
#   'accept': True},
#  {'original': 'terserempak dengan seekor badak',
#   'cleaned': 'terserempak dengan seekor badak',
#   'accept': True},
#  {'original': 'dan hanipa maidin kini menduduki jawatan menteri dan',
#   'cleaned': 'dan hanipa maidin kini menduduki jawatan menteri dan',
#   'accept': True},
#  {'original': 'oleh orang orang dari',
#   'cleaned': 'oleh orang orang dari',
#   'accept': True},
#  {'original': 'sebarang makluman hebahan yang mendakwa berlakunya lagi gangguan',
#   'cleaned': 'sebarang makluman hebahan yang mendakwa berlakunya lagi gangguan',
#   'accept': True},
#  {'original': 'kenapa bukan persaudaraan muslim yang diharamkan di eropah',
#   'cleaned': 'kenapa bukan persaudaraan muslim yang diharamkan di eropah',
#   'accept': True},
#  {'original': 'yee ketemuu teriak yasmin girang sambil mengangkat kunci motornya setinggi',
#   'cleaned': 'yee ketemuu teriak yasmin girang sambil mengangkat kunci motornya setinggi',
#   'accept': True},
#  {'original': 'mengapa orang india mengambil pil tanpa ubat',
#   'cleaned': 'mengapa orang india mengambil pil tanpa ubat',
#   'accept': True},
#  {'original': 'adakah nasionalisme cina menjijikkan anda',
#   'cleaned': 'adakah nasionalisme cina menjijikkan anda',
#   'accept': True},
#  {'original': 'setelah kalah dalam perang',
#   'cleaned': 'setelah kalah dalam perang',
#   'accept': True},
#  {'original': 'kenapa hanya di amerika kita mempunyai ucapan bebas',
#   'cleaned': 'kenapa hanya di amerika kita mempunyai ucapan bebas',
#   'accept': True},
#  {'original': 'menyelar bekas menteri besar selangor tan sri muhammad muhammad taib',
#   'cleaned': 'menyelar bekas menteri besar selangor tan sri muhammad muhammad taib',
#   'accept': True},
#  {'original': 'tolong sebut penyataan',
#   'cleaned': 'tolong sebut penyataan',
#   'accept': True},
#  {'original': 'kelima diluluskan melalui pungutan',
#   'cleaned': 'kelima diluluskan melalui pungutan',
#   'accept': True},
#  {'original': 'adakah orang berfikir truf seperti beruang teddy atau cicak hewan peliharaan',
#   'cleaned': 'adakah orang berfikir truf seperti beruang teddy atau cicak hewan peliharaan',
#   'accept': True},
#  {'original': 'saya tahu dia mengharapkan saya bermurah hati mahu menaja pakaian sekolahnya',
#   'cleaned': 'saya tahu dia mengharapkan saya bermurah hati mahu menaja pakaian sekolahnya',
#   'accept': True},
#  {'original': 'plankton kepada ikan besar',
#   'cleaned': 'plankton kepada ikan besar',
#   'accept': True},
#  {'original': 'saya tidak akan terlibat dalam apa apa cara sama ada siasatan',
#   'cleaned': 'saya tidak akan terlibat dalam apa apa cara sama ada siasatan',
#   'accept': True},
#  {'original': 'tolong sebut memecahkan',
#   'cleaned': 'tolong sebut memecahkan',
#   'accept': True},
#  {'original': 'adakah demokrat menyedari bahawa robert e lee bukan asian',
#   'cleaned': 'adakah demokrat menyedari bahawa robert e lee bukan asian',
#   'accept': True},
#  {'original': 'dah lah suami aku tu bukan calon pilihan',
#   'cleaned': 'dah lah suami aku tu bukan calon pilihan',
#   'accept': True},
#  {'original': 'tolong sebut komisar',
#   'cleaned': 'tolong sebut komisar',
#   'accept': True},
#  {'original': 'bagaimana ramai orang mengalami kemurungan pada masa kini',
#   'cleaned': 'bagaimana ramai orang mengalami kemurungan pada masa kini',
#   'accept': True},
#  {'original': 'pembangunan luar bandar rina harun dan ketua setiausaha negara datuk seri',
#   'cleaned': 'pembangunan luar bandar rina harun dan ketua setiausaha negara datuk seri',
#   'accept': True},
#  {'original': '45 ahli belia yang dilantik itu menjadi penyambung legasi',
#   'cleaned': 'empat puluh lima ahli belia yang dilantik itu menjadi penyambung legasi',
#   'accept': True},
#  {'original': 'bisa dibilang siswa yang paling benci fisika',
#   'cleaned': 'bisa dibilang siswa yang paling benci fisika',
#   'accept': True},
#  {'original': 'bolehkah saya membeli rumpai secara sah di stockton dan di mana',
#   'cleaned': 'bolehkah saya membeli rumpai secara sah di stockton dan di mana',
#   'accept': True},
#  {'original': 'akhirnya yang ditunggu bel pulang sekolah berbunyi libra melepas kacamatanya',
#   'cleaned': 'akhirnya yang ditunggu bel pulang sekolah berbunyi libra melepas kacamatanya',
#   'accept': True},
#  {'original': 'sebab aku tersalah cinta',
#   'cleaned': 'sebab aku tersalah cinta',
#   'accept': True},
#  {'original': 'ppfftt andra menahan ketawa sambil menutup mulutnya',
#   'cleaned': 'ppfftt andra menahan ketawa sambil menutup mulutnya',
#   'accept': True},
#  {'original': 'lelaki hitam seperti wanita hitam',
#   'cleaned': 'lelaki hitam seperti wanita hitam',
#   'accept': True},
#  {'original': 'berbunyi libra akan segera keluar dari ruangan maut',
#   'cleaned': 'berbunyi libra akan segera keluar dari ruangan maut',
#   'accept': True},
#  {'original': 'bagaimana kita akan mengeluarkan virus yang dipanggil islam',
#   'cleaned': 'bagaimana kita akan mengeluarkan virus yang dipanggil islam',
#   'accept': True},
#  {'original': 'apabila obama ditangkap bolehkah dia dibunuh kerana kejahatannya',
#   'cleaned': 'apabila obama ditangkap bolehkah dia dibunuh kerana kejahatannya',
#   'accept': True},
#  {'original': 'sebut perkataan adilkan',
#   'cleaned': 'sebut perkataan adilkan',
#   'accept': True},
#  {'original': 'sebut perkataan revolvable',
#   'cleaned': 'sebut perkataan revolvable',
#   'accept': True},
#  {'original': 'kita perlu masa yang sesuai untuk kita menilai secara',
#   'cleaned': 'kita perlu masa yang sesuai untuk kita menilai secara',
#   'accept': True},
#  {'original': 'aku emang rakus kalau udah makan masakan bangdik gila abang cuma belajar',
#   'cleaned': 'aku emang rakus kalau udah makan masakan bangdik gila abang cuma belajar',
#   'accept': True},
#  {'original': 'boleh fuckers quora sila tutup fuck tentang iq',
#   'cleaned': 'boleh fuckers quora sila tutup fuck tentang iq',
#   'accept': True},
#  {'original': 'felda engineering services sdn',
#   'cleaned': 'felda engineering services sdn',
#   'accept': True},
#  {'original': 'melaka yang mana bahasa',
#   'cleaned': 'melaka yang mana bahasa',
#   'accept': True},
#  {'original': 'libra segera berlari menuju andra hh akhirnya aku ketemu kamu juga',
#   'cleaned': 'libra segera berlari menuju andra hh akhirnya aku ketemu kamu juga',
#   'accept': True},
#  {'original': 'cuba mengekalkan status ekonomi',
#   'cleaned': 'cuba mengekalkan status ekonomi',
#   'accept': True},
#  {'original': 'kita pon fikir takpelah at least dia pakai tudung',
#   'cleaned': 'kita pon fikir takpelah at least dia pakai tudung',
#   'accept': True},
#  {'original': 'kripton pada tahun biro',
#   'cleaned': 'kripton pada tahun biro',
#   'accept': True},
#  {'original': 'meter nanometer per laksa',
#   'cleaned': 'meter nanometer per laksa',
#   'accept': True},
#  {'original': 'berapa ramai wanita seperti seks doggystyle',
#   'cleaned': 'berapa ramai wanita seperti seks doggystyle',
#   'accept': True},
#  {'original': 'aku terdiam menatap piring didepanku sedetik kemudian menatap abangku dengan',
#   'cleaned': 'aku terdiam menatap piring didepanku sedetik kemudian menatap abangku dengan',
#   'accept': True},
#  {'original': 'pilih kelas jenis kereta yang sesuai',
#   'cleaned': 'pilih kelas jenis kereta yang sesuai',
#   'accept': True},
#  {'original': 'kenapa ada orang amerika ingin diktator sosialis pemerintah dengan pemerintah',
#   'cleaned': 'kenapa ada orang amerika ingin diktator sosialis pemerintah dengan pemerintah',
#   'accept': True},
#  {'original': 'libra menjalani lika liku pelajaran sma ya masing masing jumlah siswa laki',
#   'cleaned': 'libra menjalani lika liku pelajaran sma ya masing masing jumlah siswa laki',
#   'accept': True},
#  {'original': 'tolong sebut jarum',
#   'cleaned': 'tolong sebut jarum',
#   'accept': True},
#  {'original': 'betul tidak', 'cleaned': 'betul tidak', 'accept': True},
#  {'original': 'kelihatan selepas 72 jam daripada aktiviti tersebut atau selepas',
#   'cleaned': 'kelihatan selepas tujuh puluh dua jam daripada aktiviti tersebut atau selepas',
#   'accept': True},
#  {'original': 'hidrogen bergabung dengan satu',
#   'cleaned': 'hidrogen bergabung dengan satu',
#   'accept': True},
#  {'original': 'sebut perkataan almarhum',
#   'cleaned': 'sebut perkataan almarhum',
#   'accept': True},
#  {'original': 'dan sejarah dan juga',
#   'cleaned': 'dan sejarah dan juga',
#   'accept': True},
#  {'original': 'saya perlu mengambil peperiksaan lanjut',
#   'cleaned': 'saya perlu mengambil peperiksaan lanjut',
#   'accept': True},
#  {'original': 'bersamaan dengan kilometer dengan',
#   'cleaned': 'bersamaan dengan kilometer dengan',
#   'accept': True},
#  {'original': 'kenapa tiba tiba orang sedang melepak gadis delhi selatan',
#   'cleaned': 'kenapa tiba tiba orang sedang melepak gadis delhi selatan',
#   'accept': True},
#  {'original': 'ditemukan beberapa bahagian dunia',
#   'cleaned': 'ditemukan beberapa bahagian dunia',
#   'accept': True},
#  {'original': 'studi ini juga mendapati sebanyak 43 persen anak yang datang',
#   'cleaned': 'studi ini juga mendapati sebanyak empat puluh tiga persen anak yang datang',
#   'accept': True},
#  {'original': 'bukit palembang pada masihi',
#   'cleaned': 'bukit palembang pada masihi',
#   'accept': True},
#  {'original': 'bagaimana stalin memulakan proses stalinisme',
#   'cleaned': 'bagaimana stalin memulakan proses stalinisme',
#   'accept': True},
#  {'original': 'dengan jelas wajah laki laki itu',
#   'cleaned': 'dengan jelas wajah laki laki itu',
#   'accept': True},
#  {'original': 'bolehkah saya mendapatkan seorang gadis di delhi',
#   'cleaned': 'bolehkah saya mendapatkan seorang gadis di delhi',
#   'accept': True},
#  {'original': 'may berharap perjanjian itu akan selesai sebelum 22 mei',
#   'cleaned': 'may berharap perjanjian itu akan selesai sebelum dua puluh dua mei',
#   'accept': True},
#  {'original': 'sampai lah aku jumpa doktor tu dan doktor tu pun terus masukkan aku dekat wad',
#   'cleaned': 'sampai lah aku jumpa doktor tu dan doktor tu pun terus masukkan aku dekat wad',
#   'accept': True},
#  {'original': 'masak dari mama aja udah mantap gini apalagi abang belajar sama chef juna',
#   'cleaned': 'masak dari mama aja udah mantap gini apalagi abang belajar sama chef juna',
#   'accept': True},
#  {'original': 'memang salah aku',
#   'cleaned': 'memang salah aku',
#   'accept': True},
#  {'original': 'musnah panjang meter piawai',
#   'cleaned': 'musnah panjang meter piawai',
#   'accept': True},
#  {'original': 'tolong sebut tidak sopan',
#   'cleaned': 'tolong sebut tidak sopan',
#   'accept': True},
#  {'original': 'adakah donald trump tahu dia adalah seorang asshole',
#   'cleaned': 'adakah donald trump tahu dia adalah seorang asshole',
#   'accept': True},
# ...
#   'cleaned': 'dia tnya kenapa tak de',
#   'accept': True},
#  {'original': 'kenapa tidak kita secara jelas mengutuk penciptaan sebagai penipuan',
#   'cleaned': 'kenapa tidak kita secara jelas mengutuk penciptaan sebagai penipuan',
#   'accept': True},
#  {'original': 'yang berlainan seperti melalui',
#   'cleaned': 'yang berlainan seperti melalui',
#   'accept': True},
#  {'original': 'haruskah kita meminta pla untuk nuke dunia jika ada china buruk barat',
#   'cleaned': 'haruskah kita meminta pla untuk nuke dunia jika ada china buruk barat',
#   'accept': True},
#  {'original': 'kenapa orang orang muslim tidak menonjol melawan spanyol',
#   'cleaned': 'kenapa orang orang muslim tidak menonjol melawan spanyol',
#   'accept': True},
#  {'original': 'elizabeth ii pemerintah rasmi di bekas koloni british',
#   'cleaned': 'elizabeth ii pemerintah rasmi di bekas koloni british',
#   'accept': True},
#  {'original': 'hmm menyesal tulis tajuk guna nombor roman kena google nak tengok bentuk nombor 8 macam mana',
#   'cleaned': 'hmm menyesal tulis tajuk guna nombor roman kena google nak tengok bentuk nombor lapan macam mana',
#   'accept': True},
#  {'original': 'ismail sabri yaakob wee ka siong mustapa mohamed',
#   'cleaned': 'ismail sabri yaakob wee ka siong mustapa mohamed',
#   'accept': True},
#  {'original': 'adakah purata lelaki russian seksual',
#   'cleaned': 'adakah purata lelaki russian seksual',
#   'accept': True},
#  {'original': 'menyukai fisika tetapi setalah bertemu pak dadi semua berubah kini libra',
#   'cleaned': 'menyukai fisika tetapi setalah bertemu pak dadi semua berubah kini libra',
#   'accept': True},
#  {'original': 'dengan terburu buru yasmin memasukkan kembali isi tasnya menutup resleting',
#   'cleaned': 'dengan terburu buru yasmin memasukkan kembali isi tasnya menutup resleting',
#   'accept': True},
#  {'original': 'di manakah saya boleh mencari budak mati di bawah air',
#   'cleaned': 'di manakah saya boleh mencari budak mati di bawah air',
#   'accept': True},
#  {'original': 'haruskah saya mengusir gypsies mongolia turks dari kirkuk kembali ke mongolia',
#   'cleaned': 'haruskah saya mengusir gypsies mongolia turks dari kirkuk kembali ke mongolia',
#   'accept': True},
#  {'original': 'analisis genealogi dalam kitab',
#   'cleaned': 'analisis genealogi dalam kitab',
#   'accept': True},
#  {'original': 'yang masih menggeledah tas yasmin',
#   'cleaned': 'yang masih menggeledah tas yasmin',
#   'accept': True},
#  {'original': 'kayaknya malah si chef juna yang minta diguruin sama bangdik',
#   'cleaned': 'kayaknya malah si chef juna yang minta diguruin sama bangdik',
#   'accept': True},
#  {'original': 'sebut perkataan boleh berubah',
#   'cleaned': 'sebut perkataan boleh berubah',
#   'accept': True},
#  {'original': 'who are you', 'cleaned': 'who are you', 'accept': True},
#  {'original': 'yasmin cuma cengengesan melihat kedua temannya yang kelelahan kalau kalian',
#   'cleaned': 'yasmin cuma cengengesan melihat kedua temannya yang kelelahan kalau kalian',
#   'accept': True},
#  {'original': 'tolong sebut tidak sabar',
#   'cleaned': 'tolong sebut tidak sabar',
#   'accept': True},
#  {'original': 'kenapa linda sarsour membenci jews',
#   'cleaned': 'kenapa linda sarsour membenci jews',
#   'accept': True},
#  {'original': 'adakah benar bahawa kebanyakan pengganas adalah muslim',
#   'cleaned': 'adakah benar bahawa kebanyakan pengganas adalah muslim',
#   'accept': True},
#  {'original': 'lain seperti andra menemukan libra yang lain atau aku akan mendapatkan',
#   'cleaned': 'lain seperti andra menemukan libra yang lain atau aku akan mendapatkan',
#   'accept': True},
#  {'original': 'penelitian libra',
#   'cleaned': 'penelitian libra',
#   'accept': True},
#  {'original': 'sendiri melalui bunyi berirama',
#   'cleaned': 'sendiri melalui bunyi berirama',
#   'accept': True},
#  {'original': 'juga gaharu tukasnya',
#   'cleaned': 'juga gaharu tukasnya',
#   'accept': True},
#  {'original': 'ketika mereka berada didepan ruang kelas 12 ipa 5 tatapan mereka langsung',
#   'cleaned': 'ketika mereka berada didepan ruang kelas dua belas ipa lima tatapan mereka langsung',
#   'accept': True},
#  {'original': 'ini', 'cleaned': 'ini', 'accept': True},
#  {'original': 'setahun yang lalu ketika baru 1 bulan semenjak libra sma libra sudah merasa',
#   'cleaned': 'setahun yang lalu ketika baru satu bulan semenjak libra sma libra sudah merasa',
#   'accept': True},
#  {'original': 'sebut perkataan aksesori',
#   'cleaned': 'sebut perkataan aksesori',
#   'accept': True},
#  {'original': 'sebut perkataan agresor',
#   'cleaned': 'sebut perkataan agresor',
#   'accept': True},
#  {'original': 'bagaimana saya memecahkan kaki anda',
#   'cleaned': 'bagaimana saya memecahkan kaki anda',
#   'accept': True},
#  {'original': 'please li kita baru aja sepuluh langkah keluar dari kelas masa kamu',
#   'cleaned': 'please li kita baru aja sepuluh langkah keluar dari kelas masa kamu',
#   'accept': True},
#  {'original': 'satu elemen utama teori ini adalah peranan elit politik',
#   'cleaned': 'satu elemen utama teori ini adalah peranan elit politik',
#   'accept': True},
#  {'original': 'adakah ibu mempunyai hubungan seks dengan anak lelaki',
#   'cleaned': 'adakah ibu mempunyai hubungan seks dengan anak lelaki',
#   'accept': True},
#  {'original': 'yasmin meraba raba permukaan meja tidak melihat kenampakan kunci motornya',
#   'cleaned': 'yasmin meraba raba permukaan meja tidak melihat kenampakan kunci motornya',
#   'accept': True},
#  {'original': 'ini mau ganti baju abangku sayangg',
#   'cleaned': 'ini mau ganti baju abangku sayangg',
#   'accept': True},
#  {'original': 'daikin malaysia sdn bhd ooi cheng suan pada majlis menandatangani',
#   'cleaned': 'daikin malaysia sdn bhd ooi cheng suan pada majlis menandatangani',
#   'accept': True},
#  {'original': 'aku takut segala galanya',
#   'cleaned': 'aku takut segala galanya',
#   'accept': True},
#  {'original': 'kenapa indian benci atau tidak percaya nris tentang cintanya kepada india',
#   'cleaned': 'kenapa indian benci atau tidak percaya nris tentang cintanya kepada india',
#   'accept': True},
#  {'original': 'di samping itu kelembapan pelaburan awam juga mempengaruhi momentum',
#   'cleaned': 'di samping itu kelembapan pelaburan awam juga mempengaruhi momentum',
#   'accept': True},
#  {'original': 'perkataan kami korang kau',
#   'cleaned': 'perkataan kami korang kau',
#   'accept': True},
#  {'original': 'akankah muhajirs dapat mencemarkan lagi pakistan',
#   'cleaned': 'akankah muhajirs dapat mencemarkan lagi pakistan',
#   'accept': True},
#  {'original': 'mengapa orang ajmer begitu banyak buta huruf dan ke belakang',
#   'cleaned': 'mengapa orang ajmer begitu banyak buta huruf dan ke belakang',
#   'accept': True},
#  {'original': 'adakah orang islam menyembunyikan agama mereka',
#   'cleaned': 'adakah orang islam menyembunyikan agama mereka',
#   'accept': True},
#  {'original': 'ialah pinjaman kata bahasa',
#   'cleaned': 'ialah pinjaman kata bahasa',
#   'accept': True},
#  {'original': 'zaman kemuncaknya antara tahun',
#   'cleaned': 'zaman kemuncaknya antara tahun',
#   'accept': True},
#  {'original': 'kedua churchill terkenal dengan',
#   'cleaned': 'kedua churchill terkenal dengan',
#   'accept': True},
#  {'original': 'kenapa justin trudeau seperti kemaluan wanita',
#   'cleaned': 'kenapa justin trudeau seperti kemaluan wanita',
#   'accept': True},
#  {'original': 'raja salman kagum dengan keharmonian pelbagai kaum yang diamalkan di malaysia',
#   'cleaned': 'raja salman kagum dengan keharmonian pelbagai kaum yang diamalkan di malaysia',
#   'accept': True},
#  {'original': 'perkhemahan slot kerohanian dan aktiviti lasak',
#   'cleaned': 'perkhemahan slot kerohanian dan aktiviti lasak',
#   'accept': True},
#  {'original': 'sebut perkataan hapus',
#   'cleaned': 'sebut perkataan hapus',
#   'accept': True},
#  {'original': 'mempersiapkan ahli waris di dalam formulir asuransi yang akan kamu isi',
#   'cleaned': 'mempersiapkan ahli waris di dalam formulir asuransi yang akan kamu isi',
#   'accept': True},
#  {'original': 'besok ada pr gak tanya libra membuka pembicaraan sambil berjalan',
#   'cleaned': 'besok ada pr gak tanya libra membuka pembicaraan sambil berjalan',
#   'accept': True},
#  {'original': 'adakah anjing jantan dani alves neymar',
#   'cleaned': 'adakah anjing jantan dani alves neymar',
#   'accept': True},
#  {'original': 'haha gak deng mungkin aku terlalu hiperbola tapi bener kalian harus coba',
#   'cleaned': 'haha gak deng mungkin aku terlalu hiperbola tapi bener kalian harus coba',
#   'accept': True},
#  {'original': 'sebut perkataan ambilan',
#   'cleaned': 'sebut perkataan ambilan',
#   'accept': True},
#  {'original': 'menubuhkan badan bertindak bagi mengambil langkah wajar agar ahli',
#   'cleaned': 'menubuhkan badan bertindak bagi mengambil langkah wajar agar ahli',
#   'accept': True},
#  {'original': 'adakah buruk bahawa saya mencuri 7k barangan dari kedai runcit',
#   'cleaned': 'adakah buruk bahawa saya mencuri 7k barangan dari kedai runcit',
#   'accept': False},
#  {'original': 'apa yang suka menjadi gay di madras iit',
#   'cleaned': 'apa yang suka menjadi gay di madras iit',
#   'accept': True},
#  {'original': 'kota paris memainkan peranan',
#   'cleaned': 'kota paris memainkan peranan',
#   'accept': True},
#  {'original': 'saat menerima gaji pertama',
#   'cleaned': 'saat menerima gaji pertama',
#   'accept': True},
#  {'original': 'bilakah orang inggeris meminta maaf atas penindasan mereka terhadap orang irak',
#   'cleaned': 'bilakah orang inggeris meminta maaf atas penindasan mereka terhadap orang irak',
#   'accept': True},
#  {'original': 'bagaimana untuk seorang wanita sepanyol tinggal di amerika',
#   'cleaned': 'bagaimana untuk seorang wanita sepanyol tinggal di amerika',
#   'accept': True},
#  {'original': 'kenapa begitu banyak orang india cina yang dimanjakan sombong kenakalan',
#   'cleaned': 'kenapa begitu banyak orang india cina yang dimanjakan sombong kenakalan',
#   'accept': True},
#  {'original': 'adakah sebahagian besar india mempunyai integriti atau kejujuran',
#   'cleaned': 'adakah sebahagian besar india mempunyai integriti atau kejujuran',
#   'accept': True},
#  {'original': 'cimochelys berenang laut silam',
#   'cleaned': 'cimochelys berenang laut silam',
#   'accept': True},
#  {'original': 'apa yang salah dengan mengatakan daging babi bagus di islam',
#   'cleaned': 'apa yang salah dengan mengatakan daging babi bagus di islam',
#   'accept': True},
#  {'original': 'sebut perkataan ampere',
#   'cleaned': 'sebut perkataan ampere',
#   'accept': True},
#  {'original': 'batu persegi menjadikannya negara',
#   'cleaned': 'batu persegi menjadikannya negara',
#   'accept': True},
#  {'original': 'pendidikan tinggi nasional ptptn sentiasa mendapat tempat dalam negara kita',
#   'cleaned': 'pendidikan tinggi nasional ptptn sentiasa mendapat tempat dalam negara kita',
#   'accept': True},
#  {'original': 'cukup serba serbi',
#   'cleaned': 'cukup serba serbi',
#   'accept': True},
#  {'original': 'pada april', 'cleaned': 'pada april', 'accept': True},
#  {'original': 'dikebumikan atas permintaannya tanah',
#   'cleaned': 'dikebumikan atas permintaannya tanah',
#   'accept': True},
#  {'original': 'kerajaan negeri yang ditetapkan sultan johor untuk melantik menteri besar yang',
#   'cleaned': 'kerajaan negeri yang ditetapkan sultan johor untuk melantik menteri besar yang',
#   'accept': True},
#  {'original': 'kenapa african americans seperti tingkap kereta gelap',
#   'cleaned': 'kenapa african americans seperti tingkap kereta gelap',
#   'accept': True},
#  {'original': 'yang dipungut melalui dewan bandaraya kuala lumpur dbkl',
#   'cleaned': 'yang dipungut melalui dewan bandaraya kuala lumpur dbkl',
#   'accept': True},
#  {'original': 'melayu telah dipinjam daripada',
#   'cleaned': 'melayu telah dipinjam daripada',
#   'accept': True},
#  {'original': 'laki dan perempuan dikelas libra memanglah ganjil jadi pasti ada satu laki',
#   'cleaned': 'laki dan perempuan dikelas libra memanglah ganjil jadi pasti ada satu laki',
#   'accept': True},
#  {'original': 'ya abisnya abang bilang aku perut karet mulu kalau lagi makan',
#   'cleaned': 'ya abisnya abang bilang aku perut karet mulu kalau lagi makan',
#   'accept': True},
#  {'original': 'measures mentakrifkan semula meter',
#   'cleaned': 'measures mentakrifkan semula meter',
#   'accept': True},
#  {'original': 'pihak', 'cleaned': 'pihak', 'accept': True},
#  {'original': 'sebut perkataan alau',
#   'cleaned': 'sebut perkataan alau',
#   'accept': True},
#  {'original': 'ini', 'cleaned': 'ini', 'accept': True},
#  {'original': 'membuatnya sesekali bergeser untuk menghindari panas rambut ikal hitam',
#   'cleaned': 'membuatnya sesekali bergeser untuk menghindari panas rambut ikal hitam',
#   'accept': True},
#  {'original': 'kurangnya hujan iklim alp',
#   'cleaned': 'kurangnya hujan iklim alp',
#   'accept': True},
#  {'original': 'phuket kochi dari rm399 bali dari rm629 nanjing dari rm589',
#   'cleaned': 'phuket kochi dari rm399 bali dari rm629 nanjing dari rm589',
#   'accept': False},
#  {'original': 'daratan ini berbeza dengan',
#   'cleaned': 'daratan ini berbeza dengan',
#   'accept': True},
#  {'original': 'isu selingkuh tak selamanya membuat bahtera rumah tangga goyah',
#   'cleaned': 'isu selingkuh tak selamanya membuat bahtera rumah tangga goyah',
#   'accept': True},
#  {'original': 'kecoklatan yang terurai sampai punggung sesekali tersorot sinar matahari',
#   'cleaned': 'kecoklatan yang terurai sampai punggung sesekali tersorot sinar matahari',
#   'accept': True},
#  {'original': 'libra dan gisel saling bertatapan kemudian mengangguk tanda mengiyakan ajakan',
#   'cleaned': 'libra dan gisel saling bertatapan kemudian mengangguk tanda mengiyakan ajakan',
#   'accept': True},
#  {'original': 'bila demam anak perlukan perhatian lebih ibu bapa lah yg kna jaga',
#   'cleaned': 'bila demam anak perlukan perhatian lebih ibu bapa lah yg kna jaga',
#   'accept': True},
#  {'original': 'guterres mengharapkan peralihan kuasa yang aman dan demokratik di algeria selepas',
#   'cleaned': 'guterres mengharapkan peralihan kuasa yang aman dan demokratik di algeria selepas',
#   'accept': True},
#  {'original': 'sebut perkataan advertensi',
#   'cleaned': 'sebut perkataan advertensi',
#   'accept': True},
#  {'original': 'mengapa kuota dipenuhi feminis',
#   'cleaned': 'mengapa kuota dipenuhi feminis',
#   'accept': True},
#  {'original': 'ketika sampan yang dinaikinya',
#   'cleaned': 'ketika sampan yang dinaikinya',
#   'accept': True},
#  {'original': 'datuk seri dr wan salim mohd',
#   'cleaned': 'datuk seri dr wan salim mohd',
#   'accept': True},
#  {'original': 'melayu proto kemudian pada',
#   'cleaned': 'melayu proto kemudian pada',
#   'accept': True},
#  {'original': 'yang menembak sheriff',
#   'cleaned': 'yang menembak sheriff',
#   'accept': True},
#  {'original': 'adakah anda akan berkahwin dengan kambing saya',
#   'cleaned': 'adakah anda akan berkahwin dengan kambing saya',
#   'accept': True},
#  {'original': 'pasang surut planet utama',
#   'cleaned': 'pasang surut planet utama',
#   'accept': True},
#  {'original': 'mungkin wajahnya berubah menjadi wajah yang sumbringah yasmin berjoget joget',
#   'cleaned': 'mungkin wajahnya berubah menjadi wajah yang sumbringah yasmin berjoget joget',
#   'accept': True},
#  {'original': 'tu janji aku pada diri aku',
#   'cleaned': 'tu janji aku pada diri aku',
#   'accept': True},
#  {'original': 'tidak hairanlah kebanyakan kediaman penduduk yang dibina di sekitar sungai berhampiran',
#   'cleaned': 'tidak hairanlah kebanyakan kediaman penduduk yang dibina di sekitar sungai berhampiran',
#   'accept': True},
#  {'original': 'yasmin libra ikut mencari di tempat pensil dan pouch milik yasmin',
#   'cleaned': 'yasmin libra ikut mencari di tempat pensil dan pouch milik yasmin',
#   'accept': True},
#  {'original': 'mempunyai kadar jenayah di bangalore meningkat kerana biharis',
#   'cleaned': 'mempunyai kadar jenayah di bangalore meningkat kerana biharis',
#   'accept': True},
#  {'original': 'semenjak ianya ditubuhkan lebih 20 tahun yang lalu',
#   'cleaned': 'semenjak ianya ditubuhkan lebih dua puluh tahun yang lalu',
#   'accept': True},
#  {'original': 'saji tempat bangdik menaruh tumis tahu buatannya itu piring saji yang isinya',
#   'cleaned': 'saji tempat bangdik menaruh tumis tahu buatannya itu piring saji yang isinya',
#   'accept': True}]

# %%
with open('postprocess-malaya-malay-test-set.json', 'w') as fopen:
    json.dump(new_data, fopen)
