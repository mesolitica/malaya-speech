# %% [markdown]
# # Train Conformer

# %% [markdown]
# Paper related https://arxiv.org/abs/2005.08100

# %% [markdown]
# <div class="alert alert-info">
#
# This tutorial is available as an IPython notebook at [malaya-speech/example/train-asr](https://github.com/huseinzol05/malaya-speech/tree/master/example/train-asr).
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#
# This example trained on a very small dataset, do not use it for production.
#
# </div>

# %% [markdown]
# ### Model Interface
#
# To initiate CNN-RNN,
#
# ```python
# import malaya_speech.train.model.conformer as conformer
#
# x = tf.placeholder(tf.float32, [None, None, num_features, 1])
# config = malaya_speech.config.conformer_small_encoder_config
# model = conformer.Model(**config)
# logits = model(x)
# ```
#
# This model interface do not required input length because we can calculate output length using `ctc.utils.calculate_input_length_deep_speech`.
#
# We also included `base` and `large` configs based on the paper,
#
# ```python
# malaya_speech.config.conformer_base_encoder_config
# malaya_speech.config.conformer_large_encoder_config
# ```

# %%
import os

os.environ['CUDA_VISIBLE_DEVICES'] = '0'

# %%
import tensorflow as tf
from glob import glob
import malaya_speech.config
import malaya_speech.train.model.conformer as conformer
import malaya_speech.train.model.ctc as ctc
import malaya_speech.train as train
import numpy as np
# Out:
# WARNING:tensorflow:From /home/husein/malaya-speech/malaya_speech/train/model/quartznet/layer.py:6: The name tf.layers.Conv1D is deprecated. Please use tf.compat.v1.layers.Conv1D instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %% [markdown]
# ### Load Featurizer
#
# We prefer use `malaya_speech.tf_featurization.STTFeaturizer` for ASR.

# %%
config = malaya_speech.config.transducer_featurizer_config
featurizer = malaya_speech.tf_featurization.STTFeaturizer(**config)
n_mels = config['num_feature_bins']
initial_learning_rate = 1e-3
max_gradient_norm = 5.0
train_steps = 1000

# %%
def preprocess_inputs(example):
    s = featurizer.vectorize(example['waveforms'])
    mel_fbanks = tf.reshape(s, (-1, n_mels))
    length = tf.cast(tf.shape(mel_fbanks)[0], tf.int32)
    length = tf.expand_dims(length, 0)
    example['inputs'] = mel_fbanks
    example['inputs_length'] = length

    return example

# %% [markdown]
# ### Define Data Pipeline

# %%
def parse(serialized_example):

    data_fields = {
        'waveforms': tf.VarLenFeature(tf.float32),
        'targets': tf.VarLenFeature(tf.int64),
    }
    features = tf.parse_single_example(
        serialized_example, features = data_fields
    )
    for k in features.keys():
        features[k] = features[k].values

    features = preprocess_inputs(features)

    keys = list(features.keys())
    for k in keys:
        if k not in ['inputs', 'inputs_length', 'targets']:
            features.pop(k, None)

    return features


def get_dataset(path, batch_size = 32, shuffle_size = 32, thread_count = 24):
    def get():
        files = glob(path)
        dataset = tf.data.TFRecordDataset(files)
        dataset = dataset.shuffle(shuffle_size)
        dataset = dataset.map(parse, num_parallel_calls = thread_count)
        dataset = dataset.padded_batch(
            batch_size,
            padded_shapes = {
                'inputs': tf.TensorShape([None, n_mels]),
                'inputs_length': tf.TensorShape([None]),
                'targets': tf.TensorShape([None]),
            },
            padding_values = {
                'inputs': tf.constant(0, dtype = tf.float32),
                'inputs_length': tf.constant(0, dtype = tf.int32),
                'targets': tf.constant(0, dtype = tf.int64),
            },
        )
        dataset = dataset.repeat()
        return dataset

    return get

# %% [markdown]
# ### Define Model definition
#
# 1. Use malaya_speech CTC loss,
#
# ```python
# mean_error, sum_error, sum_weight = ctc.loss.ctc_loss(
#     logits, targets_int32, seq_lens
# )
# ```
#
# 2. Use malaya_speech CTC sequence accuracy,
#
# ```python
# accuracy = ctc.metrics.ctc_sequence_accuracy(
#     logits, targets_int32, seq_lens
# )
# ```
#
# This will automatically recorded in Tensorboard.
#
# 3. Use malaya_speech output length calculation,
#
# ```python
# seq_lens = ctc.utils.calculate_input_length_deep_speech(
#     features['inputs'], logits
# )
# ```
#
# 4. Use malaya_speech metrics for Evaluation session,
#
# ```python
# elif mode == tf.estimator.ModeKeys.EVAL:
#
#     estimator_spec = tf.estimator.EstimatorSpec(
#         mode = tf.estimator.ModeKeys.EVAL,
#         loss = loss,
#         eval_metric_ops = {
#             'accuracy': ctc.metrics.ctc_sequence_accuracy_estimator(
#                 logits, targets_int32, seq_lens
#             ),
#             'WER': ctc.metrics.word_error_rate_estimator(
#                 logits, targets_int32
#             ),
#         },
#     )
# ```
#
# If we passed directly tensor values to `eval_metric_ops`, Tensorflow will throw error, required update operations. So just stick with that implementation.

# %%
def model_fn(features, labels, mode, params):
    
    config = malaya_speech.config.conformer_small_encoder_config
    model = conformer.Model(**config)
    inputs = tf.expand_dims(features['inputs'], axis = -1)
    logits = model(inputs)
    logits = tf.layers.dense(logits, malaya_speech.char.VOCAB_SIZE)

    seq_lens = ctc.utils.calculate_input_length_deep_speech(
        features['inputs'], logits
    )

    targets_int32 = tf.cast(features['targets'], tf.int32)

    mean_error, sum_error, sum_weight = ctc.loss.ctc_loss(
        logits, targets_int32, seq_lens
    )

    loss = mean_error
    accuracy = ctc.metrics.ctc_sequence_accuracy(
        logits, targets_int32, seq_lens
    )

    tf.identity(loss, 'train_loss')
    tf.identity(accuracy, name = 'train_accuracy')

    if mode == tf.estimator.ModeKeys.TRAIN:
        global_step = tf.train.get_or_create_global_step()
        step = tf.cast(global_step, tf.float32)
        dmodel = tf.cast(config['dmodel'], tf.float32)
        learning_rate = train.schedule.transformer_schedule(step,
                                                           dmodel,
                                                           warmup_steps = 100)

        optimizer = tf.train.AdamOptimizer(learning_rate = learning_rate)
        train_op = optimizer.minimize(loss, global_step = global_step)
        estimator_spec = tf.estimator.EstimatorSpec(
            mode = mode, loss = loss, train_op = train_op
        )

    elif mode == tf.estimator.ModeKeys.EVAL:

        estimator_spec = tf.estimator.EstimatorSpec(
            mode = tf.estimator.ModeKeys.EVAL,
            loss = loss,
            eval_metric_ops = {
                'accuracy': ctc.metrics.ctc_sequence_accuracy_estimator(
                    logits, targets_int32, seq_lens
                ),
                'WER': ctc.metrics.word_error_rate_estimator(
                    logits, targets_int32
                ),
            },
        )

    return estimator_spec

# %%
train_hooks = [
    tf.train.LoggingTensorHook(
        ['train_accuracy', 'train_loss'], every_n_iter = 1
    )
]
train_dataset = get_dataset('tolong-sebut/data/tolong-sebut-train*')
dev_dataset = get_dataset('tolong-sebut/data/tolong-sebut-dev*')

# %%
# !rm -rf asr-smallconformer smallconformer

# %%
train.run_training(
    train_fn = train_dataset,
    model_fn = model_fn,
    model_dir = 'asr-smallconformer',
    num_gpus = 1,
    log_step = 1,
    save_checkpoint_step = 200,
    max_steps = train_steps,
    eval_fn = dev_dataset,
    train_hooks = train_hooks,
)
# Out:
# WARNING:tensorflow:From /home/husein/malaya-speech/malaya_speech/train/__init__.py:40: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From /home/husein/malaya-speech/malaya_speech/train/__init__.py:40: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# INFO:tensorflow:Using config: {'_model_dir': 'smallconformer', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': 200, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f0496a505f8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps 200 or save_checkpoints_secs None.
# WARNING:tensorflow:From /home/husein/.local/lib/python3.6/site-packages/tensorflow_core/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From /home/husein/.local/lib/python3.6/site-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.VarLenFeature is deprecated. Please use tf.io.VarLenFeature instead.
#
# WARNING:tensorflow:From /home/husein/.local/lib/python3.6/site-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.parse_single_example is deprecated. Please use tf.io.parse_single_example instead.
#
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /home/husein/.local/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From <ipython-input-7-940743bc3823>:7: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From /home/husein/.local/lib/python3.6/site-packages/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /home/husein/.local/lib/python3.6/site-packages/tensorflow_core/python/util/deprecation.py:507: calling count_nonzero (from tensorflow.python.ops.math_ops) with axis is deprecated and will be removed in a future version.
# Instructions for updating:
# reduction_indices is deprecated, use axis instead
# WARNING:tensorflow:From /home/husein/malaya-speech/malaya_speech/train/model/ctc/loss.py:21: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /home/husein/malaya-speech/malaya_speech/train/model/ctc/loss.py:26: The name tf.nn.ctc_loss is deprecated. Please use tf.compat.v1.nn.ctc_loss instead.
#
# WARNING:tensorflow:From /home/husein/malaya-speech/malaya_speech/train/model/ctc/loss.py:5: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into smallconformer/model.ckpt.
# INFO:tensorflow:train_accuracy = 0.0, train_loss = 366.34152
# INFO:tensorflow:loss = 366.34152, step = 0
# INFO:tensorflow:global_step/sec: 0.0378867
# INFO:tensorflow:train_accuracy = 0.0, train_loss = 362.8675 (26.395 sec)
# INFO:tensorflow:loss = 362.8675, step = 1 (26.393 sec)
# INFO:tensorflow:global_step/sec: 2.18814
# INFO:tensorflow:train_accuracy = 0.0, train_loss = 264.64792 (0.457 sec)
# INFO:tensorflow:loss = 264.64792, step = 2 (0.457 sec)
# INFO:tensorflow:global_step/sec: 1.98608
# INFO:tensorflow:train_accuracy = 0.0, train_loss = 194.81483 (0.503 sec)
# INFO:tensorflow:loss = 194.81483, step = 3 (0.503 sec)
# INFO:tensorflow:global_step/sec: 2.23116
# INFO:tensorflow:train_accuracy = 0.018064516, train_loss = 184.04941 (0.448 sec)
# INFO:tensorflow:loss = 184.04941, step = 4 (0.448 sec)
# INFO:tensorflow:global_step/sec: 2.39489
# INFO:tensorflow:train_accuracy = 0.012853471, train_loss = 157.70865 (0.418 sec)
# INFO:tensorflow:loss = 157.70865, step = 5 (0.419 sec)
# INFO:tensorflow:global_step/sec: 2.61704
# INFO:tensorflow:train_accuracy = 0.014248705, train_loss = 159.03758 (0.382 sec)
# INFO:tensorflow:loss = 159.03758, step = 6 (0.381 sec)
# INFO:tensorflow:global_step/sec: 2.0375
# INFO:tensorflow:train_accuracy = 0.015831135, train_loss = 142.63837 (0.491 sec)
# INFO:tensorflow:loss = 142.63837, step = 7 (0.491 sec)
# INFO:tensorflow:global_step/sec: 2.14842
# INFO:tensorflow:train_accuracy = 0.0131752305, train_loss = 137.90854 (0.465 sec)
# INFO:tensorflow:loss = 137.90854, step = 8 (0.465 sec)
# INFO:tensorflow:global_step/sec: 1.97962
# INFO:tensorflow:train_accuracy = 0.019404916, train_loss = 139.54233 (0.505 sec)
# INFO:tensorflow:loss = 139.54233, step = 9 (0.505 sec)
# INFO:tensorflow:global_step/sec: 2.29201
# INFO:tensorflow:train_accuracy = 0.018666666, train_loss = 130.99231 (0.436 sec)
# INFO:tensorflow:loss = 130.99231, step = 10 (0.436 sec)
# INFO:tensorflow:global_step/sec: 2.06366
# INFO:tensorflow:train_accuracy = 0.014492754, train_loss = 127.67216 (0.485 sec)
# INFO:tensorflow:loss = 127.67216, step = 11 (0.485 sec)
# INFO:tensorflow:global_step/sec: 2.03802
# INFO:tensorflow:train_accuracy = 0.016107382, train_loss = 122.6028 (0.491 sec)
# INFO:tensorflow:loss = 122.6028, step = 12 (0.491 sec)
# INFO:tensorflow:global_step/sec: 1.99538
# INFO:tensorflow:train_accuracy = 0.020026702, train_loss = 122.491066 (0.501 sec)
# INFO:tensorflow:loss = 122.491066, step = 13 (0.501 sec)
# INFO:tensorflow:global_step/sec: 2.48416
# INFO:tensorflow:train_accuracy = 0.015267176, train_loss = 125.88825 (0.403 sec)
# INFO:tensorflow:loss = 125.88825, step = 14 (0.403 sec)
# INFO:tensorflow:global_step/sec: 2.04766
# INFO:tensorflow:train_accuracy = 0.01171875, train_loss = 119.57432 (0.489 sec)
# INFO:tensorflow:loss = 119.57432, step = 15 (0.489 sec)
# INFO:tensorflow:global_step/sec: 1.93985
# INFO:tensorflow:train_accuracy = 0.015384615, train_loss = 120.45496 (0.515 sec)
# INFO:tensorflow:loss = 120.45496, step = 16 (0.515 sec)
# INFO:tensorflow:global_step/sec: 2.14576
# INFO:tensorflow:train_accuracy = 0.014138818, train_loss = 117.52348 (0.466 sec)
# INFO:tensorflow:loss = 117.52348, step = 17 (0.465 sec)
# INFO:tensorflow:global_step/sec: 2.02879
# INFO:tensorflow:train_accuracy = 0.016774194, train_loss = 113.99678 (0.493 sec)
# INFO:tensorflow:loss = 113.99678, step = 18 (0.494 sec)
# INFO:tensorflow:global_step/sec: 2.61475
# INFO:tensorflow:train_accuracy = 0.022516556, train_loss = 114.42412 (0.382 sec)
# INFO:tensorflow:loss = 114.42412, step = 19 (0.383 sec)
# INFO:tensorflow:global_step/sec: 2.09826
# INFO:tensorflow:train_accuracy = 0.01458886, train_loss = 109.36681 (0.476 sec)
# INFO:tensorflow:loss = 109.36681, step = 20 (0.476 sec)
# INFO:tensorflow:global_step/sec: 2.39986
# INFO:tensorflow:train_accuracy = 0.016949153, train_loss = 109.833694 (0.417 sec)
# INFO:tensorflow:loss = 109.833694, step = 21 (0.416 sec)
# INFO:tensorflow:global_step/sec: 2.42899
# INFO:tensorflow:train_accuracy = 0.01142132, train_loss = 111.8834 (0.412 sec)
# INFO:tensorflow:loss = 111.8834, step = 22 (0.412 sec)
# INFO:tensorflow:global_step/sec: 2.41203
# INFO:tensorflow:train_accuracy = 0.011795544, train_loss = 106.53912 (0.415 sec)
# INFO:tensorflow:loss = 106.53912, step = 23 (0.415 sec)
# INFO:tensorflow:global_step/sec: 2.08204
# INFO:tensorflow:train_accuracy = 0.015604681, train_loss = 105.193665 (0.480 sec)
# INFO:tensorflow:loss = 105.193665, step = 24 (0.480 sec)
# INFO:tensorflow:global_step/sec: 1.9793
# INFO:tensorflow:train_accuracy = 0.018158237, train_loss = 104.88016 (0.505 sec)
# INFO:tensorflow:loss = 104.88016, step = 25 (0.505 sec)
# INFO:tensorflow:global_step/sec: 2.58696
# INFO:tensorflow:train_accuracy = 0.016348774, train_loss = 102.19976 (0.387 sec)
# INFO:tensorflow:loss = 102.19976, step = 26 (0.387 sec)
# INFO:tensorflow:global_step/sec: 2.26251
# INFO:tensorflow:train_accuracy = 0.020278834, train_loss = 110.22637 (0.442 sec)
# INFO:tensorflow:loss = 110.22637, step = 27 (0.442 sec)
# INFO:tensorflow:global_step/sec: 2.33734
# INFO:tensorflow:train_accuracy = 0.01509434, train_loss = 105.53534 (0.428 sec)
# INFO:tensorflow:loss = 105.53534, step = 28 (0.429 sec)
# INFO:tensorflow:global_step/sec: 2.52331
# INFO:tensorflow:train_accuracy = 0.012578616, train_loss = 105.64967 (0.396 sec)
# INFO:tensorflow:loss = 105.64967, step = 29 (0.395 sec)
# INFO:tensorflow:global_step/sec: 2.07532
# INFO:tensorflow:train_accuracy = 0.015345269, train_loss = 106.27735 (0.482 sec)
# INFO:tensorflow:loss = 106.27735, step = 30 (0.482 sec)
# INFO:tensorflow:global_step/sec: 2.63318
# INFO:tensorflow:train_accuracy = 0.014397906, train_loss = 103.16409 (0.380 sec)
# INFO:tensorflow:loss = 103.16409, step = 31 (0.380 sec)
# INFO:tensorflow:global_step/sec: 2.17546
# INFO:tensorflow:train_accuracy = 0.013888889, train_loss = 104.72889 (0.460 sec)
# INFO:tensorflow:loss = 104.72889, step = 32 (0.460 sec)
# INFO:tensorflow:global_step/sec: 1.92495
# INFO:tensorflow:train_accuracy = 0.01891551, train_loss = 106.20057 (0.520 sec)
# INFO:tensorflow:loss = 106.20057, step = 33 (0.520 sec)
# INFO:tensorflow:global_step/sec: 2.77517
# INFO:tensorflow:train_accuracy = 0.01509434, train_loss = 107.59737 (0.360 sec)
# INFO:tensorflow:loss = 107.59737, step = 34 (0.360 sec)
# INFO:tensorflow:global_step/sec: 2.1369
# INFO:tensorflow:train_accuracy = 0.020434227, train_loss = 107.734795 (0.468 sec)
# INFO:tensorflow:loss = 107.734795, step = 35 (0.468 sec)
# INFO:tensorflow:global_step/sec: 2.67588
# INFO:tensorflow:train_accuracy = 0.015306123, train_loss = 105.0259 (0.374 sec)
# INFO:tensorflow:loss = 105.0259, step = 36 (0.373 sec)
# INFO:tensorflow:global_step/sec: 2.3789
# INFO:tensorflow:train_accuracy = 0.015345269, train_loss = 102.09475 (0.420 sec)
# INFO:tensorflow:loss = 102.09475, step = 37 (0.420 sec)
# INFO:tensorflow:global_step/sec: 1.9418
# INFO:tensorflow:train_accuracy = 0.016270338, train_loss = 102.65009 (0.515 sec)
# INFO:tensorflow:loss = 102.65009, step = 38 (0.514 sec)
# INFO:tensorflow:global_step/sec: 2.88567
# INFO:tensorflow:train_accuracy = 0.013924051, train_loss = 99.0083 (0.347 sec)
# INFO:tensorflow:loss = 99.0083, step = 39 (0.347 sec)
# INFO:tensorflow:global_step/sec: 2.82625
# INFO:tensorflow:train_accuracy = 0.020408163, train_loss = 101.93703 (0.354 sec)
# INFO:tensorflow:loss = 101.93703, step = 40 (0.353 sec)
# INFO:tensorflow:global_step/sec: 1.90115
# INFO:tensorflow:train_accuracy = 0.027704485, train_loss = 92.93355 (0.526 sec)
# INFO:tensorflow:loss = 92.93355, step = 41 (0.527 sec)
# INFO:tensorflow:global_step/sec: 2.92559
# INFO:tensorflow:train_accuracy = 0.027061855, train_loss = 97.46834 (0.342 sec)
# INFO:tensorflow:loss = 97.46834, step = 42 (0.341 sec)
# INFO:tensorflow:global_step/sec: 2.85235
# INFO:tensorflow:train_accuracy = 0.026490066, train_loss = 91.109604 (0.351 sec)
# INFO:tensorflow:loss = 91.109604, step = 43 (0.351 sec)
# INFO:tensorflow:global_step/sec: 2.80193
# INFO:tensorflow:train_accuracy = 0.0, train_loss = 96.17671 (0.357 sec)
# INFO:tensorflow:loss = 96.17671, step = 44 (0.357 sec)
# INFO:tensorflow:global_step/sec: 2.71908
# INFO:tensorflow:train_accuracy = 0.0, train_loss = 93.92184 (0.367 sec)
# INFO:tensorflow:loss = 93.92184, step = 45 (0.367 sec)
# INFO:tensorflow:global_step/sec: 2.40596
# INFO:tensorflow:train_accuracy = 0.0, train_loss = 95.42091 (0.416 sec)
# INFO:tensorflow:loss = 95.42091, step = 46 (0.416 sec)
# INFO:tensorflow:global_step/sec: 2.70504
# INFO:tensorflow:train_accuracy = 0.0, train_loss = 96.81825 (0.370 sec)
# INFO:tensorflow:loss = 96.81825, step = 47 (0.370 sec)
# INFO:tensorflow:global_step/sec: 2.60971
# INFO:tensorflow:train_accuracy = 0.0, train_loss = 100.547165 (0.383 sec)
# INFO:tensorflow:loss = 100.547165, step = 48 (0.383 sec)
# INFO:tensorflow:global_step/sec: 2.6403
# INFO:tensorflow:train_accuracy = 0.0, train_loss = 99.99084 (0.379 sec)
# INFO:tensorflow:loss = 99.99084, step = 49 (0.379 sec)
# INFO:tensorflow:global_step/sec: 2.73128
# INFO:tensorflow:train_accuracy = 0.0, train_loss = 89.83876 (0.366 sec)
# INFO:tensorflow:loss = 89.83876, step = 50 (0.365 sec)
# INFO:tensorflow:global_step/sec: 2.63681
# INFO:tensorflow:train_accuracy = 0.0, train_loss = 92.47521 (0.380 sec)
# INFO:tensorflow:loss = 92.47521, step = 51 (0.380 sec)
# INFO:tensorflow:global_step/sec: 2.7073
# INFO:tensorflow:train_accuracy = 0.053915277, train_loss = 92.81206 (0.369 sec)
# INFO:tensorflow:loss = 92.81206, step = 52 (0.369 sec)
# INFO:tensorflow:global_step/sec: 2.46879
# INFO:tensorflow:train_accuracy = 0.048714478, train_loss = 87.747604 (0.405 sec)
# INFO:tensorflow:loss = 87.747604, step = 53 (0.405 sec)
# INFO:tensorflow:global_step/sec: 2.52158
# INFO:tensorflow:train_accuracy = 0.021656051, train_loss = 93.61688 (0.396 sec)
# INFO:tensorflow:loss = 93.61688, step = 54 (0.396 sec)
# INFO:tensorflow:global_step/sec: 2.67581
# INFO:tensorflow:train_accuracy = 0.027667984, train_loss = 89.71619 (0.374 sec)
# INFO:tensorflow:loss = 89.71619, step = 55 (0.374 sec)
# INFO:tensorflow:global_step/sec: 2.83407
# INFO:tensorflow:train_accuracy = 0.026385223, train_loss = 87.09268 (0.352 sec)
# INFO:tensorflow:loss = 87.09268, step = 56 (0.352 sec)
# INFO:tensorflow:global_step/sec: 2.37836
# INFO:tensorflow:train_accuracy = 0.049414825, train_loss = 92.332535 (0.421 sec)
# INFO:tensorflow:loss = 92.332535, step = 57 (0.421 sec)
# INFO:tensorflow:global_step/sec: 2.75182
# INFO:tensorflow:train_accuracy = 0.022106633, train_loss = 90.58803 (0.363 sec)
# INFO:tensorflow:loss = 90.58803, step = 58 (0.363 sec)
# INFO:tensorflow:global_step/sec: 2.83004
# INFO:tensorflow:train_accuracy = 0.0, train_loss = 84.13824 (0.353 sec)
# INFO:tensorflow:loss = 84.13824, step = 59 (0.354 sec)
# INFO:tensorflow:global_step/sec: 2.85991
# INFO:tensorflow:train_accuracy = 0.0, train_loss = 89.190765 (0.350 sec)
# INFO:tensorflow:loss = 89.190765, step = 60 (0.350 sec)
# INFO:tensorflow:global_step/sec: 2.74547
# INFO:tensorflow:train_accuracy = 0.0, train_loss = 87.524284 (0.364 sec)
# INFO:tensorflow:loss = 87.524284, step = 61 (0.363 sec)
# INFO:tensorflow:global_step/sec: 2.88885
# INFO:tensorflow:train_accuracy = 0.0, train_loss = 86.912994 (0.346 sec)
# INFO:tensorflow:loss = 86.912994, step = 62 (0.346 sec)
# INFO:tensorflow:global_step/sec: 2.6505
# INFO:tensorflow:train_accuracy = 0.02457956, train_loss = 84.20546 (0.377 sec)
# INFO:tensorflow:loss = 84.20546, step = 63 (0.378 sec)
# INFO:tensorflow:global_step/sec: 2.41171
# INFO:tensorflow:train_accuracy = 0.057298772, train_loss = 78.91551 (0.414 sec)
# INFO:tensorflow:loss = 78.91551, step = 64 (0.414 sec)
# INFO:tensorflow:global_step/sec: 2.7415
# INFO:tensorflow:train_accuracy = 0.041775458, train_loss = 83.64827 (0.365 sec)
# INFO:tensorflow:loss = 83.64827, step = 65 (0.364 sec)
# INFO:tensorflow:global_step/sec: 2.73489
# INFO:tensorflow:train_accuracy = 0.04076433, train_loss = 85.654236 (0.366 sec)
# INFO:tensorflow:loss = 85.654236, step = 66 (0.366 sec)
# INFO:tensorflow:global_step/sec: 2.52377
# INFO:tensorflow:train_accuracy = 0.049222797, train_loss = 101.51657 (0.396 sec)
# INFO:tensorflow:loss = 101.51657, step = 67 (0.396 sec)
# INFO:tensorflow:global_step/sec: 2.49205
# INFO:tensorflow:train_accuracy = 0.024813896, train_loss = 87.62999 (0.401 sec)
# INFO:tensorflow:loss = 87.62999, step = 68 (0.401 sec)
# INFO:tensorflow:global_step/sec: 2.01348
# INFO:tensorflow:train_accuracy = 0.06481481, train_loss = 91.34483 (0.496 sec)
# INFO:tensorflow:loss = 91.34483, step = 69 (0.496 sec)
# INFO:tensorflow:global_step/sec: 2.89666
# INFO:tensorflow:train_accuracy = 0.041237112, train_loss = 84.09352 (0.345 sec)
# INFO:tensorflow:loss = 84.09352, step = 70 (0.345 sec)
# INFO:tensorflow:global_step/sec: 2.84294
# INFO:tensorflow:train_accuracy = 0.072386056, train_loss = 79.1992 (0.352 sec)
# INFO:tensorflow:loss = 79.1992, step = 71 (0.352 sec)
# INFO:tensorflow:global_step/sec: 2.6907
# INFO:tensorflow:train_accuracy = 0.048843186, train_loss = 86.44265 (0.372 sec)
# INFO:tensorflow:loss = 86.44265, step = 72 (0.372 sec)
# INFO:tensorflow:global_step/sec: 2.65635
# INFO:tensorflow:train_accuracy = 0.029262086, train_loss = 81.86558 (0.376 sec)
# INFO:tensorflow:loss = 81.86558, step = 73 (0.376 sec)
# INFO:tensorflow:global_step/sec: 2.55669
# INFO:tensorflow:train_accuracy = 0.019035533, train_loss = 84.7525 (0.391 sec)
# INFO:tensorflow:loss = 84.7525, step = 74 (0.391 sec)
# INFO:tensorflow:global_step/sec: 2.75561
# INFO:tensorflow:train_accuracy = 0.02464332, train_loss = 78.062126 (0.363 sec)
# INFO:tensorflow:loss = 78.062126, step = 75 (0.363 sec)
# INFO:tensorflow:global_step/sec: 2.74238
# INFO:tensorflow:train_accuracy = 0.04035309, train_loss = 76.80178 (0.365 sec)
# INFO:tensorflow:loss = 76.80178, step = 76 (0.365 sec)
# INFO:tensorflow:global_step/sec: 2.15815
# INFO:tensorflow:train_accuracy = 0.15645371, train_loss = 71.55801 (0.463 sec)
# INFO:tensorflow:loss = 71.55801, step = 77 (0.463 sec)
# INFO:tensorflow:global_step/sec: 2.73803
# INFO:tensorflow:train_accuracy = 0.15625, train_loss = 76.873474 (0.365 sec)
# INFO:tensorflow:loss = 76.873474, step = 78 (0.365 sec)
# INFO:tensorflow:global_step/sec: 2.66031
# INFO:tensorflow:train_accuracy = 0.23391089, train_loss = 76.12234 (0.376 sec)
# INFO:tensorflow:loss = 76.12234, step = 79 (0.376 sec)
# INFO:tensorflow:global_step/sec: 2.31487
# INFO:tensorflow:train_accuracy = 0.21571238, train_loss = 70.12114 (0.432 sec)
# INFO:tensorflow:loss = 70.12114, step = 80 (0.432 sec)
# INFO:tensorflow:global_step/sec: 1.75117
# INFO:tensorflow:train_accuracy = 0.14091471, train_loss = 76.619064 (0.571 sec)
# INFO:tensorflow:loss = 76.619064, step = 81 (0.572 sec)
# INFO:tensorflow:global_step/sec: 2.36337
# INFO:tensorflow:train_accuracy = 0.15809284, train_loss = 76.058784 (0.423 sec)
# INFO:tensorflow:loss = 76.058784, step = 82 (0.423 sec)
# INFO:tensorflow:global_step/sec: 2.44639
# INFO:tensorflow:train_accuracy = 0.10759494, train_loss = 68.72663 (0.408 sec)
# INFO:tensorflow:loss = 68.72663, step = 83 (0.408 sec)
# INFO:tensorflow:global_step/sec: 2.99263
# INFO:tensorflow:train_accuracy = 0.23589744, train_loss = 59.071636 (0.334 sec)
# INFO:tensorflow:loss = 59.071636, step = 84 (0.334 sec)
# INFO:tensorflow:global_step/sec: 2.63489
# INFO:tensorflow:train_accuracy = 0.07930607, train_loss = 70.72281 (0.380 sec)
# INFO:tensorflow:loss = 70.72281, step = 85 (0.380 sec)
# INFO:tensorflow:global_step/sec: 2.72332
# INFO:tensorflow:train_accuracy = 0.0, train_loss = 71.68194 (0.367 sec)
# INFO:tensorflow:loss = 71.68194, step = 86 (0.367 sec)
# INFO:tensorflow:global_step/sec: 2.42197
# INFO:tensorflow:train_accuracy = 0.23631841, train_loss = 62.431587 (0.413 sec)
# INFO:tensorflow:loss = 62.431587, step = 87 (0.413 sec)
# INFO:tensorflow:global_step/sec: 2.7365
# INFO:tensorflow:train_accuracy = 0.22503328, train_loss = 55.14688 (0.366 sec)
# INFO:tensorflow:loss = 55.14688, step = 88 (0.366 sec)
# INFO:tensorflow:global_step/sec: 2.0798
# INFO:tensorflow:train_accuracy = 0.036505867, train_loss = 52.265003 (0.481 sec)
# INFO:tensorflow:loss = 52.265003, step = 89 (0.481 sec)
# INFO:tensorflow:global_step/sec: 2.8125
# INFO:tensorflow:train_accuracy = 0.2537931, train_loss = 46.025356 (0.356 sec)
# INFO:tensorflow:loss = 46.025356, step = 90 (0.356 sec)
# INFO:tensorflow:global_step/sec: 2.82456
# INFO:tensorflow:train_accuracy = 0.11111111, train_loss = 52.32105 (0.354 sec)
# INFO:tensorflow:loss = 52.32105, step = 91 (0.354 sec)
# INFO:tensorflow:global_step/sec: 2.36229
# INFO:tensorflow:train_accuracy = 0.21989529, train_loss = 48.077057 (0.423 sec)
# INFO:tensorflow:loss = 48.077057, step = 92 (0.423 sec)
# INFO:tensorflow:global_step/sec: 2.93188
# INFO:tensorflow:train_accuracy = 0.29003784, train_loss = 49.76819 (0.341 sec)
# INFO:tensorflow:loss = 49.76819, step = 93 (0.341 sec)
# INFO:tensorflow:global_step/sec: 2.95944
# INFO:tensorflow:train_accuracy = 0.09505703, train_loss = 50.70616 (0.338 sec)
# INFO:tensorflow:loss = 50.70616, step = 94 (0.339 sec)
# INFO:tensorflow:global_step/sec: 2.54762
# INFO:tensorflow:train_accuracy = 0.14814815, train_loss = 50.03411 (0.392 sec)
# INFO:tensorflow:loss = 50.03411, step = 95 (0.392 sec)
# INFO:tensorflow:global_step/sec: 2.55094
# INFO:tensorflow:train_accuracy = 0.28145266, train_loss = 47.378998 (0.392 sec)
# INFO:tensorflow:loss = 47.378998, step = 96 (0.393 sec)
# INFO:tensorflow:global_step/sec: 2.52763
# INFO:tensorflow:train_accuracy = 0.21456437, train_loss = 46.82217 (0.395 sec)
# INFO:tensorflow:loss = 46.82217, step = 97 (0.394 sec)
# INFO:tensorflow:global_step/sec: 2.55362
# INFO:tensorflow:train_accuracy = 0.2869898, train_loss = 45.883293 (0.392 sec)
# INFO:tensorflow:loss = 45.883293, step = 98 (0.392 sec)
# INFO:tensorflow:global_step/sec: 2.09686
# INFO:tensorflow:train_accuracy = 0.2549801, train_loss = 46.58568 (0.477 sec)
# INFO:tensorflow:loss = 46.58568, step = 99 (0.477 sec)
# INFO:tensorflow:global_step/sec: 3.0143
# INFO:tensorflow:train_accuracy = 0.31258106, train_loss = 46.661102 (0.333 sec)
# INFO:tensorflow:loss = 46.661102, step = 100 (0.333 sec)
# INFO:tensorflow:global_step/sec: 2.38705
# INFO:tensorflow:train_accuracy = 0.25, train_loss = 45.892708 (0.418 sec)
# INFO:tensorflow:loss = 45.892708, step = 101 (0.418 sec)
# INFO:tensorflow:global_step/sec: 2.53235
# INFO:tensorflow:train_accuracy = 0.18758257, train_loss = 44.984642 (0.395 sec)
# INFO:tensorflow:loss = 44.984642, step = 102 (0.395 sec)
# INFO:tensorflow:global_step/sec: 2.59077
# INFO:tensorflow:train_accuracy = 0.21796565, train_loss = 44.02687 (0.386 sec)
# INFO:tensorflow:loss = 44.02687, step = 103 (0.385 sec)
# INFO:tensorflow:global_step/sec: 2.60895
# INFO:tensorflow:train_accuracy = 0.10810811, train_loss = 44.503586 (0.384 sec)
# INFO:tensorflow:loss = 44.503586, step = 104 (0.384 sec)
# INFO:tensorflow:global_step/sec: 2.57062
# INFO:tensorflow:train_accuracy = 0.13189772, train_loss = 42.83908 (0.389 sec)
# INFO:tensorflow:loss = 42.83908, step = 105 (0.389 sec)
# INFO:tensorflow:global_step/sec: 2.67004
# INFO:tensorflow:train_accuracy = 0.32941177, train_loss = 43.23312 (0.375 sec)
# INFO:tensorflow:loss = 43.23312, step = 106 (0.375 sec)
# INFO:tensorflow:global_step/sec: 2.44057
# INFO:tensorflow:train_accuracy = 0.30125, train_loss = 46.476173 (0.410 sec)
# INFO:tensorflow:loss = 46.476173, step = 107 (0.410 sec)
# INFO:tensorflow:global_step/sec: 2.44141
# INFO:tensorflow:train_accuracy = 0.3026316, train_loss = 43.49082 (0.410 sec)
# INFO:tensorflow:loss = 43.49082, step = 108 (0.410 sec)
# INFO:tensorflow:global_step/sec: 2.62085
# INFO:tensorflow:train_accuracy = 0.30232558, train_loss = 42.67875 (0.381 sec)
# INFO:tensorflow:loss = 42.67875, step = 109 (0.381 sec)
# INFO:tensorflow:global_step/sec: 2.56506
# INFO:tensorflow:train_accuracy = 0.32147563, train_loss = 41.241405 (0.390 sec)
# INFO:tensorflow:loss = 41.241405, step = 110 (0.390 sec)
# INFO:tensorflow:global_step/sec: 2.50063
# INFO:tensorflow:train_accuracy = 0.32891247, train_loss = 42.484932 (0.400 sec)
# INFO:tensorflow:loss = 42.484932, step = 111 (0.400 sec)
# INFO:tensorflow:global_step/sec: 2.56347
# INFO:tensorflow:train_accuracy = 0.3958869, train_loss = 42.089836 (0.390 sec)
# INFO:tensorflow:loss = 42.089836, step = 112 (0.390 sec)
# INFO:tensorflow:global_step/sec: 1.95632
# INFO:tensorflow:train_accuracy = 0.37124184, train_loss = 41.35884 (0.511 sec)
# INFO:tensorflow:loss = 41.35884, step = 113 (0.511 sec)
# INFO:tensorflow:global_step/sec: 2.54846
# INFO:tensorflow:train_accuracy = 0.28342247, train_loss = 42.199776 (0.392 sec)
# INFO:tensorflow:loss = 42.199776, step = 114 (0.392 sec)
# INFO:tensorflow:global_step/sec: 2.33639
# INFO:tensorflow:train_accuracy = 0.33505154, train_loss = 42.657516 (0.428 sec)
# INFO:tensorflow:loss = 42.657516, step = 115 (0.428 sec)
# INFO:tensorflow:global_step/sec: 2.73047
# INFO:tensorflow:train_accuracy = 0.094736844, train_loss = 41.138885 (0.367 sec)
# INFO:tensorflow:loss = 41.138885, step = 116 (0.367 sec)
# INFO:tensorflow:global_step/sec: 2.38731
# INFO:tensorflow:train_accuracy = 0.28643852, train_loss = 44.922592 (0.419 sec)
# INFO:tensorflow:loss = 44.922592, step = 117 (0.419 sec)
# INFO:tensorflow:global_step/sec: 2.5892
# INFO:tensorflow:train_accuracy = 0.32219252, train_loss = 39.573387 (0.386 sec)
# INFO:tensorflow:loss = 39.573387, step = 118 (0.386 sec)
# INFO:tensorflow:global_step/sec: 2.58238
# INFO:tensorflow:train_accuracy = 0.3625954, train_loss = 42.426838 (0.387 sec)
# INFO:tensorflow:loss = 42.426838, step = 119 (0.387 sec)
# INFO:tensorflow:global_step/sec: 2.1962
# INFO:tensorflow:train_accuracy = 0.2754717, train_loss = 45.29125 (0.455 sec)
# INFO:tensorflow:loss = 45.29125, step = 120 (0.456 sec)
# INFO:tensorflow:global_step/sec: 2.57911
# INFO:tensorflow:train_accuracy = 0.3549223, train_loss = 40.863976 (0.388 sec)
# INFO:tensorflow:loss = 40.863976, step = 121 (0.388 sec)
# INFO:tensorflow:global_step/sec: 2.55678
# INFO:tensorflow:train_accuracy = 0.2864259, train_loss = 45.286404 (0.391 sec)
# INFO:tensorflow:loss = 45.286404, step = 122 (0.391 sec)
# INFO:tensorflow:global_step/sec: 2.44975
# INFO:tensorflow:train_accuracy = 0.3164721, train_loss = 41.102158 (0.408 sec)
# INFO:tensorflow:loss = 41.102158, step = 123 (0.408 sec)
# INFO:tensorflow:global_step/sec: 2.45611
# INFO:tensorflow:train_accuracy = 0.2893726, train_loss = 43.26918 (0.407 sec)
# INFO:tensorflow:loss = 43.26918, step = 124 (0.407 sec)
# INFO:tensorflow:global_step/sec: 2.44427
# INFO:tensorflow:train_accuracy = 0.29789865, train_loss = 43.91452 (0.409 sec)
# INFO:tensorflow:loss = 43.91452, step = 125 (0.409 sec)
# INFO:tensorflow:global_step/sec: 2.53003
# INFO:tensorflow:train_accuracy = 0.3415906, train_loss = 39.579372 (0.396 sec)
# INFO:tensorflow:loss = 39.579372, step = 126 (0.396 sec)
# INFO:tensorflow:global_step/sec: 2.40784
# INFO:tensorflow:train_accuracy = 0.315, train_loss = 43.78041 (0.415 sec)
# INFO:tensorflow:loss = 43.78041, step = 127 (0.415 sec)
# INFO:tensorflow:global_step/sec: 2.30477
# INFO:tensorflow:train_accuracy = 0.2782719, train_loss = 44.24954 (0.434 sec)
# INFO:tensorflow:loss = 44.24954, step = 128 (0.434 sec)
# INFO:tensorflow:global_step/sec: 2.60198
# INFO:tensorflow:train_accuracy = 0.12323492, train_loss = 41.495926 (0.384 sec)
# INFO:tensorflow:loss = 41.495926, step = 129 (0.384 sec)
# INFO:tensorflow:global_step/sec: 2.30802
# INFO:tensorflow:train_accuracy = 0.13307984, train_loss = 40.015083 (0.433 sec)
# INFO:tensorflow:loss = 40.015083, step = 130 (0.433 sec)
# INFO:tensorflow:global_step/sec: 2.5261
# INFO:tensorflow:train_accuracy = 0.28644502, train_loss = 44.107357 (0.396 sec)
# INFO:tensorflow:loss = 44.107357, step = 131 (0.396 sec)
# INFO:tensorflow:global_step/sec: 2.16965
# INFO:tensorflow:train_accuracy = 0.35630688, train_loss = 39.063713 (0.461 sec)
# INFO:tensorflow:loss = 39.063713, step = 132 (0.461 sec)
# INFO:tensorflow:global_step/sec: 2.57198
# INFO:tensorflow:train_accuracy = 0.30818415, train_loss = 42.290794 (0.389 sec)
# INFO:tensorflow:loss = 42.290794, step = 133 (0.389 sec)
# INFO:tensorflow:global_step/sec: 2.76538
# INFO:tensorflow:train_accuracy = 0.2782719, train_loss = 42.960167 (0.362 sec)
# INFO:tensorflow:loss = 42.960167, step = 134 (0.362 sec)
# INFO:tensorflow:global_step/sec: 2.41125
# INFO:tensorflow:train_accuracy = 0.12483745, train_loss = 40.929626 (0.415 sec)
# INFO:tensorflow:loss = 40.929626, step = 135 (0.415 sec)
# INFO:tensorflow:global_step/sec: 2.6601
# INFO:tensorflow:train_accuracy = 0.14516129, train_loss = 36.426254 (0.376 sec)
# INFO:tensorflow:loss = 36.426254, step = 136 (0.376 sec)
# INFO:tensorflow:global_step/sec: 2.87397
# INFO:tensorflow:train_accuracy = 0.29064038, train_loss = 35.430893 (0.348 sec)
# INFO:tensorflow:loss = 35.430893, step = 137 (0.348 sec)
# INFO:tensorflow:global_step/sec: 2.28751
# INFO:tensorflow:train_accuracy = 0.33333334, train_loss = 37.015686 (0.437 sec)
# INFO:tensorflow:loss = 37.015686, step = 138 (0.437 sec)
# INFO:tensorflow:global_step/sec: 2.44305
# INFO:tensorflow:train_accuracy = 0.26871166, train_loss = 44.488472 (0.409 sec)
# INFO:tensorflow:loss = 44.488472, step = 139 (0.409 sec)
# INFO:tensorflow:global_step/sec: 2.3065
# INFO:tensorflow:train_accuracy = 0.29336736, train_loss = 42.013206 (0.434 sec)
# INFO:tensorflow:loss = 42.013206, step = 140 (0.434 sec)
# INFO:tensorflow:global_step/sec: 2.01902
# INFO:tensorflow:train_accuracy = 0.16412213, train_loss = 40.934677 (0.495 sec)
# INFO:tensorflow:loss = 40.934677, step = 141 (0.495 sec)
# INFO:tensorflow:global_step/sec: 2.47319
# INFO:tensorflow:train_accuracy = 0.16431323, train_loss = 41.33882 (0.404 sec)
# INFO:tensorflow:loss = 41.33882, step = 142 (0.404 sec)
# INFO:tensorflow:global_step/sec: 2.54849
# INFO:tensorflow:train_accuracy = 0.3469388, train_loss = 40.556747 (0.392 sec)
# INFO:tensorflow:loss = 40.556747, step = 143 (0.392 sec)
# INFO:tensorflow:global_step/sec: 2.88149
# INFO:tensorflow:train_accuracy = 0.38845146, train_loss = 38.352203 (0.347 sec)
# INFO:tensorflow:loss = 38.352203, step = 144 (0.346 sec)
# INFO:tensorflow:global_step/sec: 2.25287
# INFO:tensorflow:train_accuracy = 0.3159304, train_loss = 38.271236 (0.444 sec)
# INFO:tensorflow:loss = 38.271236, step = 145 (0.444 sec)
# INFO:tensorflow:global_step/sec: 2.35716
# INFO:tensorflow:train_accuracy = 0.32207793, train_loss = 40.869766 (0.425 sec)
# INFO:tensorflow:loss = 40.869766, step = 146 (0.425 sec)
# INFO:tensorflow:global_step/sec: 2.59107
# INFO:tensorflow:train_accuracy = 0.15852048, train_loss = 37.99257 (0.386 sec)
# INFO:tensorflow:loss = 37.99257, step = 147 (0.386 sec)
# INFO:tensorflow:global_step/sec: 2.44911
# INFO:tensorflow:train_accuracy = 0.15897436, train_loss = 40.878147 (0.409 sec)
# INFO:tensorflow:loss = 40.878147, step = 148 (0.409 sec)
# INFO:tensorflow:global_step/sec: 2.5395
# INFO:tensorflow:train_accuracy = 0.13833992, train_loss = 37.622314 (0.394 sec)
# INFO:tensorflow:loss = 37.622314, step = 149 (0.394 sec)
# INFO:tensorflow:global_step/sec: 2.58189
# INFO:tensorflow:train_accuracy = 0.344692, train_loss = 37.20218 (0.387 sec)
# INFO:tensorflow:loss = 37.20218, step = 150 (0.387 sec)
# INFO:tensorflow:global_step/sec: 2.56954
# INFO:tensorflow:train_accuracy = 0.34871796, train_loss = 42.143288 (0.389 sec)
# INFO:tensorflow:loss = 42.143288, step = 151 (0.389 sec)
# INFO:tensorflow:global_step/sec: 2.11375
# INFO:tensorflow:train_accuracy = 0.3617021, train_loss = 39.30356 (0.473 sec)
# INFO:tensorflow:loss = 39.30356, step = 152 (0.472 sec)
# INFO:tensorflow:global_step/sec: 2.44027
# INFO:tensorflow:train_accuracy = 0.34649682, train_loss = 40.70337 (0.410 sec)
# INFO:tensorflow:loss = 40.70337, step = 153 (0.410 sec)
# INFO:tensorflow:global_step/sec: 2.61412
# INFO:tensorflow:train_accuracy = 0.14266667, train_loss = 36.49625 (0.383 sec)
# INFO:tensorflow:loss = 36.49625, step = 154 (0.383 sec)
# INFO:tensorflow:global_step/sec: 2.52063
# INFO:tensorflow:train_accuracy = 0.14545454, train_loss = 40.864853 (0.396 sec)
# INFO:tensorflow:loss = 40.864853, step = 155 (0.397 sec)
# INFO:tensorflow:global_step/sec: 2.49124
# INFO:tensorflow:train_accuracy = 0.16370559, train_loss = 40.41439 (0.401 sec)
# INFO:tensorflow:loss = 40.41439, step = 156 (0.400 sec)
# INFO:tensorflow:global_step/sec: 2.61113
# INFO:tensorflow:train_accuracy = 0.3133515, train_loss = 37.035843 (0.383 sec)
# INFO:tensorflow:loss = 37.035843, step = 157 (0.383 sec)
# INFO:tensorflow:global_step/sec: 2.55895
# INFO:tensorflow:train_accuracy = 0.34378922, train_loss = 42.12439 (0.391 sec)
# INFO:tensorflow:loss = 42.12439, step = 158 (0.391 sec)
# INFO:tensorflow:global_step/sec: 2.59067
# INFO:tensorflow:train_accuracy = 0.27854455, train_loss = 42.052177 (0.386 sec)
# INFO:tensorflow:loss = 42.052177, step = 159 (0.386 sec)
# INFO:tensorflow:global_step/sec: 2.53179
# INFO:tensorflow:train_accuracy = 0.32133332, train_loss = 38.13816 (0.395 sec)
# INFO:tensorflow:loss = 38.13816, step = 160 (0.395 sec)
# INFO:tensorflow:global_step/sec: 2.66023
# INFO:tensorflow:train_accuracy = 0.38326585, train_loss = 35.2705 (0.376 sec)
# INFO:tensorflow:loss = 35.2705, step = 161 (0.376 sec)
# INFO:tensorflow:global_step/sec: 2.61065
# INFO:tensorflow:train_accuracy = 0.37715805, train_loss = 35.99958 (0.383 sec)
# INFO:tensorflow:loss = 35.99958, step = 162 (0.383 sec)
# INFO:tensorflow:global_step/sec: 2.51771
# INFO:tensorflow:train_accuracy = 0.33505154, train_loss = 41.568428 (0.397 sec)
# INFO:tensorflow:loss = 41.568428, step = 163 (0.397 sec)
# INFO:tensorflow:global_step/sec: 1.8876
# INFO:tensorflow:train_accuracy = 0.3175416, train_loss = 40.906715 (0.530 sec)
# INFO:tensorflow:loss = 40.906715, step = 164 (0.530 sec)
# INFO:tensorflow:global_step/sec: 2.46637
# INFO:tensorflow:train_accuracy = 0.31632653, train_loss = 42.048218 (0.405 sec)
# INFO:tensorflow:loss = 42.048218, step = 165 (0.405 sec)
# INFO:tensorflow:global_step/sec: 2.48892
# INFO:tensorflow:train_accuracy = 0.34111544, train_loss = 39.251736 (0.402 sec)
# INFO:tensorflow:loss = 39.251736, step = 166 (0.402 sec)
# INFO:tensorflow:global_step/sec: 2.7487
# INFO:tensorflow:train_accuracy = 0.36398467, train_loss = 39.331005 (0.364 sec)
# INFO:tensorflow:loss = 39.331005, step = 167 (0.364 sec)
# INFO:tensorflow:global_step/sec: 2.44439
# INFO:tensorflow:train_accuracy = 0.3554443, train_loss = 41.16679 (0.409 sec)
# INFO:tensorflow:loss = 41.16679, step = 168 (0.409 sec)
# INFO:tensorflow:global_step/sec: 2.50153
# INFO:tensorflow:train_accuracy = 0.28342247, train_loss = 39.613907 (0.399 sec)
# INFO:tensorflow:loss = 39.613907, step = 169 (0.399 sec)
# INFO:tensorflow:global_step/sec: 2.47696
# INFO:tensorflow:train_accuracy = 0.3790013, train_loss = 38.752285 (0.404 sec)
# INFO:tensorflow:loss = 38.752285, step = 170 (0.404 sec)
# INFO:tensorflow:global_step/sec: 2.52466
# INFO:tensorflow:train_accuracy = 0.3654321, train_loss = 41.3493 (0.396 sec)
# INFO:tensorflow:loss = 41.3493, step = 171 (0.397 sec)
# INFO:tensorflow:global_step/sec: 2.42586
# INFO:tensorflow:train_accuracy = 0.3147208, train_loss = 41.90531 (0.412 sec)
# INFO:tensorflow:loss = 41.90531, step = 172 (0.412 sec)
# INFO:tensorflow:global_step/sec: 2.39669
# INFO:tensorflow:train_accuracy = 0.30807453, train_loss = 44.007633 (0.417 sec)
# INFO:tensorflow:loss = 44.007633, step = 173 (0.417 sec)
# INFO:tensorflow:global_step/sec: 2.4432
# INFO:tensorflow:train_accuracy = 0.32581455, train_loss = 41.23 (0.409 sec)
# INFO:tensorflow:loss = 41.23, step = 174 (0.409 sec)
# INFO:tensorflow:global_step/sec: 2.45747
# INFO:tensorflow:train_accuracy = 0.27864584, train_loss = 40.312042 (0.407 sec)
# INFO:tensorflow:loss = 40.312042, step = 175 (0.407 sec)
# INFO:tensorflow:global_step/sec: 2.66956
# INFO:tensorflow:train_accuracy = 0.26169404, train_loss = 38.923176 (0.374 sec)
# INFO:tensorflow:loss = 38.923176, step = 176 (0.374 sec)
# INFO:tensorflow:global_step/sec: 2.4058
# INFO:tensorflow:train_accuracy = 0.2907712, train_loss = 42.60811 (0.416 sec)
# INFO:tensorflow:loss = 42.60811, step = 177 (0.416 sec)
# INFO:tensorflow:global_step/sec: 2.48944
# INFO:tensorflow:train_accuracy = 0.3263158, train_loss = 38.8667 (0.402 sec)
# INFO:tensorflow:loss = 38.8667, step = 178 (0.401 sec)
# INFO:tensorflow:global_step/sec: 2.60823
# INFO:tensorflow:train_accuracy = 0.41939712, train_loss = 36.165977 (0.383 sec)
# INFO:tensorflow:loss = 36.165977, step = 179 (0.384 sec)
# INFO:tensorflow:global_step/sec: 2.4685
# INFO:tensorflow:train_accuracy = 0.32178217, train_loss = 43.61881 (0.405 sec)
# INFO:tensorflow:loss = 43.61881, step = 180 (0.405 sec)
# INFO:tensorflow:global_step/sec: 2.28611
# INFO:tensorflow:train_accuracy = 0.3387978, train_loss = 35.97323 (0.437 sec)
# INFO:tensorflow:loss = 35.97323, step = 181 (0.438 sec)
# INFO:tensorflow:global_step/sec: 2.53594
# INFO:tensorflow:train_accuracy = 0.36692506, train_loss = 38.11105 (0.394 sec)
# INFO:tensorflow:loss = 38.11105, step = 182 (0.395 sec)
# INFO:tensorflow:global_step/sec: 2.67482
# INFO:tensorflow:train_accuracy = 0.2173913, train_loss = 38.877914 (0.374 sec)
# INFO:tensorflow:loss = 38.877914, step = 183 (0.374 sec)
# INFO:tensorflow:global_step/sec: 2.24798
# INFO:tensorflow:train_accuracy = 0.19663648, train_loss = 39.392086 (0.445 sec)
# INFO:tensorflow:loss = 39.392086, step = 184 (0.445 sec)
# INFO:tensorflow:global_step/sec: 2.51462
# INFO:tensorflow:train_accuracy = 0.18935643, train_loss = 43.135406 (0.398 sec)
# INFO:tensorflow:loss = 43.135406, step = 185 (0.398 sec)
# INFO:tensorflow:global_step/sec: 2.42046
# INFO:tensorflow:train_accuracy = 0.21843435, train_loss = 41.432507 (0.413 sec)
# INFO:tensorflow:loss = 41.432507, step = 186 (0.413 sec)
# INFO:tensorflow:global_step/sec: 2.27368
# INFO:tensorflow:train_accuracy = 0.17534943, train_loss = 40.407295 (0.440 sec)
# INFO:tensorflow:loss = 40.407295, step = 187 (0.440 sec)
# INFO:tensorflow:global_step/sec: 2.49123
# INFO:tensorflow:train_accuracy = 0.18709677, train_loss = 40.162895 (0.402 sec)
# INFO:tensorflow:loss = 40.162895, step = 188 (0.402 sec)
# INFO:tensorflow:global_step/sec: 2.44545
# INFO:tensorflow:train_accuracy = 0.33248082, train_loss = 39.589264 (0.408 sec)
# INFO:tensorflow:loss = 39.589264, step = 189 (0.408 sec)
# INFO:tensorflow:global_step/sec: 2.57043
# INFO:tensorflow:train_accuracy = 0.14025974, train_loss = 37.581802 (0.389 sec)
# INFO:tensorflow:loss = 37.581802, step = 190 (0.389 sec)
# INFO:tensorflow:global_step/sec: 2.45287
# INFO:tensorflow:train_accuracy = 0.13654096, train_loss = 37.496735 (0.407 sec)
# INFO:tensorflow:loss = 37.496735, step = 191 (0.407 sec)
# INFO:tensorflow:global_step/sec: 2.59493
# INFO:tensorflow:train_accuracy = 0.33066666, train_loss = 37.38498 (0.385 sec)
# INFO:tensorflow:loss = 37.38498, step = 192 (0.385 sec)
# INFO:tensorflow:global_step/sec: 2.51593
# INFO:tensorflow:train_accuracy = 0.31020942, train_loss = 39.94328 (0.398 sec)
# INFO:tensorflow:loss = 39.94328, step = 193 (0.398 sec)
# INFO:tensorflow:global_step/sec: 2.73236
# INFO:tensorflow:train_accuracy = 0.42723632, train_loss = 34.25537 (0.366 sec)
# INFO:tensorflow:loss = 34.25537, step = 194 (0.365 sec)
# INFO:tensorflow:global_step/sec: 2.62196
# INFO:tensorflow:train_accuracy = 0.342556, train_loss = 38.068832 (0.382 sec)
# INFO:tensorflow:loss = 38.068832, step = 195 (0.382 sec)
# INFO:tensorflow:global_step/sec: 2.55948
# INFO:tensorflow:train_accuracy = 0.3041237, train_loss = 41.110672 (0.390 sec)
# INFO:tensorflow:loss = 41.110672, step = 196 (0.390 sec)
# INFO:tensorflow:global_step/sec: 2.51062
# INFO:tensorflow:train_accuracy = 0.1261498, train_loss = 38.736702 (0.398 sec)
# INFO:tensorflow:loss = 38.736702, step = 197 (0.398 sec)
# INFO:tensorflow:global_step/sec: 2.67041
# INFO:tensorflow:train_accuracy = 0.18085106, train_loss = 36.58947 (0.374 sec)
# INFO:tensorflow:loss = 36.58947, step = 198 (0.374 sec)
# INFO:tensorflow:Saving checkpoints for 200 into smallconformer/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /home/husein/malaya-speech/malaya_speech/train/model/ctc/metrics.py:58: The name tf.metrics.mean is deprecated. Please use tf.compat.v1.metrics.mean instead.
#
# WARNING:tensorflow:From /home/husein/malaya-speech/malaya_speech/train/model/ctc/metrics.py:119: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /home/husein/malaya-speech/malaya_speech/train/model/ctc/metrics.py:106: The name tf.regex_replace is deprecated. Please use tf.strings.regex_replace instead.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-10-25T19:36:06Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from smallconformer/model.ckpt-200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/10]
# INFO:tensorflow:Evaluation [2/10]
# INFO:tensorflow:Evaluation [3/10]
# INFO:tensorflow:Evaluation [4/10]
# INFO:tensorflow:Evaluation [5/10]
# INFO:tensorflow:Evaluation [6/10]
# INFO:tensorflow:Evaluation [7/10]
# INFO:tensorflow:Evaluation [8/10]
# INFO:tensorflow:Evaluation [9/10]
# INFO:tensorflow:Evaluation [10/10]
# INFO:tensorflow:Finished evaluation at 2020-10-25-19:36:16
# INFO:tensorflow:Saving dict for global step 200: WER = 1.0, accuracy = 0.3128834, global_step = 200, loss = 43.574013
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 200: smallconformer/model.ckpt-200
# INFO:tensorflow:global_step/sec: 0.0412571
# INFO:tensorflow:train_accuracy = 0.153048, train_loss = 36.66128 (24.238 sec)
# INFO:tensorflow:loss = 36.66128, step = 199 (24.238 sec)
# INFO:tensorflow:global_step/sec: 2.58644
# INFO:tensorflow:train_accuracy = 0.29074314, train_loss = 39.47863 (0.388 sec)
# INFO:tensorflow:loss = 39.47863, step = 200 (0.388 sec)
# INFO:tensorflow:global_step/sec: 2.52069
# INFO:tensorflow:train_accuracy = 0.34561625, train_loss = 40.36689 (0.397 sec)
# INFO:tensorflow:loss = 40.36689, step = 201 (0.397 sec)
# INFO:tensorflow:global_step/sec: 2.464
# INFO:tensorflow:train_accuracy = 0.3416557, train_loss = 37.82902 (0.406 sec)
# INFO:tensorflow:loss = 37.82902, step = 202 (0.406 sec)
# INFO:tensorflow:global_step/sec: 2.28511
# INFO:tensorflow:train_accuracy = 0.3523316, train_loss = 38.07567 (0.438 sec)
# INFO:tensorflow:loss = 38.07567, step = 203 (0.438 sec)
# INFO:tensorflow:global_step/sec: 2.7478
# INFO:tensorflow:train_accuracy = 0.39784947, train_loss = 34.688156 (0.364 sec)
# INFO:tensorflow:loss = 34.688156, step = 204 (0.365 sec)
# INFO:tensorflow:global_step/sec: 2.44348
# INFO:tensorflow:train_accuracy = 0.31632653, train_loss = 42.633278 (0.409 sec)
# INFO:tensorflow:loss = 42.633278, step = 205 (0.408 sec)
# INFO:tensorflow:global_step/sec: 2.61757
# INFO:tensorflow:train_accuracy = 0.42025316, train_loss = 38.005974 (0.382 sec)
# INFO:tensorflow:loss = 38.005974, step = 206 (0.382 sec)
# INFO:tensorflow:global_step/sec: 2.54897
# INFO:tensorflow:train_accuracy = 0.32082793, train_loss = 38.697258 (0.393 sec)
# INFO:tensorflow:loss = 38.697258, step = 207 (0.393 sec)
# INFO:tensorflow:global_step/sec: 2.53028
# INFO:tensorflow:train_accuracy = 0.3901099, train_loss = 33.63069 (0.395 sec)
# INFO:tensorflow:loss = 33.63069, step = 208 (0.395 sec)
# INFO:tensorflow:global_step/sec: 2.48213
# INFO:tensorflow:train_accuracy = 0.3216602, train_loss = 40.16996 (0.403 sec)
# INFO:tensorflow:loss = 40.16996, step = 209 (0.402 sec)
# INFO:tensorflow:global_step/sec: 2.46124
# INFO:tensorflow:train_accuracy = 0.35370612, train_loss = 37.685673 (0.407 sec)
# INFO:tensorflow:loss = 37.685673, step = 210 (0.407 sec)
# INFO:tensorflow:global_step/sec: 2.4219
# INFO:tensorflow:train_accuracy = 0.3033419, train_loss = 40.51184 (0.413 sec)
# INFO:tensorflow:loss = 40.51184, step = 211 (0.413 sec)
# INFO:tensorflow:global_step/sec: 2.16627
# INFO:tensorflow:train_accuracy = 0.16223067, train_loss = 40.80644 (0.461 sec)
# INFO:tensorflow:loss = 40.80644, step = 212 (0.461 sec)
# INFO:tensorflow:global_step/sec: 2.70467
# INFO:tensorflow:train_accuracy = 0.12611465, train_loss = 39.915165 (0.370 sec)
# INFO:tensorflow:loss = 39.915165, step = 213 (0.370 sec)
# INFO:tensorflow:global_step/sec: 2.49667
# INFO:tensorflow:train_accuracy = 0.30506328, train_loss = 41.996178 (0.401 sec)
# INFO:tensorflow:loss = 41.996178, step = 214 (0.401 sec)
# INFO:tensorflow:global_step/sec: 2.36048
# INFO:tensorflow:train_accuracy = 0.2857143, train_loss = 41.677338 (0.424 sec)
# INFO:tensorflow:loss = 41.677338, step = 215 (0.424 sec)
# INFO:tensorflow:global_step/sec: 1.8869
# INFO:tensorflow:train_accuracy = 0.35639685, train_loss = 36.843063 (0.529 sec)
# INFO:tensorflow:loss = 36.843063, step = 216 (0.529 sec)
# INFO:tensorflow:global_step/sec: 2.57696
# INFO:tensorflow:train_accuracy = 0.36097562, train_loss = 42.377403 (0.388 sec)
# INFO:tensorflow:loss = 42.377403, step = 217 (0.388 sec)
# INFO:tensorflow:global_step/sec: 2.57189
# INFO:tensorflow:train_accuracy = 0.32418302, train_loss = 39.057964 (0.389 sec)
# INFO:tensorflow:loss = 39.057964, step = 218 (0.389 sec)
# INFO:tensorflow:global_step/sec: 2.35335
# INFO:tensorflow:train_accuracy = 0.19319563, train_loss = 43.43686 (0.425 sec)
# INFO:tensorflow:loss = 43.43686, step = 219 (0.424 sec)
# INFO:tensorflow:global_step/sec: 2.10169
# INFO:tensorflow:train_accuracy = 0.325887, train_loss = 37.82602 (0.476 sec)
# INFO:tensorflow:loss = 37.82602, step = 220 (0.477 sec)
# INFO:tensorflow:global_step/sec: 2.51581
# INFO:tensorflow:train_accuracy = 0.28255528, train_loss = 40.97563 (0.397 sec)
# INFO:tensorflow:loss = 40.97563, step = 221 (0.397 sec)
# INFO:tensorflow:global_step/sec: 2.62077
# INFO:tensorflow:train_accuracy = 0.2724758, train_loss = 35.257652 (0.381 sec)
# INFO:tensorflow:loss = 35.257652, step = 222 (0.382 sec)
# INFO:tensorflow:global_step/sec: 2.68202
# INFO:tensorflow:train_accuracy = 0.3234568, train_loss = 42.003925 (0.373 sec)
# INFO:tensorflow:loss = 42.003925, step = 223 (0.373 sec)
# INFO:tensorflow:global_step/sec: 2.50146
# INFO:tensorflow:train_accuracy = 0.25375, train_loss = 41.916187 (0.400 sec)
# INFO:tensorflow:loss = 41.916187, step = 224 (0.400 sec)
# INFO:tensorflow:global_step/sec: 2.54425
# INFO:tensorflow:train_accuracy = 0.13938619, train_loss = 38.785828 (0.393 sec)
# INFO:tensorflow:loss = 38.785828, step = 225 (0.393 sec)
# INFO:tensorflow:global_step/sec: 2.18587
# INFO:tensorflow:train_accuracy = 0.1513158, train_loss = 37.82728 (0.458 sec)
# INFO:tensorflow:loss = 37.82728, step = 226 (0.458 sec)
# INFO:tensorflow:global_step/sec: 2.57152
# INFO:tensorflow:train_accuracy = 0.21293801, train_loss = 34.945396 (0.388 sec)
# INFO:tensorflow:loss = 34.945396, step = 227 (0.388 sec)
# INFO:tensorflow:global_step/sec: 2.64903
# INFO:tensorflow:train_accuracy = 0.3834197, train_loss = 38.076805 (0.378 sec)
# INFO:tensorflow:loss = 38.076805, step = 228 (0.378 sec)
# INFO:tensorflow:global_step/sec: 5.43848
# INFO:tensorflow:train_accuracy = 0.215311, train_loss = 39.26917 (0.184 sec)
# INFO:tensorflow:loss = 39.26917, step = 229 (0.183 sec)
# INFO:tensorflow:global_step/sec: 2.29046
# INFO:tensorflow:train_accuracy = 0.21870883, train_loss = 36.940727 (0.437 sec)
# INFO:tensorflow:loss = 36.940727, step = 230 (0.437 sec)
# INFO:tensorflow:global_step/sec: 2.58134
# INFO:tensorflow:train_accuracy = 0.14869888, train_loss = 39.968872 (0.387 sec)
# INFO:tensorflow:loss = 39.968872, step = 231 (0.387 sec)
# INFO:tensorflow:global_step/sec: 2.34684
# INFO:tensorflow:train_accuracy = 0.18718593, train_loss = 44.11416 (0.426 sec)
# INFO:tensorflow:loss = 44.11416, step = 232 (0.426 sec)
# INFO:tensorflow:global_step/sec: 2.42787
# INFO:tensorflow:train_accuracy = 0.15178572, train_loss = 38.414677 (0.412 sec)
# INFO:tensorflow:loss = 38.414677, step = 233 (0.412 sec)
# INFO:tensorflow:global_step/sec: 2.49382
# INFO:tensorflow:train_accuracy = 0.16603774, train_loss = 39.588203 (0.401 sec)
# INFO:tensorflow:loss = 39.588203, step = 234 (0.401 sec)
# INFO:tensorflow:global_step/sec: 2.58119
# INFO:tensorflow:train_accuracy = 0.28964612, train_loss = 35.93984 (0.387 sec)
# INFO:tensorflow:loss = 35.93984, step = 235 (0.387 sec)
# INFO:tensorflow:global_step/sec: 2.39205
# INFO:tensorflow:train_accuracy = 0.34424084, train_loss = 36.51117 (0.418 sec)
# INFO:tensorflow:loss = 36.51117, step = 236 (0.418 sec)
# INFO:tensorflow:global_step/sec: 2.58742
# ...
# INFO:tensorflow:loss = 32.338223, step = 917 (0.384 sec)
# INFO:tensorflow:global_step/sec: 2.5325
# INFO:tensorflow:train_accuracy = 0.29787233, train_loss = 35.035484 (0.395 sec)
# INFO:tensorflow:loss = 35.035484, step = 918 (0.395 sec)
# INFO:tensorflow:global_step/sec: 2.91887
# INFO:tensorflow:train_accuracy = 0.3970588, train_loss = 29.266014 (0.343 sec)
# INFO:tensorflow:loss = 29.266014, step = 919 (0.343 sec)
# INFO:tensorflow:global_step/sec: 2.39476
# INFO:tensorflow:train_accuracy = 0.36005256, train_loss = 33.87047 (0.418 sec)
# INFO:tensorflow:loss = 33.87047, step = 920 (0.417 sec)
# INFO:tensorflow:global_step/sec: 2.25898
# INFO:tensorflow:train_accuracy = 0.3572327, train_loss = 35.173737 (0.443 sec)
# INFO:tensorflow:loss = 35.173737, step = 921 (0.443 sec)
# INFO:tensorflow:global_step/sec: 2.63284
# INFO:tensorflow:train_accuracy = 0.2979798, train_loss = 36.861145 (0.380 sec)
# INFO:tensorflow:loss = 36.861145, step = 922 (0.380 sec)
# INFO:tensorflow:global_step/sec: 2.55441
# INFO:tensorflow:train_accuracy = 0.36386767, train_loss = 35.240097 (0.391 sec)
# INFO:tensorflow:loss = 35.240097, step = 923 (0.391 sec)
# INFO:tensorflow:global_step/sec: 2.28866
# INFO:tensorflow:train_accuracy = 0.33170733, train_loss = 40.18011 (0.437 sec)
# INFO:tensorflow:loss = 40.18011, step = 924 (0.437 sec)
# INFO:tensorflow:global_step/sec: 2.43541
# INFO:tensorflow:train_accuracy = 0.32806325, train_loss = 33.59903 (0.410 sec)
# INFO:tensorflow:loss = 33.59903, step = 925 (0.410 sec)
# INFO:tensorflow:global_step/sec: 2.34726
# INFO:tensorflow:train_accuracy = 0.3398693, train_loss = 34.55716 (0.426 sec)
# INFO:tensorflow:loss = 34.55716, step = 926 (0.427 sec)
# INFO:tensorflow:global_step/sec: 2.36253
# INFO:tensorflow:train_accuracy = 0.3546284, train_loss = 33.847862 (0.424 sec)
# INFO:tensorflow:loss = 33.847862, step = 927 (0.424 sec)
# INFO:tensorflow:global_step/sec: 2.21064
# INFO:tensorflow:train_accuracy = 0.31454784, train_loss = 34.643303 (0.452 sec)
# INFO:tensorflow:loss = 34.643303, step = 928 (0.452 sec)
# INFO:tensorflow:global_step/sec: 2.565
# INFO:tensorflow:train_accuracy = 0.4274301, train_loss = 30.085289 (0.390 sec)
# INFO:tensorflow:loss = 30.085289, step = 929 (0.390 sec)
# INFO:tensorflow:global_step/sec: 2.63057
# INFO:tensorflow:train_accuracy = 0.3394018, train_loss = 34.847866 (0.380 sec)
# INFO:tensorflow:loss = 34.847866, step = 930 (0.381 sec)
# INFO:tensorflow:global_step/sec: 2.4933
# INFO:tensorflow:train_accuracy = 0.35500652, train_loss = 33.226 (0.401 sec)
# INFO:tensorflow:loss = 33.226, step = 931 (0.400 sec)
# INFO:tensorflow:global_step/sec: 2.53819
# INFO:tensorflow:train_accuracy = 0.31406045, train_loss = 35.794945 (0.394 sec)
# INFO:tensorflow:loss = 35.794945, step = 932 (0.394 sec)
# INFO:tensorflow:global_step/sec: 2.37919
# INFO:tensorflow:train_accuracy = 0.3176312, train_loss = 34.822674 (0.421 sec)
# INFO:tensorflow:loss = 34.822674, step = 933 (0.421 sec)
# INFO:tensorflow:global_step/sec: 2.70502
# INFO:tensorflow:train_accuracy = 0.40873015, train_loss = 32.02835 (0.370 sec)
# INFO:tensorflow:loss = 32.02835, step = 934 (0.369 sec)
# INFO:tensorflow:global_step/sec: 2.528
# INFO:tensorflow:train_accuracy = 0.37185928, train_loss = 35.01853 (0.396 sec)
# INFO:tensorflow:loss = 35.01853, step = 935 (0.396 sec)
# INFO:tensorflow:global_step/sec: 2.46134
# INFO:tensorflow:train_accuracy = 0.31923077, train_loss = 37.384235 (0.406 sec)
# INFO:tensorflow:loss = 37.384235, step = 936 (0.406 sec)
# INFO:tensorflow:global_step/sec: 2.56894
# INFO:tensorflow:train_accuracy = 0.36787564, train_loss = 34.258224 (0.389 sec)
# INFO:tensorflow:loss = 34.258224, step = 937 (0.389 sec)
# INFO:tensorflow:global_step/sec: 2.54232
# INFO:tensorflow:train_accuracy = 0.3708166, train_loss = 31.75136 (0.394 sec)
# INFO:tensorflow:loss = 31.75136, step = 938 (0.394 sec)
# INFO:tensorflow:global_step/sec: 2.45446
# INFO:tensorflow:train_accuracy = 0.36448598, train_loss = 32.480915 (0.407 sec)
# INFO:tensorflow:loss = 32.480915, step = 939 (0.407 sec)
# INFO:tensorflow:global_step/sec: 2.34494
# INFO:tensorflow:train_accuracy = 0.33376125, train_loss = 37.123604 (0.427 sec)
# INFO:tensorflow:loss = 37.123604, step = 940 (0.427 sec)
# INFO:tensorflow:global_step/sec: 2.63088
# INFO:tensorflow:train_accuracy = 0.38007382, train_loss = 37.10559 (0.380 sec)
# INFO:tensorflow:loss = 37.10559, step = 941 (0.380 sec)
# INFO:tensorflow:global_step/sec: 2.47342
# INFO:tensorflow:train_accuracy = 0.29960054, train_loss = 34.3438 (0.404 sec)
# INFO:tensorflow:loss = 34.3438, step = 942 (0.404 sec)
# INFO:tensorflow:global_step/sec: 2.46339
# INFO:tensorflow:train_accuracy = 0.35968378, train_loss = 32.84086 (0.406 sec)
# INFO:tensorflow:loss = 32.84086, step = 943 (0.406 sec)
# INFO:tensorflow:global_step/sec: 2.51749
# INFO:tensorflow:train_accuracy = 0.3683528, train_loss = 33.463306 (0.398 sec)
# INFO:tensorflow:loss = 33.463306, step = 944 (0.398 sec)
# INFO:tensorflow:global_step/sec: 2.97096
# INFO:tensorflow:train_accuracy = 0.38739946, train_loss = 31.750332 (0.336 sec)
# INFO:tensorflow:loss = 31.750332, step = 945 (0.336 sec)
# INFO:tensorflow:global_step/sec: 2.44271
# INFO:tensorflow:train_accuracy = 0.31349206, train_loss = 34.215614 (0.409 sec)
# INFO:tensorflow:loss = 34.215614, step = 946 (0.409 sec)
# INFO:tensorflow:global_step/sec: 2.36623
# INFO:tensorflow:train_accuracy = 0.36848634, train_loss = 37.585236 (0.423 sec)
# INFO:tensorflow:loss = 37.585236, step = 947 (0.423 sec)
# INFO:tensorflow:global_step/sec: 2.58608
# INFO:tensorflow:train_accuracy = 0.40052015, train_loss = 32.999447 (0.387 sec)
# INFO:tensorflow:loss = 32.999447, step = 948 (0.387 sec)
# INFO:tensorflow:global_step/sec: 2.46834
# INFO:tensorflow:train_accuracy = 0.31823745, train_loss = 41.734016 (0.405 sec)
# INFO:tensorflow:loss = 41.734016, step = 949 (0.405 sec)
# INFO:tensorflow:global_step/sec: 2.5609
# INFO:tensorflow:train_accuracy = 0.3478836, train_loss = 33.508728 (0.390 sec)
# INFO:tensorflow:loss = 33.508728, step = 950 (0.391 sec)
# INFO:tensorflow:global_step/sec: 2.45354
# INFO:tensorflow:train_accuracy = 0.30217668, train_loss = 36.00417 (0.408 sec)
# INFO:tensorflow:loss = 36.00417, step = 951 (0.408 sec)
# INFO:tensorflow:global_step/sec: 2.42133
# INFO:tensorflow:train_accuracy = 0.31893265, train_loss = 37.833073 (0.413 sec)
# INFO:tensorflow:loss = 37.833073, step = 952 (0.413 sec)
# INFO:tensorflow:global_step/sec: 2.34202
# INFO:tensorflow:train_accuracy = 0.31392404, train_loss = 36.769608 (0.427 sec)
# INFO:tensorflow:loss = 36.769608, step = 953 (0.426 sec)
# INFO:tensorflow:global_step/sec: 2.43262
# INFO:tensorflow:train_accuracy = 0.38224414, train_loss = 37.09552 (0.412 sec)
# INFO:tensorflow:loss = 37.09552, step = 954 (0.413 sec)
# INFO:tensorflow:global_step/sec: 2.22984
# INFO:tensorflow:train_accuracy = 0.38976377, train_loss = 32.516922 (0.448 sec)
# INFO:tensorflow:loss = 32.516922, step = 955 (0.446 sec)
# INFO:tensorflow:global_step/sec: 2.39346
# INFO:tensorflow:train_accuracy = 0.32459426, train_loss = 38.535904 (0.418 sec)
# INFO:tensorflow:loss = 38.535904, step = 956 (0.418 sec)
# INFO:tensorflow:global_step/sec: 2.41922
# INFO:tensorflow:train_accuracy = 0.30038023, train_loss = 37.801224 (0.414 sec)
# INFO:tensorflow:loss = 37.801224, step = 957 (0.414 sec)
# INFO:tensorflow:global_step/sec: 2.47808
# INFO:tensorflow:train_accuracy = 0.3346354, train_loss = 34.459736 (0.404 sec)
# INFO:tensorflow:loss = 34.459736, step = 958 (0.404 sec)
# INFO:tensorflow:global_step/sec: 2.53455
# INFO:tensorflow:train_accuracy = 0.3768116, train_loss = 32.34656 (0.395 sec)
# INFO:tensorflow:loss = 32.34656, step = 959 (0.395 sec)
# INFO:tensorflow:global_step/sec: 2.89766
# INFO:tensorflow:train_accuracy = 0.37390214, train_loss = 36.80999 (0.345 sec)
# INFO:tensorflow:loss = 36.80999, step = 960 (0.345 sec)
# INFO:tensorflow:global_step/sec: 2.39106
# INFO:tensorflow:train_accuracy = 0.34874505, train_loss = 33.94954 (0.418 sec)
# INFO:tensorflow:loss = 33.94954, step = 961 (0.418 sec)
# INFO:tensorflow:global_step/sec: 2.54357
# INFO:tensorflow:train_accuracy = 0.33547556, train_loss = 36.611656 (0.393 sec)
# INFO:tensorflow:loss = 36.611656, step = 962 (0.394 sec)
# INFO:tensorflow:global_step/sec: 2.41073
# INFO:tensorflow:train_accuracy = 0.28716645, train_loss = 39.668648 (0.415 sec)
# INFO:tensorflow:loss = 39.668648, step = 963 (0.415 sec)
# INFO:tensorflow:global_step/sec: 2.60237
# INFO:tensorflow:train_accuracy = 0.41090426, train_loss = 30.779463 (0.384 sec)
# INFO:tensorflow:loss = 30.779463, step = 964 (0.384 sec)
# INFO:tensorflow:global_step/sec: 5.13782
# INFO:tensorflow:train_accuracy = 0.26635513, train_loss = 33.911934 (0.194 sec)
# INFO:tensorflow:loss = 33.911934, step = 965 (0.194 sec)
# INFO:tensorflow:global_step/sec: 2.32983
# INFO:tensorflow:train_accuracy = 0.30819246, train_loss = 35.034878 (0.430 sec)
# INFO:tensorflow:loss = 35.034878, step = 966 (0.430 sec)
# INFO:tensorflow:global_step/sec: 2.54869
# INFO:tensorflow:train_accuracy = 0.37721518, train_loss = 34.30732 (0.392 sec)
# INFO:tensorflow:loss = 34.30732, step = 967 (0.392 sec)
# INFO:tensorflow:global_step/sec: 2.42282
# INFO:tensorflow:train_accuracy = 0.3214724, train_loss = 38.148743 (0.413 sec)
# INFO:tensorflow:loss = 38.148743, step = 968 (0.413 sec)
# INFO:tensorflow:global_step/sec: 2.4303
# INFO:tensorflow:train_accuracy = 0.3653846, train_loss = 34.719883 (0.412 sec)
# INFO:tensorflow:loss = 34.719883, step = 969 (0.412 sec)
# INFO:tensorflow:global_step/sec: 2.24254
# INFO:tensorflow:train_accuracy = 0.31806615, train_loss = 36.76418 (0.446 sec)
# INFO:tensorflow:loss = 36.76418, step = 970 (0.446 sec)
# INFO:tensorflow:global_step/sec: 2.33237
# INFO:tensorflow:train_accuracy = 0.32082793, train_loss = 35.63713 (0.429 sec)
# INFO:tensorflow:loss = 35.63713, step = 971 (0.429 sec)
# INFO:tensorflow:global_step/sec: 2.32908
# INFO:tensorflow:train_accuracy = 0.29011554, train_loss = 36.637825 (0.429 sec)
# INFO:tensorflow:loss = 36.637825, step = 972 (0.429 sec)
# INFO:tensorflow:global_step/sec: 2.55076
# INFO:tensorflow:train_accuracy = 0.3611111, train_loss = 33.09068 (0.392 sec)
# INFO:tensorflow:loss = 33.09068, step = 973 (0.392 sec)
# INFO:tensorflow:global_step/sec: 2.46563
# INFO:tensorflow:train_accuracy = 0.37224385, train_loss = 31.92162 (0.406 sec)
# INFO:tensorflow:loss = 31.92162, step = 974 (0.405 sec)
# INFO:tensorflow:global_step/sec: 2.40903
# INFO:tensorflow:train_accuracy = 0.3620915, train_loss = 32.699715 (0.415 sec)
# INFO:tensorflow:loss = 32.699715, step = 975 (0.415 sec)
# INFO:tensorflow:global_step/sec: 2.60101
# INFO:tensorflow:train_accuracy = 0.36742935, train_loss = 31.644924 (0.384 sec)
# INFO:tensorflow:loss = 31.644924, step = 976 (0.384 sec)
# INFO:tensorflow:global_step/sec: 2.34357
# INFO:tensorflow:train_accuracy = 0.2956636, train_loss = 34.92886 (0.427 sec)
# INFO:tensorflow:loss = 34.92886, step = 977 (0.427 sec)
# INFO:tensorflow:global_step/sec: 2.48581
# INFO:tensorflow:train_accuracy = 0.3398693, train_loss = 35.12975 (0.402 sec)
# INFO:tensorflow:loss = 35.12975, step = 978 (0.402 sec)
# INFO:tensorflow:global_step/sec: 2.45363
# INFO:tensorflow:train_accuracy = 0.34691197, train_loss = 33.93254 (0.407 sec)
# INFO:tensorflow:loss = 33.93254, step = 979 (0.407 sec)
# INFO:tensorflow:global_step/sec: 2.32038
# INFO:tensorflow:train_accuracy = 0.40261438, train_loss = 31.738173 (0.431 sec)
# INFO:tensorflow:loss = 31.738173, step = 980 (0.431 sec)
# INFO:tensorflow:global_step/sec: 2.50291
# INFO:tensorflow:train_accuracy = 0.32677165, train_loss = 36.87128 (0.399 sec)
# INFO:tensorflow:loss = 36.87128, step = 981 (0.399 sec)
# INFO:tensorflow:global_step/sec: 2.60578
# INFO:tensorflow:train_accuracy = 0.36132315, train_loss = 34.470512 (0.384 sec)
# INFO:tensorflow:loss = 34.470512, step = 982 (0.384 sec)
# INFO:tensorflow:global_step/sec: 2.54469
# INFO:tensorflow:train_accuracy = 0.34210527, train_loss = 34.386116 (0.393 sec)
# INFO:tensorflow:loss = 34.386116, step = 983 (0.393 sec)
# INFO:tensorflow:global_step/sec: 2.46606
# INFO:tensorflow:train_accuracy = 0.38368985, train_loss = 31.394917 (0.405 sec)
# INFO:tensorflow:loss = 31.394917, step = 984 (0.405 sec)
# INFO:tensorflow:global_step/sec: 2.39482
# INFO:tensorflow:train_accuracy = 0.33461538, train_loss = 36.78634 (0.418 sec)
# INFO:tensorflow:loss = 36.78634, step = 985 (0.418 sec)
# INFO:tensorflow:global_step/sec: 2.49379
# INFO:tensorflow:train_accuracy = 0.3606341, train_loss = 32.701546 (0.400 sec)
# INFO:tensorflow:loss = 32.701546, step = 986 (0.400 sec)
# INFO:tensorflow:global_step/sec: 2.41034
# INFO:tensorflow:train_accuracy = 0.33955225, train_loss = 39.87561 (0.415 sec)
# INFO:tensorflow:loss = 39.87561, step = 987 (0.416 sec)
# INFO:tensorflow:global_step/sec: 2.41275
# INFO:tensorflow:train_accuracy = 0.32555124, train_loss = 34.673008 (0.414 sec)
# INFO:tensorflow:loss = 34.673008, step = 988 (0.415 sec)
# INFO:tensorflow:global_step/sec: 2.43771
# INFO:tensorflow:train_accuracy = 0.41066667, train_loss = 29.793339 (0.410 sec)
# INFO:tensorflow:loss = 29.793339, step = 989 (0.410 sec)
# INFO:tensorflow:global_step/sec: 2.51466
# INFO:tensorflow:train_accuracy = 0.348, train_loss = 32.330563 (0.398 sec)
# INFO:tensorflow:loss = 32.330563, step = 990 (0.397 sec)
# INFO:tensorflow:global_step/sec: 2.60678
# INFO:tensorflow:train_accuracy = 0.39655173, train_loss = 31.794353 (0.383 sec)
# INFO:tensorflow:loss = 31.794353, step = 991 (0.383 sec)
# INFO:tensorflow:global_step/sec: 2.42652
# INFO:tensorflow:train_accuracy = 0.33762887, train_loss = 35.00888 (0.412 sec)
# INFO:tensorflow:loss = 35.00888, step = 992 (0.412 sec)
# INFO:tensorflow:global_step/sec: 2.32507
# INFO:tensorflow:train_accuracy = 0.3654321, train_loss = 39.68162 (0.430 sec)
# INFO:tensorflow:loss = 39.68162, step = 993 (0.430 sec)
# INFO:tensorflow:global_step/sec: 2.39549
# INFO:tensorflow:train_accuracy = 0.2931258, train_loss = 37.953312 (0.417 sec)
# INFO:tensorflow:loss = 37.953312, step = 994 (0.417 sec)
# INFO:tensorflow:global_step/sec: 2.56299
# INFO:tensorflow:train_accuracy = 0.39163497, train_loss = 33.87432 (0.390 sec)
# INFO:tensorflow:loss = 33.87432, step = 995 (0.390 sec)
# INFO:tensorflow:global_step/sec: 2.58839
# INFO:tensorflow:train_accuracy = 0.37303665, train_loss = 34.17825 (0.386 sec)
# INFO:tensorflow:loss = 34.17825, step = 996 (0.386 sec)
# INFO:tensorflow:global_step/sec: 2.39036
# INFO:tensorflow:train_accuracy = 0.26400995, train_loss = 41.952084 (0.419 sec)
# INFO:tensorflow:loss = 41.952084, step = 997 (0.419 sec)
# INFO:tensorflow:global_step/sec: 2.2552
# INFO:tensorflow:train_accuracy = 0.3486005, train_loss = 35.285675 (0.443 sec)
# INFO:tensorflow:loss = 35.285675, step = 998 (0.443 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into smallconformer/model.ckpt.
# WARNING:tensorflow:From /home/husein/.local/lib/python3.6/site-packages/tensorflow_core/python/training/saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-10-25T19:42:16Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from smallconformer/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/10]
# INFO:tensorflow:Evaluation [2/10]
# INFO:tensorflow:Evaluation [3/10]
# INFO:tensorflow:Evaluation [4/10]
# INFO:tensorflow:Evaluation [5/10]
# INFO:tensorflow:Evaluation [6/10]
# INFO:tensorflow:Evaluation [7/10]
# INFO:tensorflow:Evaluation [8/10]
# INFO:tensorflow:Evaluation [9/10]
# INFO:tensorflow:Evaluation [10/10]
# INFO:tensorflow:Finished evaluation at 2020-10-25-19:42:27
# INFO:tensorflow:Saving dict for global step 1000: WER = 1.0, accuracy = 0.3159509, global_step = 1000, loss = 39.51786
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: smallconformer/model.ckpt-1000
# INFO:tensorflow:global_step/sec: 0.0433366
# INFO:tensorflow:train_accuracy = 0.26835442, train_loss = 37.208748 (23.075 sec)
# INFO:tensorflow:loss = 37.208748, step = 999 (23.076 sec)
# INFO:tensorflow:Loss for final step: 37.208748.

# %% [markdown]
# ### Reference
#
# 1. Tensorflow ASR, https://github.com/TensorSpeech/TensorFlowASR/tree/main/examples/conformer
