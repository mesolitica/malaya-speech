# %%
# !wget https://raw.githubusercontent.com/pyannote/pyannote-audio/develop/tutorials/data_preparation/AMI/MixHeadset.test.rttm

# %%
# %matplotlib inline

import malaya_speech

# %%
annotations = malaya_speech.extra.rttm.load('MixHeadset.test.rttm')

# %%
a = annotations['ES2004a.Mix-Headset'].crop(600, 660, mode = 'strict')
a.plot()

# %%
a = annotations['ES2004a.Mix-Headset'].crop(600, 660, mode = 'loose')
a.plot()

# %%
a = annotations['ES2004a.Mix-Headset'].crop(600, 660)
a.plot()
