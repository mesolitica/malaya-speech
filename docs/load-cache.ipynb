# %% [markdown]
# # Cache

# %% [markdown]
# <div class="alert alert-info">
#
# This tutorial is available as an IPython notebook at [malaya-speech/example/cache](https://github.com/huseinzol05/malaya-speech/tree/master/example/cache).
#
# </div>

# %% [markdown]
# ### Cache location

# %% [markdown]
# You actually can know where is your Malaya-Speech caching folder.

# %%
import malaya_speech

# %%
malaya_speech.home
# Out:
# '/Users/huseinzolkepli/Malaya-Speech'

# %% [markdown]
# ### Cache subdirectories
#
# Malaya-Speech put models in subdirectories, you can print it by simply,

# %%
malaya_speech.print_cache()
# Out:
# Malaya-Speech/
# ├── age-detection/
# │   ├── deep-speaker/
# │   │   ├── model.pb
# │   │   └── version
# │   └── vggvox-v2/
# │       ├── model.pb
# │       ├── quantized/
# │       │   ├── model.pb
# │       │   └── version
# │       └── version
# ├── emotion/
# │   ├── deep-speaker/
# │   │   ├── model.pb
# │   │   └── version
# │   └── vggvox-v2/
# │       ├── model.pb
# │       ├── quantized/
# │       │   ├── model.pb
# │       │   └── version
# │       └── version
# ├── gender/
# │   ├── deep-speaker/
# │   │   ├── model.pb
# │   │   └── version
# │   └── vggvox-v2/
# │       ├── model.pb
# │       ├── quantized/
# │       │   ├── model.pb
# │       │   └── version
# │       └── version
# ├── language-detection/
# │   ├── deep-speaker/
# │   │   ├── model.pb
# │   │   └── version
# │   └── vggvox-v2/
# │       ├── model.pb
# │       ├── quantized/
# │       │   ├── model.pb
# │       │   └── version
# │       └── version
# ├── lm/
# │   ├── malaya-speech/
# │   │   ├── model.trie.klm
# │   │   └── version
# │   ├── malaya-speech-wikipedia/
# │   │   ├── model.trie.klm
# │   │   └── version
# │   └── vocab.json
# ├── noise-reduction/
# │   ├── quantized/
# │   │   ├── resnet-unet.pb
# │   │   └── version
# │   ├── resnet-unet.pb
# │   ├── unet.pb
# │   └── version
# ├── speaker-change/
# │   ├── speakernet/
# │   │   ├── model.pb
# │   │   └── version
# │   └── vggvox-v2/
# │       ├── model.pb
# │       ├── quantized/
# │       │   ├── model.pb
# │       │   └── version
# │       └── version
# ├── speaker-overlap/
# │   └── vggvox-v2/
# │       ├── model.pb
# │       ├── quantized/
# │       │   ├── model.pb
# │       │   └── version
# │       └── version
# ├── speaker-vector/
# │   ├── deep-speaker/
# │   │   ├── model.pb
# │   │   └── version
# │   ├── speakernet/
# │   │   ├── model.pb
# │   │   ├── quantized/
# │   │   │   ├── model.pb
# │   │   │   └── version
# │   │   └── version
# │   ├── vggvox-v1/
# │   │   ├── model.pb
# │   │   └── version
# │   └── vggvox-v2/
# │       ├── model.pb
# │       └── version
# ├── speech-enhancement/
# │   ├── quantized/
# │   │   ├── resnet-unet.pb
# │   │   └── version
# │   ├── resnet-unet.pb
# │   └── version
# ├── stt/
# │   ├── conformer-transducer/
# │   │   ├── model.pb
# │   │   ├── quantized/
# │   │   │   ├── model.pb
# │   │   │   └── version
# │   │   └── version
# │   ├── medium-jasper-ctc/
# │   │   └── quantized/
# │   │       ├── model.pb
# │   │       └── version
# │   ├── mini-jasper-ctc/
# │   │   ├── model.pb
# │   │   ├── quantized/
# │   │   │   ├── model.pb
# │   │   │   └── version
# │   │   └── version
# │   ├── quartznet-ctc/
# │   │   ├── model.pb
# │   │   ├── quantized/
# │   │   │   ├── model.pb
# │   │   │   └── version
# │   │   └── version
# │   ├── small-conformer-transducer/
# │   │   ├── model.pb
# │   │   ├── quantized/
# │   │   │   ├── model.pb
# │   │   │   └── version
# │   │   └── version
# │   └── vocab/
# │       ├── ctc/
# │       │   └── vocab.json
# │       └── transducer/
# │           └── vocab.tokenizer.subwords
# ├── super-resolution/
# │   └── srgan-256/
# │       ├── model.pb
# │       ├── model.pb.quantized
# │       └── version
# ├── tts/
# │   ├── fastspeech2-female/
# │   │   ├── model.pb
# │   │   └── version
# │   ├── fastspeech2-female-v2/
# │   │   ├── model.pb
# │   │   └── version
# │   ├── fastspeech2-haqkiem/
# │   │   ├── model.pb
# │   │   └── version
# │   ├── fastspeech2-husein/
# │   │   ├── model.pb
# │   │   └── version
# │   ├── fastspeech2-husein-v2/
# │   │   ├── model.pb
# │   │   └── version
# │   ├── fastspeech2-male/
# │   │   ├── model.pb
# │   │   ├── quantized/
# │   │   │   ├── model.pb
# │   │   │   └── version
# │   │   └── version
# │   ├── fastspeech2-male-v2/
# │   │   ├── model.pb
# │   │   └── version
# │   ├── tacotron2-female/
# │   │   ├── model.pb
# │   │   └── version
# │   ├── tacotron2-haqkiem/
# │   │   ├── model.pb
# │   │   └── version
# │   ├── tacotron2-husein/
# │   │   ├── model.pb
# │   │   └── version
# │   └── tacotron2-male/
# │       ├── model.pb
# │       └── version
# ├── vad/
# │   ├── speakernet/
# │   │   ├── model.pb
# │   │   └── version
# │   ├── vggvox-v1/
# │   │   ├── model.pb
# │   │   └── version
# │   └── vggvox-v2/
# │       ├── model.pb
# │       ├── quantized/
# │       │   ├── model.pb
# │       │   └── version
# │       └── version
# ├── version
# ├── vocab/
# │   └── malaya-speech/
# │       └── vocab.json
# └── vocoder/
#     ├── mbmelgan-female/
#     │   ├── model.pb
#     │   ├── quantized/
#     │   │   ├── model.pb
#     │   │   └── version
#     │   └── version
#     ├── mbmelgan-haqkiem/
#     │   ├── model.pb
#     │   └── version
#     ├── melgan-female/
#     │   ├── model.pb
#     │   ├── quantized/
#     │   │   ├── model.pb
#     │   │   └── version
#     │   └── version
#     ├── melgan-haqkiem/
#     │   ├── model.pb
#     │   └── version
#     ├── melgan-husein/
#     │   ├── model.pb
#     │   └── version
#     └── melgan-male/
#         ├── model.pb
#         └── version
