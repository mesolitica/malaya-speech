# %%
import os

os.environ['CUDA_VISIBLE_DEVICES'] = ''

# %%
import tensorflow as tf
import malaya_speech
import malaya_speech.train
from malaya_speech.train.model import resnet_unet
from malaya_speech.utils import tf_featurization
import malaya_speech.augmentation.waveform as augmentation
import IPython.display as ipd
import numpy as np
from malaya_speech.utils.tf_featurization import separation_exponent, EPSILON
# Out:
# WARNING:tensorflow:From /home/husein/malaya-speech/malaya_speech/train/model/quartznet/layer.py:6: The name tf.layers.Conv1D is deprecated. Please use tf.compat.v1.layers.Conv1D instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
class Model:
    def __init__(self, size = 2):
        self.X = tf.placeholder(tf.float32, (None))
        
        stft_X, D_X = tf_featurization.get_stft(self.X)
        
        self.outputs = []
        for i in range(size):
            with tf.variable_scope(f'model_{i}'):
                self.outputs.append(resnet_unet.Model(D_X).logits)
        
        output_sum = tf.reduce_sum([o ** separation_exponent for o in self.outputs], axis=0) + EPSILON
        
        self.istft = []
        for no, D in enumerate(self.outputs):

            instrument_mask = (D ** separation_exponent + (EPSILON / size)) / output_sum
            instrument_mask = tf_featurization.extend_mask(instrument_mask)
            old_shape = tf.shape(instrument_mask)
            new_shape = tf.concat(
                [[old_shape[0] * old_shape[1]], old_shape[2:]],
                axis=0)
            instrument_mask = tf.reshape(instrument_mask, new_shape)

            instrument_mask = instrument_mask[:tf.shape(stft_X)[0]]
            masked_stft = tf.cast(instrument_mask, dtype=tf.complex64) * stft_X
            self.istft.append(tf_featurization.istft(masked_stft, self.X)[:,0])
        
        for i in range(size):
            tf.identity(self.istft[i], name = f'logits_{i}')

# %%
tf.compat.v1.reset_default_graph()
model = Model()
sess = tf.InteractiveSession()
sess.run(tf.global_variables_initializer())
# Out:
# WARNING:tensorflow:From /home/husein/.local/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %%
var_lists = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES)
saver = tf.train.Saver(var_list = var_lists)
saver.restore(sess, 'noise-reduction-unet9/model.ckpt-500000')
# Out:
# INFO:tensorflow:Restoring parameters from noise-reduction-unet9/model.ckpt-500000

# %%
from glob import glob
import random

files = glob('../youtube/clean-wav/*.wav')
noises = glob('../noise-44k/clean-wav/*.wav')

# %%
def read_wav(f):
    return malaya_speech.load(f, sr = 44100)

y = read_wav('2x5%20Ep%2010.wav')[0]
# n = read_wav(random.choice(noises))[0]
sr = 44100

# %%
# y = y[:sr * 15]

# %%
# combined, noise = augmentation.add_noise(
#     y, n, factor = random.uniform(0.5, 0.9), return_noise = True
# )

# %%
istft = sess.run(model.istft, feed_dict = {model.X: y})

# %%
import IPython.display as ipd

# %%
# ipd.Audio(y[:sr * 15], rate = sr)

# %%
# ipd.Audio(istft[0][:sr * 15], rate = sr)

# %%
# ipd.Audio(istft[1][:sr * 30], rate = sr)

# %%
saver = tf.train.Saver()
saver.save(sess, 'noise-reduction-resnet-unet-output/model.ckpt')
# Out:
# 'noise-reduction-resnet-unet-output/model.ckpt'

# %%
strings = ','.join(
    [
        n.name
        for n in tf.get_default_graph().as_graph_def().node
        if ('Variable' in n.op
        or 'Placeholder' in n.name
        or 'logits' in n.name
        or 'alphas' in n.name
        or 'self/Softmax' in n.name)
        and 'adam' not in n.name
        and 'beta' not in n.name
        and 'global_step' not in n.name
        and 'Assign' not in n.name
    ]
)
strings.split(',')
# Out:
# ['Placeholder',
#  'model_0/conv2d/kernel/Read/ReadVariableOp',
#  'model_0/conv2d/Conv2D/ReadVariableOp',
#  'model_0/conv2d_1/kernel/Read/ReadVariableOp',
#  'model_0/conv2d_1/bias/Read/ReadVariableOp',
#  'model_0/conv2d_1/Conv2D/ReadVariableOp',
#  'model_0/conv2d_1/BiasAdd/ReadVariableOp',
#  'model_0/batch_normalization/gamma/Read/ReadVariableOp',
#  'model_0/batch_normalization/moving_mean/Read/ReadVariableOp',
#  'model_0/batch_normalization/moving_variance/Read/ReadVariableOp',
#  'model_0/batch_normalization/cond/ReadVariableOp',
#  'model_0/batch_normalization/cond/ReadVariableOp_1',
#  'model_0/batch_normalization/cond/ReadVariableOp_2',
#  'model_0/batch_normalization/cond/ReadVariableOp_3',
#  'model_0/batch_normalization/cond/FusedBatchNormV3_1/ReadVariableOp',
#  'model_0/batch_normalization/cond/FusedBatchNormV3_1/ReadVariableOp_1',
#  'model_0/conv2d_2/kernel/Read/ReadVariableOp',
#  'model_0/conv2d_2/bias/Read/ReadVariableOp',
#  'model_0/conv2d_2/Conv2D/ReadVariableOp',
#  'model_0/conv2d_2/BiasAdd/ReadVariableOp',
#  'model_0/batch_normalization_1/gamma/Read/ReadVariableOp',
#  'model_0/batch_normalization_1/moving_mean/Read/ReadVariableOp',
#  'model_0/batch_normalization_1/moving_variance/Read/ReadVariableOp',
#  'model_0/batch_normalization_1/cond/ReadVariableOp',
#  'model_0/batch_normalization_1/cond/ReadVariableOp_1',
#  'model_0/batch_normalization_1/cond/ReadVariableOp_2',
#  'model_0/batch_normalization_1/cond/ReadVariableOp_3',
#  'model_0/batch_normalization_1/cond/FusedBatchNormV3_1/ReadVariableOp',
#  'model_0/batch_normalization_1/cond/FusedBatchNormV3_1/ReadVariableOp_1',
#  'model_0/conv2d_3/kernel/Read/ReadVariableOp',
#  'model_0/conv2d_3/Conv2D/ReadVariableOp',
#  'model_0/conv2d_4/kernel/Read/ReadVariableOp',
#  'model_0/conv2d_4/bias/Read/ReadVariableOp',
#  'model_0/conv2d_4/Conv2D/ReadVariableOp',
#  'model_0/conv2d_4/BiasAdd/ReadVariableOp',
#  'model_0/batch_normalization_2/gamma/Read/ReadVariableOp',
#  'model_0/batch_normalization_2/moving_mean/Read/ReadVariableOp',
#  'model_0/batch_normalization_2/moving_variance/Read/ReadVariableOp',
#  'model_0/batch_normalization_2/cond/ReadVariableOp',
#  'model_0/batch_normalization_2/cond/ReadVariableOp_1',
#  'model_0/batch_normalization_2/cond/ReadVariableOp_2',
#  'model_0/batch_normalization_2/cond/ReadVariableOp_3',
#  'model_0/batch_normalization_2/cond/FusedBatchNormV3_1/ReadVariableOp',
#  'model_0/batch_normalization_2/cond/FusedBatchNormV3_1/ReadVariableOp_1',
#  'model_0/conv2d_5/kernel/Read/ReadVariableOp',
#  'model_0/conv2d_5/bias/Read/ReadVariableOp',
#  'model_0/conv2d_5/Conv2D/ReadVariableOp',
#  'model_0/conv2d_5/BiasAdd/ReadVariableOp',
#  'model_0/batch_normalization_3/gamma/Read/ReadVariableOp',
#  'model_0/batch_normalization_3/moving_mean/Read/ReadVariableOp',
#  'model_0/batch_normalization_3/moving_variance/Read/ReadVariableOp',
#  'model_0/batch_normalization_3/cond/ReadVariableOp',
#  'model_0/batch_normalization_3/cond/ReadVariableOp_1',
#  'model_0/batch_normalization_3/cond/ReadVariableOp_2',
#  'model_0/batch_normalization_3/cond/ReadVariableOp_3',
#  'model_0/batch_normalization_3/cond/FusedBatchNormV3_1/ReadVariableOp',
#  'model_0/batch_normalization_3/cond/FusedBatchNormV3_1/ReadVariableOp_1',
#  'model_0/conv2d_6/kernel/Read/ReadVariableOp',
#  'model_0/conv2d_6/Conv2D/ReadVariableOp',
#  'model_0/conv2d_7/kernel/Read/ReadVariableOp',
#  'model_0/conv2d_7/bias/Read/ReadVariableOp',
#  'model_0/conv2d_7/Conv2D/ReadVariableOp',
#  'model_0/conv2d_7/BiasAdd/ReadVariableOp',
#  'model_0/batch_normalization_4/gamma/Read/ReadVariableOp',
#  'model_0/batch_normalization_4/moving_mean/Read/ReadVariableOp',
#  'model_0/batch_normalization_4/moving_variance/Read/ReadVariableOp',
#  'model_0/batch_normalization_4/cond/ReadVariableOp',
#  'model_0/batch_normalization_4/cond/ReadVariableOp_1',
#  'model_0/batch_normalization_4/cond/ReadVariableOp_2',
#  'model_0/batch_normalization_4/cond/ReadVariableOp_3',
#  'model_0/batch_normalization_4/cond/FusedBatchNormV3_1/ReadVariableOp',
#  'model_0/batch_normalization_4/cond/FusedBatchNormV3_1/ReadVariableOp_1',
#  'model_0/conv2d_8/kernel/Read/ReadVariableOp',
#  'model_0/conv2d_8/bias/Read/ReadVariableOp',
#  'model_0/conv2d_8/Conv2D/ReadVariableOp',
#  'model_0/conv2d_8/BiasAdd/ReadVariableOp',
#  'model_0/batch_normalization_5/gamma/Read/ReadVariableOp',
#  'model_0/batch_normalization_5/moving_mean/Read/ReadVariableOp',
#  'model_0/batch_normalization_5/moving_variance/Read/ReadVariableOp',
#  'model_0/batch_normalization_5/cond/ReadVariableOp',
#  'model_0/batch_normalization_5/cond/ReadVariableOp_1',
#  'model_0/batch_normalization_5/cond/ReadVariableOp_2',
#  'model_0/batch_normalization_5/cond/ReadVariableOp_3',
#  'model_0/batch_normalization_5/cond/FusedBatchNormV3_1/ReadVariableOp',
#  'model_0/batch_normalization_5/cond/FusedBatchNormV3_1/ReadVariableOp_1',
#  'model_0/conv2d_9/kernel/Read/ReadVariableOp',
#  'model_0/conv2d_9/Conv2D/ReadVariableOp',
#  'model_0/conv2d_10/kernel/Read/ReadVariableOp',
#  'model_0/conv2d_10/bias/Read/ReadVariableOp',
#  'model_0/conv2d_10/Conv2D/ReadVariableOp',
#  'model_0/conv2d_10/BiasAdd/ReadVariableOp',
#  'model_0/batch_normalization_6/gamma/Read/ReadVariableOp',
#  'model_0/batch_normalization_6/moving_mean/Read/ReadVariableOp',
#  'model_0/batch_normalization_6/moving_variance/Read/ReadVariableOp',
#  'model_0/batch_normalization_6/cond/ReadVariableOp',
#  'model_0/batch_normalization_6/cond/ReadVariableOp_1',
#  'model_0/batch_normalization_6/cond/ReadVariableOp_2',
#  'model_0/batch_normalization_6/cond/ReadVariableOp_3',
#  'model_0/batch_normalization_6/cond/FusedBatchNormV3_1/ReadVariableOp',
#  'model_0/batch_normalization_6/cond/FusedBatchNormV3_1/ReadVariableOp_1',
#  'model_0/conv2d_11/kernel/Read/ReadVariableOp',
#  'model_0/conv2d_11/bias/Read/ReadVariableOp',
#  'model_0/conv2d_11/Conv2D/ReadVariableOp',
#  'model_0/conv2d_11/BiasAdd/ReadVariableOp',
#  'model_0/batch_normalization_7/gamma/Read/ReadVariableOp',
#  'model_0/batch_normalization_7/moving_mean/Read/ReadVariableOp',
#  'model_0/batch_normalization_7/moving_variance/Read/ReadVariableOp',
#  'model_0/batch_normalization_7/cond/ReadVariableOp',
#  'model_0/batch_normalization_7/cond/ReadVariableOp_1',
#  'model_0/batch_normalization_7/cond/ReadVariableOp_2',
#  'model_0/batch_normalization_7/cond/ReadVariableOp_3',
#  'model_0/batch_normalization_7/cond/FusedBatchNormV3_1/ReadVariableOp',
#  'model_0/batch_normalization_7/cond/FusedBatchNormV3_1/ReadVariableOp_1',
#  'model_0/conv2d_12/kernel/Read/ReadVariableOp',
#  'model_0/conv2d_12/Conv2D/ReadVariableOp',
#  'model_0/conv2d_13/kernel/Read/ReadVariableOp',
#  'model_0/conv2d_13/bias/Read/ReadVariableOp',
#  'model_0/conv2d_13/Conv2D/ReadVariableOp',
#  'model_0/conv2d_13/BiasAdd/ReadVariableOp',
#  'model_0/batch_normalization_8/gamma/Read/ReadVariableOp',
#  'model_0/batch_normalization_8/moving_mean/Read/ReadVariableOp',
#  'model_0/batch_normalization_8/moving_variance/Read/ReadVariableOp',
#  'model_0/batch_normalization_8/cond/ReadVariableOp',
#  'model_0/batch_normalization_8/cond/ReadVariableOp_1',
#  'model_0/batch_normalization_8/cond/ReadVariableOp_2',
#  'model_0/batch_normalization_8/cond/ReadVariableOp_3',
#  'model_0/batch_normalization_8/cond/FusedBatchNormV3_1/ReadVariableOp',
#  'model_0/batch_normalization_8/cond/FusedBatchNormV3_1/ReadVariableOp_1',
#  'model_0/conv2d_14/kernel/Read/ReadVariableOp',
#  'model_0/conv2d_14/bias/Read/ReadVariableOp',
#  'model_0/conv2d_14/Conv2D/ReadVariableOp',
#  'model_0/conv2d_14/BiasAdd/ReadVariableOp',
#  'model_0/batch_normalization_9/gamma/Read/ReadVariableOp',
#  'model_0/batch_normalization_9/moving_mean/Read/ReadVariableOp',
#  'model_0/batch_normalization_9/moving_variance/Read/ReadVariableOp',
#  'model_0/batch_normalization_9/cond/ReadVariableOp',
#  'model_0/batch_normalization_9/cond/ReadVariableOp_1',
#  'model_0/batch_normalization_9/cond/ReadVariableOp_2',
#  'model_0/batch_normalization_9/cond/ReadVariableOp_3',
#  'model_0/batch_normalization_9/cond/FusedBatchNormV3_1/ReadVariableOp',
#  'model_0/batch_normalization_9/cond/FusedBatchNormV3_1/ReadVariableOp_1',
#  'model_0/conv2d_15/kernel/Read/ReadVariableOp',
#  'model_0/conv2d_15/bias/Read/ReadVariableOp',
#  'model_0/conv2d_15/Conv2D/ReadVariableOp',
#  'model_0/conv2d_15/BiasAdd/ReadVariableOp',
#  'model_0/conv2d_transpose/kernel/Read/ReadVariableOp',
#  'model_0/conv2d_transpose/bias/Read/ReadVariableOp',
#  'model_0/conv2d_transpose/conv2d_transpose/ReadVariableOp',
#  'model_0/conv2d_transpose/BiasAdd/ReadVariableOp',
#  'model_0/batch_normalization_10/gamma/Read/ReadVariableOp',
#  'model_0/batch_normalization_10/moving_mean/Read/ReadVariableOp',
#  'model_0/batch_normalization_10/moving_variance/Read/ReadVariableOp',
#  'model_0/batch_normalization_10/cond/ReadVariableOp',
#  'model_0/batch_normalization_10/cond/ReadVariableOp_1',
#  'model_0/batch_normalization_10/cond/ReadVariableOp_2',
#  'model_0/batch_normalization_10/cond/ReadVariableOp_3',
#  'model_0/batch_normalization_10/cond/FusedBatchNormV3_1/ReadVariableOp',
#  'model_0/batch_normalization_10/cond/FusedBatchNormV3_1/ReadVariableOp_1',
#  'model_0/conv2d_transpose_1/kernel/Read/ReadVariableOp',
#  'model_0/conv2d_transpose_1/bias/Read/ReadVariableOp',
#  'model_0/conv2d_transpose_1/conv2d_transpose/ReadVariableOp',
#  'model_0/conv2d_transpose_1/BiasAdd/ReadVariableOp',
#  'model_0/batch_normalization_11/gamma/Read/ReadVariableOp',
#  'model_0/batch_normalization_11/moving_mean/Read/ReadVariableOp',
#  'model_0/batch_normalization_11/moving_variance/Read/ReadVariableOp',
#  'model_0/batch_normalization_11/cond/ReadVariableOp',
#  'model_0/batch_normalization_11/cond/ReadVariableOp_1',
#  'model_0/batch_normalization_11/cond/ReadVariableOp_2',
#  'model_0/batch_normalization_11/cond/ReadVariableOp_3',
#  'model_0/batch_normalization_11/cond/FusedBatchNormV3_1/ReadVariableOp',
#  'model_0/batch_normalization_11/cond/FusedBatchNormV3_1/ReadVariableOp_1',
#  'model_0/conv2d_transpose_2/kernel/Read/ReadVariableOp',
#  'model_0/conv2d_transpose_2/bias/Read/ReadVariableOp',
#  'model_0/conv2d_transpose_2/conv2d_transpose/ReadVariableOp',
#  'model_0/conv2d_transpose_2/BiasAdd/ReadVariableOp',
#  'model_0/batch_normalization_12/gamma/Read/ReadVariableOp',
#  'model_0/batch_normalization_12/moving_mean/Read/ReadVariableOp',
#  'model_0/batch_normalization_12/moving_variance/Read/ReadVariableOp',
#  'model_0/batch_normalization_12/cond/ReadVariableOp',
#  'model_0/batch_normalization_12/cond/ReadVariableOp_1',
#  'model_0/batch_normalization_12/cond/ReadVariableOp_2',
#  'model_0/batch_normalization_12/cond/ReadVariableOp_3',
#  'model_0/batch_normalization_12/cond/FusedBatchNormV3_1/ReadVariableOp',
#  'model_0/batch_normalization_12/cond/FusedBatchNormV3_1/ReadVariableOp_1',
#  'model_0/conv2d_transpose_3/kernel/Read/ReadVariableOp',
#  'model_0/conv2d_transpose_3/bias/Read/ReadVariableOp',
#  'model_0/conv2d_transpose_3/conv2d_transpose/ReadVariableOp',
#  'model_0/conv2d_transpose_3/BiasAdd/ReadVariableOp',
#  'model_0/batch_normalization_13/gamma/Read/ReadVariableOp',
#  'model_0/batch_normalization_13/moving_mean/Read/ReadVariableOp',
#  'model_0/batch_normalization_13/moving_variance/Read/ReadVariableOp',
#  'model_0/batch_normalization_13/cond/ReadVariableOp',
#  'model_0/batch_normalization_13/cond/ReadVariableOp_1',
#  'model_0/batch_normalization_13/cond/ReadVariableOp_2',
#  'model_0/batch_normalization_13/cond/ReadVariableOp_3',
#  'model_0/batch_normalization_13/cond/FusedBatchNormV3_1/ReadVariableOp',
#  'model_0/batch_normalization_13/cond/FusedBatchNormV3_1/ReadVariableOp_1',
#  'model_0/conv2d_transpose_4/kernel/Read/ReadVariableOp',
#  'model_0/conv2d_transpose_4/bias/Read/ReadVariableOp',
#  'model_0/conv2d_transpose_4/conv2d_transpose/ReadVariableOp',
#  'model_0/conv2d_transpose_4/BiasAdd/ReadVariableOp',
#  'model_0/batch_normalization_14/gamma/Read/ReadVariableOp',
#  'model_0/batch_normalization_14/moving_mean/Read/ReadVariableOp',
#  'model_0/batch_normalization_14/moving_variance/Read/ReadVariableOp',
#  'model_0/batch_normalization_14/cond/ReadVariableOp',
#  'model_0/batch_normalization_14/cond/ReadVariableOp_1',
#  'model_0/batch_normalization_14/cond/ReadVariableOp_2',
#  'model_0/batch_normalization_14/cond/ReadVariableOp_3',
#  'model_0/batch_normalization_14/cond/FusedBatchNormV3_1/ReadVariableOp',
#  'model_0/batch_normalization_14/cond/FusedBatchNormV3_1/ReadVariableOp_1',
#  'model_0/conv2d_transpose_5/kernel/Read/ReadVariableOp',
#  'model_0/conv2d_transpose_5/bias/Read/ReadVariableOp',
#  'model_0/conv2d_transpose_5/conv2d_transpose/ReadVariableOp',
#  'model_0/conv2d_transpose_5/BiasAdd/ReadVariableOp',
#  'model_0/batch_normalization_15/gamma/Read/ReadVariableOp',
#  'model_0/batch_normalization_15/moving_mean/Read/ReadVariableOp',
#  'model_0/batch_normalization_15/moving_variance/Read/ReadVariableOp',
#  'model_0/batch_normalization_15/cond/ReadVariableOp',
#  'model_0/batch_normalization_15/cond/ReadVariableOp_1',
#  'model_0/batch_normalization_15/cond/ReadVariableOp_2',
#  'model_0/batch_normalization_15/cond/ReadVariableOp_3',
#  'model_0/batch_normalization_15/cond/FusedBatchNormV3_1/ReadVariableOp',
#  'model_0/batch_normalization_15/cond/FusedBatchNormV3_1/ReadVariableOp_1',
#  'model_0/conv2d_16/kernel/Read/ReadVariableOp',
#  'model_0/conv2d_16/bias/Read/ReadVariableOp',
#  'model_0/conv2d_16/Conv2D/ReadVariableOp',
#  'model_0/conv2d_16/BiasAdd/ReadVariableOp',
#  'model_1/conv2d_17/kernel/Read/ReadVariableOp',
#  'model_1/conv2d_17/Conv2D/ReadVariableOp',
#  'model_1/conv2d_18/kernel/Read/ReadVariableOp',
#  'model_1/conv2d_18/bias/Read/ReadVariableOp',
#  'model_1/conv2d_18/Conv2D/ReadVariableOp',
#  'model_1/conv2d_18/BiasAdd/ReadVariableOp',
#  'model_1/batch_normalization_16/gamma/Read/ReadVariableOp',
#  'model_1/batch_normalization_16/moving_mean/Read/ReadVariableOp',
#  'model_1/batch_normalization_16/moving_variance/Read/ReadVariableOp',
#  'model_1/batch_normalization_16/cond/ReadVariableOp',
#  'model_1/batch_normalization_16/cond/ReadVariableOp_1',
#  'model_1/batch_normalization_16/cond/ReadVariableOp_2',
#  'model_1/batch_normalization_16/cond/ReadVariableOp_3',
#  'model_1/batch_normalization_16/cond/FusedBatchNormV3_1/ReadVariableOp',
#  'model_1/batch_normalization_16/cond/FusedBatchNormV3_1/ReadVariableOp_1',
#  'model_1/conv2d_19/kernel/Read/ReadVariableOp',
#  'model_1/conv2d_19/bias/Read/ReadVariableOp',
#  'model_1/conv2d_19/Conv2D/ReadVariableOp',
#  'model_1/conv2d_19/BiasAdd/ReadVariableOp',
#  'model_1/batch_normalization_17/gamma/Read/ReadVariableOp',
#  'model_1/batch_normalization_17/moving_mean/Read/ReadVariableOp',
#  'model_1/batch_normalization_17/moving_variance/Read/ReadVariableOp',
#  'model_1/batch_normalization_17/cond/ReadVariableOp',
#  'model_1/batch_normalization_17/cond/ReadVariableOp_1',
#  'model_1/batch_normalization_17/cond/ReadVariableOp_2',
#  'model_1/batch_normalization_17/cond/ReadVariableOp_3',
#  'model_1/batch_normalization_17/cond/FusedBatchNormV3_1/ReadVariableOp',
#  'model_1/batch_normalization_17/cond/FusedBatchNormV3_1/ReadVariableOp_1',
#  'model_1/conv2d_20/kernel/Read/ReadVariableOp',
#  'model_1/conv2d_20/Conv2D/ReadVariableOp',
#  'model_1/conv2d_21/kernel/Read/ReadVariableOp',
#  'model_1/conv2d_21/bias/Read/ReadVariableOp',
#  'model_1/conv2d_21/Conv2D/ReadVariableOp',
#  'model_1/conv2d_21/BiasAdd/ReadVariableOp',
#  'model_1/batch_normalization_18/gamma/Read/ReadVariableOp',
#  'model_1/batch_normalization_18/moving_mean/Read/ReadVariableOp',
#  'model_1/batch_normalization_18/moving_variance/Read/ReadVariableOp',
#  'model_1/batch_normalization_18/cond/ReadVariableOp',
#  'model_1/batch_normalization_18/cond/ReadVariableOp_1',
#  'model_1/batch_normalization_18/cond/ReadVariableOp_2',
#  'model_1/batch_normalization_18/cond/ReadVariableOp_3',
#  'model_1/batch_normalization_18/cond/FusedBatchNormV3_1/ReadVariableOp',
#  'model_1/batch_normalization_18/cond/FusedBatchNormV3_1/ReadVariableOp_1',
#  'model_1/conv2d_22/kernel/Read/ReadVariableOp',
#  'model_1/conv2d_22/bias/Read/ReadVariableOp',
#  'model_1/conv2d_22/Conv2D/ReadVariableOp',
#  'model_1/conv2d_22/BiasAdd/ReadVariableOp',
#  'model_1/batch_normalization_19/gamma/Read/ReadVariableOp',
#  'model_1/batch_normalization_19/moving_mean/Read/ReadVariableOp',
#  'model_1/batch_normalization_19/moving_variance/Read/ReadVariableOp',
#  'model_1/batch_normalization_19/cond/ReadVariableOp',
#  'model_1/batch_normalization_19/cond/ReadVariableOp_1',
#  'model_1/batch_normalization_19/cond/ReadVariableOp_2',
#  'model_1/batch_normalization_19/cond/ReadVariableOp_3',
#  'model_1/batch_normalization_19/cond/FusedBatchNormV3_1/ReadVariableOp',
#  'model_1/batch_normalization_19/cond/FusedBatchNormV3_1/ReadVariableOp_1',
#  'model_1/conv2d_23/kernel/Read/ReadVariableOp',
#  'model_1/conv2d_23/Conv2D/ReadVariableOp',
#  'model_1/conv2d_24/kernel/Read/ReadVariableOp',
#  'model_1/conv2d_24/bias/Read/ReadVariableOp',
#  'model_1/conv2d_24/Conv2D/ReadVariableOp',
#  'model_1/conv2d_24/BiasAdd/ReadVariableOp',
#  'model_1/batch_normalization_20/gamma/Read/ReadVariableOp',
#  'model_1/batch_normalization_20/moving_mean/Read/ReadVariableOp',
#  'model_1/batch_normalization_20/moving_variance/Read/ReadVariableOp',
#  'model_1/batch_normalization_20/cond/ReadVariableOp',
#  'model_1/batch_normalization_20/cond/ReadVariableOp_1',
#  'model_1/batch_normalization_20/cond/ReadVariableOp_2',
#  'model_1/batch_normalization_20/cond/ReadVariableOp_3',
#  'model_1/batch_normalization_20/cond/FusedBatchNormV3_1/ReadVariableOp',
#  'model_1/batch_normalization_20/cond/FusedBatchNormV3_1/ReadVariableOp_1',
#  'model_1/conv2d_25/kernel/Read/ReadVariableOp',
#  'model_1/conv2d_25/bias/Read/ReadVariableOp',
#  'model_1/conv2d_25/Conv2D/ReadVariableOp',
#  'model_1/conv2d_25/BiasAdd/ReadVariableOp',
#  'model_1/batch_normalization_21/gamma/Read/ReadVariableOp',
#  'model_1/batch_normalization_21/moving_mean/Read/ReadVariableOp',
#  'model_1/batch_normalization_21/moving_variance/Read/ReadVariableOp',
#  'model_1/batch_normalization_21/cond/ReadVariableOp',
#  'model_1/batch_normalization_21/cond/ReadVariableOp_1',
#  'model_1/batch_normalization_21/cond/ReadVariableOp_2',
#  'model_1/batch_normalization_21/cond/ReadVariableOp_3',
#  'model_1/batch_normalization_21/cond/FusedBatchNormV3_1/ReadVariableOp',
#  'model_1/batch_normalization_21/cond/FusedBatchNormV3_1/ReadVariableOp_1',
#  'model_1/conv2d_26/kernel/Read/ReadVariableOp',
#  'model_1/conv2d_26/Conv2D/ReadVariableOp',
#  'model_1/conv2d_27/kernel/Read/ReadVariableOp',
#  'model_1/conv2d_27/bias/Read/ReadVariableOp',
#  'model_1/conv2d_27/Conv2D/ReadVariableOp',
#  'model_1/conv2d_27/BiasAdd/ReadVariableOp',
#  'model_1/batch_normalization_22/gamma/Read/ReadVariableOp',
#  'model_1/batch_normalization_22/moving_mean/Read/ReadVariableOp',
#  'model_1/batch_normalization_22/moving_variance/Read/ReadVariableOp',
#  'model_1/batch_normalization_22/cond/ReadVariableOp',
#  'model_1/batch_normalization_22/cond/ReadVariableOp_1',
#  'model_1/batch_normalization_22/cond/ReadVariableOp_2',
#  'model_1/batch_normalization_22/cond/ReadVariableOp_3',
#  'model_1/batch_normalization_22/cond/FusedBatchNormV3_1/ReadVariableOp',
#  'model_1/batch_normalization_22/cond/FusedBatchNormV3_1/ReadVariableOp_1',
#  'model_1/conv2d_28/kernel/Read/ReadVariableOp',
#  'model_1/conv2d_28/bias/Read/ReadVariableOp',
#  'model_1/conv2d_28/Conv2D/ReadVariableOp',
#  'model_1/conv2d_28/BiasAdd/ReadVariableOp',
#  'model_1/batch_normalization_23/gamma/Read/ReadVariableOp',
#  'model_1/batch_normalization_23/moving_mean/Read/ReadVariableOp',
#  'model_1/batch_normalization_23/moving_variance/Read/ReadVariableOp',
#  'model_1/batch_normalization_23/cond/ReadVariableOp',
#  'model_1/batch_normalization_23/cond/ReadVariableOp_1',
#  'model_1/batch_normalization_23/cond/ReadVariableOp_2',
#  'model_1/batch_normalization_23/cond/ReadVariableOp_3',
#  'model_1/batch_normalization_23/cond/FusedBatchNormV3_1/ReadVariableOp',
#  'model_1/batch_normalization_23/cond/FusedBatchNormV3_1/ReadVariableOp_1',
#  'model_1/conv2d_29/kernel/Read/ReadVariableOp',
#  'model_1/conv2d_29/Conv2D/ReadVariableOp',
#  'model_1/conv2d_30/kernel/Read/ReadVariableOp',
#  'model_1/conv2d_30/bias/Read/ReadVariableOp',
#  'model_1/conv2d_30/Conv2D/ReadVariableOp',
#  'model_1/conv2d_30/BiasAdd/ReadVariableOp',
#  'model_1/batch_normalization_24/gamma/Read/ReadVariableOp',
#  'model_1/batch_normalization_24/moving_mean/Read/ReadVariableOp',
#  'model_1/batch_normalization_24/moving_variance/Read/ReadVariableOp',
#  'model_1/batch_normalization_24/cond/ReadVariableOp',
#  'model_1/batch_normalization_24/cond/ReadVariableOp_1',
#  'model_1/batch_normalization_24/cond/ReadVariableOp_2',
#  'model_1/batch_normalization_24/cond/ReadVariableOp_3',
#  'model_1/batch_normalization_24/cond/FusedBatchNormV3_1/ReadVariableOp',
#  'model_1/batch_normalization_24/cond/FusedBatchNormV3_1/ReadVariableOp_1',
#  'model_1/conv2d_31/kernel/Read/ReadVariableOp',
#  'model_1/conv2d_31/bias/Read/ReadVariableOp',
#  'model_1/conv2d_31/Conv2D/ReadVariableOp',
#  'model_1/conv2d_31/BiasAdd/ReadVariableOp',
#  'model_1/batch_normalization_25/gamma/Read/ReadVariableOp',
#  'model_1/batch_normalization_25/moving_mean/Read/ReadVariableOp',
#  'model_1/batch_normalization_25/moving_variance/Read/ReadVariableOp',
#  'model_1/batch_normalization_25/cond/ReadVariableOp',
#  'model_1/batch_normalization_25/cond/ReadVariableOp_1',
#  'model_1/batch_normalization_25/cond/ReadVariableOp_2',
#  'model_1/batch_normalization_25/cond/ReadVariableOp_3',
#  'model_1/batch_normalization_25/cond/FusedBatchNormV3_1/ReadVariableOp',
#  'model_1/batch_normalization_25/cond/FusedBatchNormV3_1/ReadVariableOp_1',
#  'model_1/conv2d_32/kernel/Read/ReadVariableOp',
#  'model_1/conv2d_32/bias/Read/ReadVariableOp',
#  'model_1/conv2d_32/Conv2D/ReadVariableOp',
#  'model_1/conv2d_32/BiasAdd/ReadVariableOp',
#  'model_1/conv2d_transpose_6/kernel/Read/ReadVariableOp',
#  'model_1/conv2d_transpose_6/bias/Read/ReadVariableOp',
#  'model_1/conv2d_transpose_6/conv2d_transpose/ReadVariableOp',
#  'model_1/conv2d_transpose_6/BiasAdd/ReadVariableOp',
#  'model_1/batch_normalization_26/gamma/Read/ReadVariableOp',
#  'model_1/batch_normalization_26/moving_mean/Read/ReadVariableOp',
#  'model_1/batch_normalization_26/moving_variance/Read/ReadVariableOp',
#  'model_1/batch_normalization_26/cond/ReadVariableOp',
#  'model_1/batch_normalization_26/cond/ReadVariableOp_1',
#  'model_1/batch_normalization_26/cond/ReadVariableOp_2',
#  'model_1/batch_normalization_26/cond/ReadVariableOp_3',
#  'model_1/batch_normalization_26/cond/FusedBatchNormV3_1/ReadVariableOp',
#  'model_1/batch_normalization_26/cond/FusedBatchNormV3_1/ReadVariableOp_1',
#  'model_1/conv2d_transpose_7/kernel/Read/ReadVariableOp',
#  'model_1/conv2d_transpose_7/bias/Read/ReadVariableOp',
#  'model_1/conv2d_transpose_7/conv2d_transpose/ReadVariableOp',
#  'model_1/conv2d_transpose_7/BiasAdd/ReadVariableOp',
#  'model_1/batch_normalization_27/gamma/Read/ReadVariableOp',
#  'model_1/batch_normalization_27/moving_mean/Read/ReadVariableOp',
#  'model_1/batch_normalization_27/moving_variance/Read/ReadVariableOp',
#  'model_1/batch_normalization_27/cond/ReadVariableOp',
#  'model_1/batch_normalization_27/cond/ReadVariableOp_1',
#  'model_1/batch_normalization_27/cond/ReadVariableOp_2',
#  'model_1/batch_normalization_27/cond/ReadVariableOp_3',
#  'model_1/batch_normalization_27/cond/FusedBatchNormV3_1/ReadVariableOp',
#  'model_1/batch_normalization_27/cond/FusedBatchNormV3_1/ReadVariableOp_1',
#  'model_1/conv2d_transpose_8/kernel/Read/ReadVariableOp',
#  'model_1/conv2d_transpose_8/bias/Read/ReadVariableOp',
#  'model_1/conv2d_transpose_8/conv2d_transpose/ReadVariableOp',
#  'model_1/conv2d_transpose_8/BiasAdd/ReadVariableOp',
#  'model_1/batch_normalization_28/gamma/Read/ReadVariableOp',
#  'model_1/batch_normalization_28/moving_mean/Read/ReadVariableOp',
#  'model_1/batch_normalization_28/moving_variance/Read/ReadVariableOp',
#  'model_1/batch_normalization_28/cond/ReadVariableOp',
#  'model_1/batch_normalization_28/cond/ReadVariableOp_1',
#  'model_1/batch_normalization_28/cond/ReadVariableOp_2',
#  'model_1/batch_normalization_28/cond/ReadVariableOp_3',
#  'model_1/batch_normalization_28/cond/FusedBatchNormV3_1/ReadVariableOp',
#  'model_1/batch_normalization_28/cond/FusedBatchNormV3_1/ReadVariableOp_1',
#  'model_1/conv2d_transpose_9/kernel/Read/ReadVariableOp',
#  'model_1/conv2d_transpose_9/bias/Read/ReadVariableOp',
#  'model_1/conv2d_transpose_9/conv2d_transpose/ReadVariableOp',
#  'model_1/conv2d_transpose_9/BiasAdd/ReadVariableOp',
#  'model_1/batch_normalization_29/gamma/Read/ReadVariableOp',
#  'model_1/batch_normalization_29/moving_mean/Read/ReadVariableOp',
#  'model_1/batch_normalization_29/moving_variance/Read/ReadVariableOp',
#  'model_1/batch_normalization_29/cond/ReadVariableOp',
#  'model_1/batch_normalization_29/cond/ReadVariableOp_1',
#  'model_1/batch_normalization_29/cond/ReadVariableOp_2',
#  'model_1/batch_normalization_29/cond/ReadVariableOp_3',
#  'model_1/batch_normalization_29/cond/FusedBatchNormV3_1/ReadVariableOp',
#  'model_1/batch_normalization_29/cond/FusedBatchNormV3_1/ReadVariableOp_1',
#  'model_1/conv2d_transpose_10/kernel/Read/ReadVariableOp',
#  'model_1/conv2d_transpose_10/bias/Read/ReadVariableOp',
#  'model_1/conv2d_transpose_10/conv2d_transpose/ReadVariableOp',
#  'model_1/conv2d_transpose_10/BiasAdd/ReadVariableOp',
#  'model_1/batch_normalization_30/gamma/Read/ReadVariableOp',
#  'model_1/batch_normalization_30/moving_mean/Read/ReadVariableOp',
#  'model_1/batch_normalization_30/moving_variance/Read/ReadVariableOp',
#  'model_1/batch_normalization_30/cond/ReadVariableOp',
#  'model_1/batch_normalization_30/cond/ReadVariableOp_1',
#  'model_1/batch_normalization_30/cond/ReadVariableOp_2',
#  'model_1/batch_normalization_30/cond/ReadVariableOp_3',
#  'model_1/batch_normalization_30/cond/FusedBatchNormV3_1/ReadVariableOp',
#  'model_1/batch_normalization_30/cond/FusedBatchNormV3_1/ReadVariableOp_1',
#  'model_1/conv2d_transpose_11/kernel/Read/ReadVariableOp',
#  'model_1/conv2d_transpose_11/bias/Read/ReadVariableOp',
#  'model_1/conv2d_transpose_11/conv2d_transpose/ReadVariableOp',
#  'model_1/conv2d_transpose_11/BiasAdd/ReadVariableOp',
#  'model_1/batch_normalization_31/gamma/Read/ReadVariableOp',
#  'model_1/batch_normalization_31/moving_mean/Read/ReadVariableOp',
#  'model_1/batch_normalization_31/moving_variance/Read/ReadVariableOp',
#  'model_1/batch_normalization_31/cond/ReadVariableOp',
#  'model_1/batch_normalization_31/cond/ReadVariableOp_1',
#  'model_1/batch_normalization_31/cond/ReadVariableOp_2',
#  'model_1/batch_normalization_31/cond/ReadVariableOp_3',
#  'model_1/batch_normalization_31/cond/FusedBatchNormV3_1/ReadVariableOp',
#  'model_1/batch_normalization_31/cond/FusedBatchNormV3_1/ReadVariableOp_1',
#  'model_1/conv2d_33/kernel/Read/ReadVariableOp',
#  'model_1/conv2d_33/bias/Read/ReadVariableOp',
#  'model_1/conv2d_33/Conv2D/ReadVariableOp',
#  'model_1/conv2d_33/BiasAdd/ReadVariableOp',
#  'logits_0',
#  'logits_1']

# %%
def freeze_graph(model_dir, output_node_names):

    if not tf.gfile.Exists(model_dir):
        raise AssertionError(
            "Export directory doesn't exists. Please specify an export "
            'directory: %s' % model_dir
        )

    checkpoint = tf.train.get_checkpoint_state(model_dir)
    input_checkpoint = checkpoint.model_checkpoint_path

    absolute_model_dir = '/'.join(input_checkpoint.split('/')[:-1])
    output_graph = absolute_model_dir + '/frozen_model.pb'
    clear_devices = True
    with tf.Session(graph = tf.Graph()) as sess:
        saver = tf.train.import_meta_graph(
            input_checkpoint + '.meta', clear_devices = clear_devices
        )
        saver.restore(sess, input_checkpoint)
        output_graph_def = tf.graph_util.convert_variables_to_constants(
            sess,
            tf.get_default_graph().as_graph_def(),
            output_node_names.split(','),
        )
        with tf.gfile.GFile(output_graph, 'wb') as f:
            f.write(output_graph_def.SerializeToString())
        print('%d ops in the final graph.' % len(output_graph_def.node))

# %%
freeze_graph('noise-reduction-resnet-unet-output', strings)
# Out:
# INFO:tensorflow:Restoring parameters from noise-reduction-resnet-unet-output/model.ckpt
# WARNING:tensorflow:From <ipython-input-16-9a7215a4e58a>:23: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# WARNING:tensorflow:From /home/husein/.local/lib/python3.6/site-packages/tensorflow_core/python/framework/graph_util_impl.py:277: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# INFO:tensorflow:Froze 210 variables.
# INFO:tensorflow:Converted 210 variables to const ops.
# 2282 ops in the final graph.

# %%
def load_graph(frozen_graph_filename, **kwargs):
    with tf.gfile.GFile(frozen_graph_filename, 'rb') as f:
        graph_def = tf.GraphDef()
        graph_def.ParseFromString(f.read())

    # https://github.com/onnx/tensorflow-onnx/issues/77#issuecomment-445066091
    # to fix import T5
    for node in graph_def.node:
        if node.op == 'RefSwitch':
            node.op = 'Switch'
            for index in xrange(len(node.input)):
                if 'moving_' in node.input[index]:
                    node.input[index] = node.input[index] + '/read'
        elif node.op == 'AssignSub':
            node.op = 'Sub'
            if 'use_locking' in node.attr:
                del node.attr['use_locking']
        elif node.op == 'AssignAdd':
            node.op = 'Add'
            if 'use_locking' in node.attr:
                del node.attr['use_locking']
        elif node.op == 'Assign':
            node.op = 'Identity'
            if 'use_locking' in node.attr:
                del node.attr['use_locking']
            if 'validate_shape' in node.attr:
                del node.attr['validate_shape']
            if len(node.input) == 2:
                node.input[0] = node.input[1]
                del node.input[1]

    with tf.Graph().as_default() as graph:
        tf.import_graph_def(graph_def)
    return graph

# %%
instruments = ['voice', 'noise']

# %%
g = load_graph('noise-reduction-resnet-unet-output/frozen_model.pb')
x = g.get_tensor_by_name('import/Placeholder:0')

logits = {instrument: g.get_tensor_by_name(f'import/logits_{no}:0') for no, instrument in enumerate(instruments)}

# %%
[f'logits_{no}' for no in range(len(instruments))]
# Out:
# ['logits_0', 'logits_1']

# %%
pb = 'noise-reduction-resnet-unet-output/frozen_model.pb'

transforms = ['add_default_attributes',
             'remove_nodes(op=Identity, op=CheckNumerics, op=Dropout)',
             'fold_constants(ignore_errors=true)',
             'fold_batch_norms',
             'fold_old_batch_norms',
             'quantize_weights(fallback_min=-10, fallback_max=10)',
             'quantize_nodes(fallback_min=-10, fallback_max=10)',
             'strip_unused_nodes',
             'sort_by_execution_order']

input_graph_def = tf.GraphDef()
with tf.gfile.FastGFile(pb, 'rb') as f:
    input_graph_def.ParseFromString(f.read())

transformed_graph_def = TransformGraph(input_graph_def, 
                                           ['Placeholder'],
                                           [f'logits_{no}' for no in range(len(instruments))], transforms)
    
with tf.gfile.GFile(f'{pb}.quantized', 'wb') as f:
    f.write(transformed_graph_def.SerializeToString())

# %%
logits

# %%
test_sess = tf.InteractiveSession(graph = g)

# %%
# l = test_sess.run(logits, feed_dict = {x: y})

# %%
# ipd.Audio(l['voice'][:sr * 30], rate = sr)

# %%
# !tar -czvf noise-reduction-unet-output-500k.tar.gz noise-reduction-unet-output
