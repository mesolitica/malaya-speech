# %%
import os

os.environ['CUDA_VISIBLE_DEVICES'] = '1'
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'

# %%
import malaya_speech
import random
import numpy as np
import malaya
from sklearn.utils import shuffle
from sklearn.utils.random import sample_without_replacement
# Out:
# `pyaudio` is not available, `malaya_speech.streaming.pyaudio` is not able to use.

# %%
malaya_speech.force_alignment.transducer.available_transformer()
# Out:
#                               Size (MB) Quantized Size (MB)           Language
# conformer-transducer                120                32.3            [malay]
# conformer-transducer-mixed          120                32.3  [malay, singlish]
# conformer-transducer-singlish       120                32.3         [singlish]

# %%
model = malaya_speech.force_alignment.transducer.transformer(model = 'conformer-transducer', device = 'gpu:0')
singlish_model = malaya_speech.force_alignment.transducer.transformer(model = 'conformer-transducer-singlish', device = 'gpu:0')
# Out:
# 2023-04-10 00:33:09.576275: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-10 00:33:09.882625: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-10 00:33:09.896028: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-10 00:33:09.896933: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-10 00:33:10.325417: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-10 00:33:10.326272: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-10 00:33:10.326781: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-10 00:33:10.327427: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-04-10 00:33:10.327446: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /device:GPU:0 with 22302 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090 Ti, pci bus id: 0000:07:00.0, compute capability: 8.6
# 2023-04-10 00:33:14.216914: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-10 00:33:14.217817: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-10 00:33:14.218371: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-10 00:33:14.218894: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-10 00:33:14.219333: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-10 00:33:14.219835: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22302 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090 Ti, pci bus id: 0000:07:00.0, compute capability: 8.6
# 2023-04-10 00:33:18.332888: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-10 00:33:18.333889: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-10 00:33:18.334421: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-10 00:33:18.334944: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-10 00:33:18.335418: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-10 00:33:18.335854: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22302 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090 Ti, pci bus id: 0000:07:00.0, compute capability: 8.6

# %%
asr = malaya_speech.stt.transducer.pt_transformer(model = 'mesolitica/conformer-medium-mixed')
_ = asr.cuda()
_ = asr.eval()

# %%
lm = malaya.language_model.kenlm(model = 'bahasa-wiki-news-iium-stt')

# %%
lm.score('tak suka hg')
# Out:
# -13.193544387817383

# %%
import json
from glob import glob
from tqdm import tqdm

with open('/home/husein/ssd1/speech-bahasa/malay-asr-train.json') as fopen:
    ms = json.load(fopen)

# %%
with open('/home/husein/dev/malaya-speech/semisupervised-transducer.json') as fopen:
    semi = json.load(fopen)
    
filtered_X, filtered_Y = [], []
for i in range(len(semi['X'])):
    if semi['Y'][i][1] > 0.2 and len(semi['Y'][i][0]):
        filtered_X.append(semi['X'][i])
        filtered_Y.append(semi['Y'][i][0])
        
ms['X'] = ms['X'] + filtered_X
ms['Y'] = ms['Y'] + filtered_Y

# %%
with open('/home/husein/dev/malaya-speech/semisupervised-transducer-v2.json') as fopen:
    semi = json.load(fopen)
    
filtered_X, filtered_Y = [], []
for i in range(len(semi['X'])):
    if semi['Y'][i][1] > 0.2 and len(semi['Y'][i][0]):
        filtered_X.append(semi['X'][i])
        filtered_Y.append(semi['Y'][i][0])
        
ms['X'] = ms['X'] + filtered_X
ms['Y'] = ms['Y'] + filtered_Y

# %%
len(ms['X'])
# Out:
# 2483546

# %%
with open('/home/husein/malaya-speech/singlish-stt-train.json') as fopen:
    sg = json.load(fopen)

# %%
from datasets import Audio

sr = 16000
minimum = int(0.3 * sr)
audio = Audio(sampling_rate=sr)

# %%
def groupby(alignment, length, min_threshold = 0.5):
    r = []
    g = []
    for no, row in enumerate(alignment):
        
        if no > 0 and len(r) and alignment[no]['start'] - alignment[no-1]['end'] >= min_threshold:
            g.append(r)
            r = []
        
        r.append(row)

    return g

# %%
# !rm -rf augmentation-switchboard-v12

# %%
# !ls
# Out:
# augmentation-switchboard-v18	    augment-switchboard-lm-v2.ipynb
# augmentation-switchboard-v20	    augment-switchboard-v2.ipynb
# augmentation-switchboard-v21	    augment-switchboard-v3.ipynb
# augment-switchboard-lm-Copy1.ipynb  augment-switchboard-v4.ipynb
# augment-switchboard-lm-Copy2.ipynb  augment-switchboard-v5.ipynb
# augment-switchboard-lm.ipynb	    README.md
# augment-switchboard-lm-tts.ipynb

# %%
directory = 'augmentation-switchboard-v22'
# !mkdir {directory}

# %%
import torchaudio
import torch
from itertools import permutations

# %%
def calculate_wer(actual, hyp):
    """
    Calculate WER using `python-Levenshtein`.
    """
    import Levenshtein as Lev

    b = set(actual.split() + hyp.split())
    word2char = dict(zip(b, range(len(b))))

    w1 = [chr(word2char[w]) for w in actual.split()]
    w2 = [chr(word2char[w]) for w in hyp.split()]

    return Lev.distance(''.join(w1), ''.join(w2)) / len(actual.split())

# %%
data = {}
for O in tqdm(range(20000)):
    try:
        i_ms = sample_without_replacement(len(ms['X']), 4)
        i_sg = sample_without_replacement(len(sg['X']), 4)

        groups = []
        for i in i_ms:
            x = ms['X'][i]
            v = ms['Y'][i]
            y = audio.decode_example(audio.encode_example(x))['array']
            asr_ = asr.forward([y])[0]
            
            if asr_[0][1][0] < 0.15 and calculate_wer(v, asr_[0][0]) > 0.1:
                # print(f'skip ms {i}', v, asr_[0][0], asr_[0][1][0])
                continue
                
            result = model.predict(y, v)

            if ' '.join([r['text'] for r in result['words_alignment']]) != v:
                continue

            grouped = groupby(result['words_alignment'], len(y) / sr)
            # print(grouped)
            for g in grouped:
                y_ = y[int(g[0]['start'] * sr): int(g[-1]['end'] * sr) + minimum]
                if len(y_):
                    v_ = [g_['text'] for g_ in g]
                    groups.append((y_, v_))

        for i in i_sg:
            x = sg['X'][i]
            v = sg['Y'][i]
            y = audio.decode_example(audio.encode_example(x))['array']
            asr_ = asr.forward([y])[0]
            
            if asr_[0][1][0] < 0.15 and calculate_wer(v, asr_[0][0]) > 0.1:
                # print(f'skip sg {i}', v, asr_[0][0], asr_[0][1][0])
                continue
                
            result = singlish_model.predict(y, v)

            if ' '.join([r['text'] for r in result['words_alignment']]) != v:
                continue

            grouped = groupby(result['words_alignment'], len(y) / sr)
            for g in grouped:
                y_ = y[int(g[0]['start'] * sr): int(g[-1]['end'] * sr) + minimum]
                if len(y_):
                    v_ = [g_['text'] for g_ in g]
                    groups.append((y_, v_))
                    
        if not len(groups):
            continue
            
        groups = sorted(groups, key = lambda x: len(' '.join(x[1])), reverse = True)[:7]
        
        strings = [' '.join(g[1]) for g in groups]
        perm = list(permutations(range(len(groups))))
        
        scores = []
        for p in perm:
            s = ' '.join([strings[p_] for p_ in p])
            scores.append(lm.score(s))
            
        best_perm = perm[np.argmax(scores)]
        
        l = 0
        combine_y, combine_v = [], []
        index = 0
        while l < 15 and index < len(groups):
            g = groups[best_perm[index]]
            l_ = len(g[0]) / sr
            if l_ < 1.0:
                index += 1
                continue
            r_int = random.randint(3000, 16000)
            l += l_ + (r_int / sr)
            combine_y.append(g[0] / np.abs(g[0]).max())
            combine_y.append(np.zeros(shape = (r_int,)))
            combine_v.extend(g[1])
            index += 1

        if len(combine_v):
            audio_path = f'{directory}/{O}.mp3'
            torchaudio.save(audio_path, 
                            torch.tensor(np.concatenate(combine_y).astype('float32')).unsqueeze(0), 
                            sr, format='mp3')
            data[O] = ' '.join(combine_v)
            
    except Exception as e:
        pass
# Out:
#  86%|███████████████████████████▌    | 17224/20000 [13:01:48<2:02:01,  2.64s/it]

# %%
len(data)
# Out:
# 12982

# %%
data
# Out:
# {0: 'menulis di atas',
#  1: 'takut nanti ada orang yang takut dengan kemaksiatan',
#  3: 'dan mereka adalah penengah di antara allah dan',
#  7: 'kawasan orang asli masya allah bulan ramadhan',
#  8: 'dan memberi alasan',
#  9: 'like i need to rest dilonggokkan di situ dan akhir sekali saya ingin',
#  11: 'wang yang muktabar orang yang hampir mati',
#  12: 'umi masih muda his n s stint',
#  13: 'cari wahhab sebagai seorang tokoh yang bergaya hidup ranggi nine twenty eight twenty six january nineteen thirty seven',
#  14: 'nabi sallallahu alaihi wa sallam apa yang telah dia korbankan masa dan tenaganya yang telah engkau ciptakan perkara yang engkau telah ciptakan tak ada satu pun yang sia sia',
#  15: 'melaksanakan tiket',
#  16: 'big picture of the whole subject that is going on whereby we are trying to create equality we are trying to create our fairness for this',
#  17: 'dia perempuan cantik jadi okey balik',
#  18: 'walaupun begitu',
#  19: 'nabi masih bayi',
#  20: 'kan perkahwinan mereka kepada petugas',
#  22: 'dia kata kita nak kena cari al quran',
#  23: 'that will be all okay thank you so much',
#  24: 'dan keperluan rakyat negara ini',
#  26: 'berkatan ketetapan pembinaan baki wang terimaan bil perbendaharaan malaysia',
#  27: 'being an p m p',
#  28: 'apabila setuju mengambil',
#  29: 'buat apa saya duduk di mimbar one thousand ways he could not build a light bulb before inventing the light bulb so if he were to quit on melaksanakan pendekatan ride hailing nine hundred and ninety nine',
#  30: 'aku fikir sendiri',
#  31: 'florence close',
#  32: 'kehidupan setiap srinivasa',
#  33: 'tapi bila melihatkan tiada seorang pun daripada mereka yang memperhatikannya hatinya beransur senang but for some people dalam hal ini kementerian sedang its not acceptable',
#  34: 'okay taken it down and consumptions is not just of goods',
#  35: 'already have about fifteen people in the group',
#  37: 'dan akan membasahkan keliling block pada kontrol ni',
#  38: 'senior will have his room with an attached bathroom',
#  39: 'adakah sama ada',
#  40: 'by using names such as jessica tan soon neo teo chee hean kenapalah rebah pada kita',
#  41: 'tiang kalau kerja azhar',
#  42: 'ada dua benda tentang masuk dalam kedai ada satu produk non muslim bagaimana dahsyatnya zionist dibuat lapan meter tinggi',
#  44: 'menyembah mengabdi kamu',
#  45: 'saya tidak bergerak jauh ke tempat kerja dengan',
#  46: 'kamu dengan anggerik chong kee hiong',
#  47: 's a j c',
#  49: 'padang pasir pun tak boleh buat keluar belakang semua a smaller grant could even be',
#  50: 'kotek akan membentuk ruangan kosong belakang ini',
#  51: 'datang daripada allah',
#  52: 'rahman lebih melihatkan beberapa orang budak muda yang sambil bercerita tentang perempuan kalau anda nak tahu lee choon seng',
#  53: 'alright sure',
#  54: 'that is what i am currently in for my c c a laporan harian ini dengan',
#  56: 'do you know how to cook',
#  60: 'orang yang mati syahid',
#  61: 'data bawa baby mai mana hang ni bapak tak ada',
#  65: 'punishment does not work because it is a reactive approach',
#  66: 'the hongkong dollar faltered',
#  68: 'kalau kalau mengikut mengikut peraturan dan pelan strategik yang memberi inspirasi kepada rakyat jika berjaya mendaftarkan diri sebelum terima petang dia layak untuk mengundi',
#  70: 'number sequence is t nine seven five two eight six four q',
#  71: 'lim chee wai david evelyn goh',
#  72: 'pencuci ran the witch put a spell on their prince',
#  73: 'kaedah hati kita memang macam tu',
#  74: 'assalamualaikum',
#  77: 'really huh no have calculator so you you have to lebih kurang tanah yang',
#  78: 'i but i say before i always say yang mendoakan',
#  79: 'mari kita bukan sedikit kemudian dikembangkan so this are the reasons why dalam satu buku',
#  81: 'ada yang masuk direct james wong tuck names found in the nominees list this year include lim kok ann',
#  82: 'or the friends that we make we are very much dependent on the community around us',
#  83: 'aku tahu hang semangat nak tanya pasal hadis ni hang jadi mula tanya kat aku soalan uh yes thats the one soya beancurd goreng pisang',
#  84: 'bukan takat jabatan laut',
#  85: 'tempat kita semua ada dalam keadaan akan bertemu banyaknya',
#  86: 'commercial affairs department',
#  87: 'i think most of the time everyone',
#  88: 'daripada alright seorang muslim ialah apabila dia membaca bismillahillazi la ilaha illa',
#  89: 'berhenti tahun lepas sweet and sour pork chua nam hai',
#  90: 'so i i dont know but if i just see like that you know i i dont know maybe he can handle his time very well',
#  91: 'tapi biasa tempat kita kecuali kita tadi kecuali harga air naik bila tak ada air air tak naik ke',
#  92: 'itu tetap menjadi satu satunya lagu singel mereka joan hon kwok peng kin francis',
#  93: 'aku nak cakap pada kau satu pasallah suaranya kuat bosan terus tanpa terus a police spokesperson confirmed that the report has been lodged mendapat barakah daripada majlis tersebut',
#  94: 'sorry not consumption production',
#  95: 'okay miss so sorry to hear that',
#  97: 'hari kiamat belum tentu ada tak nampak tak wujud chek chai long chuen temple bishan h d b branch office',
#  98: 'ariff bongso',
#  100: 'it covers historic buildings twenty fifth march nineteen forty four',
#  101: 'longchamp comfortdelgro',
#  102: 'number sequence is s eight five nine zero four six three p',
#  103: 'ada yang menyebut dia ini seorang nabi',
#  104: 'okay i would like to have a lalu kasih kepadanya sehinggakan takut kepada hati mati semua orang takut tapi masalahnya dia hidup macam tak nak mati dah',
#  105: 'ng yat chuan',
#  106: 'shan rui yao cai tang',
#  108: 'itu jika siang lebih panjang maka malam akan lebih pendek kanagasuntheram ragunathar',
#  109: 'nak sapu rumah orang tu ke does it come cold',
#  110: 'kenapa apinya padam you still need the offline',
#  111: 'so its all over the world and its very interesting',
#  112: 'its about sixteen minutes to walk to',
#  113: 'dia kahwin dengan mak dia sendiri',
#  114: 'names found in the nominees list this year include tung chye hong',
#  115: 'its it it it seems like shes explaining a little too deep',
#  116: 'kalau orang tu mati menangis ya im surprised that you you dont have any complaints before i did',
#  117: 'kita ada kereta or or what the ingredients the the flour and the mixture into the the ratio must be correct then the method how you the baking powder',
#  118: 'bahawa sistem if the this two bite me again',
#  119: 'pada jalan jalan falsafah',
#  120: 'in some other the',
#  121: 'there are stories about tan teck neo chan chun sing',
#  122: 'select the bar',
#  123: 'okay i was working very hard t p j c',
#  125: 'technology in this case created not a gulf but',
#  128: 'bodoh dari buat video',
#  129: 'abuse is very much in malaysia merupakan sebuah negara yang mempunyai keistimewaan',
#  131: 'lagi banyak ikan lagi besar ikan kecil kecil dapat ikan tahap kecil kecil',
#  132: 'fazlur rahman tidak percaya new revivalism atau islamisme chen sucheng and s rajendran abdul',
#  133: 'nasi goreng seafood could i have your name and your e mail so that i can have some compensation some sorts of compensation yes we will definitely but occasionally',
#  134: 'billion of these individuals work hand in hand having the same view',
#  135: 'i mean personalised something like that i dont want to go with big groups is that and you have to follow everybody is is there any other one that i could',
#  136: 'dalam facebook mengata dalam bukan',
#  137: 'ataupun empat oranglah',
#  138: 'you could either purchase it over the benefits you get a house nearby his workplace',
#  139: 'tidak sesiapa pun yang mempedulikan longkang ini kalau ada pun yang mengambil berat tentangnya di dalam hutan dalam berjalan itu',
#  141: 'waktu kerja ke macam mana ke tengah kerja ke apa',
#  142: 'where is bougainvillea',
#  143: 'there is a food court selling ambil tindakan ataupun',
#  144: 'you can book the sure so the discount dont worry the discount right is last for one year koh yong guan joash moo and your stay within the next',
#  145: 'she lazed her whole morning away on the deck chair dalam kehidupan ini',
#  146: 'lagipun dia nak tak bagi pun dia naik john turnbull thomson ismail marjan minta berlindung daripada allah',
#  147: 'he might be able to become a singapore citizen',
#  150: 'senior instructors also asked trainees if they needed any assistance',
#  151: 'sebuah kereta moden dan canggih',
#  153: 'ada seorang anak murid ni hampir semua budak budak muda yang duduk meminum kopi serba itu berpakaian baharu bonek dia panjang sikit',
#  155: 'but premiums the the the restaurant ambience was',
#  157: 'cara yang istimewa',
#  158: 'subhanahu wa ta ala ke atas mereka berperang',
#  159: 'alim pada makbapak now our topic touches on the statement which says that as a society progresses',
#  160: 'first it will complicate compliance requirements involving additional processes for companies to correctly account for hidup kehidupan seharian',
#  161: 'buat status facebook',
#  163: 'dan melambai lambai',
#  164: 'allah akan mengharamkan',
#  165: 'karaage fried chicken',
#  166: 'but operators noted some companies may not be keen okay thank you see you soon',
#  167: 'i think i will go on the eleven as well the thirteenth december',
#  170: 'may i know what is the requirement for the iphone twelve what is storage okay for iphone twelve rasuah solar yang dihadapinya',
#  171: 'so it will become cheaper so i also like woo',
#  172: 'yes yes and regarding the bug we will definitely fixed it properly so that our customers get',
#  173: 'balaji sadasivan john eber chia tee chiak chan keng howe harry',
#  174: 'they brought some clothes and there three days the bench by the bank of the river',
#  175: 'daripada penemuan pemantauan kita selepas daripada enam bulan itu',
#  176: 'bergaul dengan lebih banyak',
#  177: 'penambahbaikan yang dibuat untuk mengambil daging penyet miss ashley said the train service started slowly sweet and sour pork on the situation this morning',
#  178: 'telah lama mempunyai kerjasama dengan indonesia',
#  179: 'kalau kita semua ni islam',
#  180: 'oreo tan and seiring dengan perubatan tradisional melayu',
#  181: 'the catch is the price',
#  182: 'ada sesetengah ulamak salah',
#  183: 'yang ni saya tak jumpa dalam mana mana hadis dia kata dan keluar darah daripada lubang rumah nabi isa ketika mendengar hiphop allah yang takdirkan itu kau yang suruh tuhan tanya dia macam tu okay understand',
#  184: 'gyoza and',
#  186: 'dia kata mak long v nine o',
#  188: 'rising borrowing costs',
#  189: 'christian paul',
#  190: 'kedaulatan wilayah juga akan terus kita pertahankan facial expression hen duo orang tak nampak ya kau fikir orang semua tak ada mata',
#  191: 'sebab tu aku menangis depan allah subhanallah ampun dosaku aku tegur benda ni dulu assumption pathway school',
#  192: 'be fearful of what of what the internet',
#  193: 'if you do consider the newly released for this tablet itself samsung tablet thats the s one eight plus you is only cost sebagaimana kehidupan mereka dahulu',
#  194: 'hi lily my name is zara sure so if you need further assistant just feel free to call this number im calling about to find out which one suits me the best',
#  195: 'dia kan semua ahli sunnah wal jamaah ialah as salafi yoon dan mengambil keuntungan berdasarkan perubahan',
#  197: 'dan diketahuinya bahawa anaknya itu menyayanginya kkm akan meneruskan aktiviti aktiviti pembendungan bagi meningkatkan kesedaran wong nai chin',
#  198: 'kita laksanakan kita ada lau chiap khai chia kiah hong steve',
#  200: 'right now we are living in his modern age where you know everything is just available online',
#  202: 'saya berharap pada hari rabu akan datang',
#  205: 'if you learn how to do something',
#  206: 'there will be a local tour guide who will be there to introduce you to the different places that they would recommend you to visit so if you all',
#  207: 'menjadi khusyuk',
#  208: 'dari sudut gambaran kebahagiaan kebahagiaan yang pernah dialami di dalam keluarga mereka mungkinlah tak cukup',
#  209: 'nothing beats having maili',
#  210: 'jadi inilah yang menyebabkan tamatnya perang it therefore becomes even more important that people choose the health plan menggunakan garam dalam perjanjian ini',
#  213: 'apapun yang kita inginkan addicts anonymous',
#  214: 'keseluruhan wanita enam tempat yang kedua',
#  215: 'rumah tangga mereka ibu bapa setuju despite her passion and commitment to excel',
#  217: 'the coffee bean and tea leaf',
#  218: 'manusia sebab tu yang tak mengaji yang tak mencaci okay so sorry about it syed hussein alatas lee kip lee',
#  219: 'p e p u b',
#  220: 'huh then how come why why cannot a five e w bila umat islam pada ketika itu mula mentaati perintah allah',
#  221: 'dhankan gusdur semakin meningkat laju penguasaannya dalam penuturan bahasa perancis dhershini govin winodan',
#  222: 'alat tu akan diambil oleh para malaikat allah',
#  223: 'at the same time the singapore flyer loke yew street and pasir panjang tamil',
#  225: 'he thought hes brave for saying the truth',
#  226: 'lu ming teh cheong choong kong',
#  228: 'tidak bertentangan dengan quran dan sunnah nabi baginya pahala',
#  230: 'i would say ill go for the',
#  234: 'subhanallah',
#  235: 'maple syrup bismillahirrahmanirrahim',
#  236: 'memberi perangsang kepada dan juga insentif kepada proton untuk makanan tu sedap',
#  237: 'langsung tak ada apa',
#  238: 'peter augustine goh a p rajah maka mereka telah dibuangnya pula ke dunia untuk menerima balasan mereka kerana berdosa itu kakak aku pun bukan anu aku',
#  242: 'carilah ulamak ulamak tak mengapa juga',
#  243: 'community so far and especially for those talents or ability or service to soc',
#  245: 'kawan kawan kita ramai three eight four zero one nine six x number sequence is',
#  246: 'ketika mati the little boy',
#  247: 'beliau kelihatan tenang k y jelly dan allah dan tak rasa allah tu ada',
#  250: 'so recently i bought some d i y paint kits and they come with like nabi menikah sekian sekian',
#  252: 'ibu ibu tunggal so by negleging apa makna kalam ini apa makna firman ini',
#  256: 'bergema suara',
#  257: 'bulan yang telah hilang dari kalendar pendidikan mereka like he was just trying to help me to',
#  258: 'there is a food court selling maili kofta',
#  259: 'bye bye have a good day dan dia sendiri',
#  260: 'there is a food court selling eddino abdul hadi matthew yap edge on other countries we dont have the resour we dont have natural resources and if we want to actually have a competitive edge if you want to outgrow',
#  261: 'kepada mereka tentang keberadaan dan kewujudan allah tu bagi mereka tak kuat lagi hujan ni',
#  262: 'kesihatankesihatan lukisan',
#  263: 'okay if you dont mind sharing',
#  264: 'when you are feeling stressed out andrews avenue jubilee yaman dah jadi wilayah',
#  265: 'mena warna warni tu nampaknya kening tipisnya terangkat angkat',
#  266: 'webster is dropping me off at',
#  267: 'halimun khabir menghidupkan sebab tu tempat',
#  270: 'shopping package one is',
#  271: 'he noted on possible head lines',
#  272: 'satay bee hoon',
#  273: 'last month though it all',
#  276: 'walaupun kau selalu kenyang didunia yang membuka hidupnya sendiri ya its no longer like perut semua kembung kembung sama',
#  278: 'they fed their hungry stomachs with the egg and ham sandwiches comfortdelgro',
#  279: 'dalam kericuhan yang terjadi setelahnya',
#  280: 'pi makan kenduri kat rumah orang sebelah',
#  281: 'robert soon she also singled out the singer',
#  283: 'sathyalingam after looking at the database we found stories about di fasa empat itu',
#  284: 'ketiga perasaan kerja raya persekutuan dan negeri',
#  286: 'kita tak boleh menafikannya unsur unsur internal lagu jual beli',
#  288: 'ong teng koon tu bukan marah sangat marah marah ke tak marah',
#  289: 'beberapa tahun sebelum haji muhammad soeharto kembali dari mekah',
#  290: 'but then the example that we are discussing is a poor country by using names such as yee jenn jong dhershini govin winodan a poor country has limited resources',
#  291: 'kahwin dengan kita beri kita makan',
#  292: 'morning shift night shift after taking a look at the database we found stories about angelina choy catherine lim and louis contoh contoh macam ni nabi musa ada tongkat pada tongkat nabi musa tongkat bertukar menjadi ular dia tak betul',
#  294: 'australia i think we did',
#  296: 'dirasakannya benar benar bahawa sebenarnya sudah timbul satu persoalan baharu',
#  297: 'kita pergi minat ya',
#  298: 'jahmiyah go on jabariah go on qodariah go on',
#  299: 'membolehkan maaf menubuhkan zakat pulau pinang',
#  300: 'larut road penang road and tai',
#  301: 'how do i get to tagora kita ada sembang banyak tadi ya sebelum kita mulakan',
#  302: 'date of birth will be the people included in the list are shanti pereira gabriel oon chong jin',
#  304: 'around the region and across industries our people',
#  306: 'tuhan ampun dosa orang yang mengajar voyage rates time charter numbers abdullah bin hawalah sambil sambil kita belajar ni bila sebut gejala sosial',
#  307: 'kerjasama dengan department agama mendahului pembentukan kementerian agama',
#  309: 'fishball noodle soup but it is quite clear that we are singapore',
#  310: 'untuk datang ataupun melawat allah je tahu bila allah suruh pasti untuk kebaikan',
#  311: 'ada siapa nak cakap apa pula kerajaan beliau memberitahu sahabat sahabat baiknya',
#  312: 'buka facebook tengok mesti ada dan berkongsi rezeki',
#  313: 'i heard that the air pollution was quite bad every local area needs a temple',
#  314: 'aku tengok je takut nak main',
#  315: 'its placed there instead instead of us going to the',
#  317: 'malaikat tak ada nafsu tak makan tak minum tapi kalau angkasa lepas tampaknya macam kosong we found stories about the additional pathway supplements the existing upgrading pathways to encourage hiring and',
#  318: 'kpt telah mengenal pasti beberapa perkara',
#  319: 'tentulah daripada al quran dan baginda rasul',
#  320: 'selamat malam',
#  321: 'nanakusa gayu',
#  322: 'library at esplanade old cathay building',
#  323: 'yang memalukan',
#  324: 'for restaurant we',
#  325: 'aiya so its not a complete escape benda benda paling besar bulu yang lebat',
#  327: 'paksi golput akhirnya orang tua itu kembali tenang setelah termenung',
#  328: 'mereka memiliki empat putri',
#  329: 'bahagian dalam kenderaan tidak ditunjuk',
#  330: 'mauro kipp and you be determined and you can achieve datang daripada diri saya sendiri',
#  331: 'lim kay siu jay lim and patricia',
#  332: 'rekod rekod lagu hindustan dibunyikan dengan pembesar suara yang sengaja dibesarkan suara para tamu lelaki berbual bual dengan pelayan pelayan yang terpaksa dikuatkan',
#  337: 'execute work',
#  338: 'evergreen gardens graduan sekarang mengeluh kerana di atas pelbagai',
#  339: 'seven nine one two four six zero m and date of birth is eleventh march number sequence is t',
#  340: 'bukan kita sikap dia positif fettuccine alfredo umar abdullah al khatib',
#  341: 'hand in documents to the government about what service what kind of service they provide right',
#  342: 'okay that will be good',
#  343: 'juga merasakan mencegah daripada allah',
#  344: 'we must serve whoever',
#  345: 'carrot halwa',
#  346: 'theres something about hotel beds that makes them disalut aluminium dan zink yang berasal dari',
#  347: 'pengetahuan ini mengejutkannya benar benar pada mulanya rasa jijik terhadap siti salina dan abdul fakar',
#  348: 'minta untuk diciptakan',
#  350: 'lee cheng yan',
#  351: 'a new television show documented the lives of various people',
#  352: 'this will come on the back of lower revenue from statutory board contributions',
#  353: 'kalau saya nak sambungkan tadi tu boleh tak',
#  354: 'nak tengok ke cara nabi sayang',
#  356: 'ataupun beberapa saya semua',
#  357: 'twenty fourth september two thousand and twenty four',
#  358: 'pada tahun lepas saya telah berbahas',
#  359: 'penyelewengan bentuk bentuk pemansuhan as reactions slow and steps wobble',
#  360: 'each participating nation submits a team of five students to debate social',
#  361: 'and a few companions',
#  362: 'pertama saya dah tunang khadijah isteri kedua umur salamah hati ini hanya memberi manfaat kepada kehidupan dunia semata mata dan tidak ada nilai kehidupan akhirat yang kekal selamanya',
#  363: 'tak ingat nak sebutkan wakil daripada ketua pengarah kesihatan juga hadir dalam yang dipercakapkan one key question is whether the tax hike',
#  364: 'nama tanah siap siap konon kononnya bila mak pak mati senang',
#  365: 'then they cannot win the business di mana mana pun ada di dalam malaysia ni',
#  366: 'it does not necessary necessarily mental framework all kind of sculpturing a persons character or a persons to be accepted into the society',
#  370: 'ya i can help you apply now ill just need some of your details can i get your name and your phone number',
#  371: 'coast plaza for a sunny place like singapore asal kapas menjadi benang',
#  372: 'jauh sekali daripada sihir sebab',
#  373: 'h c i',
#  374: 'baik baik dengan betul betul dan teruskan belajar',
#  375: 'the thing that were looking for is more of the the hike termasuk ketua polis negara yang terbaru bekas ketua polis negara sebelum ini imam baihaqi ke tak',
#  376: 'eighteenth february okay ya saturday is it its saturday okay good good good ya apabila hujan lebat',
#  378: 'apakah inisiatif kplb tapi disatukan menjadi satu',
#  380: 'and by august next year sedap pengeluaran pemprosesan tanaman ternakan dan sebagainya',
#  381: 'tak payahlah nak pergi merayau ni jiang ji ge yue',
#  382: 'i am particular about my we studied about loh kok heng tan kian por and lim',
#  383: 'okay so the room is well furnished employers play a very very critical role in enabling the development of their people',
#  385: 'assalamualaikum',
#  386: 'she practically had a mini rally right then',
#  387: 'bismillah yang anda boleh consider dalam anda punya',
#  389: 'dalam usaha untuk memastikan murid mendapat pengetahuan',
#  390: 'kerajaan pakatan harapan diserang okay can can i have specific delivery timing or its a range of timing',
#  391: 'dibiayai oleh pihak kerajaan insyaallah',
#  392: 'akibat dari faham sentiasa mengharapkan agar kerjasama antara seah street gallop stables at pasir ris',
#  393: 'just to you know and make sure that you know my tapi dia tidak bersikap adil contoh lompat parti',
#  395: 'and when the',
#  397: 'disebut dalam quran tadi dengan perkataan',
#  398: 'yang kita mahu ini supaya tidak ada hilang kepercayaan rakyat terhadap sistem demokrasi pilihanraya it would be my group of friends and we are looking at the twenty years old some twenty one but dapat weekends but i think weekends also he go out also spend time with wife',
#  399: 'setiap pagi setelah bangun',
#  400: 'assalamualaikum apa khabar semua but when we aggregate those results',
#  401: 'probably supposed to do more hands on stuff but i should study and work hard',
#  402: 'hanya beberapa spesies binatang mungkin ikan',
#  403: 'mary fell asleep on her mothers lap',
#  404: 'ada jkkn jabatan kebudayaan kesenian negara',
#  405: 'walaupun secara teknikal gusdur dan cinta nuriah kini telah berkahwin mereka menganggapnya',
#  406: 'filed into the hall at frontier primary anxious pupils from the pioneer batch',
#  407: 'now also like have the nabi yang terakhir daripada kalangan bani israel',
#  408: 'minimum requirement to i would like to know more about the i air miles credit card',
#  410: 'menyimpan anggapan yang tidak baik terhadap sitisalina dia akan mempertahankannya itulah satu kemampuannya thats thats ya unless if its',
#  412: 'then certainly that if they find out who is responsible is indeed from within calls for more stringent kerusi di seluruh negara terutamanya di kawasan luar bandar',
#  414: 'how to say out outlook on life and it may not apply to everyone each subject is different in term of structure',
#  415: 'yes i can actually email you the link or alternatively you can search it up on our company website we are facing whichever job we have been dot a b c hotel',
#  416: 'maybe i answer first',
#  417: 'you can actually install wi fi mesh',
#  418: 'maybe weekends i will cycling with friends tan kek hiang vilma laus and ruth wong',
#  419: 'supaya isu berkaitan laut china selatan ini',
#  420: 'ya i think because after dyson came out with that thing kita buat perhimpunan tahi',
#  423: 'mendaki bukit dan ini menyebabkan banyak',
#  424: 'saya cadang kementerian dan spm ravioli rogan josh market products to us or just needs like for example insurance company they only want g they only want you have your number and your companies that want to',
#  425: 'empat dara duduk di building a community of readers is something we would see i actually for our bank m r c airmiles we have the m r c cashback m r c bank we actually have three types of credit card',
#  426: 'amin sekolah pagi seafood linguine caramelized maui onion dip and',
#  427: 'so we prefer the meals to be catered for we in the retreat well have a lot of bonding session within the hotel dan yang ke seterusnya saya ingin mencadangkan supaya christ methodist church and also because its a team retreat right',
#  428: 'wishes like i want to have like okay for the tea appreciation it will be able to be invisible',
#  429: 'kalau kita melihat di peringkat awal ucapan adalah generasi yang telah diutuskan kepada mereka ada pihak mengatakan he is said to have wanted to avoid the kind of personality',
#  430: 'the association holds at least',
#  431: 'bawa ayam betina duduk tang tepi tepi',
#  433: 'this criticism shows that at least for the general public for the general public and the world and',
#  434: 'he also admitted to one count of causing hurt by performing a rash act room kita terkenal dengan agama nasrani',
#  436: 'you must escape from ghosts in this game',
#  439: 'actually at the highest level not all athletes can balance studies and sports jalan dermawan anita sarawak',
#  441: 'okay so in total you checked in two bags hasil produk tempatan untuk disenaraikan sebagai zon pelaburan pelancongan maybe you can describe to me but you only manage to',
#  442: 'bapak dah meninggal ni siapa nak bagi minum kat aku nak menghuraikan sedikit apakah dia katakan hukum memang tindakan ni bagi saya bercanggah three six two three',
#  443: 'why you so fast i mean all of army you could come to your three hundred and ninety nine thousand milik mereka sendiri',
#  444: 'lebih menarik perhatiannya perlawanan perlawanan bola sepak',
#  446: 'sebab itulah seorang ulamak kata',
#  447: 'sungguh kerana we will just move on with this well be emailing you the details so that you can perompak dan sebagainya',
#  448: 'in kita pastikan ada',
#  449: 'salurkan kepada golongan yang yang memerlukannya',
#  450: 'perlu membersihkan dan menyucikan',
#  451: 'tapi cukai bererti mereka',
#  452: 'melahirkan seorang baby atau bayi ini',
#  453: 'ibunya bangun duduk seketika dan sesudah batuknya berhenti rakyat yang umum',
#  454: 'seven december nineteen forty two',
#  455: 'it will be a ten percent of stands for standard and poors s p d r',
#  456: 'we made verbal vows to each other in the past old town white coffee',
#  457: 'abang sakar most indian families had single incomes during those days mati dia kan buka mata dia dia memandang cermin sungguh sungguh',
#  458: 'this is the best',
#  459: 'selamat menyambut ramadhan al mubarak',
#  460: 'sitisalina mister farid if im not wrong im really really sorry about you',
#  461: 'itulah yang tuan tuan bawa dalam kubur commonwealth avenue',
#  462: 'the baker used a whole block of butter rogan josh tempura seorang presiden pembaharu memang tidak mudah',
#  463: 'actually i was with there with my family ya and then we were there because',
#  464: 'yup sure its a u d r e y',
#  465: 'tunjukkan kita ni tempat ibu balik program anjuran bahagian pembinaan bakat dan kepakaran dewan bahasa dan pustaka sebenarnya kita masih ada pelbagai soalan lagi ramai nak bertanya soalan tapi tidak mengapa tuan tuan dan puan puan',
#  466: 'nine zero three zero four one two',
#  467: 'nallur road boon lay garden primary school',
#  469: 'i think thats about all for now',
#  471: 'diambilnya kain itu the development will have',
#  472: 'for my point is i think that we should consider subjective factors like part time employment performance and also other outstanding',
#  473: 'kalau nak berjalan kena yakin any goodies if i sign up masih juga berada di hadapannya',
#  475: 'pada hari berikutnya beliau bertemu dengan menteri menteri kanan',
#  476: 'i i actually prefer samsung so i i think the samsung tetapi sekarang ini',
#  477: 'sesetengah pihak dalam umno mengecam gusdur yang menuduhnya menimbulkan terlalu banyak masalah',
#  478: 'the value of education is actually just to',
#  480: 'kamu kepada allah dengan sebenar benar taqwa',
#  481: 'orang satu kena ada jek yeun thong di luar sana',
#  482: 'eight four four eight',
#  483: 'wong kah chun',
#  485: 'there is a food court selling bistake',
#  486: 'so just one one will do layan tak layan acuh tak acuh',
#  488: 'temenggong abdul rahman carl alexander gibson hill and lam pin',
#  490: 'kemarahannya terhadap perompak itu we are very sorry that you experienced this well like to offer you a voucher so that you can come and visit the restaurant again would you want to',
#  491: 'but theres also just limited ones like just a smaller maybe the the the biggest you can go',
#  492: 'lee gek tan eng okay so i think the black one sounds nice',
#  493: 'akan tanggungjawab menyebarkan ilmu pengetahuan',
#  495: 'boleh jadi kencing manis and different people have different interpretations of what they want and what they need travel delay maximum you can claim is up to one thousand dollar at the situation and every six hour you can claim up to one hundred fifty',
#  496: 'kau cari makan di sini riverina crescent paya lebar neighbourhood police post and number sequence is t one three eight five zero four seven l',
#  497: 'simple stuff like you know i want to do something it can be simple',
#  498: 'dan dianggap sebagai murid oleh nasir sendiri dalam tempoh hampir sekelip mata beliau bertukar dari disegani menjadi berkontroversi this shop sells',
#  499: 'then he and',
#  500: 'beliau dipilih untuk melaksanakan tugas itu',
#  501: 'gambar proton perdana menteri telah is that why are we not having trust in our own local',
#  502: 'c d a c c lima puluh tiga tahun meninggal di hospital tawau',
#  503: 'bagaimana kita boleh membantu dan saya menyambut baik',
#  504: 'tak mendapat keringanan',
#  505: 'kerajaan khususnya',
#  507: 'and agedashi okonomiyaki belajar seperti mana sekalipun kadang kadang akan mendakwa dan claim dia adalah seorang',
#  509: 'okay so in front of the',
#  511: 'ya are there any penalties if like example i pay i have a late payment of like maybe',
#  512: 'dengan geran khas prihatin ekoran kekurangan keadaan pelancong pantene pet safari and number sequence is t seven zero six eight nine five four',
#  514: 'tahan memandang muka abangnya itu lama lama wan kam fook and chan sek keong model itu akan diperluas ke negeri lain dengan pembabitan badan bukan kerajaan ngo serta penggerak komuniti',
#  515: 'penawar bagi segala racun yang berbisa penangkis sihir dengan izin had a cool vibe',
#  517: 'kerajaan ataupun kementerian',
#  518: 'i i dont know whats the i dont know which region it is but they go to the more scenic places',
#  520: 'berikut dia cadangan ini bukan untuk menetapkan harga minyak',
#  521: 'polis yang mampu berkereta mewah two weeks okay sure',
#  522: 'how far away is lorong',
#  524: 'dekat sini kita ada',
#  525: 'risk classes help insurance underwriters to',
#  526: 'jalan mana yang kita ikut kita buat dosa kita buat salah kita nak pastikan they received cash handouts for daily expenses and those with children had help with school',
#  527: 'okay okay kartar singh can i check whats the limit on the sudah tercium',
#  529: 'ataupun telah terkurang pendapatan mereka tahun ini',
#  530: 'hidung hari ini terjadi disini hari ini terjadi disini ini menunjukkan bahawa',
#  531: 'lepas tu terasa nak ambil quran menyenangkan hatinya kerana dengan kata kata itu',
#  533: 'cari mak ayah kita dulu so for the rates ilmu hadis riwayat sahabat jumpa mak dulu sebab doa mak mustajab',
#  534: 'tropical marine science institute riders lodge',
#  535: 'there is a food court selling mushroom tofu the witch put a spell on the prince',
#  537: 'pelbagai pihak wajar memainkan peranan agar',
#  538: 'and its operation control centre centre for employability skills',
#  539: 'also it may them to question whether paper qualification are',
#  540: 'so other than petrol if the car isnt nine million and twelve in one years time it is faster to take the bus nearby so probably berkata pasti seterusnya baginda bersabda',
#  542: 'dan keluarga saat ini para siswa administrator lulusan',
#  543: 'ya thats about it theres one young child so we would even though sure i im staying at',
#  544: 'for members birthday promotion dan juga oleh goh keng swee',
#  545: 'kawan yang terbaik yang pernah dibentangkan kerajaan seakan sudah menjadi senario biasa travel package so actually itll be seven seven days and six nights to italy',
#  546: 'jika ini tidak dapat dilakukan sebaliknya ianya hendaklah diuji di dewan yang mulia ini',
#  547: 'dia tak cukup syarat dia tak cukup syarat tourists there the following few nights also no dolphin but but we do find out from kadangkala hilang sifat untuk menarik orang orang yang tak reti',
#  548: 'please tell me how to get to hua number sequence is t zero three two eight one six four c',
#  549: 'okay sure so firstly i would need to verify some of your particulars so may i know what is your bertemu dengan orang orang yang hebat',
#  552: 'are there food courts or restaurants near',
#  553: 'okay sure we we we do have activity and then you guys have like cocktail mixing cooking our local nasi',
#  554: 'begitulah mengikut fikiran zarina dan boleh jadi juga rantai leher itu',
#  555: 'my auntie right shes working',
#  556: 'is it necessary for me to go for cancer screening which should be met jualan ataupun',
#  557: 'jangan jadi gila pula sunarto membiarkan sahaja injil dan alquran',
#  558: 'how long will it take to walk to',
#  559: 'because i did i was not able to afford it a large sum of money that i actually needed for my polytechnic fees',
#  560: 'you will you will be looking at nine hundred a month so with a five years with the current interest rate that our bank offer and the loan amount bekalkan seekor kuda daripada istana',
#  562: 'kita ada sembang banyak tadi ya sebelum kita mulakan so maybe they can or maybe you can tell the tour right i got a case that cannot eat spicy food and can it be arranged yin foh kuan cemetery arcadia road',
#  563: 'akak tak tahu tabiatnya ada katijah so long as the baby is still in the stomach abortion means taking out the baby from the stomach it believes the planting of the trees can help to offset the event carbon',
#  564: 'sampai satu tahap hamilton road rochelle at newton',
#  566: 'after taking a look at the database we found stories about loh choo kiat robert',
#  569: 'dia dah boleh bercampur antara',
#  570: 'then we will then well check into the hotel ya cannot be like you fish inside the check leave the park around twelve p m',
#  572: 'macam macam macam macam pemahaman mereka kepada akhir zaman lebih merujuk kepada',
#  573: 'setan shopee menjalani',
#  574: 'five time of the reward point dan ia tidak jarang berlaku dia menerangkan',
#  575: 'a f is a key cause ataupun tidak bergantung kepada kita',
#  578: 'i think only once korean barbecue and then thats it but its just mainly the dinners maybe because theres a lot of korean barbecue outlets near our i think for all our dinners we had korean barbecue typically needs two cord blood units',
#  580: 'okay im calling regarding my recent stay in your hotel okay good morning this is eugene here',
#  582: 'number sequence is s five three nine four six one eight j',
#  583: 'it also generated a discussion on whether priority seats created a sense of among',
#  585: 'maybe you want to try',
#  586: 'jadi sebab tulah dia minta diangkat abang dia mati mengejut adalah jahat',
#  589: 'isu yang paling banyak dibincangkan',
#  590: 'atas asas ini kentungan asia tenggara boleh digunakan dan nabi suruh kita ni pakai celak',
#  591: 'a former flight attendant who was with singapore airlines for the past six years',
#  595: 'saya sibuk ni sahabat nabi ini bukan cerita tadi ain ini bukan cerita salah pusat wykidd song by using names such as foo ah bee lee peh gee kenangan lelongan yang dilakukan',
#  596: 'keesokkannya menteri pertahanan mahmud dipetik oleh rotasi japanese kindergarten ada tanya dekat saya ustaz apa tu solat lepas subuh solat sunat lepas zohor tu apa tu saya mahu bikin pergi oh solat sunat dhuha',
#  597: 'apa yang rasa agama ni benar',
#  598: 'tengok warna merah dia takkan dapat rasa apa',
#  599: 'bila nabi sebut dialah berkatilah bumi to compete against its genuinely',
#  600: 'mengimbas politik negara',
#  601: 'terima kasih datuk seri pengerusi okay sure sure we we get it bermasalah disini',
#  602: 'baik umat yang pernah dikeluarkan they saw a huge tree and sat beneath the when they reached baru dengar betul memang dia ada tulis',
#  603: 'datuk seri fadhilah berkata tun dr mahathir sepatutnya berpolitik ke arah pembangunan negara ni berkemas kemas bersiap siap sebab esok',
#  604: 'sallallahu alaihi salam dalam telaga yang pada malam ni',
#  606: 'zubir said tham sien yen tan soo nan',
#  607: 'kawan kawan semua tahun berhubung pencemaran air mentah di sungai batang benar nilai',
#  609: 'i see my neighbours are quite frail',
#  611: 'okay sure we currently have we are currently offering three kinds of credit card the cashback credit card the air miles credit card and the rewards credit card and then purchases',
#  612: 'bibit bibit perpaduan dalam kalangan di kalangan',
#  613: 'buat penerangan',
#  614: 'wahyu kepada nabi nuh peristiwa abrahah serang kota mekah',
#  615: 'chan cheng wah bernard goh soo khim norm fee is calculated based on the reported fees charges',
#  616: 'kita pun duk rumah pun tak sama macam mana kita duduk di surau ni yang terus mengancam taraf negara palestin how long does it take to get to mountbatten m r t',
#  617: 'a lot of people are not',
#  618: 'mungkin pada kita',
#  621: 'pelaburan ini',
#  622: 'they also noted with concern lahirkan dalam keadaan memikul dosa',
#  624: 'sekolah sekolah di kawasan tanjung manis maybe you want to like provide provide me with your email address so i can just send you the itineraries membawa pembangunan yang boleh menjadi suara yang jelas kepada rakyat',
#  627: 'kecuali orang tadi datang diluar majlis the connecting twin bedroom and i actually booked the twin hello last week i was here at the a b c hotel',
#  628: 'mereka dibenarkan untuk membuat t seven u six my conclusion is that farming while it is possible without science',
#  629: 'manakala golongan beriman yang kedua ialah unsur but in recent years the republics weaknesses in innovation output',
#  631: 'this shop sells untuk mengambil mereka',
#  632: 'sure my address is then in that case can i just ask will i what is your',
#  633: 'bersamanya anggap yang',
#  634: 'projek ini dijangka dapat mewujudkan perkampungan nelayan yang lebih teratur dalam kemuncak ke muda muda mereka kita',
#  635: 'kreativiti wahid dalam mempelbagaikan',
#  636: 'kalau guru yang mengajar ni kena tinggal di gurun pasir angin kencang sambar carrot',
#  637: 'manusia tak suka awak mintalah seven eleven',
#  638: 'we are not discouraging baca doa allahumma inni auzubika min',
#  639: 's nine two one five zero six three q number sequence is',
#  640: 'if we succeed',
#  641: 'board of architects',
#  642: 'di mana kau berikan kepada wanita yang baik merdeka',
#  643: 'huh okay okay thats definitely not acceptable jalan empat',
#  644: 'six march nineteen sixty five that makes it beneficial to us humans rather than harmful so terus solat dengan imam lepas tu bangun dua rakaat',
#  645: 'the jackknife a large knife with a folding blade',
#  647: 'saya didapati sambal dan jangkaan pendapatan',
#  648: 'if the language is just orang orang di sekelilingnya terhadap pembaharuan',
#  649: 'global growth concerns white bee hoon kerana satu kesalahan yang dilakukan oleh',
#  650: 'okay yes we do tie to a b c tour agency so you are interested right you can actually get an',
#  651: 'tell them how to run a cust difficult customer',
#  652: 'kemudian kita baca tiga qul juga dengan maksud al fatihah dengan maksud untuk kita habiskan kan kalau sekecil itu pun awak bagi komuniti ayat kursi dengan maksud anak anak tuan tuan',
#  654: 'so he was like i forgot his name but but',
#  655: 'kuasa mandu dan teknikal',
#  659: 'terus berulang alik ke kelapia dan di sana beliau tinggal di rumah kyai can i have some glue for bani israel',
#  661: 'tidak berpura pura',
#  662: 'tolong ambilkan garam ya fanny ya fanny fanny if dan juga yang terakhir sekali adalah',
#  664: 'gaji struktur kulitnya bergelar ibu tahun',
#  665: 'and date of birth is number sequence is five hundred and nine thousand s one nine two six five zero three x',
#  666: 'more people are now aware of the power of colour',
#  668: 'economic sustainability can be viewed through',
#  669: 'membawa kuah panas meletakkannya we studied about alvin tan cheong kheng and pan cheng lui and angelo sanelli',
#  671: 'atau berita tidak benar pada kita ini',
#  672: 'pei hwa secondary school nativity church centre',
#  673: 'kerajaan akan mengambil kira pesanan pesanan pesanan pesanan saya ini',
#  674: 'di mana yang kita to nice scenery like the swimming pool or you know',
#  675: 'ayah belum juga alim besar',
#  676: 'ya the food came on time sebelum itu beliau menjadi timbalan menteri besar pahang di bawah dato kurnia faham dia sabar aku tak mahu pilihan yang kedua ialah',
#  678: 'ya thank you so much for your duit tu tak halal',
#  679: 'mediterranean',
#  680: 'clementi road',
#  681: 'hen hao to people dont see the need of having its very nice to',
#  682: 'buka negara line pula tu islam khalifah kalimah tu jatuh kepada date tamarind chutney ootoro sushi',
#  685: 'yang baik aku la dia iphone okay how many',
#  686: 'we studied about masuri s n koh yong guan',
#  687: 'minta nabi namakan nabi namakan dengan abdullah',
#  688: 'okay for example right now if you are swapping to habis kenduri belah jantan di selinsing kenduri belah jantan',
#  689: 'mengisi segala kerinduan hati masing masing akan laksanakan untuk memastikan residents undergo diabetes and metabolism centre',
#  691: 'sahabat nabi kan selalu sebut sebab kita sangat memerlukan doa doa orang yang dekat dengan allah',
#  692: 'sorry to my char siew bao okay sure no worries',
#  693: 'yang pertama sekali saya nak ucap tahniah kepada kekurangan',
#  694: 'pengunjung dengan tujuan posting',
#  695: 'ha dia punya company ada kat dalam tu',
#  698: 'binaan dan sebagainya semua benda boleh berlaku tak kiralah ada handset ke apakah',
#  699: 'can i just check which ho minfong mobile plan will you happen to be more apa ni orang yang terdahulu',
#  700: 'kumpulkan kat situ',
#  701: 'apakah kita ini menyesal dengan apa',
#  702: 'kereta bulan bulan bukan senang mau senang kerana tidak disangkanya wanita itu mengetahui apa yang diperlukannya after all its not the first time that',
#  704: 'by tucking in close behind another a rider or vehicle',
#  705: 'his life is filled with activity and friendships',
#  706: 'yes i have a part time job but i think i can only saving up to',
#  707: 'terimalah syafaat ku untuk makhluk makhluk mu tolonglah tentang keperluan kerajaan untuk sekurang kurangnya membeli',
#  708: 'given the high number of trains being returned',
#  710: 'i cant eat all of this',
#  711: 'mana dalil dia kopiah sunnah nabi',
#  712: 'daripada dalam kawasan pkpd tidak boleh keluar',
#  713: 'kam kee yong',
#  714: 'at local clubs he has also been holding',
#  715: 'so are you a self employed okay so in this case',
#  716: 'boom berguguran dimana mana',
#  717: 'number sequence is s three seven six nine two one eight l and date of birth is zero six december',
#  719: 'it does not matter',
#  720: 'christopher chia',
#  721: 'filem yakullahu hasanatul speaking to us in',
#  723: 'ratus lima puluh tahun almond crescent',
#  724: 'however when you make overseas call the overseas charges okay free data roaming also so that means there will be no connection charge',
#  725: 'pendekatan tegasnya itu',
#  726: 'chancery hill road oriole',
#  729: 'kalau tuhan yang tidak pernah memungkiri janji',
#  730: 'tapi saya berikan satu kepada belah sini',
#  731: 'beberapa persoalan di kampung kambing itu dihadapinya can you send these like to the through the email as well so i can discuss with my son about it',
#  733: 'the government has also created policies designed to encourage family members nescaya dia tidak akan disesatkan oleh allah',
#  734: 'kopi and it is much easier to drop bombs on them marmite pork ribs than to fly',
#  735: 'it will offer them',
#  737: 'liga malaysia kpm sentiasa komited dalam usaha menyediakan i think wo yao copy ni',
#  738: 'saudara mara he had soiled himself while buying groceries with his wife',
#  741: 'penghormatan yang terakhir pada simati',
#  743: 'lim fong jock david john fraser and',
#  746: 'cause i really',
#  747: 'lepas saya cakap dalam dalam',
#  748: 'beliau tidak pernah diberi peluang hakiki gusdur sendiri menyebut beberapa peluang yang telah diberi',
#  750: 'i can i can try and ask the prof but untuk melihat dari segi tangga gaji',
#  753: 'khoo teck puat hospital',
#  754: 'untuk membina pelapis negarawan yang akhirnya akan menyebabkan',
#  755: 'there is a food court selling pita behind sylvas adakah teknologi penyembelihan tersebut akan diperkenalkan dalam masa terdekat',
#  756: 'so basically i spend on mostly clothes online shopping about one to two k per month for asyhadu anna muhammadar rasulullah',
#  757: 'di restoran sakura itulah',
#  758: 'where is the best view walaupun tiada bukti bahawa beliau melakukannya demi kepentingan peribadi kesanggupannya',
#  759: 'pejabat daerah jkm di seluruh malaysia',
#  760: 'tan ban soon sehingga kita memerlukan pandangan pihak pemukul dan pembesar quraisy',
#  761: 'twenty october nineteen sixty eight dimakbulkan oleh allah subhanahu wa taala',
#  762: 'do you know where is antara lainnya',
#  764: 'think singapore companies large and small',
#  765: 'sotong char youre one of my very few friends and also i dont really care much with you all also the results which is so they are the more that they are more of the key criteria more than the how to say',
#  767: 'katakan muraqabah adalah satu benda yang kita katakan sebagai five six eight one seven three nine i number sequence is t',
#  769: 'rebecca chua mohamed rozani maarof',
#  771: 'allahu alaihi wasallam ya there will be special promotion by using names such as ang hiong chiok naomi tan and henry chia for dinner in our hotel',
#  773: 'maybe i could just ask from you a few more iss a few more things so basically number sequence is s seven two',
#  774: 'okay i think i know who youre referring to it about forty six minute walk to the sebelum sebarang keputusan pelaksanaan',
#  775: 'just as they were trying to find a tool or two that they could use to fend off',
#  776: 'kalau paksa kat masuk anak telefon bomba',
#  777: 'and for your tomato based pasta okay this maybe',
#  778: 'you literally have nothing to do with the organisation anymore okay just get on with your life and then like dont bother',
#  779: 'awal lagi lebih yakin maknanya low siew nghee',
#  780: 'you must try gyudon who know their children most intimately',
#  781: 'siapa yang dengan allah allah sentiasa bersama dengan dia habis semua memang tak dapat',
#  782: 'youre facing each other twenty four seven literally twenty four seven',
#  783: 'factors being considered include the ventilation system for the underground facility',
#  784: 'dekat ingat perkara itu boleh diselesaikan secara begitu he now has less time to read newspapers and only recently bought keperihatinan ini dizahirkan bukan saja oleh barisan hadapan negara',
#  785: 'takkan dua kes lain johor empat kes but is not really a full time kind of study more of a maybe a few hours two two climbing requires a lot of patience you do not',
#  786: 'i dont really understand so does it means the first hour i can claim from two p m is',
#  787: 'antara kita melainkan kedahsyatan hari kiamat kerana kita semua akan menghadapi hari tersebut dan sehingga mereka pergi tidak putus putus mereka menggusiknya dengan harapan bahawa zahida akan menjawab',
#  788: 'but the italian',
# ...
#  1082: 'then why not you just ask her like ask her if',
#  1083: 'alright i think kayley recently opened',
#  1084: 'okay so well deliver your food today at three p m',
#  1086: 'perbelanjaan yang sebesar ini about certain individuals or that are very important in publics eye',
#  1087: 'a countrys economic and political and that that person who is helping',
#  1088: 'four nine five zero one eight two number sequence is s',
#  1089: 'the nurse folded a paper jib for the little boys',
#  1090: 'tanya abdul pakar sesudah melihat',
#  1091: 'tidak difikirkan nya tan boo liat cheong soo pieng and',
#  1092: 'tarikh macam bulan ni bulan ni',
#  1093: 'pengukuhan jati diri melakukan',
#  1094: 'okay so you are looking for a mobile plus',
#  1095: 'i knew a person who have met both',
#  1096: 'adil walaupun kejujuran kamu itu akan membawa hukuman kepada kamu yakni jangan buat benda yang mungkar',
#  1097: 'like he didnt give us enough time to look at the attractions to take photos',
#  1099: 'the people include in the list are tan soo khoon kiah hong steve',
#  1101: 'kind of complicated topic pula jadi itulah yang berlaku dalam bahasa',
#  1102: 'mengikat tali kasut mereka yang tersangkut tidur dalam pertemuan rasmi dan kadang kadang',
#  1103: 'berikrar dan berazamlah kepada allah',
#  1105: 'holidays can be a time',
#  1106: 'ya allah subhanahu wa taala bagi beritahu hasil yang luar biasa yang berhubung dengan makanan atau barang barang itu',
#  1107: 'berjalan dengan hati yang semakin berat dan untuk meninggalkan',
#  1108: 'nak beli phone tu kena ataupun keperluan i suspect that this practice will be hard to',
#  1109: 'but returns will come down as more money is institutionally kepada kuasa ke pembahagian faraid yang tak adil tak jalan membina barat',
#  1110: 'room service and',
#  1111: 'kepada tuhanku zat yang hebat tidak begitu adil kita bandingkan two weeks before your flight then i can do the necessary arrangement for you okay so if this the case right then',
#  1112: 'then i realized that actually',
#  1113: 'golden star hotel the woodbridge museum sudah diganti lagi saya mengharapkan supaya kementerian dapat',
#  1114: 'di mana pun dajjal pergi satu hari nanti',
#  1115: 'kehebatan families will need to demonstrate effort for example by',
#  1116: 'kocok orang ni lah bagus untung banyak etonhouse international school turf city road yes i have i have',
#  1117: 'so its a it can exchange it do i have a choice so i have a choice between',
#  1118: 'han yong hong alfred duff cooper',
#  1122: 'amount of interest rate i can expect to get',
#  1123: 'andika syazwani dirangka itu akan menjadikan lebih',
#  1124: 'show me the way to let me just check for you we do have three different clueless about the right way to do it',
#  1125: 'babi menghapuskan cu kelewatan dari segi',
#  1126: 'then after that we going to call and say like due to logistic errors than like i see i see okay okay',
#  1127: 'itulah yang menyuruh ku both woman gave reasons that did not serve',
#  1128: 'tahu melihat kepada lifestyle cara hidup dia keperibadian dia amal ibadat dia',
#  1129: 'malaysia bukan sahaja menghargai minat yang ditunjukkan',
#  1131: 'and i didnt have any interest in business then',
#  1133: 'like before we left our rooms at like six a m seven a m sorry we placed the makeup',
#  1134: 'what is it so good to buy to go to your store he was sent to the hospital that night and pronounced dead dia di hari kiamat',
#  1135: 'i think give back to',
#  1136: 'semut yang tadinya berbaris untuk memanjat cawan kopinya itu',
#  1139: 'beberapa langkah yang telah diambil oleh pihak banjir kilat yang selalu',
#  1140: 'play a part in the singapore army to explore the diverse way saya harap usaha ini menjadi contoh kepada pereka fesyen tempatan',
#  1141: 'if you have payment companies that happen to own delivery companies allah subhanahu wa ta ala nak benda yang baik hadir dalam diri kita',
#  1146: 'proses tersebut daripada berlaku akan menunaikan segala janji janjinya pada aku',
#  1147: 'if i wanna get add on like a starter and how much do i have to add if i want to make it a set ke shi you go back to malaysia you still have to pay hes like a big cat in a small cage',
#  1148: 'exactly like approach any travel agency for this kind of stuffs usually we just do everything off online we never really physically go meet and all so okay i havent really like',
#  1149: 'yes because my kids wanted to',
#  1150: 'and there is a host of incentives to boost innovation and creative and develop a maritime and aviation formation',
#  1151: 'alright so we just drop you an email so look around like one working day so thatll be the email',
#  1154: 'walaupun mak ayah tak kata pun tak sebut pun',
#  1160: 'okey boleh berhenti aku rumah ni pun kau tak pernah pergi',
#  1161: 'venerable shi ming yi',
#  1162: 'pasukan yang kuat satu pasukan yang besar',
#  1164: 'kedua dua tokoh itu cari ahli maksum dan kiai as ad',
#  1165: 'hi i would like to make a feedback di masa pemerintahan jepun',
#  1167: 'the the waters you know eight seven three four hasbunallah wanikmal wakil ah allah meletakkan kita pada tempat tempat kebaikan',
#  1168: 'like for now theyre just all into entertainment',
#  1169: 'twenty two april nineteen fifty six',
#  1170: 'also having been in the workforce for so many years he understands',
#  1172: 'its about five minutes walk to sciences ataupun kita bercakap bab munakahat tak jadi bila bercakap bab nikah kahwin',
#  1173: 'kaulah pergerakan secara mendalam apakah punca recommend me what are the most popular that your your restaurant betamethasone dipropionate ointment olopatadine',
#  1174: 'yau tian yau',
#  1177: 'yes it will it will include the whole en any of the days or any specific activities and if you would like to change',
#  1178: 'i know people who have the exact name as loh kok heng',
#  1179: 'ataupun program kita pada pagi yang indah lagi bertuah ini six zero nine k t two seven four five number sequence is',
#  1181: 'seorang yang macam aku tak macam tak ada tak ada so maybe just one',
#  1183: 'sengih sengih sampai sekarang tak tukar tukar bi nama bila alasan dia kereta banyak tengah jalan tak boleh ni lepas tu bos saya nak kahwinlah bos use of lighting and amazing',
#  1184: 'dan di dalam matanya semakin nyata bahawa ada sesuatu edwin tessensohn cheong choong kong',
#  1187: 'tidak memberi kerjasama di dalam rumah itu',
#  1188: 'i i last term work i last time work',
#  1189: 'persembahan tarian melayu dan kita akan berbincang lanjut berkenaan dengan',
#  1190: 'apa kau berdua buat kat sini two four five six three nine eight g number sequence is t',
#  1191: 'get you mean',
#  1192: 'ya so i think the air miles credit card right now no because of the covid situation kita sembahyang satu sekali sembahyang ramai ahli ahli yang berhormat tadi bertanyakan tentang',
#  1194: 'ke bawah tidak berurat seperti pucuk ru',
#  1195: 'pada pandangan saya memperbanyakkan sunat tu satu benda yang sangat',
#  1196: 'mengenal dirinya sendiri',
#  1197: 'abang endak pergi cungkil kulitnya dan kalau abang tak mahu kerja takkanlah bila ada lawan main bola di stadium jalan besar abang pergi jaga kereta cabbies said that early last month easy taxi had refunded',
#  1199: 'ya if you have something that i can earn cashback while not so much on the delivery but i do dine out and most of the time doing grocery shopping',
#  1203: 'seorang perempuan india segera masuk ke bilik mandi itu',
#  1204: 'sri arifa as a way for students to pula telah mula menurunkan had umur mengundi untuk menjadikan ianya sebagai',
#  1205: 'kamu yang berjaya mengalahkan tuhan permohonan dan kelulusan permit pembinaan place the emphasis',
#  1206: 'atau pembelian',
#  1207: 'mudian tubuh badan taklah kuat macam orang lain buat aku ni orang tak segak tak handsome then also got another room that allows you to go qiang ge to sing with like strangers or despite all this infrastructure ya rasulullah kalau macam tu kamu akan dapati harga aku ni sangat murah ya rasulullah',
#  1208: 'we currently we do not have only applicable for the data only plan only for data only plans',
#  1209: 'doktor haji abdul rahman bin haji abbas',
#  1210: 'lui pao chuen',
#  1211: 'cara kebiasaan secara logiknya',
#  1212: 'that but but but i do late at night then not say late at night like ten a ten p m',
#  1215: 'cara amali mempunyai banyak sumber yang boleh digunakan tell me the price of tom',
#  1217: 'beberapa ekor itik dan ayam hilang agen sosial atau sebagai the workers braved through sun',
#  1218: 'ayu and dua tiga kali berlaku macam ni',
#  1219: 'bukannya lagi kak ina mary fell asleep on her mothers lap tan chin siong low swee chen',
#  1221: 'the significant moments cover a wide range of achievements in academia',
#  1223: 'taco salad',
#  1224: 'okay secondly i will need a copy of the like all the receipts and everything of the five hundred credit points for your membership so actually it can be used to upgrade the two youre stopping again',
#  1225: 'tetapi beliau juga dianggap',
#  1229: 'so for yourself how much did the hospitalisation dengan kawan kawan dia tu tak hairan',
#  1231: 'doktor doktornya bimbang tekanan tinggi yang sedang dihadapi gusdur the showcase features music performances',
#  1232: 'bila kita susah kita cari siapa',
#  1233: 'umpamanya lebih mudah difahami despite some unevenness in growth performance ada kekuasaan',
#  1234: 'kerajaan negeri bersetuju',
#  1236: 'they started off my staycation very well their customer service and very friendly',
#  1237: 'sebenarnya saya takut saya bodoh tuan tuan saya nak datang terengganu ni three nine nine six five six three a coroners inquiry for the two men',
#  1239: 'yang dirahmati allah hari ketiga',
#  1241: 'orang lain yang orang lain mesti dia',
#  1242: 'five eight six nine three four two n number sequence is it should not be treated as a replacement for seeing a doctor and date of birth is especially when certain symptoms six july',
#  1246: 'okay cause the thing about insurance is that right every year as i aged the premium gets very expensive',
#  1248: 'johor ketika kita tumbuk abdul dahulu hoe chiang road',
#  1249: 'petua menjauhkan diri daripada perkara perkara yang haram',
#  1250: 'mungkin tangan ini',
#  1252: 'kalau kurang disiplin turf ciub road kawan duk bapak ni yang duk sembang dalam masjid',
#  1253: 'but if i would like to increase my so thats for five hundred thousand jangan belia memain peranan penting sebagai antara pelopor',
#  1254: 'i know i have a free ice',
#  1255: 'saya harap dia boleh menegur pihak kerajaan supaya',
#  1256: 'undi tidak percaya terhadap habibi kini memungkinkan akhbar tanjung untukdicalonkan mengganti habibie three hundred and eighty eight thousand whoa that is so nice deal man',
#  1257: 'so later you want your memandangkan virus covid sembilan belas ini',
#  1258: 'two ways all right okay we do have this package that is more on the scenery and activities in dunman high hostel tian kong temple acara acara mereka',
#  1261: 'tadi nadia lagi dah then ni dai ni de camera wo men',
#  1262: 'goh tshin en',
#  1263: 'yong pung how and lim swee lian',
#  1264: 'sudah lebih daripada mencukupi untuk mengisi waktu kerja sehari bagi kursus itu baru separuh hari kerja',
#  1265: 'with the movers hired to settle the rest of their luggage and furniture',
#  1267: 'so you will actually have a choice between the cajun seasoning and the truffle truffle fries seasoning so yang tidak sesuai langsung dengan kenderaan berat',
#  1269: 'jangan kamu menghampiri solat',
#  1273: 'after you have discharge this is not include the no this is just for medical expenses this is not',
#  1274: 'jadi kalau kita tengok di sini untuk kait dengan rasulullah',
#  1275: 'hutang hutang dia dapat mengembalikan semula',
#  1276: 'kedua benda pada umat aku yang tidak bertulang lembut',
#  1277: 'dia punya bapak dulu pernah mati',
#  1278: 'yi bai ge ni siao',
#  1280: 'impak sesuatu kemalangan itu terutamanya yang menyebabkan',
#  1281: 'great world singapore buddhist youth mission and was more prepared for school',
#  1282: 'okay and from there your password is your date of birth collect for themself for their own self benefit mengalami pandemik covid',
#  1283: 'you would like to enquiry for our okay thank you so much for your info',
#  1285: 'if the hot one will no currently we dont have it we used to have but for now we dont have we only have cold if you go for the cold one it will be ice cream yang mati tersepit kerana',
#  1286: 'but she has had no luck for so',
#  1287: 'menteri tetapi dalam konteks ini ada anggota dewan broadrick close in order to stand up against it inspires a sense of camaraderie and',
#  1288: 'kata nak jadi budak pandai i get it sure sure thats a thats another',
#  1289: 'where can i find the best and jaafar latiff j y pillay mohamed eunos abdullah',
#  1290: 'who which one of them',
#  1291: 'how far away is cause i feel that na ge nei xie nv de',
#  1292: 'ya i will never go on a car',
#  1293: 'does fritada',
#  1294: 'at the unit yesterday',
#  1299: 'pelbagai sudut mungkin disebabkan mereka antaranya negeri sembilan',
#  1301: 'm o e said three more bodies have been found in one of the videos',
#  1305: 'i saw from your website theres hi good afternoon',
#  1306: 'the company said it reserves all rights against her melakukan pembayaran bulanan',
#  1308: 'pengerusi jawatankuasa hal ehwal agama islam negeri touching jabatan berkata mesyuarat bertujuan merangka tindakan bagi memastikan kejadian sama tidak berulang',
#  1309: 'orang orang yang datang menanyakan ibunya pada hari itu kerana perlu benar',
#  1310: 'pelajar pelajar universiti',
#  1311: 'but government initiatives and smart city programs have also given a spurt to a i jadi imam ghazali suruh kita fikir',
#  1313: 'dunia tu satu benda yang jauh daripada dia sebab hati dia kosong daripada menurunkan gog sing hooi sehingga menyebabkan dia ni jadi orang yang makin lama dia rasa jauh diri dengan allah subhanahu taala',
#  1314: 'ibrahim awang',
#  1317: 'victoria hotel sekurang kurangnya',
#  1318: 'thats really nice to hear so you stayed with us last weekend ya big already now',
#  1319: 'cik salim ketawa berdiri tegak tegak sedikit menyeluk saku seluarnya a suggestion for one party to the move to the next block was raised constance mary turnbull',
#  1320: 'bukan minta kepada allah subhanahu wa ta ala ramakrishna how long will it take to walk to',
#  1321: 'i think no amount',
#  1324: 'changi north rise textile centre',
#  1325: 'they were shocked to see a pack of as they walked back',
#  1326: 'bahawa apabila di rumah',
#  1327: 'okey doktor sepanjang kempen ya nine o nine seven punya ada ni kami semua perlu untuk tanya dengan',
#  1328: 'jalan krian dairy farm lane',
#  1330: 'you must try bak',
#  1331: 'so who are these people',
#  1332: 'sng choon yee',
#  1333: 'gravy rendang',
#  1335: 'eight four six nine',
#  1336: 'di mana dia sekarang dan juga keusahawan mereka supaya mereka dapat keluar',
#  1338: 'ya we do have promotion set for',
#  1339: 'sudah cukup jelas bahawa dunia berubah dengan banyak kerana kemajuan saintifik dan teknologi manusia dan masalah menjadi lebih besar',
#  1340: 'yew lian hotel',
#  1342: 'untuk dipadamkan berkurun kurun lebih tua daripada oxford universiti tertua di dunia',
#  1344: 'bukti ilmu sesuatu yang berharga',
#  1345: 'program tersebut dapat menyuburan',
#  1346: 'yang pertama yang keduanya dan kita tak bolehlah',
#  1347: 'yang binatang tu makan yang boleh hang ambil ambil tapi jangan dok pergi marah tuan dia',
#  1348: 'shui lan and milenko ee peng liang',
#  1349: 'so currently do you have any dengan apa yang',
#  1350: 'kuih dadar think of your favourite singlish word or praise maka jangan kita kata allah tak apa',
#  1351: 'lau chiap khai vivien quahe seah',
#  1352: 'menjadi perantara bagi kelompok kelompok di daerah yang sedang putus itu',
#  1354: 'but even then its one small topic out of so many g p topics',
#  1355: 'for a poorer country they are already having',
#  1356: 'untuk membantu perjalanan mekah ke basrah',
#  1357: 'dan tangan kanannya pergi ke mukanya dan tidak cukup cekap untuk tugas yang ditanggung first street church and',
#  1359: 'on the way to their destination',
#  ...}

# %%
import IPython.display as ipd
ipd.Audio(f'{directory}/215.mp3')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
directory
# Out:
# 'augmentation-switchboard-v22'

# %%
with open('augment-switchboard-v22.json', 'w') as fopen:
    json.dump(data, fopen)
